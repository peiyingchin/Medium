# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.sql.functions import year
from pyspark.sql.functions import to_date
from pyspark.sql.functions import month

# %%
spark = SparkSession.builder.appName('ML').getOrCreate()
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-KMGMT4B.mshome.net:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>ML</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# read data
train= spark.read.csv('train.csv',header=True,inferSchema=True)

# %%
train.show()
# Out:
# +---------------+-----+--------------+-------+-------------------+---------------------+------+
# |         row_id|cfips|        county|  state| first_day_of_month|microbusiness_density|active|
# +---------------+-----+--------------+-------+-------------------+---------------------+------+
# |1001_2019-08-01| 1001|Autauga County|Alabama|2019-08-01 00:00:00|            3.0076818|  1249|
# |1001_2019-09-01| 1001|Autauga County|Alabama|2019-09-01 00:00:00|            2.8848701|  1198|
# |1001_2019-10-01| 1001|Autauga County|Alabama|2019-10-01 00:00:00|            3.0558431|  1269|
# |1001_2019-11-01| 1001|Autauga County|Alabama|2019-11-01 00:00:00|            2.9932332|  1243|
# |1001_2019-12-01| 1001|Autauga County|Alabama|2019-12-01 00:00:00|            2.9932332|  1243|
# |1001_2020-01-01| 1001|Autauga County|Alabama|2020-01-01 00:00:00|              2.96909|  1242|
# |1001_2020-02-01| 1001|Autauga County|Alabama|2020-02-01 00:00:00|            2.9093256|  1217|
# |1001_2020-03-01| 1001|Autauga County|Alabama|2020-03-01 00:00:00|            2.9332314|  1227|
# |1001_2020-04-01| 1001|Autauga County|Alabama|2020-04-01 00:00:00|            3.0001674|  1255|
# |1001_2020-05-01| 1001|Autauga County|Alabama|2020-05-01 00:00:00|            3.0049484|  1257|
# |1001_2020-06-01| 1001|Autauga County|Alabama|2020-06-01 00:00:00|            3.0192919|  1263|
# |1001_2020-07-01| 1001|Autauga County|Alabama|2020-07-01 00:00:00|            3.0838373|  1290|
# |1001_2020-08-01| 1001|Autauga County|Alabama|2020-08-01 00:00:00|             3.174679|  1328|
# |1001_2020-09-01| 1001|Autauga County|Alabama|2020-09-01 00:00:00|            3.2057564|  1341|
# |1001_2020-10-01| 1001|Autauga County|Alabama|2020-10-01 00:00:00|            3.1938035|  1336|
# |1001_2020-11-01| 1001|Autauga County|Alabama|2020-11-01 00:00:00|            3.0384164|  1271|
# |1001_2020-12-01| 1001|Autauga County|Alabama|2020-12-01 00:00:00|             3.002558|  1256|
# |1001_2021-01-01| 1001|Autauga County|Alabama|2021-01-01 00:00:00|            2.9472437|  1243|
# |1001_2021-02-01| 1001|Autauga County|Alabama|2021-02-01 00:00:00|            3.1061056|  1310|
# |1001_2021-03-01| 1001|Autauga County|Alabama|2021-03-01 00:00:00|            3.1440427|  1326|
# +---------------+-----+--------------+-------+-------------------+---------------------+------+
# only showing top 20 rows

# %%
train.printSchema()
# Out:
# root
#  |-- row_id: string (nullable = true)
#  |-- cfips: integer (nullable = true)
#  |-- county: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- first_day_of_month: timestamp (nullable = true)
#  |-- microbusiness_density: double (nullable = true)
#  |-- active: integer (nullable = true)

# %%
#[cfips,county,state,first_dat_of_month,active]

# %%
# one hot encoder to process county 
varIdxer = StringIndexer(inputCol='county',outputCol='varcounty').fit(train)
train = varIdxer.transform(train)
encodeer = OneHotEncoder(inputCol="varcounty",outputCol="county_Vec")
train = encodeer.fit(train).transform(train)
train.show(5)
# Out:
# +---------------+-----+--------------+-------+-------------------+---------------------+------+---------+------------------+
# |         row_id|cfips|        county|  state| first_day_of_month|microbusiness_density|active|varcounty|        county_Vec|
# +---------------+-----+--------------+-------+-------------------+---------------------+------+---------+------------------+
# |1001_2019-08-01| 1001|Autauga County|Alabama|2019-08-01 00:00:00|            3.0076818|  1249|    494.0|(1870,[494],[1.0])|
# |1001_2019-09-01| 1001|Autauga County|Alabama|2019-09-01 00:00:00|            2.8848701|  1198|    494.0|(1870,[494],[1.0])|
# |1001_2019-10-01| 1001|Autauga County|Alabama|2019-10-01 00:00:00|            3.0558431|  1269|    494.0|(1870,[494],[1.0])|
# |1001_2019-11-01| 1001|Autauga County|Alabama|2019-11-01 00:00:00|            2.9932332|  1243|    494.0|(1870,[494],[1.0])|
# |1001_2019-12-01| 1001|Autauga County|Alabama|2019-12-01 00:00:00|            2.9932332|  1243|    494.0|(1870,[494],[1.0])|
# +---------------+-----+--------------+-------+-------------------+---------------------+------+---------+------------------+
# only showing top 5 rows

# %%
# one hot encoder to process state
varIdxer = StringIndexer(inputCol='state',outputCol='varstate').fit(train)
train = varIdxer.transform(train)
encodeer = OneHotEncoder(inputCol="varstate",outputCol="state_Vec")
train = encodeer.fit(train).transform(train)
train.select(['state_Vec']).show(5)
# Out:
# +---------------+
# |      state_Vec|
# +---------------+
# |(50,[19],[1.0])|
# |(50,[19],[1.0])|
# |(50,[19],[1.0])|
# |(50,[19],[1.0])|
# |(50,[19],[1.0])|
# +---------------+
# only showing top 5 rows

# %%
#get year of the first day of month
train = train.withColumn('year',year(train.first_day_of_month))
train.select(['first_day_of_month','year']).show()
# Out:
# +-------------------+----+
# | first_day_of_month|year|
# +-------------------+----+
# |2019-08-01 00:00:00|2019|
# |2019-09-01 00:00:00|2019|
# |2019-10-01 00:00:00|2019|
# |2019-11-01 00:00:00|2019|
# |2019-12-01 00:00:00|2019|
# |2020-01-01 00:00:00|2020|
# |2020-02-01 00:00:00|2020|
# |2020-03-01 00:00:00|2020|
# |2020-04-01 00:00:00|2020|
# |2020-05-01 00:00:00|2020|
# |2020-06-01 00:00:00|2020|
# |2020-07-01 00:00:00|2020|
# |2020-08-01 00:00:00|2020|
# |2020-09-01 00:00:00|2020|
# |2020-10-01 00:00:00|2020|
# |2020-11-01 00:00:00|2020|
# |2020-12-01 00:00:00|2020|
# |2021-01-01 00:00:00|2021|
# |2021-02-01 00:00:00|2021|
# |2021-03-01 00:00:00|2021|
# +-------------------+----+
# only showing top 20 rows

# %%
### Get Month from date in pyspark
train = train.withColumn('month',month(train.first_day_of_month))
train.select(['first_day_of_month','month']).show()
# Out:
# +-------------------+-----+
# | first_day_of_month|month|
# +-------------------+-----+
# |2019-08-01 00:00:00|    8|
# |2019-09-01 00:00:00|    9|
# |2019-10-01 00:00:00|   10|
# |2019-11-01 00:00:00|   11|
# |2019-12-01 00:00:00|   12|
# |2020-01-01 00:00:00|    1|
# |2020-02-01 00:00:00|    2|
# |2020-03-01 00:00:00|    3|
# |2020-04-01 00:00:00|    4|
# |2020-05-01 00:00:00|    5|
# |2020-06-01 00:00:00|    6|
# |2020-07-01 00:00:00|    7|
# |2020-08-01 00:00:00|    8|
# |2020-09-01 00:00:00|    9|
# |2020-10-01 00:00:00|   10|
# |2020-11-01 00:00:00|   11|
# |2020-12-01 00:00:00|   12|
# |2021-01-01 00:00:00|    1|
# |2021-02-01 00:00:00|    2|
# |2021-03-01 00:00:00|    3|
# +-------------------+-----+
# only showing top 20 rows

# %%
train.printSchema()
# Out:
# root
#  |-- row_id: string (nullable = true)
#  |-- cfips: integer (nullable = true)
#  |-- county: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- first_day_of_month: timestamp (nullable = true)
#  |-- microbusiness_density: double (nullable = true)
#  |-- active: integer (nullable = true)
#  |-- varcounty: double (nullable = false)
#  |-- county_Vec: vector (nullable = true)
#  |-- varstate: double (nullable = false)
#  |-- state_Vec: vector (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)

# %%
# create a input vector
assembler = VectorAssembler(inputCols=['county_Vec','state_Vec','year','month'],outputCol = "Independent_fea" )

# %%
output = assembler.transform(train)

# %%
# output.show()
# Out:
# +---------------+-----+--------------+-------+-------------------+---------------------+------+---------+------------------+--------+---------------+----+-----+--------------------+
# |         row_id|cfips|        county|  state| first_day_of_month|microbusiness_density|active|varcounty|        county_Vec|varstate|      state_Vec|year|month|     Independent_fea|
# +---------------+-----+--------------+-------+-------------------+---------------------+------+---------+------------------+--------+---------------+----+-----+--------------------+
# |1001_2019-08-01| 1001|Autauga County|Alabama|2019-08-01 00:00:00|            3.0076818|  1249|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2019|    8|(1924,[0,1,496,18...|
# |1001_2019-09-01| 1001|Autauga County|Alabama|2019-09-01 00:00:00|            2.8848701|  1198|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2019|    9|(1924,[0,1,496,18...|
# |1001_2019-10-01| 1001|Autauga County|Alabama|2019-10-01 00:00:00|            3.0558431|  1269|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2019|   10|(1924,[0,1,496,18...|
# |1001_2019-11-01| 1001|Autauga County|Alabama|2019-11-01 00:00:00|            2.9932332|  1243|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2019|   11|(1924,[0,1,496,18...|
# |1001_2019-12-01| 1001|Autauga County|Alabama|2019-12-01 00:00:00|            2.9932332|  1243|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2019|   12|(1924,[0,1,496,18...|
# |1001_2020-01-01| 1001|Autauga County|Alabama|2020-01-01 00:00:00|              2.96909|  1242|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2020|    1|(1924,[0,1,496,18...|
# |1001_2020-02-01| 1001|Autauga County|Alabama|2020-02-01 00:00:00|            2.9093256|  1217|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2020|    2|(1924,[0,1,496,18...|
# |1001_2020-03-01| 1001|Autauga County|Alabama|2020-03-01 00:00:00|            2.9332314|  1227|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2020|    3|(1924,[0,1,496,18...|
# |1001_2020-04-01| 1001|Autauga County|Alabama|2020-04-01 00:00:00|            3.0001674|  1255|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2020|    4|(1924,[0,1,496,18...|
# |1001_2020-05-01| 1001|Autauga County|Alabama|2020-05-01 00:00:00|            3.0049484|  1257|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2020|    5|(1924,[0,1,496,18...|
# |1001_2020-06-01| 1001|Autauga County|Alabama|2020-06-01 00:00:00|            3.0192919|  1263|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2020|    6|(1924,[0,1,496,18...|
# |1001_2020-07-01| 1001|Autauga County|Alabama|2020-07-01 00:00:00|            3.0838373|  1290|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2020|    7|(1924,[0,1,496,18...|
# |1001_2020-08-01| 1001|Autauga County|Alabama|2020-08-01 00:00:00|             3.174679|  1328|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2020|    8|(1924,[0,1,496,18...|
# |1001_2020-09-01| 1001|Autauga County|Alabama|2020-09-01 00:00:00|            3.2057564|  1341|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2020|    9|(1924,[0,1,496,18...|
# |1001_2020-10-01| 1001|Autauga County|Alabama|2020-10-01 00:00:00|            3.1938035|  1336|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2020|   10|(1924,[0,1,496,18...|
# |1001_2020-11-01| 1001|Autauga County|Alabama|2020-11-01 00:00:00|            3.0384164|  1271|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2020|   11|(1924,[0,1,496,18...|
# |1001_2020-12-01| 1001|Autauga County|Alabama|2020-12-01 00:00:00|             3.002558|  1256|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2020|   12|(1924,[0,1,496,18...|
# |1001_2021-01-01| 1001|Autauga County|Alabama|2021-01-01 00:00:00|            2.9472437|  1243|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2021|    1|(1924,[0,1,496,18...|
# |1001_2021-02-01| 1001|Autauga County|Alabama|2021-02-01 00:00:00|            3.1061056|  1310|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2021|    2|(1924,[0,1,496,18...|
# |1001_2021-03-01| 1001|Autauga County|Alabama|2021-03-01 00:00:00|            3.1440427|  1326|    494.0|(1870,[494],[1.0])|    19.0|(50,[19],[1.0])|2021|    3|(1924,[0,1,496,18...|
# +---------------+-----+--------------+-------+-------------------+---------------------+------+---------+------------------+--------+---------------+----+-----+--------------------+
# only showing top 20 rows

# %%
# create a finalized data with only independent variable and output
finalized_data=output.select("independent_fea","microbusiness_density")
finalized_data.show()

# %%
finalized_data.show()
# Out:
# +--------------------+---------------------+
# |     independent_fea|microbusiness_density|
# +--------------------+---------------------+
# |(1924,[0,1,496,18...|            3.0076818|
# |(1924,[0,1,496,18...|            2.8848701|
# |(1924,[0,1,496,18...|            3.0558431|
# |(1924,[0,1,496,18...|            2.9932332|
# |(1924,[0,1,496,18...|            2.9932332|
# |(1924,[0,1,496,18...|              2.96909|
# |(1924,[0,1,496,18...|            2.9093256|
# |(1924,[0,1,496,18...|            2.9332314|
# |(1924,[0,1,496,18...|            3.0001674|
, 1.9533, 2.4617, 2.6452, 4.8388, 3.4641, 3.0472, 3.7494, 5.4853, 3.7298, 1.939, 2.6048, 0.5262, 2.6939, 8.6219, 2.8662, 4.5108, 2.975, 18.2043, 4.387, -0.5033, 0.2418, 6.2684, 1.8229, 5.1874, -1.284, -1.0387, 19.3477, 2.2614, 3.1889, 2.9266, 2.9871, 4.2052, -0.2188, 2.015, 2.2556, 2.9392, 8.3217, 2.5319, 2.0952, 2.2931, 3.3983, 2.6107, 2.9202, 1.861, 3.9837, 0.3918, 4.0699, 1.314, 3.2655, 4.9748, 5.9449, 2.2788, 1.2047, 2.3329, 6.6695, 5.2394, 2.1976, 10.4883, 2.0712, 3.3118, 12.921, 1.3491, 2.109, 2.4618, 4.5326, 2.8298, 3.3624, 2.1156, -0.3361, 2.9933, 5.6909, 1.1641, 2.6444, 2.1889, 2.5798, 3.1708, 1.5785, 3.7597, 2.1976, 0.7508, 5.7647, 4.7054, 5.5158, 0.3053, -0.7105, 1.7178, 2.1244, 2.3498 ...

# %%
regressor.intercept
# Out:
# -180.16630917402625

# %%
pred_result = regressor.evaluate(test)

# %%
pred_result.predictions.show()
# Out:
# +--------------------+---------------------+------------------+
# |     independent_fea|microbusiness_density|        prediction|
# +--------------------+---------------------+------------------+
# |(1924,[0,1,2,1873...|            1.2780961|2.9575622723869515|
# |(1924,[0,1,2,1873...|            1.2906882| 2.950390756807707|
# |(1924,[0,1,2,1873...|            1.3324115| 3.003675476155763|
# |(1924,[0,1,2,1873...|            1.3391467|3.0931903737900086|
# |(1924,[0,1,2,1873...|             1.364061|3.0861430583407525|
# |(1924,[0,1,2,1873...|            1.4347472|  3.21257123497611|
# |(1924,[0,1,2,1873...|            1.4472778|3.1543297094322043|
# |(1924,[0,1,2,1873...|            1.4535431| 3.176278956624884|
# |(1924,[0,1,2,1875...|            1.4857391|1.8412214257194535|
# |(1924,[0,1,2,1875...|            1.4857391|1.8485171414286867|
# |(1924,[0,1,2,1875...|            1.5001631|1.6553306151966183|
# |(1924,[0,1,2,1875...|            1.5291183|1.7903998160147694|
# |(1924,[0,1,2,1875...|             1.559792|1.8872104293582765|
# |(1924,[0,1,2,1875...|            1.5771155|1.7232067659631412|
# |(1924,[0,1,2,1875...|            1.5879922| 1.745156013155821|
# |(1924,[0,1,2,1875...|            1.5879922| 1.774338875992754|
# |(1924,[0,1,2,1875...|            1.6097455|1.7088016347396149|
# |(1924,[0,1,2,1875...|            1.6197413|1.6633094316207178|
# |(1924,[0,1,2,1877...|            1.7366816| 2.220022821446122|
# |(1924,[0,1,2,1877...|            1.7836189|2.1617812959022444|
# +--------------------+---------------------+------------------+
# only showing top 20 rows

# %%
# mean absolute error, mean squared error
pred_result.meanAbsoluteError, pred_result.meanSquaredError
# Out:
# (1.0566802704570228, 12.245007133204323)
