# %%
# Import necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
import datetime 
from pandas_datareader import data as pdr
import pandas_ta as ta
import seaborn as sns
import yfinance as yf

# %%
# data = dataframe in pandas format to calculate sma
# sma_value = is an array to calcuate the lenth of sma 
# variable = variable used to calculate sma, it can be a "Close", or "Adj Close" in string format
def sma(data,sma_value,variable):
     # auto assign a variable name based on length of sma 
    variable_name = 'SMA'+ str(sma_value)
    # calculate sma 
    data[variable_name] =ta.sma(data[variable], length=sma_value)
    # return sma variable calculated 
    return data[variable_name]
# sym =  string format, ticker name
# ema value = is an array to calcuate the lenth of ema 
# sma_value = is an array to calcuate the lenth of sma 
# close = variable use for calcuate sma and ema, either "Close"or "Adj Close" in string format
def getdata(sym,sma_value,ema_value,close):
    yf.pdr_override()
    today = datetime.datetime.now()
    df = pdr.get_data_yahoo(sym, start=datetime.datetime(today.year-5,today.month, 1),
                                    end=datetime.datetime(today.year, today.month, today.day)).reset_index()
    df['ticker'] =sym
        
    for i in sma_value:
        variable_name = 'SMA'+ str(i)
        df[variable_name] = sma(df,i,close)
    
    for i in ema_value:
        variable_name = 'EMA'+ str(i)
        df[variable_name] = ema(df,i,close)
        
    df['Bearish_engulfing'] = np.nan
    df['Bearish swing'] = np.nan
    df['Bearish pinbar'] = np.nan
    for i in range(2,df.shape[0]):
        current = df.iloc[i,:]
        prev = df.iloc[i-1,:]
        prev_2 = df.iloc[i-2,:]
        realbody = abs(current['Open'] - current['Close'])
        candle_range = current['High'] - current['Low']
        idx = df.index[i]
        df.loc[idx,'Bearish_engulfing'] = current['High'] > prev['High'] and current['Low'] < prev['Low'] and realbody >= 0.8 * candle_range and current['Close'] < current['Open']
        df.loc[idx,'Bearish swing'] = current['High'] < prev['High'] and prev['High'] > prev_2['High']
        df.loc[idx,'Bearish pinbar'] = realbody <= candle_range/3 and max(current['Open'] , current['Close']) < (current['High'] + current['Low'])/2 and current['High'] > prev['High']        
    return df
# data = dataframe in pandas format to calculate ema
# ema_value = is an array to calcuate the lenth of ema 
# variable = variable used to calculate sma, it can be a "Close", or "Adj Close" in string format
def ema(data,ema_value,variable):
    # auto assign a variable name based on length of ema 
    variable_name = 'EMA'+ str(ema_value)
    # calculate ema 
    data[variable_name] = data[variable].ewm(span=ema_value, adjust=False).mean()
     # return ema variable calculated 
    return data[variable_name]

# %%
# buy when price > SMA120 and SMA10>EMA10, annual return> 20 and (RSI <70 or RSI >30)
# sell when sma10 < ema10 or bearish engulfing candles or annual return < 20 or price< sma120
############input###########
#data = dataframe with variable needed
#sma_selected, cross over sma selected
#ema_selected, cross over ema selected
def Generate_signal(data, sma_selected,ema_selected):    
    #table start
    df_init =  data.copy()
    
    '''To make sure row arrange in an ascending order'''
    df.sort_values(by = 'Date',inplace=True)
    
    '''Process data by remove Null value in moving average varaible that your want to used for triggered''' 
    df_init.dropna(subset=[ema_selected,sma_selected],inplace=True)
    '''generate as 1 if Adj close is higher than variable you want to test, generate as -1 if Adj close is less than the
    variable you want to test in a signal variable  
    '''
    # create a signal variable
    df_init['signal'] = np.nan 
    # trigger a buy only if it is a up trend 
    df_init.loc[(df_init[sma_selected]>=df_init[ema_selected]) &(df_init['Price']>df_init['SMA120'])&(df_init['Return']>20)&((df_init['RSI']<70)|(df_init['RSI']>30)),'signal'] = 1
    
    # just triggered sell as close is less than variable triggered
    df_init.loc[((df_init[sma_selected]<df_init[ema_selected]) )| (df_init['Bearish_engulfing']==True)|(df_init['Return']<20)|(df_init['Price']<=df_init['SMA120']),'signal'] = -1
    
    # if close > variable triggered but sma20<= sma 200, let it be do nothing
    df_init['signal'].fillna(0,inplace=True) 
    
    ''' move the signal of today to tmr, thus, we need to define a shift(1), as the signal buy is based on yesterday'''
    df_init['signal'] = df_init['signal'].shift(1)
    
    '''after we have a buy and sell signal, lets create a hold signal which is equal to 2 after a buy signal and
    a do nothing signal which is equal to 0 after a sell signal'''
    
    # In order to make a decision on a hold or do nothing signal based on yesterday signal we need to create a for loop 
    # a calendar date should be created to used for a a for loop 
    date_list = df_init.Date.unique()
    
    # declare a first day, the first date is a null in signal as there is no yesterday data for first data
    first_date = date_list[0]
    
    # declare a previous day 
    prev = first_date 
    
    for i in date_list:
        if i == first_date:
            df_init.loc[df_init.Date == i,'signal'] = 0 
        else:
            # if you have a sell signal yesterday, you should have a do nothing signal today
            if (df_init.loc[df_init.Date == prev,'signal'].values[0]==-1):
                df_init.loc[df_init.Date == i,'signal']=0 
            # if you have a buy signal yesterday, you should have a hold signal today
            elif (df_init.loc[df_init.Date == prev,'signal'].values[0]==1):
                df_init.loc[df_init.Date == i,'signal'] = 2
              
            # if you have a hold signal yesterday and you do not have a sell signal today, you should have a hold signal today
            elif ((df_init.loc[df_init.Date == prev,'signal'].values[0]==2)&(df_init.loc[df_init.Date == i,'signal'].values[0]!=-1) ):
                df_init.loc[df_init.Date == i,'signal'] = 2
                
            # if you have a do nothing signal yesterday and today is a sell signal, you should equal to have a do nothing signal
            elif ((df_init.loc[df_init.Date == prev,'signal'].values[0]==0)&(df_init.loc[df_init.Date == i,'signal'].values[0]==-1) ):
                df_init.loc[df_init.Date == i,'signal'] = 0
                
        # redeclare your previous date before to next day in for loop
        prev = i
    
    return df_init

# %%
# data = dataframe with signal to trigger
# capital = assume starting capital
from statistics import mean
def backtest_strategy(data,capital):   
    
    #table start
    df_init =  data.copy()
    df_init.set_index('Date',inplace=True) 
    
    #assign dummy row - day before the trade
    start_date = pd.DataFrame(columns=data.columns,index=[df_init.index.min()- datetime.timedelta(days=1)])
    df_init = df_init.append(start_date)
    
    #initiat 2 variable: cash and units which represent each status of cash and units of apple holding for each day
    df_init = df_init.assign(cash=np.nan,units = 0)
    
    #assign capital for first dummy day assigned to be capital defined in function
    df_init.loc[pd.Series(df_init.index.min()), 'cash'] = capital
    
    # obtain list of calendar 
    calendar = pd.Series(df_init.index.sort_values().unique()).iloc[1:]
    
    ''' assign a variable which is trade, earn trade and lost trade to calculate total number of trade, total earn trade 
    and total lost trade'''
    trade = 0
    earn_trade = 0
    loss_trade = 0
    
    ''' create an array to keep all earn value and lost value for each trade'''
    earn_value =[]
    lost_value =[]

    for date in calendar:
        
        #get yesterday data
        prev_date = df_init.index[df_init.index<date].unique().sort_values()[-1]
        
        # calculate total stock value of yesterday 
        stock_holding = df_init.loc[(df_init.index==prev_date), 'units'].values[0]*df_init.loc[(df_init.index==date),'Price'].values[0]
        
        # total portfolio value by add cash and stock value of yesterday 
        port_value = stock_holding + df_init.loc[prev_date, 'cash'].sum()
        
        
        # if signal is do nothing, mean our cash = portfolio value and units=0
        if df_init.loc[(df_init.index==date), 'signal'].values[0] == 0:          
            df_init.loc[(df_init.index==date), 'units'] = 0
            df_init.loc[(df_init.index==date), 'cash'] =port_value        
        #if we have a buy signal 
        #start to calculate the trade
        #we start to calculate start_cap which represent the starting capital for each trade
        #unit_buy is total unit buy based on port_value available
        elif df_init.loc[(df_init.index==date), 'signal'].values[0] == 1:
            trade+=1
            start_cap = port_value 
            unit_buy = port_value/df_init.loc[(df_init.index==date), 'Price'].values[0]
            df_init.loc[(df_init.index==date), 'units'] = unit_buy
            df_init.loc[(df_init.index==date), 'cash'] = port_value - unit_buy*df_init.loc[(df_init.index==date), 'Price'].values[0]        
#             df_init.loc[(df_init.index==date), 'CL_price'] = df_init.loc[(df_init.index==date), 'Price'].values[0] * 0.95
#             df_init.loc[(df_init.index==date), 'CL_based_price'] = df_init.loc[(df_init.index==date), 'Price'].values[0]
        #if we have a hold signal or do nothing signal,
        #mean today units hold and cash are same as yesterday units hold and yesterday cash
        elif ((df_init.loc[(df_init.index==date), 'signal'].values[0] == 2) | (df_init.loc[(df_init.index==date), 'signal'].values[0] == 0)): 
            df_init.loc[(df_init.index==date), 'units'] = df_init.loc[(df_init.index==prev_date), 'units'].values[0]
            df_init.loc[(df_init.index==date), 'cash'] =df_init.loc[(df_init.index==prev_date), 'cash'].values[0]
#             if  df_init.loc[(df_init.index==date), 'Price'].values[0] > df_init.loc[(df_init.index==prev_date), 'CL_based_price'].values[0]:
#                 df_init.loc[(df_init.index==date), 'CL_price'] = df_init.loc[(df_init.index==date), 'Price'].values[0] * 0.95
#                 df_init.loc[(df_init.index==date), 'CL_based_price'] = df_init.loc[(df_init.index==date), 'Price'].values[0]
#             else:
#                 df_init.loc[(df_init.index==date), 'CL_price'] = df_init.loc[(df_init.index==prev_date), 'CL_price'].values[0]
#                 df_init.loc[(df_init.index==date), 'CL_based_price'] =  df_init.loc[(df_init.index==prev_date), 'CL_based_price'].values[0]
        #if we have a sell signal,
        #1. we sell all the units at the today open price and thus units =0 and cash = port_value
        #2. we calculate the total earn/lost of this trade by using port_value - start cap of the trade and store as v variable
        #3. if v> 0, we store as earn_value array
        #4. if v<0, we store as lost trade
        elif (df_init.loc[(df_init.index==date), 'signal'].values[0] == -1) :
            df_init.loc[(df_init.index==date), 'units'] = 0
            df_init.loc[(df_init.index==date), 'cash'] =port_value 
            if (start_cap is None):
                0
            else:
                v = port_value  - start_cap 
                if v>= 0: 
                    earn_value.append(v)
                    earn_trade +=1
                elif v<0: 
                    lost_value.append(v)
                    loss_trade+=1

    # calculate current value of the strategy, the formula = unit holding * Price + cash available
    df_init['Total_value_todate'] = df_init['units']*df_init['Price'] + df_init['cash'] 
    
    # append 0 to earn value array to prevent later calculation fail if there is no any earn trade
    earn_value.append(0)
    #remove dummy rows
    df_init.drop(df_init[df_init.index == df_init.index.min()].index,axis=0,inplace=True)
  
    # get summarize of total portfolio value, return by date, benchmark_index
    total_port_value = pd.DataFrame(df_init.groupby([df_init.index])['Total_value_todate'].sum())
    total_port_value['Return_without_trailing'] = total_port_value['Total_value_todate']/total_port_value['Total_value_todate'].iloc[0] *100
    total_port_value['Return_trailing_12m'] = total_port_value['Total_value_todate']/total_port_value['Total_value_todate'].shift(12)*100

    # to print out statistic to know how your strategy perform and the win change of this strategy
    print('total_trade:',trade)
    print('earn_trade:',earn_trade)
    print('lost_trade:',loss_trade)
    print('win_chance:',earn_trade/trade)
    print('Max earning:',max(earn_value))
    print('Max lost:',min(lost_value))
    print('Average lost:',mean(lost_value))
    print('Average Win:',mean(earn_value))
    # Create a dictionary with the data for the new data frame
#     data = {
#         'ticket': [data.ticker.values[0]],
#         'total_trade' : [trade],
#         'Average Win': [mean(earn_value)],
#         'Average lost' :  [mean(lost_value)],
#         'win_chance': [earn_trade/trade]
#     }

    # Create the new data frame
    df = pd.DataFrame(data)
    #result_data =  pd.concat([df , result_data])
    return total_port_value, df_init

# %%
def backtest_strategy_portfolio(data,capital):   
    
    #table start
    df_init =  data.copy()
    df_init.set_index('Date',inplace=True) 
    #stock_pick_df = stock_pick_data.copy()
    
    
    #assign dummy row - day before the trade
    start_date = pd.DataFrame(columns=data.columns,index=[df_init.index.min()- datetime.timedelta(days=1)])
    df_init = df_init.append(start_date)
    
    #initiat 2 variable: cash and units which represent each status of cash and units of apple holding for each day
    df_init = df_init.assign(cash=np.nan,units = 0)
    
    #assign capital for first dummy day assigned to be capital defined in function
    df_init.loc[pd.Series(df_init.index.min()), 'cash'] = capital
    
    # obtain list of calendar 
    calendar = pd.Series(df_init[df_init['ticker']!='spy'].index.sort_values().unique()).iloc[1:]
    #sp_calendar = pd.Series(stock_pick_df.index.sort_values().unique())
    i=0

    for date in calendar:
        
        #emp = stock_pick_df[(stock_pick_df['Return_without_trailing']>=stock_pick_df['hold_without_sell_return (%)'])&(stock_pick_df['Return_trailing_12m']>100)&(stock_pick_df['Return_without_trailing']>120)&(stock_pick_df.index==date)].sort_values(by='Return_without_trailing',ascending=False)[:10]
        #temp = stock_pick_df.sort_values(by='RSI',ascending=False)[:10]
        #temp = stock_pick_df[(stock_pick_df['Return_trailing_12m']>120)&(stock_pick_df.index==date)].sort_values(by='Return_trailing_12m_hold',ascending=False)[:5]
        stock_pick = df_init[(df_init.index==date)].ticker.unique() 


        #get yesterday data
        prev_date = df_init.index[df_init.index<date].unique().sort_values()[-1]
        
        
        # calculate total stock value of yesterday 
        total_stock_holding=[]
        cash = []
        for stock in  df_init.loc[(df_init.index==prev_date) &((df_init.signal==1)|(df_init.signal==2))].ticker.unique():
#             print(stock)
#             print(prev_date)
#             print("unit")
#             print(df_init.loc[(df_init.index==prev_date)&(df_init['ticker']==stock), 'units'].values[0])
#             print("Price")
#             print(date)
#             print(df_init.loc[(df_init.index==date)&(df_init['ticker']==stock),'Price'].values[0])
            stock_holding = df_init.loc[(df_init.index==prev_date)&(df_init['ticker']==stock), 'units'].values[0]*df_init.loc[(df_init.index==date)&(df_init['ticker']==stock),'Price'].values[0]
            total_stock_holding.append(stock_holding)
            cash_value = df_init.loc[(df_init.index==prev_date)&(df_init['ticker']==stock), 'cash'].values[0]
            cash.append(cash_value)
        
        # total portfolio value by add cash and stock value of yesterday 
        port_value = sum(total_stock_holding) + df_init.loc[prev_date, 'cash'].sum()

        # reallocation to each stock
        if len(df_init.loc[(df_init.index==date) &((df_init.signal==1)|(df_init.signal==2))].ticker.unique())==0:
            number_stock =1 
            df_init.loc[((df_init.index==date)&(df_init['ticker']=='spy')), 'signal'] = 1
            stock_pick = np.append(stock_pick,'spy')
            
        else: 
            number_stock = len(df_init.loc[(df_init.index==date) &((df_init.signal==1)|(df_init.signal==2))& (df_init.ticker.isin(stock_pick))].ticker.unique())

        allocation_each = port_value/number_stock
        print(date)
        print(port_value)
        print(df_init.loc[(df_init.index==date) &((df_init.signal==1)|(df_init.signal==2))].ticker.unique())
        
        
        for stock in stock_pick:
            # if signal is do nothing or sell, mean our cash = portfolio value and units=0
            
            if ((df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'signal'].values[0] == 0)|(df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'signal'].values[0] == -1)):          
                df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'units'] = 0
                df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'cash'] = 0
            #if we have a buy signal 
            #start to calculate the trade
            #we start to calculate start_cap which represent the starting capital for each trade
            #unit_buy is total unit buy based on port_value available
            elif ((df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'signal'].values[0] == 1)|(df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'signal'].values[0] == 2)):
                unit_buy = allocation_each /df_init.loc[((df_init.index==date)&(df_init['ticker']==stock)), 'Price'].values[0]
                df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'units'] = unit_buy
                df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'cash'] = allocation_each - unit_buy*df_init.loc[((df_init.index==date)&(df_init['ticker']==stock)), 'Price'].values[0]
        
        i=i+1
    # calculate current value of the strategy, the formula = unit holding * Price + cash available
    df_init['Total_value_todate'] = df_init['units']*df_init['Price'] + df_init['cash'] 
    
    #remove dummy rows
    df_init.drop(df_init[df_init.index == df_init.index.min()].index,axis=0,inplace=True)
  
    # get summarize of total portfolio value, return by date, benchmark_index
    total_port_value = pd.DataFrame(df_init.groupby([df_init.index])['Total_value_todate'].sum())
    total_port_value['Return_without_trailing'] = total_port_value['Total_value_todate']/total_port_value['Total_value_todate'].iloc[0] *100
    total_port_value['Return_trailing_12m'] = total_port_value['Total_value_todate']/total_port_value['Total_value_todate'].shift(12)*100

    return total_port_value, df_init

# %%
# annualized return 
# df =data with return 
# variable = variable name of return
def annualized(df,variable):
    days_held =df.shape[0]
    Return = (df.iloc[-1][variable] - df.iloc[0][variable])/df.iloc[0][variable]
    ar = ((1+Return) ** (365/days_held))-1
    # get annualized in %
    return ar*100
# maximum drawdown 
# df =data with return 
# variable = variable name of return
def MDD(df,variable):
    window = 252
    Roll_Max = df[variable].rolling(window, min_periods=1).max()
    Drawdown = df[variable]/Roll_Max - 1.0
    mdd = Drawdown.min()
    # get drawdown in %
    return mdd*100

# %%
# Function to calculate RSI
def RSI(prices, n=14):
  # Get the difference in price from previous step
    delta = prices.diff()

  # Get rid of the first row, which is NaN since it did not have a previous
  # row to calculate the differences
    delta = delta[1:]

  # Make the positive gains (up) and negative gains (down) Series
    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0

  # Calculate the SMA
    roll_up = up.rolling(n).mean()
    roll_down = down.abs().rolling(n).mean()

  # Calculate the RSI based on SMA
    RS = roll_up / roll_down
    RSI = 100.0 - (100.0 / (1.0 + RS))

    return RSI

# %%
def Calculate_Return (df): 
    
    df['12_months_date'] = pd.to_datetime(df.Date) +  pd.DateOffset(months=12) 
    
    df_12_ago = df[['ticker','Date','12_months_date','Close']].rename(
    columns={'Close':'df_ago','Date':'Date_12_ago','12_months_date':'Date'})
    
    df_uptodate = df.rename(
    columns={'Close':'Price'})
    
    df_12 = df_12_ago.merge(df_uptodate,how = 'left', on=['ticker','Date'])
    df_12.drop(df_12[df_12.Price.isna()].index,axis=0)
    df_12.set_index('Date',inplace=True) 
    
    df_12['Return'] = ((df_12['Price'] - df_12['df_ago']) /  df_12['df_ago'])*100
    
    return df_12

# %%
table=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df = table[0]
ticker = df['Symbol'].values
result_data = pd.DataFrame()

# %%
summary = pd.DataFrame()
all_signal = pd.DataFrame()
for i in ticker:
    # Read in the data
    try:
        print(i)
        df = getdata(i,sma_value = [5,10,15,20,50,60,120,150,200],ema_value = [5,10,15,20,50,60,120,150,200],close = "Close")
        if df is not None:
            df['RSI'] = RSI(df['Close'])
            df =Calculate_Return (df)
            df.reset_index(inplace=True)
            df_signal = Generate_signal(df,'SMA10','EMA10')
            # back test your strategy using Open price as price action to buy sell on particular day
            df_signal['Price']=df_signal['Open']
            df_backtest = df_signal[['Date','Price','signal','Open']].copy()
            #result, hold_detail = backtest_strategy(df_backtest,1000)
            # calculate the return without trailing of hold without sell 
    #         df_signal['hold_without_sell_return (%)'] = df_signal['Close']/df_signal['Close'].iloc[0]*100
    #         df_signal['Return_trailing_12m_hold'] =df_signal['Close']/df_signal['Close'].shift(250)*100
    #         result['hold_without_sell_return (%)'] = df_signal.set_index('Date')['hold_without_sell_return (%)']
    #         result['Return_trailing_12m_hold'] = df_signal.set_index('Date')['Return_trailing_12m_hold']
            result['ticker'] = i
            df_signal['ticker']=i
            all_signal = pd.concat([all_signal,df_signal])
            #summary = pd.concat([result,summary])
            df= None
    except:
        pass # doing nothing on exception
# Out:
# MMM
# [*********************100%***********************]  1 of 1 completed
# AOS
# [*********************100%***********************]  1 of 1 completed
# ABT
# [*********************100%***********************]  1 of 1 completed
# ABBV
# [*********************100%***********************]  1 of 1 completed
# ACN
# [*********************100%***********************]  1 of 1 completed
# ATVI
# [*********************100%***********************]  1 of 1 completed
# ADM
# [*********************100%***********************]  1 of 1 completed
# ADBE
# [*********************100%***********************]  1 of 1 completed
# ADP
# [*********************100%***********************]  1 of 1 completed
# AAP
# [*********************100%***********************]  1 of 1 completed
# AES
# [*********************100%***********************]  1 of 1 completed
# AFL
# [*********************100%***********************]  1 of 1 completed
# A
# [*********************100%***********************]  1 of 1 completed
# APD
# [*********************100%***********************]  1 of 1 completed
# AKAM
# [*********************100%***********************]  1 of 1 completed
# ALK
# [*********************100%***********************]  1 of 1 completed
# ALB
# [*********************100%***********************]  1 of 1 completed
# ARE
# [*********************100%***********************]  1 of 1 completed
# ALGN
# [*********************100%***********************]  1 of 1 completed
# ALLE
# [*********************100%***********************]  1 of 1 completed
# LNT
# [*********************100%***********************]  1 of 1 completed
# ALL
# [*********************100%***********************]  1 of 1 completed
# GOOGL
# [*********************100%***********************]  1 of 1 completed
# GOOG
# [*********************100%***********************]  1 of 1 completed
# MO
# [*********************100%***********************]  1 of 1 completed
# AMZN
# [*********************100%***********************]  1 of 1 completed
# AMCR
# [*********************100%***********************]  1 of 1 completed
# AMD
# [*********************100%***********************]  1 of 1 completed
# AEE
# [*********************100%***********************]  1 of 1 completed
# AAL
# [*********************100%***********************]  1 of 1 completed
# AEP
# [*********************100%***********************]  1 of 1 completed
# AXP
# [*********************100%***********************]  1 of 1 completed
# AIG
# [*********************100%***********************]  1 of 1 completed
# AMT
# [*********************100%***********************]  1 of 1 completed
# AWK
# [*********************100%***********************]  1 of 1 completed
# AMP
# [*********************100%***********************]  1 of 1 completed
# ABC
# [*********************100%***********************]  1 of 1 completed
# AME
# [*********************100%***********************]  1 of 1 completed
# AMGN
# [*********************100%***********************]  1 of 1 completed
# APH
# [*********************100%***********************]  1 of 1 completed
# ADI
# [*********************100%***********************]  1 of 1 completed
# ANSS
# [*********************100%***********************]  1 of 1 completed
# AON
# [*********************100%***********************]  1 of 1 completed
# APA
# [*********************100%***********************]  1 of 1 completed
# AAPL
# [*********************100%***********************]  1 of 1 completed
# AMAT
# [*********************100%***********************]  1 of 1 completed
# APTV
# [*********************100%***********************]  1 of 1 completed
# ACGL
# [*********************100%***********************]  1 of 1 completed
# ANET
# [*********************100%***********************]  1 of 1 completed
# AJG
# [*********************100%***********************]  1 of 1 completed
# AIZ
# [*********************100%***********************]  1 of 1 completed
# T
# [*********************100%***********************]  1 of 1 completed
# ATO
# [*********************100%***********************]  1 of 1 completed
# ADSK
# [*********************100%***********************]  1 of 1 completed
# AZO
# [*********************100%***********************]  1 of 1 completed
# AVB
# [*********************100%***********************]  1 of 1 completed
# AVY
# [*********************100%***********************]  1 of 1 completed
# BKR
# [*********************100%***********************]  1 of 1 completed
# BALL
# [*********************100%***********************]  1 of 1 completed
# BAC
# [*********************100%***********************]  1 of 1 completed
# BBWI
# [*********************100%***********************]  1 of 1 completed
# BAX
# [*********************100%***********************]  1 of 1 completed
# BDX
# [*********************100%***********************]  1 of 1 completed
# WRB
# [*********************100%***********************]  1 of 1 completed
# BRK.B
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BRK.B: No data found, symbol may be delisted
# BBY
# [*********************100%***********************]  1 of 1 completed
# BIO
# [*********************100%***********************]  1 of 1 completed
# TECH
# [*********************100%***********************]  1 of 1 completed
# BIIB
# [*********************100%***********************]  1 of 1 completed
# BLK
# [*********************100%***********************]  1 of 1 completed
# BK
# [*********************100%***********************]  1 of 1 completed
# BA
# [*********************100%***********************]  1 of 1 completed
# BKNG
# [*********************100%***********************]  1 of 1 completed
# BWA
# [*********************100%***********************]  1 of 1 completed
# BXP
# [*********************100%***********************]  1 of 1 completed
# BSX
# [*********************100%***********************]  1 of 1 completed
# BMY
# [*********************100%***********************]  1 of 1 completed
# AVGO
# [*********************100%***********************]  1 of 1 completed
# BR
# [*********************100%***********************]  1 of 1 completed
# BRO
# [*********************100%***********************]  1 of 1 completed
# BF.B
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
# CHRW
# [*********************100%***********************]  1 of 1 completed
# CDNS
# [*********************100%***********************]  1 of 1 completed
# CZR
# [*********************100%***********************]  1 of 1 completed
# CPT
# [*********************100%***********************]  1 of 1 completed
# CPB
# [*********************100%***********************]  1 of 1 completed
# COF
# [*********************100%***********************]  1 of 1 completed
# CAH
# [*********************100%***********************]  1 of 1 completed
# KMX
# [*********************100%***********************]  1 of 1 completed
# CCL
# [*********************100%***********************]  1 of 1 completed
# CARR
# [*********************100%***********************]  1 of 1 completed
# CTLT
# [*********************100%***********************]  1 of 1 completed
# CAT
# [*********************100%***********************]  1 of 1 completed
# CBOE
# [*********************100%***********************]  1 of 1 completed
# CBRE
# [*********************100%***********************]  1 of 1 completed
# CDW
# [*********************100%***********************]  1 of 1 completed
# CE
# [*********************100%***********************]  1 of 1 completed
# CNC
# [*********************100%***********************]  1 of 1 completed
# CNP
# [*********************100%***********************]  1 of 1 completed
# CDAY
# [*********************100%***********************]  1 of 1 completed
# CF
# [*********************100%***********************]  1 of 1 completed
# CRL
# [*********************100%***********************]  1 of 1 completed
# SCHW
# [*********************100%***********************]  1 of 1 completed
# CHTR
# [*********************100%***********************]  1 of 1 completed
# CVX
# [*********************100%***********************]  1 of 1 completed
# CMG
# [*********************100%***********************]  1 of 1 completed
# CB
# [*********************100%***********************]  1 of 1 completed
# CHD
# [*********************100%***********************]  1 of 1 completed
# CI
# [*********************100%***********************]  1 of 1 completed
# CINF
# [*********************100%***********************]  1 of 1 completed
# CTAS
# [*********************100%***********************]  1 of 1 completed
# CSCO
# [*********************100%***********************]  1 of 1 completed
# C
# [*********************100%***********************]  1 of 1 completed
# CFG
# [*********************100%***********************]  1 of 1 completed
# CLX
# [*********************100%***********************]  1 of 1 completed
# CME
# [*********************100%***********************]  1 of 1 completed
# CMS
# [*********************100%***********************]  1 of 1 completed
# KO
# [*********************100%***********************]  1 of 1 completed
# CTSH
# [*********************100%***********************]  1 of 1 completed
# CL
# [*********************100%***********************]  1 of 1 completed
# CMCSA
# [*********************100%***********************]  1 of 1 completed
# CMA
# [*********************100%***********************]  1 of 1 completed
# CAG
# [*********************100%***********************]  1 of 1 completed
# COP
# [*********************100%***********************]  1 of 1 completed
# ED
# [*********************100%***********************]  1 of 1 completed
# STZ
# [*********************100%***********************]  1 of 1 completed
# CEG
# [*********************100%***********************]  1 of 1 completed
# COO
# [*********************100%***********************]  1 of 1 completed
# CPRT
# [*********************100%***********************]  1 of 1 completed
# GLW
# [*********************100%***********************]  1 of 1 completed
# CTVA
# [*********************100%***********************]  1 of 1 completed
# CSGP
# [*********************100%***********************]  1 of 1 completed
# COST
# [*********************100%***********************]  1 of 1 completed
# CTRA
# [*********************100%***********************]  1 of 1 completed
# CCI
# [*********************100%***********************]  1 of 1 completed
# CSX
# [*********************100%***********************]  1 of 1 completed
# CMI
# [*********************100%***********************]  1 of 1 completed
# CVS
# [*********************100%***********************]  1 of 1 completed
# DHI
# [*********************100%***********************]  1 of 1 completed
# DHR
# [*********************100%***********************]  1 of 1 completed
# DRI
# [*********************100%***********************]  1 of 1 completed
# DVA
# [*********************100%***********************]  1 of 1 completed
# DE
# [*********************100%***********************]  1 of 1 completed
# DAL
# [*********************100%***********************]  1 of 1 completed
# XRAY
# [*********************100%***********************]  1 of 1 completed
# DVN
# [*********************100%***********************]  1 of 1 completed
# DXCM
# [*********************100%***********************]  1 of 1 completed
# FANG
# [*********************100%***********************]  1 of 1 completed
# DLR
# [*********************100%***********************]  1 of 1 completed
# DFS
# [*********************100%***********************]  1 of 1 completed
# DISH
# [*********************100%***********************]  1 of 1 completed
# DIS
# [*********************100%***********************]  1 of 1 completed
# DG
# [*********************100%***********************]  1 of 1 completed
# DLTR
# [*********************100%***********************]  1 of 1 completed
# D
# [*********************100%***********************]  1 of 1 completed
# DPZ
# [*********************100%***********************]  1 of 1 completed
# DOV
# [*********************100%***********************]  1 of 1 completed
# DOW
# [*********************100%***********************]  1 of 1 completed
# DTE
# [*********************100%***********************]  1 of 1 completed
# DUK
# [*********************100%***********************]  1 of 1 completed
# DD
# [*********************100%***********************]  1 of 1 completed
# DXC
# [*********************100%***********************]  1 of 1 completed
# EMN
# [*********************100%***********************]  1 of 1 completed
# ETN
# [*********************100%***********************]  1 of 1 completed
# EBAY
# [*********************100%***********************]  1 of 1 completed
# ECL
# [*********************100%***********************]  1 of 1 completed
# EIX
# [*********************100%***********************]  1 of 1 completed
# EW
# [*********************100%***********************]  1 of 1 completed
# EA
# [*********************100%***********************]  1 of 1 completed
# ELV
# [*********************100%***********************]  1 of 1 completed
# LLY
# [*********************100%***********************]  1 of 1 completed
# EMR
# [*********************100%***********************]  1 of 1 completed
# ENPH
# [*********************100%***********************]  1 of 1 completed
# ETR
# [*********************100%***********************]  1 of 1 completed
# EOG
# [*********************100%***********************]  1 of 1 completed
# EPAM
# [*********************100%***********************]  1 of 1 completed
# EQT
# [*********************100%***********************]  1 of 1 completed
# EFX
# [*********************100%***********************]  1 of 1 completed
# EQIX
# [*********************100%***********************]  1 of 1 completed
# EQR
# [*********************100%***********************]  1 of 1 completed
# ESS
# [*********************100%***********************]  1 of 1 completed
# EL
# [*********************100%***********************]  1 of 1 completed
# ETSY
# [*********************100%***********************]  1 of 1 completed
# RE
# [*********************100%***********************]  1 of 1 completed
# EVRG
# [*********************100%***********************]  1 of 1 completed
# ES
# [*********************100%***********************]  1 of 1 completed
# EXC
# [*********************100%***********************]  1 of 1 completed
# EXPE
# [*********************100%***********************]  1 of 1 completed
# EXPD
# [*********************100%***********************]  1 of 1 completed
# EXR
# [*********************100%***********************]  1 of 1 completed
# XOM
# [*********************100%***********************]  1 of 1 completed
# FFIV
# [*********************100%***********************]  1 of 1 completed
# FDS
# [*********************100%***********************]  1 of 1 completed
# FAST
# [*********************100%***********************]  1 of 1 completed
# FRT
# [*********************100%***********************]  1 of 1 completed
# FDX
# [*********************100%***********************]  1 of 1 completed
# FITB
# [*********************100%***********************]  1 of 1 completed
# FRC
# [*********************100%***********************]  1 of 1 completed
# FSLR
# [*********************100%***********************]  1 of 1 completed
# FE
# [*********************100%***********************]  1 of 1 completed
# FIS
# [*********************100%***********************]  1 of 1 completed
# FISV
# [*********************100%***********************]  1 of 1 completed
# FLT
# [*********************100%***********************]  1 of 1 completed
# FMC
# [*********************100%***********************]  1 of 1 completed
# F
# [*********************100%***********************]  1 of 1 completed
# FTNT
# [*********************100%***********************]  1 of 1 completed
# FTV
# [*********************100%***********************]  1 of 1 completed
# FOXA
# [*********************100%***********************]  1 of 1 completed
# FOX
# [*********************100%***********************]  1 of 1 completed
# BEN
# [*********************100%***********************]  1 of 1 completed
# FCX
# [*********************100%***********************]  1 of 1 completed
# GRMN
# [*********************100%***********************]  1 of 1 completed
# IT
# [*********************100%***********************]  1 of 1 completed
# GEHC
# [*********************100%***********************]  1 of 1 completed
# GEN
# [*********************100%***********************]  1 of 1 completed
# GNRC
# [*********************100%***********************]  1 of 1 completed
# GD
# [*********************100%***********************]  1 of 1 completed
# GE
# [*********************100%***********************]  1 of 1 completed
# GIS
# [*********************100%***********************]  1 of 1 completed
# GM
# [*********************100%***********************]  1 of 1 completed
# GPC
# [*********************100%***********************]  1 of 1 completed
# GILD
# [*********************100%***********************]  1 of 1 completed
# GL
# [*********************100%***********************]  1 of 1 completed
# GPN
# [*********************100%***********************]  1 of 1 completed
# GS
# [*********************100%***********************]  1 of 1 completed
# HAL
# [*********************100%***********************]  1 of 1 completed
# HIG
# [*********************100%***********************]  1 of 1 completed
# HAS
# [*********************100%***********************]  1 of 1 completed
# HCA
# [*********************100%***********************]  1 of 1 completed
# PEAK
# [*********************100%***********************]  1 of 1 completed
# HSIC
# [*********************100%***********************]  1 of 1 completed
# HSY
# [*********************100%***********************]  1 of 1 completed
# HES
# [*********************100%***********************]  1 of 1 completed
# HPE
# [*********************100%***********************]  1 of 1 completed
# HLT
# [*********************100%***********************]  1 of 1 completed
# HOLX
# [*********************100%***********************]  1 of 1 completed
# HD
# [*********************100%***********************]  1 of 1 completed
# HON
# [*********************100%***********************]  1 of 1 completed
# HRL
# [*********************100%***********************]  1 of 1 completed
# HST
# [*********************100%***********************]  1 of 1 completed
# HWM
# [*********************100%***********************]  1 of 1 completed
# HPQ
# [*********************100%***********************]  1 of 1 completed
# HUM
# [*********************100%***********************]  1 of 1 completed
# HBAN
# [*********************100%***********************]  1 of 1 completed
# HII
# [*********************100%***********************]  1 of 1 completed
# IBM
# [*********************100%***********************]  1 of 1 completed
# IEX
# [*********************100%***********************]  1 of 1 completed
# IDXX
# [*********************100%***********************]  1 of 1 completed
# ITW
# [*********************100%***********************]  1 of 1 completed
# ILMN
# [*********************100%***********************]  1 of 1 completed
# INCY
# [*********************100%***********************]  1 of 1 completed
# IR
# [*********************100%***********************]  1 of 1 completed
# INTC
# [*********************100%***********************]  1 of 1 completed
# ICE
# [*********************100%***********************]  1 of 1 completed
# IP
# [*********************100%***********************]  1 of 1 completed
# IPG
# [*********************100%***********************]  1 of 1 completed
# IFF
# [*********************100%***********************]  1 of 1 completed
# INTU
# [*********************100%***********************]  1 of 1 completed
# ISRG
# [*********************100%***********************]  1 of 1 completed
# IVZ
# [*********************100%***********************]  1 of 1 completed
# INVH
# [*********************100%***********************]  1 of 1 completed
# IQV
# [*********************100%***********************]  1 of 1 completed
# IRM
# [*********************100%***********************]  1 of 1 completed
# JBHT
# [*********************100%***********************]  1 of 1 completed
# JKHY
# [*********************100%***********************]  1 of 1 completed
# J
# [*********************100%***********************]  1 of 1 completed
# JNJ
# [*********************100%***********************]  1 of 1 completed
# JCI
# [*********************100%***********************]  1 of 1 completed
# JPM
# [*********************100%***********************]  1 of 1 completed
# JNPR
# [*********************100%***********************]  1 of 1 completed
# K
# [*********************100%***********************]  1 of 1 completed
# KDP
# [*********************100%***********************]  1 of 1 completed
# KEY
# [*********************100%***********************]  1 of 1 completed
# KEYS
# [*********************100%***********************]  1 of 1 completed
# KMB
# [*********************100%***********************]  1 of 1 completed
# KIM
# [*********************100%***********************]  1 of 1 completed
# KMI
# [*********************100%***********************]  1 of 1 completed
# KLAC
# [*********************100%***********************]  1 of 1 completed
# KHC
# [*********************100%***********************]  1 of 1 completed
# KR
# [*********************100%***********************]  1 of 1 completed
# LHX
# [*********************100%***********************]  1 of 1 completed
# LH
# [*********************100%***********************]  1 of 1 completed
# LRCX
# [*********************100%***********************]  1 of 1 completed
# LW
# [*********************100%***********************]  1 of 1 completed
# LVS
# [*********************100%***********************]  1 of 1 completed
# LDOS
# [*********************100%***********************]  1 of 1 completed
# LEN
# [*********************100%***********************]  1 of 1 completed
# LNC
# [*********************100%***********************]  1 of 1 completed
# LIN
# [*********************100%***********************]  1 of 1 completed
# LYV
# [*********************100%***********************]  1 of 1 completed
# LKQ
# [*********************100%***********************]  1 of 1 completed
# LMT
# [*********************100%***********************]  1 of 1 completed
# L
# [*********************100%***********************]  1 of 1 completed
# LOW
# [*********************100%***********************]  1 of 1 completed
# LUMN
# [*********************100%***********************]  1 of 1 completed
# LYB
# [*********************100%***********************]  1 of 1 completed
# MTB
# [*********************100%***********************]  1 of 1 completed
# MRO
# [*********************100%***********************]  1 of 1 completed
# MPC
# [*********************100%***********************]  1 of 1 completed
# MKTX
# [*********************100%***********************]  1 of 1 completed
# MAR
# [*********************100%***********************]  1 of 1 completed
# MMC
# [*********************100%***********************]  1 of 1 completed
# MLM
# [*********************100%***********************]  1 of 1 completed
# MAS
# [*********************100%***********************]  1 of 1 completed
# MA
# [*********************100%***********************]  1 of 1 completed
# MTCH
# [*********************100%***********************]  1 of 1 completed
# MKC
# [*********************100%***********************]  1 of 1 completed
# MCD
# [*********************100%***********************]  1 of 1 completed
# MCK
# [*********************100%***********************]  1 of 1 completed
# MDT
# [*********************100%***********************]  1 of 1 completed
# MRK
# [*********************100%***********************]  1 of 1 completed
# META
# [*********************100%***********************]  1 of 1 completed
# MET
# [*********************100%***********************]  1 of 1 completed
# MTD
# [*********************100%***********************]  1 of 1 completed
# MGM
# [*********************100%***********************]  1 of 1 completed
# MCHP
# [*********************100%***********************]  1 of 1 completed
# MU
# [*********************100%***********************]  1 of 1 completed
# MSFT
# [*********************100%***********************]  1 of 1 completed
# MAA
# [*********************100%***********************]  1 of 1 completed
# MRNA
# [*********************100%***********************]  1 of 1 completed
# MHK
# [*********************100%***********************]  1 of 1 completed
# MOH
# [*********************100%***********************]  1 of 1 completed
# TAP
# [*********************100%***********************]  1 of 1 completed
# MDLZ
# [*********************100%***********************]  1 of 1 completed
# MPWR
# [*********************100%***********************]  1 of 1 completed
# MNST
# [*********************100%***********************]  1 of 1 completed
# MCO
# [*********************100%***********************]  1 of 1 completed
# MS
# [*********************100%***********************]  1 of 1 completed
# MOS
# [*********************100%***********************]  1 of 1 completed
# MSI
# [*********************100%***********************]  1 of 1 completed
# MSCI
# [*********************100%***********************]  1 of 1 completed
# NDAQ
# [*********************100%***********************]  1 of 1 completed
# NTAP
# [*********************100%***********************]  1 of 1 completed
# NFLX
# [*********************100%***********************]  1 of 1 completed
# NWL
# [*********************100%***********************]  1 of 1 completed
# NEM
# [*********************100%***********************]  1 of 1 completed
# NWSA
# [*********************100%***********************]  1 of 1 completed
# NWS
# [*********************100%***********************]  1 of 1 completed
# NEE
# [*********************100%***********************]  1 of 1 completed
# NKE
# [*********************100%***********************]  1 of 1 completed
# NI
# [*********************100%***********************]  1 of 1 completed
# NDSN
# [*********************100%***********************]  1 of 1 completed
# NSC
# [*********************100%***********************]  1 of 1 completed
# NTRS
# [*********************100%***********************]  1 of 1 completed
# NOC
# [*********************100%***********************]  1 of 1 completed
# NCLH
# [*********************100%***********************]  1 of 1 completed
# NRG
# [*********************100%***********************]  1 of 1 completed
# NUE
# [*********************100%***********************]  1 of 1 completed
# NVDA
# [*********************100%***********************]  1 of 1 completed
# NVR
# [*********************100%***********************]  1 of 1 completed
# NXPI
# [*********************100%***********************]  1 of 1 completed
# ORLY
# [*********************100%***********************]  1 of 1 completed
# OXY
# [*********************100%***********************]  1 of 1 completed
# ODFL
# [*********************100%***********************]  1 of 1 completed
# OMC
# [*********************100%***********************]  1 of 1 completed
# ON
# [*********************100%***********************]  1 of 1 completed
# OKE
# [*********************100%***********************]  1 of 1 completed
# ORCL
# [*********************100%***********************]  1 of 1 completed
# OGN
# [*********************100%***********************]  1 of 1 completed
# OTIS
# [*********************100%***********************]  1 of 1 completed
# PCAR
# [*********************100%***********************]  1 of 1 completed
# PKG
# [*********************100%***********************]  1 of 1 completed
# PARA
# [*********************100%***********************]  1 of 1 completed
# PH
# [*********************100%***********************]  1 of 1 completed
# PAYX
# [*********************100%***********************]  1 of 1 completed
# PAYC
# [*********************100%***********************]  1 of 1 completed
# PYPL
# [*********************100%***********************]  1 of 1 completed
# PNR
# [*********************100%***********************]  1 of 1 completed
# PEP
# [*********************100%***********************]  1 of 1 completed
# PKI
# [*********************100%***********************]  1 of 1 completed
# PFE
# [*********************100%***********************]  1 of 1 completed
# PCG
# [*********************100%***********************]  1 of 1 completed
# PM
# [*********************100%***********************]  1 of 1 completed
# PSX
# [*********************100%***********************]  1 of 1 completed
# PNW
# [*********************100%***********************]  1 of 1 completed
# PXD
# [*********************100%***********************]  1 of 1 completed
# PNC
# [*********************100%***********************]  1 of 1 completed
# POOL
# [*********************100%***********************]  1 of 1 completed
# PPG
# [*********************100%***********************]  1 of 1 completed
# PPL
# [*********************100%***********************]  1 of 1 completed
# PFG
# [*********************100%***********************]  1 of 1 completed
# PG
# [*********************100%***********************]  1 of 1 completed
# PGR
# [*********************100%***********************]  1 of 1 completed
# PLD
# [*********************100%***********************]  1 of 1 completed
# PRU
# [*********************100%***********************]  1 of 1 completed
# PEG
# [*********************100%***********************]  1 of 1 completed
# PTC
# [*********************100%***********************]  1 of 1 completed
# PSA
# [*********************100%***********************]  1 of 1 completed
# PHM
# [*********************100%***********************]  1 of 1 completed
# QRVO
# [*********************100%***********************]  1 of 1 completed
# PWR
# [*********************100%***********************]  1 of 1 completed
# QCOM
# [*********************100%***********************]  1 of 1 completed
# DGX
# [*********************100%***********************]  1 of 1 completed
# RL
# [*********************100%***********************]  1 of 1 completed
# RJF
# [*********************100%***********************]  1 of 1 completed
# RTX
# [*********************100%***********************]  1 of 1 completed
# O
# [*********************100%***********************]  1 of 1 completed
# REG
# [*********************100%***********************]  1 of 1 completed
# REGN
# [*********************100%***********************]  1 of 1 completed
# RF
# [*********************100%***********************]  1 of 1 completed
# RSG
# [*********************100%***********************]  1 of 1 completed
# RMD
# [*********************100%***********************]  1 of 1 completed
# RHI
# [*********************100%***********************]  1 of 1 completed
# ROK
# [*********************100%***********************]  1 of 1 completed
# ROL
# [*********************100%***********************]  1 of 1 completed
# ROP
# [*********************100%***********************]  1 of 1 completed
# ROST
# [*********************100%***********************]  1 of 1 completed
# RCL
# [*********************100%***********************]  1 of 1 completed
# SPGI
# [*********************100%***********************]  1 of 1 completed
# CRM
# [*********************100%***********************]  1 of 1 completed
# SBAC
# [*********************100%***********************]  1 of 1 completed
# SLB
# [*********************100%***********************]  1 of 1 completed
# STX
# [*********************100%***********************]  1 of 1 completed
# SEE
# [*********************100%***********************]  1 of 1 completed
# SRE
# [*********************100%***********************]  1 of 1 completed
# NOW
# [*********************100%***********************]  1 of 1 completed
# SHW
# [*********************100%***********************]  1 of 1 completed
# SBNY
# [*********************100%***********************]  1 of 1 completed
# SPG
# [*********************100%***********************]  1 of 1 completed
# SWKS
# [*********************100%***********************]  1 of 1 completed
# SJM
# [*********************100%***********************]  1 of 1 completed
# SNA
# [*********************100%***********************]  1 of 1 completed
# SEDG
# [*********************100%***********************]  1 of 1 completed
# SO
# [*********************100%***********************]  1 of 1 completed
# LUV
# [*********************100%***********************]  1 of 1 completed
# SWK
# [*********************100%***********************]  1 of 1 completed
# SBUX
# [*********************100%***********************]  1 of 1 completed
# STT
# [*********************100%***********************]  1 of 1 completed
# STLD
# [*********************100%***********************]  1 of 1 completed
# STE
# [*********************100%***********************]  1 of 1 completed
# SYK
# [*********************100%***********************]  1 of 1 completed
# SIVB
# [*********************100%***********************]  1 of 1 completed
# SYF
# [*********************100%***********************]  1 of 1 completed
# SNPS
# [*********************100%***********************]  1 of 1 completed
# SYY
# [*********************100%***********************]  1 of 1 completed
# TMUS
# [*********************100%***********************]  1 of 1 completed
# TROW
# [*********************100%***********************]  1 of 1 completed
# TTWO
# [*********************100%***********************]  1 of 1 completed
# TPR
# [*********************100%***********************]  1 of 1 completed
# TRGP
# [*********************100%***********************]  1 of 1 completed
# TGT
# [*********************100%***********************]  1 of 1 completed
# TEL
# [*********************100%***********************]  1 of 1 completed
# TDY
# [*********************100%***********************]  1 of 1 completed
# TFX
# [*********************100%***********************]  1 of 1 completed
# TER
# [*********************100%***********************]  1 of 1 completed
# TSLA
# [*********************100%***********************]  1 of 1 completed
# TXN
# [*********************100%***********************]  1 of 1 completed
# TXT
# [*********************100%***********************]  1 of 1 completed
# TMO
# [*********************100%***********************]  1 of 1 completed
# TJX
# [*********************100%***********************]  1 of 1 completed
# TSCO
# [*********************100%***********************]  1 of 1 completed
# TT
# [*********************100%***********************]  1 of 1 completed
# TDG
# [*********************100%***********************]  1 of 1 completed
# TRV
# [*********************100%***********************]  1 of 1 completed
# TRMB
# [*********************100%***********************]  1 of 1 completed
# TFC
# [*********************100%***********************]  1 of 1 completed
# TYL
# [*********************100%***********************]  1 of 1 completed
# TSN
# [*********************100%***********************]  1 of 1 completed
# USB
# [*********************100%***********************]  1 of 1 completed
# UDR
# [*********************100%***********************]  1 of 1 completed
# ULTA
# [*********************100%***********************]  1 of 1 completed
# UNP
# [*********************100%***********************]  1 of 1 completed
# UAL
# [*********************100%***********************]  1 of 1 completed
# UPS
# [*********************100%***********************]  1 of 1 completed
# URI
# [*********************100%***********************]  1 of 1 completed
# UNH
# [*********************100%***********************]  1 of 1 completed
# UHS
# [*********************100%***********************]  1 of 1 completed
# VLO
# [*********************100%***********************]  1 of 1 completed
# VTR
# [*********************100%***********************]  1 of 1 completed
# VRSN
# [*********************100%***********************]  1 of 1 completed
# VRSK
# [*********************100%***********************]  1 of 1 completed
# VZ
# [*********************100%***********************]  1 of 1 completed
# VRTX
# [*********************100%***********************]  1 of 1 completed
# VFC
# [*********************100%***********************]  1 of 1 completed
# VTRS
# [*********************100%***********************]  1 of 1 completed
# VICI
# [*********************100%***********************]  1 of 1 completed
# V
# [*********************100%***********************]  1 of 1 completed
# VMC
# [*********************100%***********************]  1 of 1 completed
# WAB
# [*********************100%***********************]  1 of 1 completed
# WBA
# [*********************100%***********************]  1 of 1 completed
# WMT
# [*********************100%***********************]  1 of 1 completed
# WBD
# [*********************100%***********************]  1 of 1 completed
# WM
# [*********************100%***********************]  1 of 1 completed
# WAT
# [*********************100%***********************]  1 of 1 completed
# WEC
# [*********************100%***********************]  1 of 1 completed
# WFC
# [*********************100%***********************]  1 of 1 completed
# WELL
# [*********************100%***********************]  1 of 1 completed
# WST
# [*********************100%***********************]  1 of 1 completed
# WDC
# [*********************100%***********************]  1 of 1 completed
# WRK
# [*********************100%***********************]  1 of 1 completed
# WY
# [*********************100%***********************]  1 of 1 completed
# WHR
# [*********************100%***********************]  1 of 1 completed
# WMB
# [*********************100%***********************]  1 of 1 completed
# WTW
# [*********************100%***********************]  1 of 1 completed
# GWW
# [*********************100%***********************]  1 of 1 completed
# WYNN
# [*********************100%***********************]  1 of 1 completed
# XEL
# [*********************100%***********************]  1 of 1 completed
# XYL
# [*********************100%***********************]  1 of 1 completed
# YUM
# [*********************100%***********************]  1 of 1 completed
# ZBRA
# [*********************100%***********************]  1 of 1 completed
# ZBH
# [*********************100%***********************]  1 of 1 completed
# ZION
# [*********************100%***********************]  1 of 1 completed
# ZTS
# [*********************100%***********************]  1 of 1 completed

# %%
spy = getdata('spy',sma_value = [20,50,200],ema_value =[20,50,200],close = "Close")
spy['signal'] = 0 
spy['ticker'] = 'spy'
spy['Price']=spy['Open']
spy =spy[spy['Date']>=all_signal.Date.min()]
spy =spy[spy['Date'].isin(all_signal.Date.unique())]
signal_etf_stock = pd.concat([spy,all_signal])
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
result, hold_detail = backtest_strategy_portfolio(signal_etf_stock[signal_etf_stock.Date>'2014-11-12'],10000)
# Out:
# 2019-01-02 00:00:00
# 10000.0
# ['spy']
# 2019-01-03 00:00:00
# 10091.470852877494
# ['spy']
# 2019-01-04 00:00:00
# 10065.452501760952
# ['spy']
# 2019-01-08 00:00:00
# 10440.686713755646
# ['spy']
# 2019-01-09 00:00:00
# 10470.770063915334
# ['ORLY']
# 2019-01-10 00:00:00
# 10573.031836948014
# ['MRK' 'ORLY']
# 2019-01-11 00:00:00
# 10528.198096419093
# ['LLY' 'MRK' 'ORLY']
# 2019-01-16 00:00:00
# 10613.76966430257
# ['LLY' 'MRK' 'ORLY']
# 2019-01-17 00:00:00
# 10583.660854043406
# ['CZR' 'MRK']
# 2019-01-18 00:00:00
# 10790.383452302995
# ['CZR' 'CMG' 'ETSY' 'IQV' 'KEYS' 'LYV' 'MRK' 'MOS' 'NFLX' 'NKE' 'CRM'
#  'NOW' 'VRTX']
# 2019-01-22 00:00:00
# 10745.668755455717
# ['AES' 'ADSK' 'CZR' 'CMG' 'DXCM' 'LLY' 'EPAM' 'ETSY' 'FE' 'IQV' 'KEYS'
#  'LYV' 'MKC' 'MOH' 'MOS' 'NFLX' 'NKE' 'NRG' 'CRM' 'NOW' 'TDG' 'VRTX']
# 2019-01-23 00:00:00
# 10708.29525500976
# ['AES' 'ADSK' 'CZR' 'CMG' 'CHD' 'DXCM' 'LLY' 'EPAM' 'ETSY' 'FE' 'INTU'
#  'IQV' 'KEYS' 'LYV' 'MKC' 'MOH' 'NFLX' 'NRG' 'RMD' 'CRM' 'NOW' 'TDG'
#  'ULTA' 'VRSN']
# 2019-01-24 00:00:00
# 10595.168640816175
# ['AAP' 'AES' 'CZR' 'CMG' 'CHD' 'DXCM' 'LLY' 'ETSY' 'HCA' 'HRL' 'INTU'
#  'ISRG' 'IQV' 'KEYS' 'MKC' 'MOH' 'NFLX' 'NRG' 'RMD' 'CRM' 'NOW' 'ULTA'
#  'VRSN']
# 2019-01-25 00:00:00
# 10567.807015840655
# ['AAP' 'AES' 'CZR' 'CMG' 'CHD' 'DXCM' 'LLY' 'ENPH' 'ETSY' 'HCA' 'PEAK'
#  'HRL' 'INTU' 'ISRG' 'IQV' 'KEYS' 'MOH' 'NFLX' 'ORLY' 'CRM' 'NOW' 'ULTA'
#  'VRSN']
# 2019-01-29 00:00:00
# 10567.176563251845
# ['ADSK' 'CZR' 'CMG' 'CHD' 'DXCM' 'LLY' 'ENPH' 'EPAM' 'ETSY' 'HCA' 'PEAK'
#  'INTU' 'IQV' 'KEYS' 'MA' 'MOH' 'NFLX' 'ORLY' 'CRM' 'NOW' 'ULTA' 'UNP'
#  'VRSN' 'ZBRA']
# 2019-01-30 00:00:00
# 10581.10465323553
# ['AEE' 'ADSK' 'BALL' 'BSX' 'CZR' 'CMG' 'CHD' 'DXCM' 'EW' 'LLY' 'ENPH'
#  'EPAM' 'ETSY' 'EXC' 'HCA' 'PEAK' 'KEYS' 'MA' 'MOH' 'NRG' 'CRM' 'NOW'
#  'STE' 'ULTA' 'UNP' 'VRSN' 'ZBRA']
# 2019-01-31 00:00:00
# 10688.566875056777
# ['AEE' 'BALL' 'BSX' 'CZR' 'CMG' 'CHD' 'DXCM' 'EW' 'LLY' 'ENPH' 'EPAM'
#  'ETSY' 'EXC' 'HCA' 'MA' 'MRK' 'MOH' 'NKE' 'NRG' 'CRM' 'STE' 'ULTA' 'UAL'
#  'VRSN' 'ZBRA']
# 2019-02-01 00:00:00
# 10828.858483771672
# ['ADBE' 'AEE' 'BALL' 'BSX' 'CZR' 'CMG' 'CHD' 'DXCM' 'DPZ' 'EW' 'LLY'
#  'ENPH' 'EPAM' 'ETSY' 'EXC' 'HRL' 'INTU' 'ISRG' 'IQV' 'MRK' 'MSCI' 'NFLX'
#  'NKE' 'NRG' 'ORLY' 'CRM' 'STE' 'ULTA' 'UAL' 'VRSN' 'ZBRA']
# 2019-02-05 00:00:00
# 10913.481804410007
# ['ADBE' 'AEE' 'BALL' 'BSX' 'CMG' 'CHD' 'DXCM' 'DPZ' 'EW' 'ENPH' 'EPAM'
#  'ETSY' 'HRL' 'INTU' 'ISRG' 'IQV' 'MSCI' 'NFLX' 'NKE' 'NRG' 'ORLY' 'STE'
#  'ULTA' 'UNP' 'ZBRA']
# 2019-02-06 00:00:00
# 10988.073490216946
# ['AEE' 'AWK' 'ATO' 'BALL' 'BSX' 'CMG' 'CSCO' 'CMS' 'COO' 'DPZ' 'EW' 'ENPH'
#  'EQR' 'ETSY' 'FE' 'FISV' 'MTCH' 'NKE' 'NRG' 'PYPL' 'PGR' 'ROST' 'STE'
#  'TDY' 'TSCO' 'ULTA' 'UNP' 'UNH' 'VTR' 'VRSK' 'VRTX' 'WELL' 'ZBRA']
# 2019-02-07 00:00:00
# 10997.019611468624
# ['AEE' 'AMT' 'AWK' 'ATO' 'AVB' 'BALL' 'CMG' 'CSCO' 'CMS' 'COO' 'DPZ' 'EW'
#  'ENPH' 'EQR' 'ETSY' 'FE' 'FISV' 'PEAK' 'MTCH' 'NRG' 'PYPL' 'PGR' 'ROST'
#  'SEDG' 'STE' 'TDY' 'TSCO' 'UDR' 'ULTA' 'UNP' 'UNH' 'VTR' 'VRSK' 'VRTX'
#  'WELL']
# 2019-02-08 00:00:00
# 10999.329902198971
# ['AMT' 'AVB' 'BALL' 'CZR' 'CPT' 'DPZ' 'EW' 'ENPH' 'EPAM' 'EQR' 'ESS'
#  'ETSY' 'EXR' 'FRT' 'FISV' 'PEAK' 'KIM' 'MTCH' 'PYPL' 'PGR' 'REGN' 'SEDG'
#  'SBUX' 'UDR' 'ULTA' 'UNP' 'VTR' 'WELL']
# 2019-02-12 00:00:00
# 11244.610024599026
# ['AMT' 'ADI' 'AVB' 'CZR' 'CPT' 'DPZ' 'ECL' 'EW' 'ELV' 'ENPH' 'EPAM' 'EQR'
#  'ESS' 'ETSY' 'EXR' 'FRT' 'FISV' 'HCA' 'PEAK' 'KEYS' 'KIM' 'MTCH' 'MAA'
#  'NKE' 'NSC' 'PKI' 'PGR' 'PLD' 'REGN' 'RSG' 'SPG' 'SEDG' 'SBUX' 'TMO'
#  'UDR' 'ULTA' 'UNP' 'UAL' 'VTR' 'WAT' 'WELL' 'YUM']
# 2019-02-13 00:00:00
# 11213.454234255949
# ['ABT' 'AES' 'AEP' 'AMT' 'ADI' 'ADSK' 'AVB' 'TECH' 'CZR' 'CPT' 'CRL' 'COO'
#  'CSGP' 'ECL' 'ELV' 'LLY' 'ENPH' 'EPAM' 'EQR' 'ESS' 'ETSY' 'ES' 'EXC'
#  'EXR' 'FRT' 'FISV' 'FTNT' 'HCA' 'PEAK' 'IQV' 'KEYS' 'KIM' 'MA' 'MTCH'
#  'MAA' 'MPWR' 'MSCI' 'NFLX' 'NKE' 'NSC' 'PKI' 'PG' 'PLD' 'O' 'REGN' 'RSG'
#  'RHI' 'NOW' 'SPG' 'SEDG' 'SBUX' 'SYK' 'TMO' 'TDG' 'UDR' 'UAL' 'VTR'
#  'VRSN' 'VRTX' 'WAT' 'WELL' 'YUM']
# 2019-02-14 00:00:00
# 11223.540354645505
# ['ABT' 'ADP' 'AES' 'AEE' 'AEP' 'AMT' 'AWK' 'ADI' 'AON' 'ATO' 'ADSK' 'AVB'
#  'TECH' 'CDNS' 'CZR' 'CPT' 'CRL' 'CMS' 'COO' 'CSGP' 'ECL' 'ELV' 'LLY'
#  'EPAM' 'EQR' 'ESS' 'ES' 'EXC' 'EXPE' 'EXR' 'FRT' 'FISV' 'FTNT' 'HCA'
#  'PEAK' 'IQV' 'KEYS' 'MA' 'MTCH' 'MOH' 'MPWR' 'MSCI' 'NFLX' 'PKI' 'PG' 'O'
#  'REGN' 'RSG' 'RHI' 'CRM' 'NOW' 'SEDG' 'SBUX' 'SYK' 'TMO' 'TDG' 'UDR'
#  'UAL' 'VTR' 'VRSN' 'VRTX' 'WEC' 'WELL' 'XEL' 'YUM']
# 2019-02-15 00:00:00
# 11333.935399131706
# ['ABT' 'ADBE' 'ADP' 'AES' 'AEE' 'AEP' 'AWK' 'ADI' 'AON' 'ATO' 'ADSK' 'AVB'
#  'TECH' 'CDNS' 'CZR' 'CPT' 'CLX' 'CMS' 'COP' 'COO' 'DPZ' 'ECL' 'ELV' 'LLY'
#  'ETR' 'EQR' 'ESS' 'ES' 'EXC' 'EXPE' 'EXR' 'FRT' 'FISV' 'FTNT' 'HCA'
#  'PEAK' 'KEYS' 'MA' 'MTCH' 'MRK' 'MOH' 'MPWR' 'NFLX' 'PAYC' 'PKI' 'PG' 'O'
#  'REGN' 'CRM' 'NOW' 'SEDG' 'TDG' 'UDR' 'UAL' 'VTR' 'VRSN' 'WEC' 'WELL'
#  'XEL' 'YUM']
# 2019-02-20 00:00:00
# 11341.806364198444
# ['ADBE' 'ADP' 'AES' 'AMD' 'AEE' 'AWK' 'AON' 'ADSK' 'AVB' 'BALL' 'TECH'
#  'CDNS' 'CZR' 'CLX' 'CMS' 'COP' 'COO' 'DXCM' 'DPZ' 'ELV' 'ENPH' 'ETR'
#  'EQR' 'ESS' 'EXC' 'EXPE' 'EXR' 'FRT' 'FISV' 'FTNT' 'PEAK' 'INTU' 'KEYS'
#  'KIM' 'MA' 'MTCH' 'MRK' 'MOH' 'NFLX' 'PAYC' 'PKI' 'O' 'CRM' 'NOW' 'STE'
#  'TDG' 'UDR' 'UAL' 'VTR' 'VRSN' 'WEC' 'WELL' 'XEL']
# 2019-02-21 00:00:00
# 11253.807708826276
# ['ADBE' 'ADP' 'AES' 'AMD' 'AEE' 'AWK' 'AON' 'ADSK' 'AVB' 'BALL' 'WRB'
#  'TECH' 'BSX' 'CZR' 'CDW' 'CMG' 'CLX' 'CMS' 'DXCM' 'DPZ' 'ELV' 'ENPH'
#  'ETR' 'EQR' 'ESS' 'EXC' 'EXPE' 'FE' 'FTNT' 'PEAK' 'HRL' 'INTU' 'KEYS'
#  'KIM' 'MA' 'MTCH' 'MOH' 'MSCI' 'NEE' 'NKE' 'NRG' 'PAYC' 'PKI' 'O' 'ROST'
#  'CRM' 'NOW' 'SBUX' 'STE' 'TDG' 'UDR' 'UAL' 'VTR' 'VRSN' 'VRSK' 'WEC'
#  'WELL' 'XEL']
# 2019-02-22 00:00:00
# 11356.154640817434
# ['ADBE' 'ADP' 'AES' 'AEE' 'AEP' 'AWK' 'AON' 'ADSK' 'AZO' 'AVB' 'BALL'
#  'WRB' 'TECH' 'BSX' 'CZR' 'CPT' 'CDW' 'CMG' 'CTAS' 'CLX' 'CMS' 'DXCM' 'DG'
#  'EW' 'ELV' 'ENPH' 'ETR' 'EQR' 'ESS' 'ES' 'EXC' 'EXPE' 'FE' 'FTNT' 'PEAK'
#  'HRL' 'KIM' 'MA' 'MTCH' 'MAA' 'MSI' 'MSCI' 'NEE' 'NKE' 'NRG' 'ORLY'
#  'PAYC' 'PKI' 'PG' 'O' 'ROST' 'CRM' 'NOW' 'SPG' 'SBUX' 'STE' 'TDY' 'TSCO'
#  'TDG' 'UDR' 'UAL' 'VTR' 'VRSN' 'VRSK' 'WEC' 'WELL' 'XEL']
# 2019-02-26 00:00:00
# 11376.298302405552
# ['ABT' 'ADBE' 'ADP' 'AES' 'AEP' 'AMT' 'AON' 'ADSK' 'AZO' 'AVB' 'BALL'
#  'WRB' 'TECH' 'BSX' 'CPT' 'CDW' 'CMG' 'CTAS' 'CLX' 'CSX' 'DG' 'EW' 'ENPH'
#  'EQR' 'ESS' 'ES' 'EXPE' 'FTNT' 'HRL' 'MA' 'MTCH' 'MAA' 'MSI' 'MSCI' 'NEE'
#  'NKE' 'NSC' 'NRG' 'ORLY' 'PAYC' 'PKI' 'PG' 'PGR' 'O' 'ROST' 'CRM' 'NOW'
#  'SPG' 'SBUX' 'STE' 'SNPS' 'TDY' 'TSCO' 'TDG' 'UDR' 'ULTA' 'UNP' 'UAL'
#  'VTR' 'VRSK' 'WEC' 'WELL']
# 2019-02-27 00:00:00
# 11324.157422999857
# ['ABT' 'ADBE' 'ADP' 'AES' 'AMT' 'ADSK' 'AZO' 'AVB' 'BALL' 'TECH' 'BSX'
#  'CPT' 'CDW' 'CRL' 'CMG' 'CLX' 'COP' 'CSX' 'DG' 'EW' 'ESS' 'IT' 'HCA'
#  'HES' 'ISRG' 'IQV' 'MA' 'MTCH' 'MRK' 'MSI' 'MSCI' 'NFLX' 'NKE' 'NSC'
#  'NRG' 'ORLY' 'PAYC' 'PYPL' 'PG' 'PGR' 'PTC' 'O' 'CRM' 'NOW' 'SBUX' 'STE'
#  'SNPS' 'TDY' 'TSCO' 'TDG' 'UDR' 'ULTA' 'UNP' 'VTR' 'VRSK' 'WEC' 'WELL'
#  'ZBRA']
# 2019-02-28 00:00:00
# 11368.006305501689
# ['ADBE' 'ADP' 'AES' 'AMD' 'AMT' 'ADSK' 'AZO' 'AVB' 'BALL' 'TECH' 'BSX'
#  'CZR' 'CPT' 'CDW' 'CRL' 'CMG' 'CHD' 'CLX' 'COP' 'CSX' 'DXCM' 'DG' 'ECL'
#  'EW' 'ELV' 'EPAM' 'ESS' 'EXC' 'IT' 'HCA' 'PEAK' 'HES' 'ISRG' 'IQV' 'MA'
#  'MTCH' 'MRK' 'MSI' 'NFLX' 'NKE' 'NSC' 'NRG' 'ORLY' 'PAYC' 'PYPL' 'PG'
#  'PGR' 'PTC' 'O' 'NOW' 'SBUX' 'STE' 'SNPS' 'TMUS' 'TDY' 'TJX' 'TSCO' 'TDG'
#  'UDR' 'ULTA' 'UNP' 'VTR' 'VRSN' 'VRSK' 'WELL' 'ZBRA']
# 2019-03-01 00:00:00
# 11454.862572803222
# ['ADP' 'AES' 'AMD' 'AMT' 'AON' 'ADSK' 'AZO' 'AVB' 'BALL' 'WRB' 'TECH'
#  'BSX' 'CZR' 'CPT' 'CDW' 'CRL' 'CMG' 'CHD' 'CTAS' 'CLX' 'COO' 'CSX' 'DRI'
#  'DXCM' 'DG' 'DTE' 'ECL' 'EW' 'ELV' 'EPAM' 'EQR' 'ESS' 'ES' 'EXC' 'HCA'
#  'PEAK' 'HES' 'HOLX' 'HRL' 'ISRG' 'IQV' 'J' 'LYV' 'MA' 'MTCH' 'MRK' 'MAA'
#  'MSI' 'NFLX' 'NEE' 'NKE' 'NSC' 'NRG' 'ORLY' 'PAYC' 'PKI' 'PG' 'PGR' 'PTC'
#  'O' 'NOW' 'SBUX' 'STE' 'SNPS' 'TMUS' 'TDY' 'TJX' 'TSCO' 'TDG' 'UDR'
#  'ULTA' 'UNP' 'UAL' 'VTR' 'VRSN' 'VRSK' 'WELL' 'XEL' 'ZBRA']
# 2019-03-05 00:00:00
# 11401.856450254476
# ['ADP' 'AES' 'AMD' 'AEE' 'AEP' 'AMT' 'AWK' 'ADI' 'AON' 'ATO' 'ADSK' 'AZO'
#  'AVB' 'WRB' 'TECH' 'BSX' 'CZR' 'CPT' 'CDW' 'CRL' 'CMG' 'CHD' 'CTAS' 'CLX'
#  'COO' 'GLW' 'CSX' 'DRI' 'DXCM' 'DG' 'DTE' 'ECL' 'EW' 'ELV' 'EPAM' 'EQR'
#  'ESS' 'ES' 'EXC' 'EXPE' 'FISV' 'FTNT' 'HCA' 'PEAK' 'HES' 'HOLX' 'HRL'
#  'ISRG' 'IQV' 'J' 'KMI' 'LYV' 'MA' 'MTCH' 'MRK' 'MAA' 'MOH' 'MSI' 'NFLX'
#  'NEE' 'NSC' 'NRG' 'ORLY' 'PAYC' 'PKI' 'PG' 'PGR' 'PTC' 'RL' 'O' 'RHI'
#  'ROL' 'ROP' 'SBUX' 'STE' 'SYK' 'SNPS' 'TDY' 'TSCO' 'TT' 'TDG' 'UDR'
#  'ULTA' 'UNP' 'UAL' 'VTR' 'VRSN' 'VRSK' 'WEC' 'WELL' 'XEL' 'ZBRA']
# 2019-03-06 00:00:00
# 11396.905512611027
# ['ADBE' 'ADP' 'AES' 'AMD' 'AEE' 'AEP' 'AWK' 'ADI' 'ATO' 'ADSK' 'TECH' 'BA'
#  'BSX' 'CDNS' 'CZR' 'CDW' 'CRL' 'CHD' 'CMS' 'COP' 'COO' 'CPRT' 'GLW' 'CSX'
#  'ECL' 'ELV' 'EPAM' 'EQR' 'ESS' 'EXC' 'EXPE' 'FE' 'FISV' 'FTNT' 'GRMN'
#  'HCA' 'PEAK' 'HES' 'HOLX' 'INTU' 'ISRG' 'IQV' 'J' 'KEYS' 'KMI' 'MTCH'
#  'MCD' 'MRK' 'MAA' 'MOH' 'MSI' 'NEE' 'NSC' 'NRG' 'ORLY' 'PAYC' 'PYPL' 'PG'
#  'PGR' 'RL' 'RHI' 'ROL' 'ROP' 'ROST' 'CRM' 'SBUX' 'STE' 'SYK' 'SNPS' 'TDY'
#  'TMO' 'TSCO' 'TT' 'TDG' 'UDR' 'ULTA' 'UNP' 'VTR' 'VRSN' 'WEC' 'XEL'
#  'ZBRA']
# 2019-03-07 00:00:00
# 11305.674134623547
# ['ABT' 'ADBE' 'ADP' 'AES' 'LNT' 'AEE' 'AEP' 'AWK' 'ATO' 'ADSK' 'BALL'
#  'TECH' 'BA' 'BSX' 'CDNS' 'CZR' 'CDW' 'CRL' 'CHD' 'CMS' 'COP' 'CPRT' 'CSX'
#  'DHR' 'ECL' 'ELV' 'EPAM' 'EQR' 'ESS' 'EXC' 'FE' 'FTNT' 'GRMN' 'PEAK'
#  'HOLX' 'INTU' 'ISRG' 'IQV' 'J' 'KEYS' 'MTCH' 'MCD' 'MRK' 'MAA' 'MSI'
#  'NEE' 'NKE' 'NSC' 'NRG' 'ORLY' 'PAYC' 'PYPL' 'PNW' 'PG' 'PGR' 'ROST'
#  'CRM' 'NOW' 'SBUX' 'STE' 'SNPS' 'TDY' 'TMO' 'TSCO' 'TT' 'TDG' 'UDR'
#  'ULTA' 'UNP' 'VTR' 'VRSN' 'V' 'WEC' 'XEL' 'ZBRA']
# 2019-03-08 00:00:00
# 11195.961182996898
# ['ABT' 'ADP' 'LNT' 'AEE' 'AEP' 'AWK' 'ATO' 'BALL' 'TECH' 'BA' 'BSX' 'CDNS'
#  'CZR' 'CDW' 'CRL' 'CHD' 'CLX' 'CMS' 'CSX' 'DHR' 'DTE' 'ECL' 'ELV' 'LLY'
#  'ENPH' 'ETR' 'EPAM' 'EQR' 'ESS' 'ETSY' 'ES' 'EXC' 'FE' 'FTNT' 'GRMN'
#  'PEAK' 'HOLX' 'INTU' 'ISRG' 'IQV' 'KEYS' 'MA' 'MTCH' 'MRK' 'MSI' 'MSCI'
#  'NEE' 'NKE' 'NSC' 'NRG' 'ORLY' 'PAYC' 'PYPL' 'PKI' 'PNW' 'PG' 'PGR' 'PEG'
#  'REGN' 'ROST' 'CRM' 'NOW' 'SBUX' 'STE' 'TDY' 'TSCO' 'TDG' 'UDR' 'ULTA'
#  'UNP' 'VTR' 'VRSN' 'VRSK' 'V' 'WEC' 'XEL' 'ZBRA']
# 2019-03-12 00:00:00
# 11409.553236671829
# ['ABT' 'ADP' 'AWK' 'BALL' 'TECH' 'BA' 'BSX' 'CDNS' 'CZR' 'CDW' 'CRL' 'CHD'
#  'CLX' 'CMS' 'CSGP' 'CSX' 'DHR' 'DG' 'DTE' 'ECL' 'ELV' 'LLY' 'ENPH' 'ETR'
#  'EPAM' 'EQR' 'ETSY' 'ES' 'EXC' 'FE' 'FTNT' 'GRMN' 'PEAK' 'HOLX' 'INTU'
#  'ISRG' 'IQV' 'KEYS' 'MA' 'MRK' 'MSI' 'MSCI' 'NEE' 'NKE' 'NSC' 'ORLY'
#  'PAYC' 'PKI' 'PNW' 'PG' 'PGR' 'PEG' 'REGN' 'CRM' 'NOW' 'SBUX' 'STE' 'TDY'
#  'TJX' 'TSCO' 'TDG' 'ULTA' 'UNP' 'VTR' 'VRSN' 'VRSK' 'V' 'ZBRA']
# 2019-03-13 00:00:00
# 11474.980206945987
# ['ABT' 'ADP' 'AZO' 'TECH' 'BSX' 'CDNS' 'CZR' 'CRL' 'CSGP' 'CSX' 'DHR' 'DG'
#  'DTE' 'ECL' 'LLY' 'ENPH' 'EPAM' 'ETSY' 'FTNT' 'GRMN' 'HOLX' 'INTU' 'ISRG'
#  'IQV' 'J' 'KEYS' 'KMI' 'MA' 'MKC' 'MRK' 'MSI' 'MSCI' 'NKE' 'PAYC' 'PGR'
#  'PEG' 'REGN' 'CRM' 'NOW' 'STE' 'TJX' 'TSCO' 'TT' 'TDG' 'ULTA' 'UNP'
#  'VRSN' 'VRSK' 'V']
# 2019-03-14 00:00:00
# 11476.347430652175
# ['ABT' 'ADP' 'AZO' 'TECH' 'BSX' 'CDNS' 'CRL' 'CSGP' 'DHR' 'DTE' 'ECL'
#  'LLY' 'ENPH' 'EPAM' 'ETSY' 'FTNT' 'GRMN' 'HOLX' 'HRL' 'INTU' 'IQV' 'J'
#  'KEYS' 'KMI' 'LYV' 'MA' 'MKC' 'MRK' 'MSI' 'MSCI' 'NKE' 'PYPL' 'PGR' 'PEG'
#  'REGN' 'CRM' 'NOW' 'TMO' 'TJX' 'TSCO' 'TT' 'ULTA']
# 2019-03-15 00:00:00
# 11498.212233325487
# ['ABT' 'ADP' 'AZO' 'TECH' 'BSX' 'CDNS' 'CRL' 'CSGP' 'DHR' 'ECL' 'LLY'
#  'ETSY' 'GRMN' 'HOLX' 'HRL' 'IQV' 'J' 'KEYS' 'KMI' 'LYV' 'MRK' 'MSI'
#  'MSCI' 'NKE' 'ORLY' 'PYPL' 'PKI' 'PEG' 'SBUX' 'TMO' 'TJX' 'TSCO' 'ULTA']
# 2019-03-19 00:00:00
# 11594.713104421504
# ['AZO' 'CDNS' 'CSGP' 'DHR' 'DG' 'LLY' 'ETSY' 'GRMN' 'KEYS' 'KMI' 'LYV'
#  'MSI' 'MSCI' 'ORLY' 'PKI' 'PEG' 'SBUX' 'TJX']
# 2019-03-20 00:00:00
# 11577.477469536441
# ['AES' 'AEE' 'CDNS' 'CLX' 'CMS' 'CSGP' 'DG' 'EQR' 'GRMN' 'PEAK' 'KMI'
#  'LYV' 'O' 'TJX' 'UDR' 'VTR' 'WEC' 'WELL' 'XEL']
# 2019-03-21 00:00:00
# 11598.148039153259
# ['AES' 'AEE' 'AEP' 'AWK' 'ATO' 'BSX' 'CDNS' 'CHD' 'CLX' 'CMS' 'COO' 'CSGP'
#  'DG' 'EQR' 'ES' 'EXC' 'FE' 'GRMN' 'PEAK' 'KMI' 'LYV' 'MKC' 'NI' 'PNW' 'O'
#  'UDR' 'VTR' 'VRSK' 'VZ' 'WEC' 'WELL' 'XEL']
# 2019-03-22 00:00:00
# 11799.794609004064
# ['AES' 'AEE' 'AEP' 'AWK' 'ATO' 'AVB' 'BIO' 'BSX' 'CDNS' 'CPT' 'CHD' 'CLX'
#  'CMS' 'COO' 'CSGP' 'COST' 'DXCM' 'DG' 'DTE' 'ENPH' 'ETR' 'EQR' 'ESS'
#  'ETSY' 'ES' 'EXC' 'FE' 'GRMN' 'PEAK' 'LYV' 'MKC' 'MAA' 'MSI' 'NI' 'PNW'
#  'PEG' 'O' 'UDR' 'VTR' 'VRSK' 'VZ' 'WEC' 'WELL' 'XEL']
# 2019-03-26 00:00:00
# 11816.920362839415
# ['ABT' 'AES' 'AEE' 'AEP' 'AWK' 'ATO' 'AVB' 'BALL' 'BIO' 'BSX' 'CDNS' 'CPT'
#  'CDW' 'CHD' 'CSCO' 'CLX' 'CMS' 'COO' 'CSGP' 'COST' 'CSX' 'DHR' 'DXCM'
#  'DTE' 'ECL' 'ENPH' 'ETR' 'EPAM' 'EQR' 'ESS' 'ETSY' 'ES' 'EXC' 'FE' 'GRMN'
#  'HOLX' 'INTU' 'J' 'KEYS' 'LYV' 'MKC' 'MAA' 'MSI' 'NKE' 'NI' 'NSC' 'NRG'
#  'PAYX' 'PAYC' 'PNW' 'PG' 'PGR' 'PEG' 'O' 'NOW' 'STE' 'SNPS' 'TJX' 'TT'
#  'UDR' 'VTR' 'VRSN' 'VRSK' 'VZ' 'V' 'WEC' 'WELL' 'XEL' 'YUM' 'ZBRA']
# 2019-03-27 00:00:00
# 11835.90989465347
# ['ABT' 'ADP' 'AES' 'AMT' 'AWK' 'AVB' 'BALL' 'BAX' 'BIO' 'TECH' 'BSX'
#  'CDNS' 'CPT' 'CDW' 'CRL' 'CSCO' 'CLX' 'COO' 'CSGP' 'COST' 'CSX' 'DHR'
#  'ECL' 'EW' 'ELV' 'ENPH' 'EPAM' 'EQR' 'ESS' 'ETSY' 'ES' 'EXR' 'FTNT' 'IT'
#  'HOLX' 'INTU' 'ISRG' 'IQV' 'J' 'KEYS' 'KMI' 'LYV' 'MA' 'MTD' 'MSFT' 'MAA'
#  'MSI' 'MSCI' 'NKE' 'NSC' 'NRG' 'PAYX' 'PAYC' 'PYPL' 'PNW' 'PG' 'PGR'
#  'PEG' 'CRM' 'NOW' 'STE' 'SYK' 'SNPS' 'TMO' 'TJX' 'TT' 'TDG' 'ULTA' 'UNP'
#  'VRSN' 'V' 'WAT' 'YUM' 'ZBRA']
# 2019-03-28 00:00:00
# 11795.378451125225
# ['ABT' 'ADP' 'AES' 'AMT' 'AWK' 'AON' 'ANET' 'AZO' 'BALL' 'BAX' 'BIO'
#  'TECH' 'BSX' 'AVGO' 'CDNS' 'CDW' 'CRL' 'CSCO' 'CMCSA' 'COO' 'CSGP' 'COST'
#  'CSX' 'DHR' 'ECL' 'EW' 'ELV' 'ENPH' 'EPAM' 'ESS' 'ETSY' 'ES' 'EXPD' 'EXR'
#  'FLT' 'FTNT' 'IT' 'GPN' 'HOLX' 'INTU' 'ISRG' 'IQV' 'J' 'KEYS' 'KMI' 'LYV'
#  'MA' 'MTCH' 'MTD' 'MSFT' 'MOH' 'MSI' 'MSCI' 'NKE' 'OKE' 'PAYX' 'PAYC'
#  'PYPL' 'PKI' 'PNW' 'PG' 'PGR' 'PEG' 'ROL' 'ROP' 'CRM' 'NOW' 'STE' 'SYK'
#  'SNPS' 'TDY' 'TMO' 'TT' 'TDG' 'ULTA' 'UNP' 'VRSN' 'V' 'WAT' 'WST' 'ZBRA'
#  'ZTS']
# 2019-03-29 00:00:00
# 11917.616478457889
# ['ABT' 'AES' 'A' 'AMZN' 'AMD' 'AEP' 'AMT' 'AWK' 'AON' 'ANET' 'ATO' 'ADSK'
#  'AZO' 'BALL' 'BIO' 'TECH' 'AVGO' 'CDNS' 'CZR' 'CDW' 'CRL' 'CSCO' 'CMCSA'
#  'COO' 'GLW' 'CSGP' 'COST' 'DHR' 'ECL' 'EW' 'ELV' 'ENPH' 'EPAM' 'ETSY'
#  'ES' 'EXPD' 'FLT' 'FTNT' 'IT' 'GPN' 'HOLX' 'INTU' 'ISRG' 'IQV' 'J' 'KEYS'
#  'KMI' 'LIN' 'LYV' 'MA' 'MTCH' 'MRK' 'MTD' 'MSFT' 'MOH' 'MSI' 'MSCI'
#  'NFLX' 'NKE' 'OKE' 'PAYX' 'PAYC' 'PYPL' 'PKI' 'PG' 'ROL' 'ROP' 'CRM'
#  'NOW' 'SYK' 'SNPS' 'TDY' 'TMO' 'TDG' 'ULTA' 'VRSN' 'V' 'WAT' 'WEC' 'WST'
#  'XEL' 'ZBRA' 'ZTS']
# 2019-04-02 00:00:00
# 12089.76027877063
# ['ABT' 'AAP' 'AES' 'A' 'AMZN' 'AMD' 'AEP' 'AMT' 'AWK' 'ANET' 'ATO' 'ADSK'
#  'AZO' 'BALL' 'BIO' 'TECH' 'AVGO' 'CDNS' 'CZR' 'CDW' 'CRL' 'CSCO' 'COO'
#  'GLW' 'CSGP' 'COST' 'DHR' 'ECL' 'EW' 'ELV' 'LLY' 'ENPH' 'EPAM' 'ETSY'
#  'ES' 'FLT' 'FTNT' 'GPN' 'ILMN' 'INTU' 'ISRG' 'IQV' 'KEYS' 'KMI' 'LIN'
#  'LYV' 'MA' 'MTCH' 'MRK' 'MTD' 'MSFT' 'MOH' 'MSCI' 'NFLX' 'NKE' 'NRG'
#  'OKE' 'PAYX' 'PYPL' 'PKI' 'CRM' 'NOW' 'SYK' 'TDY' 'TMO' 'TDG' 'ULTA'
#  'VRSN' 'V' 'WAT' 'WEC' 'XEL' 'ZBRA' 'ZTS']
# 2019-04-03 00:00:00
# 12150.09565333561
# ['AAP' 'AES' 'ALGN' 'AMZN' 'AMD' 'AEE' 'AEP' 'AMT' 'AWK' 'ANET' 'ATO'
#  'BALL' 'BIO' 'AVGO' 'CZR' 'CMG' 'CMS' 'COST' 'DHR' 'DRI' 'DG' 'EW' 'ELV'
#  'LLY' 'ESS' 'ES' 'EXC' 'FE' 'FTNT' 'PEAK' 'IDXX' 'ILMN' 'ISRG' 'KIM'
#  'KMI' 'MTCH' 'MRK' 'MSFT' 'MOH' 'MDLZ' 'MPWR' 'NFLX' 'NRG' 'OKE' 'PYPL'
#  'PGR' 'O' 'CRM' 'NOW' 'SYK' 'TFX' 'TJX' 'VTR' 'VZ' 'WEC' 'WELL' 'XEL'
#  'ZBRA']
# 2019-04-04 00:00:00
# 12141.12257447488
# ['AAP' 'AES' 'ALGN' 'AMZN' 'AMD' 'AEE' 'AEP' 'AMT' 'AWK' 'ANET' 'ATO'
#  'BALL' 'AVGO' 'CZR' 'CMG' 'CLX' 'CMS' 'COST' 'DRI' 'DG' 'EW' 'ELV' 'LLY'
#  'ESS' 'EXC' 'FE' 'PEAK' 'IDXX' 'KIM' 'KMI' 'MTCH' 'MRK' 'MSFT' 'MDLZ'
#  'MPWR' 'NRG' 'OKE' 'PGR' 'O' 'NOW' 'SYK' 'TFX' 'TJX' 'VTR' 'VZ' 'WEC'
#  'WELL' 'XEL']
# 2019-04-05 00:00:00
# 12099.625080873931
# ['AES' 'AEE' 'AEP' 'AMT' 'AWK' 'ATO' 'AVB' 'BALL' 'AVGO' 'CZR' 'CMG' 'CLX'
#  'CMS' 'COST' 'DRI' 'DG' 'EW' 'LLY' 'EXC' 'PEAK' 'KIM' 'KMI' 'MTCH' 'MRK'
#  'NRG' 'OKE' 'PG' 'O' 'NOW' 'SYK' 'UDR' 'ULTA' 'VTR' 'VZ' 'VICI' 'WAT'
#  'WEC' 'WELL' 'XEL']
# 2019-04-09 00:00:00
# 12091.22076097489
# ['ABT' 'AES' 'AEE' 'AEP' 'AMT' 'AWK' 'ATO' 'AVB' 'BALL' 'BAX' 'AVGO' 'CZR'
#  'CMG' 'CHD' 'CMS' 'COO' 'DHR' 'DRI' 'EW' 'LLY' 'EXC' 'PEAK' 'HOLX' 'KIM'
#  'KMI' 'LYV' 'MTCH' 'MKC' 'MRK' 'NRG' 'OKE' 'PAYC' 'PYPL' 'PG' 'O' 'NOW'
#  'SBUX' 'STE' 'SYK' 'SNPS' 'TMO' 'UDR' 'ULTA' 'VTR' 'VZ' 'VICI' 'WAT'
#  'WEC' 'WELL' 'XEL']
# 2019-04-10 00:00:00
# 12143.478613467763
# ['ABT' 'ADBE' 'ADP' 'APD' 'AEE' 'AEP' 'AMT' 'AON' 'ANET' 'AZO' 'AVB'
#  'BALL' 'BAX' 'AVGO' 'CDNS' 'CPT' 'CRL' 'CMG' 'CHD' 'CMS' 'COO' 'CSX'
#  'DHR' 'DRI' 'DOV' 'EW' 'LLY' 'EPAM' 'EQR' 'EXC' 'FAST' 'FISV' 'FLT'
#  'GRMN' 'GPC' 'GPN' 'PEAK' 'HOLX' 'IDXX' 'INCY' 'INTU' 'J' 'KIM' 'KMI'
#  'LYV' 'MA' 'MKC' 'MRK' 'MSI' 'NSC' 'NRG' 'OKE' 'PAYX' 'PAYC' 'PYPL' 'PG'
#  'O' 'REGN' 'ROL' 'ROP' 'NOW' 'SBUX' 'STE' 'SYK' 'SNPS' 'TMO' 'TDG' 'UDR'
#  'ULTA' 'UNP' 'VTR' 'VRSK' 'VZ' 'V' 'WM' 'WAT' 'WEC' 'WELL' 'XEL' 'ZTS']
# 2019-04-11 00:00:00
# 12195.133187430922
# ['ABT' 'ADBE' 'ADP' 'AAP' 'APD' 'AEE' 'AMT' 'AON' 'ACGL' 'ANET' 'AZO'
#  'AVB' 'BALL' 'BAX' 'BSX' 'AVGO' 'CDNS' 'CPT' 'KMX' 'CRL' 'CMG' 'CHD'
#  'CTAS' 'CSCO' 'CMS' 'COO' 'CSGP' 'COST' 'CCI' 'CSX' 'DHR' 'DRI' 'DOV'
#  'EW' 'LLY' 'EPAM' 'EQR' 'ETSY' 'EXC' 'EXPD' 'FDS' 'FAST' 'FISV' 'FLT'
#  'GRMN' 'IT' 'GPC' 'GPN' 'PEAK' 'HSY' 'HOLX' 'IDXX' 'INCY' 'INTU' 'IQV'
#  'J' 'KEYS' 'KIM' 'KMI' 'LYV' 'LOW' 'MA' 'MKC' 'MRK' 'MTD' 'MSFT' 'MSI'
#  'NSC' 'PAYX' 'PAYC' 'PG' 'O' 'REGN' 'ROL' 'ROP' 'SBAC' 'NOW' 'SBUX' 'STE'
#  'SYK' 'SNPS' 'TMO' 'TT' 'TDG' 'UDR' 'ULTA' 'UNP' 'VTR' 'VRSK' 'VZ' 'V'
#  'WM' 'WAT' 'WEC' 'WELL' 'WST' 'ZTS']
# 2019-04-12 00:00:00
# 12214.649701115586
# ['ABT' 'ACN' 'ADBE' 'ADP' 'AAP' 'A' 'AMZN' 'AMD' 'AEE' 'AMT' 'ANSS' 'AON'
#  'ACGL' 'ANET' 'ATO' 'AZO' 'AVB' 'BAX' 'BIO' 'TECH' 'BSX' 'AVGO' 'CDNS'
#  'KMX' 'CRL' 'CMG' 'CHD' 'CTAS' 'CSCO' 'CMS' 'COO' 'CPRT' 'CSGP' 'COST'
#  'CCI' 'CSX' 'DHR' 'DRI' 'DOV' 'ECL' 'EW' 'LLY' 'EPAM' 'ESS' 'ETSY' 'EXC'
#  'EXPD' 'FDS' 'FAST' 'FISV' 'FLT' 'GRMN' 'IT' 'GPC' 'GPN' 'PEAK' 'HSY'
#  'HOLX' 'INCY' 'INTU' 'ISRG' 'IQV' 'J' 'KEYS' 'KIM' 'KMI' 'LIN' 'LYV'
#  'LOW' 'MA' 'MKC' 'MRK' 'MTD' 'MSFT' 'MOH' 'NFLX' 'NKE' 'NSC' 'PAYX'
#  'PAYC' 'PG' 'PTC' 'O' 'ROL' 'ROP' 'CRM' 'SBAC' 'NOW' 'SBUX' 'STE' 'SYK'
#  'SNPS' 'TDY' 'TMO' 'TSCO' 'TT' 'TDG' 'UDR' 'ULTA' 'UNP' 'VTR' 'VRSN'
#  'VRSK' 'VZ' 'V' 'WM' 'WAT' 'WEC' 'WELL' 'WST' 'ZTS']
# 2019-04-16 00:00:00
# 12251.325065055345
# ['ABT' 'ACN' 'ADP' 'AAP' 'A' 'AMZN' 'AMD' 'APH' 'ANSS' 'AON' 'ACGL' 'ANET'
#  'ATO' 'ADSK' 'AZO' 'AVB' 'BAX' 'BIO' 'TECH' 'BSX' 'CDNS' 'KMX' 'CRL'
#  'CMG' 'CHD' 'CTAS' 'CSCO' 'COO' 'CPRT' 'GLW' 'CSGP' 'COST' 'CCI' 'CSX'
#  'DHR' 'DRI' 'DLR' 'DOV' 'ECL' 'EW' 'LLY' 'ENPH' 'EPAM' 'ESS' 'ETSY' 'EXC'
#  'EXPD' 'FDS' 'FAST' 'FRT' 'FISV' 'FLT' 'GRMN' 'IT' 'GPC' 'GPN' 'PEAK'
#  'HSY' 'HOLX' 'INTU' 'ISRG' 'IQV' 'J' 'KEYS' 'KMI' 'LIN' 'LYV' 'LOW' 'MA'
#  'MKC' 'MRK' 'MTD' 'MSFT' 'MAA' 'MOH' 'NFLX' 'NKE' 'NSC' 'ORLY' 'OKE'
#  'PAYX' 'PAYC' 'PYPL' 'PKI' 'PGR' 'PTC' 'O' 'ROL' 'ROP' 'ROST' 'CRM' 'SPG'
#  'SNPS' 'TDY' 'TMO' 'TJX' 'TSCO' 'TT' 'TDG' 'UDR' 'ULTA' 'UNP' 'VTR'
#  'VRSN' 'VRSK' 'VZ' 'V' 'WM' 'WAT' 'WELL' 'WST' 'ZTS']
# 2019-04-17 00:00:00
# 12157.447034741215
# ['ABT' 'AAP' 'AES' 'AMZN' 'AMD' 'AWK' 'APH' 'ADI' 'ADSK' 'AZO' 'BALL'
#  'TECH' 'CDNS' 'KMX' 'CRL' 'CHD' 'CTAS' 'CSCO' 'CPRT' 'GLW' 'COST' 'DHR'
#  'DRI' 'DLR' 'DOV' 'ECL' 'ENPH' 'ETSY' 'EXPD' 'FRT' 'FLT' 'GRMN' 'GPC'
#  'PEAK' 'HSY' 'HOLX' 'INTU' 'ISRG' 'IQV' 'J' 'KEYS' 'KMI' 'LOW' 'MKC'
#  'MRK' 'MSFT' 'MAA' 'NSC' 'ORLY' 'OKE' 'PYPL' 'PKI' 'PGR' 'O' 'RSG' 'ROP'
#  'ROST' 'SPG' 'SNPS' 'TDY' 'TMO' 'TJX' 'TT' 'TDG' 'UDR' 'ULTA' 'UNP'
#  'VRSN' 'VRSK' 'VZ' 'VICI' 'WBD' 'WELL']
# 2019-04-18 00:00:00
# 12018.470177142468
# ['AAP' 'AES' 'AMZN' 'AMD' 'AMT' 'AWK' 'ADI' 'ADSK' 'AZO' 'BALL' 'TECH'
#  'CDNS' 'KMX' 'CRL' 'CHD' 'CPRT' 'GLW' 'COST' 'DHR' 'DRI' 'DG' 'DOV'
#  'ENPH' 'ETSY' 'FLT' 'GRMN' 'HSY' 'ILMN' 'INTU' 'ISRG' 'IQV' 'J' 'KEYS'
#  'KIM' 'KMI' 'LOW' 'MKTX' 'MKC' 'MSCI' 'NSC' 'NRG' 'ORLY' 'PKI' 'O' 'RSG'
#  'ROST' 'SBUX' 'STE' 'SNPS' 'TDY' 'TJX' 'TT' 'TDG' 'UDR' 'ULTA' 'UNP'
#  'UAL' 'VRSN' 'VRSK' 'VICI' 'WBD' 'WEC' 'XEL']
# 2019-04-23 00:00:00
# 12014.01373030798
# ['AAP' 'AES' 'AMZN' 'AMD' 'AEE' 'AEP' 'AMT' 'AWK' 'ADI' 'ACGL' 'ADSK'
#  'AZO' 'BALL' 'TECH' 'CDNS' 'KMX' 'CDW' 'CRL' 'CMG' 'CHD' 'COO' 'CPRT'
#  'GLW' 'CSGP' 'COST' 'DHR' 'DRI' 'DG' 'EW' 'ENPH' 'EQR' 'ETSY' 'EXC' 'FDS'
#  'GRMN' 'IT' 'HSY' 'ILMN' 'INTU' 'IQV' 'J' 'KEYS' 'KIM' 'LOW' 'MKTX' 'MKC'
#  'MTD' 'MSCI' 'NSC' 'NRG' 'ORLY' 'PAYX' 'PKI' 'O' 'ROST' 'CRM' 'SBUX'
#  'STE' 'SNPS' 'TDY' 'TSCO' 'TT' 'UDR' 'ULTA' 'UAL' 'VRSN' 'WBD' 'WEC'
#  'WST' 'XEL']
# 2019-04-24 00:00:00
# 12138.74002543289
# ['ABT' 'AAP' 'AES' 'AEE' 'AEP' 'AMT' 'APH' 'ADI' 'ACGL' 'ANET' 'ADSK'
#  'AZO' 'AVB' 'TECH' 'AVGO' 'CDNS' 'KMX' 'CDW' 'CRL' 'CMG' 'CHD' 'CSCO'
#  'CMCSA' 'COO' 'CPRT' 'GLW' 'CSGP' 'COST' 'DHR' 'DG' 'ECL' 'EW' 'ENPH'
#  'EQR' 'ETSY' 'EXC' 'FDS' 'FTNT' 'GRMN' 'IT' 'HSY' 'ILMN' 'IQV' 'KEYS'
#  'KIM' 'KLAC' 'LOW' 'MKTX' 'MKC' 'MTD' 'MPWR' 'MSCI' 'NRG' 'ORLY' 'PAYX'
#  'PYPL' 'PKI' 'PNW' 'PG' 'PWR' 'O' 'ROST' 'CRM' 'SBAC' 'NOW' 'SBUX' 'STE'
#  'SNPS' 'TDY' 'TMO' 'TSCO' 'TT' 'UDR' 'ULTA' 'VRSN' 'WBD' 'WEC' 'WST'
#  'XEL' 'ZBRA']
# 2019-04-25 00:00:00
# 12160.2214794377
# ['ABT' 'ADP' 'AAP' 'AES' 'AEP' 'AMT' 'APH' 'ADI' 'ACGL' 'ANET' 'ADSK'
#  'AZO' 'AVB' 'TECH' 'AVGO' 'KMX' 'CDW' 'CRL' 'CMG' 'CHD' 'CSCO' 'CMCSA'
#  'COO' 'CPRT' 'GLW' 'CSGP' 'DHR' 'DOV' 'ECL' 'EW' 'ENPH' 'EQR' 'ETSY'
#  'FDS' 'FTNT' 'GRMN' 'IT' 'GNRC' 'HSY' 'ILMN' 'IQV' 'KEYS' 'KIM' 'KLAC'
#  'LIN' 'LOW' 'MKTX' 'MKC' 'MTD' 'MAA' 'MPWR' 'MSCI' 'NRG' 'ORLY' 'PYPL'
#  'PKI' 'PNW' 'PG' 'PWR' 'O' 'ROP' 'ROST' 'CRM' 'SBAC' 'NOW' 'SBUX' 'STE'
#  'TDY' 'TXN' 'TMO' 'TSCO' 'TT' 'UDR' 'VRSN' 'VICI' 'WBD' 'WELL' 'WST'
#  'WTW' 'XEL' 'ZBRA']
# 2019-04-26 00:00:00
# 12183.004779005681
# ['ADP' 'AAP' 'AES' 'AMT' 'APH' 'ADI' 'ACGL' 'ANET' 'ADSK' 'AZO' 'AVB'
#  'TECH' 'AVGO' 'CZR' 'KMX' 'CDW' 'CMG' 'CHD' 'CSCO' 'CMCSA' 'COO' 'CPRT'
#  'GLW' 'CSGP' 'DIS' 'DOV' 'ECL' 'EW' 'EQR' 'EXPD' 'FDS' 'FAST' 'FE' 'FTNT'
#  'FTV' 'GRMN' 'IT' 'GNRC' 'ILMN' 'KEYS' 'LIN' 'LOW' 'MKTX' 'MKC' 'MTD'
#  'MAA' 'MDLZ' 'MPWR' 'MSCI' 'NKE' 'NRG' 'ORLY' 'PYPL' 'PKI' 'PG' 'PWR'
#  'REG' 'ROP' 'ROST' 'SBAC' 'SBUX' 'TDY' 'TXN' 'TMO' 'TSCO' 'TT' 'UDR'
#  'UAL' 'VRSN' 'VICI' 'V' 'WBD' 'WELL' 'WTW' 'ZBRA']
# 2019-04-30 00:00:00
# 12242.70658699294
# ['ADP' 'AAP' 'AES' 'AMT' 'AME' 'ADI' 'ANET' 'AZO' 'AVGO' 'CZR' 'KMX' 'CDW'
#  'CMG' 'CHD' 'CSCO' 'CMCSA' 'COO' 'CPRT' 'GLW' 'CSGP' 'COST' 'CSX' 'DE'
#  'DIS' 'DG' 'DOV' 'ECL' 'EW' 'EQR' 'EXPE' 'EXPD' 'FAST' 'FE' 'FTNT' 'FTV'
#  'GRMN' 'IT' 'GNRC' 'ILMN' 'KEYS' 'KMB' 'LOW' 'MKTX' 'MKC' 'MTD' 'MDLZ'
#  'MPWR' 'MSCI' 'NKE' 'NRG' 'ORLY' 'PYPL' 'PEP' 'PKI' 'PG' 'PGR' 'PWR'
#  'REG' 'ROP' 'ROST' 'SBAC' 'TDY' 'TSCO' 'TT' 'UAL' 'VRSK' 'V' 'WM' 'WTW'
#  'ZBRA']
# 2019-05-01 00:00:00
# 12302.905697880053
# ['ADP' 'AAP' 'AES' 'AMD' 'AME' 'ADI' 'AAPL' 'AZO' 'AVGO' 'CZR' 'KMX' 'CDW'
#  'CMG' 'CSCO' 'COST' 'CSX' 'DE' 'DIS' 'DG' 'DOV' 'ECL' 'EXPE' 'EXPD'
#  'FAST' 'FTNT' 'FTV' 'IT' 'GNRC' 'ILMN' 'INTU' 'J' 'KEYS' 'KMB' 'LYV'
#  'LOW' 'MTCH' 'MPWR' 'MSI' 'MSCI' 'NKE' 'ORLY' 'PEP' 'PG' 'PGR' 'PWR'
#  'QCOM' 'ROST' 'SHW' 'TMUS' 'TDY' 'TJX' 'TSCO' 'ULTA' 'UNP' 'UAL' 'VRSK'
#  'WM' 'ZBRA']
# 2019-05-02 00:00:00
# 12121.256963395055
# ['ADP' 'AES' 'AMZN' 'AMD' 'ADI' 'AON' 'AAPL' 'AZO' 'AVGO' 'KMX' 'CDW'
#  'CMG' 'CTAS' 'CSCO' 'COST' 'CSX' 'DE' 'DIS' 'DG' 'DOV' 'ECL' 'EXPD'
#  'FAST' 'FTNT' 'GNRC' 'ILMN' 'INTU' 'J' 'KEYS' 'KMB' 'KMI' 'LYV' 'LOW'
#  'MTCH' 'MPWR' 'MSI' 'MSCI' 'NKE' 'NSC' 'ORLY' 'PEP' 'POOL' 'PWR' 'QCOM'
#  'RL' 'ROST' 'SHW' 'TMUS' 'TDY' 'TJX' 'TSCO' 'ULTA' 'UNP' 'UAL' 'WM'
#  'ZBRA']
# 2019-05-03 00:00:00
# 12227.384233577506
# ['ADP' 'AES' 'AMZN' 'AMD' 'ADI' 'AON' 'ADSK' 'AZO' 'BALL' 'AVGO' 'KMX'
#  'CDAY' 'CTAS' 'CSCO' 'CMCSA' 'CPRT' 'COST' 'CSX' 'DRI' 'DE' 'DIS' 'DG'
#  'DOV' 'ECL' 'EPAM' 'EL' 'EXPD' 'FAST' 'FLT' 'FTNT' 'GRMN' 'GPN' 'HON'
#  'ILMN' 'INTU' 'J' 'KEYS' 'KMB' 'KMI' 'LYV' 'LOW' 'MTCH' 'MCD' 'MSFT'
#  'MPWR' 'MSI' 'MSCI' 'NFLX' 'NKE' 'NSC' 'ORLY' 'PAYX' 'PEP' 'POOL' 'PWR'
#  'QCOM' 'RL' 'ROST' 'SHW' 'TMUS' 'TDY' 'TJX' 'TSCO' 'TDG' 'ULTA' 'UNP'
#  'UAL' 'V' 'WM' 'WTW' 'YUM' 'ZBRA']
# 2019-05-07 00:00:00
# 12102.976678931263
# ['ADP' 'AES' 'AMZN' 'AMD' 'AWK' 'AME' 'AON' 'AJG' 'ADSK' 'BALL' 'CZR'
#  'KMX' 'CDAY' 'CSCO' 'CMCSA' 'CPRT' 'COST' 'CSX' 'DRI' 'DE' 'DIS' 'DG'
#  'ECL' 'EPAM' 'EL' 'EXC' 'EXPD' 'FAST' 'FLT' 'FTNT' 'GRMN' 'IT' 'GPN'
#  'HAS' 'HON' 'INTU' 'J' 'KEYS' 'KMB' 'KMI' 'LYV' 'LOW' 'MA' 'MTCH' 'MCD'
#  'MSFT' 'MPWR' 'MCO' 'MSI' 'MSCI' 'NFLX' 'NKE' 'NSC' 'ORLY' 'ORCL' 'PAYX'
#  'PEP' 'POOL' 'PGR' 'QCOM' 'RL' 'RTX' 'ROST' 'CRM' 'SHW' 'SNPS' 'TDY'
#  'TJX' 'TSCO' 'TDG' 'ULTA' 'UNP' 'UAL' 'VFC' 'V' 'WBD' 'WM' 'WTW' 'YUM'
#  'ZBRA']
# 2019-05-08 00:00:00
# 11987.434963327725
# ['ABT' 'ADP' 'APD' 'ALGN' 'AMZN' 'AMD' 'AEE' 'AEP' 'AMT' 'AWK' 'AME' 'AON'
#  'AJG' 'ADSK' 'WRB' 'CDNS' 'CZR' 'KMX' 'CDAY' 'CRL' 'CHTR' 'CHD' 'CINF'
#  'CMCSA' 'CPRT' 'COST' 'CSX' 'DHR' 'DRI' 'DIS' 'DG' 'ECL' 'EPAM' 'EL'
#  'ETSY' 'EXC' 'FAST' 'FLT' 'FTNT' 'GRMN' 'IT' 'GPN' 'HAS' 'HSY' 'HON'
#  'INTU' 'IQV' 'J' 'KMI' 'LYV' 'LOW' 'MA' 'MTCH' 'MCD' 'MSFT' 'MCO' 'MSI'
#  'MSCI' 'NSC' 'ORCL' 'PAYX' 'PAYC' 'PYPL' 'PEP' 'POOL' 'PGR' 'QCOM' 'RTX'
#  'ROP' 'ROST' 'CRM' 'NOW' 'SBUX' 'STE' 'SNPS' 'TER' 'TJX' 'TSCO' 'TDG'
#  'ULTA' 'UNP' 'VRSN' 'VRSK' 'VFC' 'VICI' 'V' 'WBD' 'WM' 'WST' 'YUM' 'ZBRA'
#  'ZTS']
# 2019-05-09 00:00:00
# 11948.59710482071
# ['ABT' 'ADP' 'APD' 'ALGN' 'ALLE' 'AMZN' 'AMD' 'AEE' 'AEP' 'AMT' 'AWK'
#  'ADI' 'AON' 'ACGL' 'AJG' 'ADSK' 'AZO' 'WRB' 'AVGO' 'CDNS' 'KMX' 'CDAY'
#  'CRL' 'CHTR' 'CHD' 'CINF' 'CTAS' 'CMS' 'CMCSA' 'CPRT' 'CSGP' 'COST' 'CSX'
#  'DHR' 'DRI' 'DIS' 'DG' 'DOV' 'DTE' 'ECL' 'EPAM' 'EL' 'ETSY' 'ES' 'FDS'
#  'FAST' 'FE' 'FLT' 'FTNT' 'GRMN' 'GPN' 'HSY' 'HOLX' 'HON' 'INTU' 'IQV' 'J'
#  'KMI' 'LYV' 'LOW' 'MKTX' 'MA' 'MCD' 'MRK' 'MTD' 'MSFT' 'MSI' 'MSCI' 'NSC'
#  'PAYX' 'PAYC' 'PYPL' 'PEP' 'POOL' 'PG' 'PGR' 'QCOM' 'RSG' 'ROP' 'CRM'
#  'NOW' 'SBUX' 'STE' 'SNPS' 'TER' 'TMO' 'TJX' 'TSCO' 'TDG' 'UDR' 'ULTA'
#  'UNP' 'VRSN' 'VRSK' 'VFC' 'VICI' 'V' 'WBD' 'WM' 'WEC' 'WST' 'XEL' 'YUM'
#  'ZBRA' 'ZTS']
# 2019-05-10 00:00:00
# 11982.802249973405
# ['ABT' 'ADP' 'APD' 'ALGN' 'ALLE' 'AMD' 'AEE' 'AEP' 'AMT' 'AWK' 'ADI' 'AON'
#  'ACGL' 'ADSK' 'AZO' 'WRB' 'TECH' 'AVGO' 'CDNS' 'KMX' 'CDW' 'CDAY' 'CRL'
#  'CHTR' 'CHD' 'CINF' 'CTAS' 'CMS' 'CMCSA' 'COO' 'CPRT' 'CSGP' 'COST' 'CSX'
#  'DHR' 'DRI' 'DIS' 'DG' 'DOV' 'DTE' 'ECL' 'ETR' 'EPAM' 'ETSY' 'ES' 'FDS'
#  'FAST' 'FE' 'FTNT' 'GRMN' 'GIS' 'GPN' 'PEAK' 'HSY' 'HOLX' 'HON' 'IQV'
#  'KMB' 'LYV' 'LOW' 'MKTX' 'MA' 'MCD' 'MRK' 'MTD' 'MSFT' 'MDLZ' 'MNST'
#  'MSI' 'MSCI' 'NKE' 'NSC' 'PAYX' 'PAYC' 'PYPL' 'PEP' 'PKI' 'POOL' 'PG'
#  'QCOM' 'RSG' 'ROP' 'CRM' 'SRE' 'NOW' 'SBUX' 'STE' 'SNPS' 'TMUS' 'TER'
#  'TMO' 'TJX' 'TSCO' 'TT' 'TDG' 'UDR' 'UNP' 'VRSN' 'VRSK' 'VFC' 'V' 'WBD'
#  'WM' 'WEC' 'WST' 'XEL' 'ZBRA' 'ZTS']
# 2019-05-14 00:00:00
# 11912.766783534564
# ['ABT' 'APD' 'ALLE' 'AEE' 'AEP' 'AWK' 'AON' 'ACGL' 'ADSK' 'AZO' 'WRB'
#  'TECH' 'AVGO' 'CDNS' 'KMX' 'CDW' 'CDAY' 'CRL' 'CHTR' 'CHD' 'CINF' 'CTAS'
#  'CMS' 'CMCSA' 'COO' 'CPRT' 'CSGP' 'CSX' 'DHR' 'DIS' 'DG' 'DOV' 'DTE'
#  'ECL' 'ETR' 'EPAM' 'EQR' 'ETSY' 'ES' 'EXC' 'FDS' 'FAST' 'FE' 'FTNT' 'GIS'
#  'GPN' 'PEAK' 'HSY' 'HON' 'HWM' 'IQV' 'KMB' 'LOW' 'MKTX' 'MA' 'MRK' 'MTD'
#  'MSFT' 'MDLZ' 'MNST' 'MSCI' 'NKE' 'NSC' 'PAYC' 'PYPL' 'PEP' 'PKI' 'PNW'
#  'POOL' 'PG' 'QCOM' 'O' 'RSG' 'ROP' 'CRM' 'SRE' 'NOW' 'SBUX' 'STE' 'SNPS'
#  'TMUS' 'TER' 'TMO' 'TJX' 'TSCO' 'TT' 'TDG' 'UDR' 'UNP' 'VRSN' 'VRSK' 'V'
#  'WMT' 'WM' 'WST' 'ZTS']
# 2019-05-15 00:00:00
# 11928.348939949481
# ['ABT' 'APD' 'ALLE' 'ACGL' 'AJG' 'ADSK' 'AZO' 'AVB' 'WRB' 'TECH' 'AVGO'
#  'CDNS' 'CDW' 'CHTR' 'CMG' 'CHD' 'CINF' 'CTAS' 'CMCSA' 'COO' 'CSGP' 'CSX'
#  'DHR' 'DIS' 'DG' 'DOV' 'ECL' 'EW' 'ENPH' 'ETR' 'EPAM' 'EQIX' 'EQR' 'EXC'
#  'FDS' 'FAST' 'FE' 'FTNT' 'GPN' 'HWM' 'IQV' 'J' 'KEYS' 'KMB' 'KIM' 'LOW'
#  'MKTX' 'MA' 'MTD' 'MSFT' 'MDLZ' 'MNST' 'MSCI' 'NSC' 'PAYC' 'PYPL' 'PEP'
#  'PNW' 'POOL' 'QCOM' 'O' 'RSG' 'ROP' 'CRM' 'NOW' 'SBUX' 'STE' 'SNPS'
#  'TMUS' 'TDY' 'TER' 'TMO' 'TJX' 'TSCO' 'TT' 'TDG' 'UNP' 'VRSN' 'VRSK' 'V'
#  'WMT' 'WST' 'YUM' 'ZTS']
# 2019-05-16 00:00:00
# 12077.438480454357
# ['ABT' 'APD' 'ALLE' 'AMD' 'ACGL' 'AJG' 'ADSK' 'AZO' 'AVB' 'BALL' 'WRB'
#  'TECH' 'AVGO' 'CDNS' 'CDW' 'CHTR' 'CMG' 'CHD' 'CINF' 'CTAS' 'CMCSA' 'COO'
#  'CSGP' 'CSX' 'DHR' 'DIS' 'DG' 'DOV' 'ECL' 'EW' 'ENPH' 'ETR' 'EPAM' 'EQIX'
#  'FDS' 'FAST' 'FE' 'GPN' 'HWM' 'IQV' 'J' 'KEYS' 'KMB' 'KIM' 'LDOS' 'LOW'
#  'MKTX' 'MA' 'MCD' 'MTD' 'MSFT' 'MDLZ' 'MNST' 'MSCI' 'NSC' 'PAYX' 'PAYC'
#  'PYPL' 'POOL' 'QCOM' 'RSG' 'ROP' 'CRM' 'NOW' 'SBUX' 'STE' 'SNPS' 'TMUS'
#  'TDY' 'TER' 'TMO' 'TJX' 'TSCO' 'TT' 'TDG' 'ULTA' 'UNP' 'VRSN' 'VRSK'
#  'WST' 'YUM' 'ZTS']
# 2019-05-17 00:00:00
# 12085.886026590259
# ['ABT' 'APD' 'ALLE' 'AMZN' 'AMD' 'ACGL' 'AJG' 'AZO' 'BALL' 'WRB' 'TECH'
#  'BSX' 'AVGO' 'CDNS' 'CDW' 'CRL' 'CHTR' 'CMG' 'CINF' 'CTAS' 'CMCSA' 'COO'
#  'CSX' 'DHR' 'DRI' 'DG' 'DOV' 'ECL' 'EW' 'ENPH' 'EPAM' 'EQIX' 'ETSY' 'FDS'
#  'FAST' 'FE' 'HON' 'HWM' 'IDXX' 'J' 'KEYS' 'KIM' 'LDOS' 'MKTX' 'MCD' 'MRK'
#  'MTD' 'MNST' 'MSCI' 'NSC' 'PAYX' 'PAYC' 'POOL' 'QCOM' 'RSG' 'ROP' 'CRM'
#  'NOW' 'SBUX' 'STE' 'TMUS' 'TDY' 'TER' 'TMO' 'TJX' 'TSCO' 'TT' 'TDG'
#  'ULTA' 'UNP' 'VRSN' 'VRSK' 'WST' 'YUM' 'ZTS']
# 2019-05-21 00:00:00
# 12099.59409227185
# ['ALLE' 'AMZN' 'ATO' 'AZO' 'BALL' 'TECH' 'BSX' 'AVGO' 'CDNS' 'CDW' 'CRL'
#  'CMG' 'CINF' 'CTAS' 'COO' 'CSX' 'DHR' 'DRI' 'DG' 'DOV' 'EW' 'ENPH' 'EQIX'
#  'ETSY' 'FDS' 'HON' 'HWM' 'IDXX' 'KEYS' 'KIM' 'LHX' 'LDOS' 'LYV' 'MKC'
#  'MCD' 'MRK' 'MTD' 'MNST' 'MSCI' 'PAYC' 'POOL' 'QCOM' 'TDY' 'TER' 'TMO'
#  'TJX' 'TT' 'TDG' 'ULTA' 'UNP' 'VRSK' 'WST']
# 2019-05-22 00:00:00
# 12087.234173445786
# ['ATO' 'BALL' 'CDNS' 'CPRT' 'CCI' 'DHR' 'EW' 'ENPH' 'EQIX' 'HSIC' 'HWM'
#  'IDXX' 'KIM' 'LHX' 'LDOS' 'LYV' 'MTCH' 'MKC' 'MCD' 'MNST' 'QCOM' 'SBAC'
#  'SNPS' 'TT' 'TDG']
# 2019-05-23 00:00:00
# 12078.262998284861
# ['APD' 'AMT' 'BALL' 'CDNS' 'CPRT' 'CCI' 'EW' 'ENPH' 'EQIX' 'HSIC' 'IDXX'
#  'J' 'KIM' 'LHX' 'LDOS' 'LYV' 'MTCH' 'MKC' 'MCD' 'MDLZ' 'MNST' 'QCOM'
#  'RSG' 'SBAC' 'NOW' 'SBUX' 'SNPS' 'TDG']
# 2019-05-24 00:00:00
# 12141.738776008064
# ['APD' 'ALLE' 'AMD' 'AEE' 'AMT' 'AWK' 'AON' 'BALL' 'WRB' 'CDNS' 'CHTR'
#  'CMG' 'CMS' 'CCI' 'DRI' 'ENPH' 'EQIX' 'PEAK' 'HSIC' 'HSY' 'IDXX' 'J'
#  'KMI' 'LDOS' 'LYV' 'MTCH' 'MKC' 'MCD' 'MDLZ' 'MNST' 'PEP' 'PNW' 'POOL'
#  'PG' 'RSG' 'SBAC' 'NOW' 'SO' 'SBUX' 'SNPS' 'TDG' 'VTR' 'WELL']
# 2019-05-29 00:00:00
# 12011.677519043018
# ['APD' 'ALLE' 'AMD' 'AEE' 'AMT' 'AWK' 'AON' 'BALL' 'WRB' 'CDNS' 'CHTR'
#  'CMG' 'CMS' 'CCI' 'DRI' 'DIS' 'ENPH' 'EQIX' 'FLT' 'PEAK' 'HSIC' 'HSY'
#  'KMI' 'LDOS' 'MKTX' 'MTCH' 'MAA' 'MDLZ' 'MNST' 'PYPL' 'PEP' 'PNW' 'POOL'
#  'PG' 'RSG' 'ROP' 'SBAC' 'NOW' 'SO' 'SBUX' 'SNPS' 'TT' 'TDG' 'VTR' 'WELL']
# 2019-05-30 00:00:00
# 11979.195585536376
# ['ADP' 'APD' 'ALLE' 'AEE' 'AEP' 'AMT' 'AWK' 'AON' 'ACGL' 'AJG' 'ADSK'
#  'AVB' 'BALL' 'WRB' 'TECH' 'CDNS' 'CDW' 'CDAY' 'CHTR' 'CMG' 'CHD' 'CINF'
#  'CTAS' 'CSCO' 'CMS' 'CMCSA' 'COO' 'CSGP' 'COST' 'CCI' 'DHR' 'DRI' 'DIS'
#  'DTE' 'ETR' 'EPAM' 'EQIX' 'EQR' 'ESS' 'ES' 'FDS' 'FE' 'FISV' 'FLT' 'GRMN'
#  'GPN' 'PEAK' 'HSY' 'HWM' 'KMB' 'KMI' 'LHX' 'LDOS' 'MKTX' 'MMC' 'MA'
#  'MTCH' 'MSFT' 'MAA' 'MDLZ' 'MNST' 'MSI' 'MSCI' 'NEE' 'NSC' 'PAYX' 'PAYC'
#  'PYPL' 'PEP' 'POOL' 'PG' 'PGR' 'O' 'RSG' 'ROP' 'SBAC' 'SRE' 'NOW' 'SBUX'
#  'STE' 'SNPS' 'TMUS' 'TSCO' 'TT' 'UDR' 'ULTA' 'VRSN' 'VRSK' 'VZ' 'V' 'WM'
#  'WEC' 'WELL' 'XEL' 'YUM' 'ZTS']
# 2019-05-31 00:00:00
# 11951.49814330366
# ['ADP' 'APD' 'ALLE' 'AEE' 'AEP' 'AMT' 'AWK' 'AON' 'ACGL' 'AJG' 'ADSK'
#  'AVB' 'BALL' 'WRB' 'TECH' 'CDNS' 'CDW' 'CDAY' 'CHTR' 'CMG' 'CHD' 'CINF'
#  'CTAS' 'CSCO' 'CMS' 'CMCSA' 'COO' 'CSGP' 'COST' 'CCI' 'DHR' 'DRI' 'DIS'
#  'DTE' 'ECL' 'ETR' 'EPAM' 'EQIX' 'EQR' 'ESS' 'ETSY' 'ES' 'FDS' 'FE' 'FISV'
#  'FLT' 'GRMN' 'GPN' 'PEAK' 'HSY' 'HWM' 'KMB' 'KMI' 'LHX' 'LDOS' 'LYV'
#  'MKTX' 'MMC' 'MA' 'MTCH' 'MKC' 'MCD' 'MRK' 'MSFT' 'MAA' 'MDLZ' 'MSI'
#  'MSCI' 'NEE' 'NSC' 'PAYX' 'PAYC' 'PYPL' 'PEP' 'POOL' 'PG' 'PGR' 'O' 'RSG'
#  'ROP' 'CRM' 'SBAC' 'SRE' 'NOW' 'SBUX' 'STE' 'SNPS' 'TMUS' 'TSCO' 'TT'
#  'UDR' 'ULTA' 'VRSN' 'VRSK' 'VZ' 'V' 'WM' 'WEC' 'WELL' 'WST' 'XEL' 'YUM'
#  'ZTS']
# 2019-06-04 00:00:00
# 12066.095360630576
# ['ADP' 'APD' 'ALLE' 'AEE' 'AEP' 'AWK' 'AON' 'ACGL' 'AJG' 'ADSK' 'AVB'
#  'BALL' 'WRB' 'TECH' 'CDW' 'CDAY' 'CHTR' 'CMG' 'CHD' 'CINF' 'CTAS' 'CSCO'
#  'CMS' 'CMCSA' 'COO' 'CSGP' 'COST' 'DRI' 'XRAY' 'DIS' 'DTE' 'ECL' 'ENPH'
#  'EQIX' 'ESS' 'ETSY' 'ES' 'FDS' 'FLT' 'PEAK' 'HSY' 'HWM' 'INTU' 'KMB'
#  'LHX' 'LDOS' 'LYV' 'MKTX' 'MA' 'MTCH' 'MKC' 'MCD' 'MRK' 'MSFT' 'MAA'
#  'MDLZ' 'MSI' 'MSCI' 'NSC' 'PAYX' 'PAYC' 'PYPL' 'PEP' 'POOL' 'PG' 'PGR'
#  'O' 'RSG' 'ROP' 'CRM' 'SRE' 'NOW' 'SBUX' 'STE' 'TMUS' 'TSCO' 'TT' 'UDR'
#  'ULTA' 'VRSN' 'VRSK' 'V' 'WMT' 'WM' 'WEC' 'WELL' 'WST' 'XEL' 'ZTS']
# 2019-06-05 00:00:00
# 12232.924355200008
# ['AEE' 'AEP' 'AWK' 'ACGL' 'AZO' 'BSX' 'CDW' 'CDAY' 'CMG' 'CINF' 'CTAS'
#  'CSCO' 'CMS' 'CMCSA' 'CSGP' 'COST' 'DRI' 'XRAY' 'D' 'DTE' 'ELV' 'ENPH'
#  'ETSY' 'ES' 'EXC' 'FDS' 'FLT' 'PEAK' 'HSIC' 'HSY' 'HWM' 'INTU' 'IQV'
#  'KMB' 'LHX' 'LDOS' 'LIN' 'LYV' 'MA' 'MTCH' 'MRK' 'MSFT' 'MDLZ' 'MNST'
#  'MSI' 'NSC' 'PAYX' 'PAYC' 'PYPL' 'PEP' 'PNW' 'PG' 'PGR' 'O' 'RSG' 'ROP'
#  'SRE' 'NOW' 'SO' 'STE' 'TMUS' 'TMO' 'TSCO' 'ULTA' 'VRSN' 'VRSK' 'V' 'WMT'
#  'WEC' 'WELL' 'WST' 'XEL']
# 2019-06-06 00:00:00
# 12387.762621740136
# ['LNT' 'AEE' 'AEP' 'AWK' 'AZO' 'BSX' 'CDAY' 'CINF' 'CSCO' 'CMCSA' 'ED'
#  'CSGP' 'COST' 'DRI' 'D' 'DTE' 'ELV' 'ENPH' 'ETR' 'EQR' 'ETSY' 'EXC' 'FLT'
#  'GIS' 'PEAK' 'HSIC' 'INTU' 'IQV' 'LIN' 'MA' 'MTCH' 'MRK' 'MSFT' 'MNST'
#  'NEE' 'PAYX' 'PYPL' 'PNW' 'PGR' 'SRE' 'NOW' 'SO' 'STE' 'TMUS' 'TMO' 'WEC'
#  'WELL' 'XEL']
# 2019-06-07 00:00:00
# 12512.368357041501
# ['LNT' 'CDAY' 'CMCSA' 'ED' 'CPRT' 'D' 'ENPH' 'ETR' 'EQIX' 'EQR' 'ETSY'
#  'FLT' 'GIS' 'PEAK' 'INTU' 'MRK' 'NEE' 'SRE' 'TMUS' 'WELL']
# 2019-06-11 00:00:00
# 12606.228526739575
# ['CDAY' 'CPRT' 'ENPH' 'EQIX' 'ETSY' 'FLT' 'PEAK' 'INTU']
# 2019-06-12 00:00:00
# 12580.950983317722
# ['AMT' 'CPRT' 'ELV' 'ENPH' 'PEAK']
# 2019-06-13 00:00:00
# 12683.458830205887
# ['AMT' 'ACGL' 'CHD' 'CPRT' 'DG' 'ELV' 'PEAK' 'LHX' 'MOH' 'PGR' 'SBAC'
#  'WELL']
# 2019-06-14 00:00:00
# 12687.119913136825
# ['AMT' 'AWK' 'ACGL' 'AJG' 'CHD' 'CLX' 'ED' 'CPRT' 'CCI' 'DG' 'ES' 'PEAK'
#  'HSY' 'KMI' 'LHX' 'MKTX' 'MKC' 'MOH' 'MSI' 'NSC' 'PNW' 'PGR' 'O' 'RSG'
#  'SBAC' 'WM' 'WELL' 'YUM']
# 2019-06-18 00:00:00
# 12779.085901244782
# ['AFL' 'APD' 'AMD' 'AEE' 'AEP' 'AMT' 'AWK' 'AON' 'ACGL' 'AJG' 'AVB' 'BALL'
#  'TECH' 'BSX' 'CHTR' 'CHD' 'CINF' 'CLX' 'CMS' 'ED' 'COO' 'CPRT' 'CCI' 'DG'
#  'DTE' 'ECL' 'ES' 'GPN' 'HSY' 'HWM' 'KMI' 'LHX' 'LDOS' 'MKTX' 'MKC' 'MAA'
#  'MOH' 'MSI' 'MSCI' 'NSC' 'ORLY' 'PNW' 'PGR' 'O' 'RSG' 'SBAC' 'SO' 'TMUS'
#  'TSCO' 'TT' 'WM' 'WELL' 'YUM' 'ZTS']
# 2019-06-19 00:00:00
# 12735.477028330839
# ['ABT' 'ADP' 'AES' 'AFL' 'APD' 'ALLE' 'LNT' 'AMD' 'AEE' 'AEP' 'AXP' 'AMT'
#  'AWK' 'AON' 'ACGL' 'AJG' 'ATO' 'AZO' 'AVB' 'BALL' 'WRB' 'TECH' 'BSX'
#  'CZR' 'CDW' 'CHTR' 'CHD' 'CINF' 'CTAS' 'CSCO' 'CMS' 'COO' 'CPRT' 'CSGP'
#  'CCI' 'DHR' 'DRI' 'XRAY' 'DG' 'DOV' 'DTE' 'ECL' 'EW' 'ETR' 'EPAM' 'EQIX'
#  'EQR' 'ESS' 'ES' 'FDS' 'FAST' 'FSLR' 'FE' 'GRMN' 'GPN' 'HSIC' 'HSY'
#  'HOLX' 'HON' 'HWM' 'INTU' 'INVH' 'J' 'KEYS' 'KMB' 'KMI' 'LHX' 'LDOS'
#  'LIN' 'MKTX' 'MA' 'MTCH' 'MKC' 'MCD' 'MRK' 'MTD' 'MSFT' 'MAA' 'MOH'
#  'MDLZ' 'MSI' 'MSCI' 'NEE' 'NSC' 'ORLY' 'PAYX' 'PAYC' 'PKI' 'PNW' 'POOL'
#  'PGR' 'PLD' 'O' 'RSG' 'ROP' 'SBAC' 'SEDG' 'SO' 'SBUX' 'STE' 'SNPS' 'TMUS'
#  'TDY' 'TMO' 'TSCO' 'TT' 'TDG' 'TRMB' 'UDR' 'VRSN' 'VRSK' 'V' 'WMT' 'WM'
#  'WEC' 'WELL' 'WTW' 'XEL' 'YUM' 'ZBRA' 'ZTS']
# 2019-06-20 00:00:00
# 12927.065421642752
# ['ABT' 'ADP' 'AES' 'AFL' 'APD' 'ALLE' 'LNT' 'AMD' 'AEE' 'AEP' 'AXP' 'AMT'
#  'AWK' 'AON' 'ACGL' 'AJG' 'ATO' 'AZO' 'AVB' 'BALL' 'WRB' 'TECH' 'BSX'
#  'CZR' 'CTLT' 'CDW' 'CHTR' 'CMG' 'CHD' 'CINF' 'CTAS' 'CSCO' 'CMS' 'COO'
#  'CPRT' 'CSGP' 'COST' 'CCI' 'CMI' 'DHR' 'DRI' 'XRAY' 'DG' 'DOV' 'DTE'
#  'ECL' 'EW' 'ETR' 'EPAM' 'EQIX' 'EQR' 'ESS' 'ES' 'EXC' 'FDS' 'FAST' 'FSLR'
#  'FE' 'GRMN' 'GNRC' 'GPN' 'HCA' 'HSIC' 'HSY' 'HOLX' 'HON' 'HWM' 'IDXX'
#  'ILMN' 'INTU' 'INVH' 'J' 'KEYS' 'KMB' 'KMI' 'LHX' 'LDOS' 'LIN' 'MKTX'
#  'MA' 'MTCH' 'MKC' 'MCD' 'MRK' 'MTD' 'MSFT' 'MAA' 'MOH' 'MDLZ' 'MSI'
#  'MSCI' 'NEE' 'NSC' 'ORLY' 'PAYX' 'PAYC' 'PYPL' 'PEP' 'PKI' 'PFE' 'PNW'
#  'POOL' 'PG' 'PGR' 'PLD' 'O' 'RSG' 'ROP' 'SEDG' 'SO' 'SBUX' 'STE' 'SNPS'
#  'TDY' 'TMO' 'TSCO' 'TT' 'TDG' 'TRMB' 'UDR' 'VRSN' 'VRSK' 'V' 'WMT' 'WM'
#  'WEC' 'WELL' 'WTW' 'XEL' 'YUM' 'ZBRA' 'ZTS']
# 2019-06-21 00:00:00
# 12899.848041580255
# ['ABT' 'ADP' 'AES' 'AFL' 'APD' 'ALLE' 'AXP' 'AWK' 'AME' 'AON' 'AJG' 'AZO'
#  'AVB' 'BALL' 'TECH' 'BSX' 'CTLT' 'CDW' 'CHTR' 'CMG' 'CHD' 'CTAS' 'CSCO'
#  'CLX' 'COO' 'CPRT' 'CSGP' 'COST' 'CCI' 'CSX' 'CMI' 'DHR' 'DRI' 'XRAY'
#  'DG' 'DLTR' 'DOV' 'ECL' 'EW' 'EPAM' 'EQIX' 'EQR' 'ESS' 'ETSY' 'ES' 'EXC'
#  'FDS' 'FAST' 'FSLR' 'FE' 'FISV' 'GRMN' 'GNRC' 'GPN' 'HCA' 'HSIC' 'HSY'
#  'HOLX' 'HON' 'IDXX' 'ILMN' 'IFF' 'INTU' 'INVH' 'KEYS' 'KMB' 'KMI' 'LDOS'
#  'LIN' 'MKTX' 'MMC' 'MA' 'MTCH' 'MKC' 'MCD' 'MRK' 'MTD' 'MSFT' 'MAA' 'MOH'
#  'MDLZ' 'MSI' 'MSCI' 'NEE' 'NSC' 'ORLY' 'ORCL' 'PAYX' 'PYPL' 'PEP' 'PKI'
#  'PFE' 'POOL' 'PG' 'PGR' 'O' 'RSG' 'ROP' 'SBUX' 'STE' 'SNPS' 'TMO' 'TSCO'
#  'TT' 'TRMB' 'UDR' 'VRSN' 'VRSK' 'V' 'WMT' 'WM' 'WTW' 'XYL' 'YUM' 'ZBRA'
#  'ZTS']
# 2019-06-25 00:00:00
# 12863.665006500158
# ['ABT' 'ADP' 'AFL' 'APD' 'ALLE' 'AXP' 'AWK' 'AME' 'AON' 'AJG' 'AZO' 'AVB'
#  'BALL' 'TECH' 'BSX' 'KMX' 'CTLT' 'CHTR' 'CMG' 'CHD' 'CTAS' 'CSCO' 'CLX'
#  'COO' 'CPRT' 'CSGP' 'COST' 'CCI' 'CSX' 'XRAY' 'DXCM' 'DG' 'DLTR' 'DOV'
#  'ECL' 'EW' 'ENPH' 'EPAM' 'EQIX' 'EQR' 'ESS' 'ETSY' 'EXC' 'FDS' 'FAST'
#  'FSLR' 'FE' 'FISV' 'GRMN' 'GNRC' 'GPN' 'HSIC' 'HSY' 'HOLX' 'HON' 'IDXX'
#  'ILMN' 'IFF' 'INTU' 'INVH' 'KEYS' 'KMB' 'LDOS' 'LIN' 'MKTX' 'MMC' 'MA'
#  'MTCH' 'MKC' 'MCD' 'MRK' 'MTD' 'MSFT' 'MAA' 'MOH' 'MDLZ' 'MSCI' 'NSC'
#  'ORLY' 'ORCL' 'PAYX' 'PYPL' 'PEP' 'PKI' 'POOL' 'PG' 'O' 'RSG' 'ROP'
#  'SBUX' 'STE' 'SNPS' 'TMO' 'TSCO' 'TT' 'TRMB' 'UDR' 'VRSN' 'VRSK' 'V'
#  'WMT' 'WM' 'WST' 'WTW' 'XYL' 'YUM' 'ZBRA' 'ZTS']
# 2019-06-26 00:00:00
# 12757.280297931253
# ['ABT' 'ADP' 'AFL' 'ALLE' 'AMD' 'AEE' 'AEP' 'AXP' 'AMT' 'AWK' 'AJG' 'AZO'
#  'TECH' 'CDNS' 'KMX' 'CDAY' 'CHTR' 'CMG' 'CHD' 'CINF' 'CTAS' 'CMS' 'COO'
#  'CPRT' 'CSGP' 'COST' 'CCI' 'XRAY' 'DXCM' 'DIS' 'DG' 'DLTR' 'ECL' 'ENPH'
#  'ETR' 'EPAM' 'EQR' 'ESS' 'FDS' 'FE' 'FLT' 'GRMN' 'IT' 'GNRC' 'GPN' 'HSY'
#  'HOLX' 'HON' 'ILMN' 'INTU' 'KEYS' 'KMB' 'LDOS' 'LIN' 'LYV' 'MA' 'MTCH'
#  'MKC' 'MCD' 'MRK' 'MSFT' 'MDLZ' 'MSCI' 'ORLY' 'PAYX' 'PYPL' 'PEP' 'PKI'
#  'PNW' 'POOL' 'PG' 'PLD' 'O' 'ROP' 'SBAC' 'NOW' 'SO' 'SBUX' 'STE' 'SNPS'
#  'TFX' 'TMO' 'TSCO' 'TRMB' 'UDR' 'ULTA' 'VRSN' 'VRSK' 'WMT' 'WEC' 'WST'
#  'WTW' 'XYL' 'YUM' 'ZBRA' 'ZTS']
# 2019-06-27 00:00:00
# 12660.100821189504
# ['ABT' 'ADP' 'AFL' 'ALLE' 'AMD' 'AEE' 'AEP' 'AXP' 'AMT' 'AWK' 'ACGL' 'AJG'
#  'AZO' 'WRB' 'TECH' 'CDNS' 'CDAY' 'CHTR' 'CMG' 'CHD' 'CINF' 'CTAS' 'CMS'
#  'CMCSA' 'COO' 'CPRT' 'CSGP' 'COST' 'CCI' 'DHR' 'XRAY' 'DXCM' 'DIS' 'DG'
#  'DLTR' 'DTE' 'ECL' 'ENPH' 'ETR' 'EPAM' 'EQR' 'ESS' 'ES' 'FDS' 'FLT'
#  'GRMN' 'IT' 'GNRC' 'GPN' 'PEAK' 'HSY' 'HON' 'ILMN' 'INTU' 'KEYS' 'KMB'
#  'LHX' 'LDOS' 'LIN' 'LYV' 'MA' 'MTCH' 'MKC' 'MCD' 'MRK' 'MSFT' 'MDLZ'
#  'MSI' 'MSCI' 'NEE' 'PAYC' 'PYPL' 'PEP' 'PKI' 'PNW' 'PG' 'PGR' 'PLD' 'ROP'
#  'SBAC' 'NOW' 'SEDG' 'SO' 'SBUX' 'STE' 'SNPS' 'TMUS' 'TFX' 'TMO' 'TDG'
#  'TRV' 'TRMB' 'ULTA' 'UAL' 'VTR' 'VRSN' 'VRSK' 'WMT' 'WEC' 'WELL' 'WST'
#  'WTW' 'XEL' 'XYL' 'YUM' 'ZBRA' 'ZTS']
# 2019-06-28 00:00:00
# 12732.872761894447
# ['ABT' 'ADP' 'AFL' 'ALLE' 'AEE' 'AEP' 'AXP' 'AMT' 'AWK' 'AON' 'ACGL' 'AJG'
#  'AZO' 'WRB' 'TECH' 'BRO' 'CDNS' 'CDAY' 'CHTR' 'CMG' 'CHD' 'CINF' 'CTAS'
#  'CSCO' 'CMS' 'CMCSA' 'COO' 'CPRT' 'GLW' 'CSGP' 'COST' 'CCI' 'CMI' 'DHR'
#  'XRAY' 'DXCM' 'DIS' 'DG' 'DLTR' 'DTE' 'EW' 'ENPH' 'ETR' 'EPAM' 'EQR'
#  'ESS' 'EL' 'ES' 'FDS' 'FISV' 'FLT' 'GRMN' 'IT' 'GNRC' 'GPN' 'PEAK' 'HSY'
#  'HLT' 'HON' 'IDXX' 'ILMN' 'INCY' 'INTU' 'KEYS' 'KMB' 'LHX' 'LDOS' 'LIN'
#  'LYV' 'MKTX' 'MA' 'MTCH' 'MKC' 'MCD' 'MRK' 'MSFT' 'MOH' 'MDLZ' 'MSI'
#  'MSCI' 'NEE' 'PAYC' 'PYPL' 'PEP' 'PKI' 'PG' 'PGR' 'PLD' 'RSG' 'ROP'
#  'SBAC' 'NOW' 'SEDG' 'SBUX' 'STE' 'SNPS' 'TMUS' 'TFX' 'TMO' 'TT' 'TDG'
#  'TRV' 'TRMB' 'ULTA' 'UAL' 'VTR' 'VRSN' 'VRSK' 'V' 'WMT' 'WM' 'WEC' 'WELL'
#  'WST' 'WTW' 'XEL' 'XYL' 'YUM' 'ZBRA' 'ZTS']
# 2019-07-02 00:00:00
# 12897.650976850413
# ['ABT' 'ADBE' 'ADP' 'AFL' 'AEE' 'AEP' 'AXP' 'AMT' 'AWK' 'AON' 'ACGL'
#  'ADSK' 'AZO' 'WRB' 'TECH' 'BRO' 'CDNS' 'CDAY' 'CHTR' 'CMG' 'CHD' 'CINF'
#  'CSCO' 'CMS' 'CMCSA' 'COO' 'GLW' 'CSGP' 'COST' 'CCI' 'CSX' 'CMI' 'DHR'
#  'XRAY' 'DXCM' 'DIS' 'DG' 'DLTR' 'DTE' 'EW' 'ENPH' 'ETR' 'ESS' 'EL' 'ES'
#  'FDS' 'FAST' 'FISV' 'FLT' 'GRMN' 'IT' 'GNRC' 'GPN' 'PEAK' 'HSIC' 'HSY'
#  'HLT' 'HOLX' 'HON' 'IDXX' 'ILMN' 'INCY' 'INTU' 'IQV' 'KEYS' 'KMB' 'LHX'
#  'LIN' 'LYV' 'LMT' 'MKTX' 'MA' 'MTCH' 'MRK' 'MTD' 'MSFT' 'MOH' 'MDLZ'
#  'MSI' 'NEE' 'PAYX' 'PAYC' 'PYPL' 'PEP' 'PKI' 'PG' 'PGR' 'PLD' 'RSG' 'ROP'
#  'SBAC' 'NOW' 'SBUX' 'STE' 'SYK' 'SNPS' 'TMUS' 'TFX' 'TMO' 'TT' 'TDG'
#  'TRV' 'ULTA' 'UAL' 'VRSN' 'VRSK' 'VRTX' 'V' 'WMT' 'WM' 'WEC' 'WELL' 'WTW'
#  'XEL' 'XYL' 'YUM' 'ZBRA' 'ZTS']
# 2019-07-03 00:00:00
# 13002.355759366581
# ['ABT' 'ADBE' 'ADP' 'AEE' 'AEP' 'AXP' 'AMT' 'AWK' 'AON' 'ADSK' 'AZO' 'AVB'
#  'WRB' 'BSX' 'CDNS' 'CZR' 'CDAY' 'CRL' 'CHTR' 'CMG' 'CHD' 'CINF' 'CSCO'
#  'CME' 'CMS' 'CMCSA' 'GLW' 'CSGP' 'COST' 'CCI' 'CSX' 'CMI' 'DHR' 'XRAY'
#  'DXCM' 'DIS' 'DG' 'DLTR' 'DTE' 'EW' 'ETR' 'EQIX' 'ESS' 'EL' 'ES' 'FDS'
#  'FAST' 'FLT' 'GRMN' 'GNRC' 'GIS' 'GPN' 'PEAK' 'HSIC' 'HSY' 'HOLX' 'HON'
#  'IDXX' 'ILMN' 'INCY' 'IR' 'INTU' 'IQV' 'J' 'KMB' 'KMI' 'LHX' 'LIN' 'LYV'
#  'LMT' 'MKTX' 'MRK' 'MTD' 'MSFT' 'MAA' 'MOH' 'MDLZ' 'MSI' 'NEE' 'PAYX'
#  'PAYC' 'PYPL' 'PEP' 'PKI' 'PFE' 'PG' 'PLD' 'RSG' 'SBAC' 'NOW' 'SBUX'
#  'SYK' 'TMUS' 'TFX' 'TMO' 'TDG' 'TRV' 'UDR' 'ULTA' 'UAL' 'VRSN' 'VRTX' 'V'
#  'WMT' 'WM' 'WEC' 'WELL' 'WTW' 'XEL' 'XYL' 'YUM' 'ZTS']
# 2019-07-05 00:00:00
# 13025.547693317174
# ['ABT' 'ADBE' 'ADP' 'ALLE' 'AEE' 'AEP' 'AXP' 'AMT' 'AWK' 'ADSK' 'AVB'
#  'WRB' 'BSX' 'CZR' 'CRL' 'CMG' 'CSCO' 'CME' 'CMS' 'CMCSA' 'GLW' 'COST'
#  'CCI' 'CMI' 'DHR' 'XRAY' 'DXCM' 'DG' 'DLTR' 'DTE' 'EW' 'ETR' 'EQIX' 'EL'
#  'ES' 'FAST' 'FE' 'GRMN' 'GNRC' 'GIS' 'PEAK' 'HOLX' 'IDXX' 'ILMN' 'INCY'
#  'IR' 'IQV' 'J' 'KMI' 'LHX' 'LIN' 'LYV' 'LMT' 'MSFT' 'MAA' 'MOH' 'MDLZ'
#  'NEE' 'ORCL' 'PAYX' 'PYPL' 'PEP' 'PFE' 'PG' 'O' 'SBAC' 'SYK' 'TFX' 'TDG'
#  'UDR' 'ULTA' 'VTR' 'V' 'WMT' 'WM' 'WEC' 'XEL' 'XYL' 'YUM' 'ZTS']
# 2019-07-09 00:00:00
# 13000.487490133804
# ['ABT' 'ADBE' 'ADP' 'ALLE' 'AEP' 'AMT' 'BSX' 'CTLT' 'CSCO' 'CMS' 'CMCSA'
#  'COO' 'GLW' 'COST' 'CMI' 'DHR' 'XRAY' 'DXCM' 'DLTR' 'EW' 'ETR' 'EL'
#  'FAST' 'FE' 'GRMN' 'GNRC' 'IEX' 'INCY' 'IQV' 'J' 'LHX' 'LIN' 'MSFT' 'MOH'
#  'ORCL' 'PEP' 'O' 'SYK' 'TFX' 'TT' 'ULTA' 'VTR' 'WMT' 'WM' 'WEC' 'WST'
#  'XEL' 'YUM' 'ZTS']
# 2019-07-10 00:00:00
# 13103.005317825931
# ['APD' 'ALLE' 'AME' 'BALL' 'BSX' 'CTLT' 'CDW' 'COO' 'CMI' 'DHR' 'XRAY'
#  'DOV' 'EL' 'GNRC' 'HCA' 'HWM' 'IEX' 'IQV' 'J' 'KEYS' 'LIN' 'QCOM' 'TDY'
#  'TFX' 'TMO' 'TT' 'TRMB' 'WST' 'YUM' 'ZBRA' 'ZTS']
# 2019-07-11 00:00:00
# 13020.263210590025
# ['APD' 'ALLE' 'AME' 'BALL' 'BSX' 'CTLT' 'CDW' 'CTAS' 'COO' 'CMI' 'DHR'
#  'XRAY' 'DOV' 'EL' 'GNRC' 'HCA' 'HLT' 'HON' 'HWM' 'IEX' 'ILMN' 'IQV' 'J'
#  'KEYS' 'MTD' 'MSCI' 'NSC' 'PKI' 'QCOM' 'STE' 'TDY' 'TMO' 'TSCO' 'TT'
#  'TRMB' 'WST' 'YUM' 'ZBRA' 'ZTS']
# 2019-07-12 00:00:00
# 12949.669679477878
# ['ADBE' 'APD' 'ALLE' 'AME' 'AON' 'ACGL' 'BALL' 'TECH' 'BSX' 'CTLT' 'CDW'
#  'CDAY' 'CTAS' 'COO' 'CMI' 'DHR' 'XRAY' 'DOV' 'ECL' 'EL' 'FSLR' 'FISV'
#  'GNRC' 'HCA' 'HLT' 'HON' 'HWM' 'IEX' 'ILMN' 'IQV' 'J' 'JCI' 'KEYS' 'LMT'
#  'MMC' 'MKC' 'MRK' 'MTD' 'MSCI' 'NSC' 'PKI' 'QCOM' 'STE' 'SYK' 'TDY' 'TMO'
#  'TSCO' 'TT' 'TRMB' 'TSN' 'UNP' 'UAL' 'WST' 'XYL' 'YUM' 'ZTS']
# 2019-07-16 00:00:00
# 12992.703058136964
# ['ABT' 'ADBE' 'AFL' 'APD' 'ALLE' 'AME' 'AON' 'ACGL' 'AJG' 'BALL' 'TECH'
#  'BSX' 'AVGO' 'BRO' 'CDNS' 'CTLT' 'CDW' 'CDAY' 'CINF' 'CTAS' 'COO' 'CSX'
#  'CMI' 'DHR' 'XRAY' 'DOV' 'ECL' 'ENPH' 'ETR' 'EL' 'FSLR' 'FISV' 'FLT'
#  'GNRC' 'GPN' 'HCA' 'HLT' 'HON' 'HWM' 'IEX' 'IQV' 'J' 'JCI' 'KEYS' 'LIN'
#  'LMT' 'MMC' 'MKC' 'MCD' 'MRK' 'MTD' 'MAA' 'MDLZ' 'MSI' 'MSCI' 'NSC'
#  'ORCL' 'PKI' 'PLD' 'QCOM' 'RSG' 'STE' 'SYK' 'SNPS' 'TDY' 'TFX' 'TMO'
#  'TSCO' 'TT' 'TDG' 'TRV' 'TRMB' 'TSN' 'UNP' 'UAL' 'VRSK' 'WST' 'WTW' 'XYL'
#  'ZTS']
# 2019-07-17 00:00:00
# 12967.649110264136
# ['ABT' 'ADBE' 'AES' 'AFL' 'APD' 'ALLE' 'AEE' 'AWK' 'AME' 'AON' 'ACGL'
#  'AJG' 'ADSK' 'AVB' 'BALL' 'WRB' 'TECH' 'AVGO' 'BRO' 'CDNS' 'CTLT' 'CDW'
#  'CDAY' 'CINF' 'CME' 'CMS' 'COO' 'CCI' 'CSX' 'DHR' 'XRAY' 'DOV' 'DTE'
#  'ECL' 'ENPH' 'ETR' 'EQR' 'ESS' 'ETSY' 'ES' 'FDS' 'FE' 'FISV' 'FLT' 'IT'
#  'GNRC' 'GIS' 'GPN' 'HCA' 'PEAK' 'HSY' 'HLT' 'HON' 'HWM' 'IEX' 'INVH'
#  'IQV' 'J' 'JCI' 'KEYS' 'KMB' 'LDOS' 'LIN' 'LYV' 'MA' 'MTCH' 'MKC' 'MCD'
#  'MRK' 'MTD' 'MSFT' 'MAA' 'MDLZ' 'MSI' 'MSCI' 'NEE' 'ORCL' 'PAYC' 'PKI'
#  'PGR' 'PLD' 'QCOM' 'RSG' 'SBAC' 'NOW' 'SBUX' 'STE' 'SNPS' 'TDY' 'TFX'
#  'TMO' 'TSCO' 'TDG' 'TRV' 'TRMB' 'TSN' 'UDR' 'UAL' 'VRSN' 'VRSK' 'V' 'WEC'
#  'WELL' 'WST' 'WTW' 'XEL' 'XYL' 'ZTS']
# 2019-07-18 00:00:00
# 12889.752877846564
# ['ABT' 'AES' 'AFL' 'APD' 'ALLE' 'AEE' 'AEP' 'AMT' 'AWK' 'AME' 'AON' 'ACGL'
#  'AJG' 'ADSK' 'AZO' 'AVB' 'BALL' 'WRB' 'TECH' 'CDNS' 'CPT' 'CTLT' 'CDW'
#  'CDAY' 'CINF' 'CME' 'CMS' 'COO' 'CCI' 'DHR' 'XRAY' 'DISH' 'DIS' 'DOV'
#  'DTE' 'ECL' 'EW' 'ENPH' 'ETR' 'EQR' 'ESS' 'ETSY' 'ES' 'FDS' 'FE' 'FIS'
#  'FISV' 'FLT' 'IT' 'GNRC' 'GIS' 'GPN' 'HCA' 'PEAK' 'HSY' 'HLT' 'HWM' 'ICE'
#  'INVH' 'IQV' 'KEYS' 'KMB' 'LDOS' 'LIN' 'LYV' 'MA' 'MTCH' 'MKC' 'MCD'
#  'MRK' 'MTD' 'MSFT' 'MAA' 'MDLZ' 'MSI' 'MSCI' 'NEE' 'PAYX' 'PAYC' 'PYPL'
#  'PKI' 'PG' 'PGR' 'PLD' 'QCOM' 'RSG' 'ROP' 'SBAC' 'NOW' 'SBUX' 'STE'
#  'SNPS' 'TDY' 'TFX' 'TMO' 'TSCO' 'TDG' 'TSN' 'UDR' 'VRSN' 'VRSK' 'V' 'WBD'
#  'WM' 'WEC' 'WELL' 'WST' 'WTW' 'XEL' 'ZTS']
# 2019-07-19 00:00:00
# 13016.470661705875
# ['AFL' 'APD' 'ALLE' 'AMD' 'AEE' 'AEP' 'AMT' 'AWK' 'AME' 'AON' 'ACGL' 'AJG'
#  'ADSK' 'AZO' 'AVB' 'BALL' 'WRB' 'TECH' 'BSX' 'CDNS' 'CPT' 'CTLT' 'CDW'
#  'CDAY' 'CINF' 'CME' 'CMS' 'COO' 'CSGP' 'DHR' 'XRAY' 'DISH' 'DIS' 'DLTR'
#  'DOV' 'DTE' 'ECL' 'EW' 'ENPH' 'EQR' 'ESS' 'ETSY' 'ES' 'FDS' 'FSLR' 'FE'
#  'FIS' 'FISV' 'FLT' 'IT' 'GNRC' 'GIS' 'HCA' 'PEAK' 'HWM' 'ICE' 'INTU'
#  'IQV' 'KEYS' 'KMB' 'LDOS' 'LYV' 'MA' 'MKC' 'MCD' 'MRK' 'MTD' 'MSFT' 'MAA'
#  'MDLZ' 'MSI' 'NEE' 'NSC' 'PAYX' 'PAYC' 'PYPL' 'PKI' 'PG' 'PGR' 'PLD'
#  'QCOM' 'ROP' 'SBAC' 'NOW' 'STE' 'SYK' 'SNPS' 'TDY' 'TMO' 'TSCO' 'TDG'
#  'TSN' 'UDR' 'VTR' 'VRSN' 'V' 'WMT' 'WBD' 'WM' 'WELL' 'WST' 'WTW' 'XEL'
#  'ZTS']
# 2019-07-23 00:00:00
# 12917.74479394381
# ['APD' 'AMD' 'AEP' 'AXP' 'AMT' 'AWK' 'AME' 'AON' 'ACGL' 'AJG' 'ADSK' 'AZO'
#  'BALL' 'WRB' 'TECH' 'BSX' 'CDNS' 'CTLT' 'CDW' 'CHTR' 'CMG' 'CINF' 'CSCO'
#  'CME' 'CMS' 'CSGP' 'DISH' 'DIS' 'DG' 'DLTR' 'DOV' 'ECL' 'EW' 'ENPH'
#  'EPAM' 'EQR' 'ESS' 'ETSY' 'ES' 'FDS' 'FSLR' 'FE' 'GNRC' 'GIS' 'HCA'
#  'PEAK' 'HON' 'HWM' 'INTU' 'IQV' 'J' 'KEYS' 'LYV' 'MA' 'MCD' 'MSFT' 'MDLZ'
#  'NEE' 'NSC' 'ORLY' 'PAYC' 'PYPL' 'PG' 'PGR' 'QCOM' 'ROP' 'SBAC' 'SRE'
#  'NOW' 'STE' 'SYK' 'SNPS' 'TMUS' 'TMO' 'TRV' 'TRMB' 'TSN' 'VTR' 'VRSN' 'V'
#  'WMT' 'WM' 'WELL' 'WST' 'WTW']
# 2019-07-24 00:00:00
# 12915.084301230137
# ['AMD' 'AEP' 'AXP' 'AMT' 'AWK' 'AME' 'ANSS' 'AON' 'ACGL' 'AJG' 'ADSK'
#  'AZO' 'WRB' 'TECH' 'BSX' 'BRO' 'CDNS' 'CDW' 'CHTR' 'CMG' 'CHD' 'CINF'
#  'CSCO' 'CME' 'CMS' 'CMCSA' 'CPRT' 'CSGP' 'COST' 'DAL' 'DXCM' 'DISH' 'DIS'
#  'DG' 'ECL' 'EW' 'ELV' 'ENPH' 'ETR' 'EPAM' 'EQR' 'ESS' 'ES' 'FDS' 'FE'
#  'FTNT' 'GIS' 'GPN' 'HCA' 'PEAK' 'HON' 'HWM' 'IEX' 'INTU' 'IQV' 'J' 'KEYS'
#  'LHX' 'LYV' 'MKTX' 'MA' 'MCD' 'MSFT' 'MOH' 'MSCI' 'NEE' 'NSC' 'ORLY'
#  'PAYC' 'PYPL' 'PGR' 'RSG' 'ROP' 'ROST' 'SBAC' 'SRE' 'NOW' 'SBUX' 'STE'
#  'SNPS' 'TMUS' 'TT' 'TRV' 'TRMB' 'ULTA' 'VRSN' 'VRSK' 'V' 'WMT' 'WM' 'WEC'
#  'WELL' 'WST' 'WTW']
# 2019-07-25 00:00:00
# 12943.318443835358
# ['ADBE' 'AFL' 'ALLE' 'AMD' 'AEE' 'AEP' 'AXP' 'AMT' 'AWK' 'AME' 'ANSS'
#  'AON' 'ACGL' 'AJG' 'ADSK' 'AZO' 'AVB' 'WRB' 'BRO' 'CDNS' 'CDW' 'CHTR'
#  'CMG' 'CHD' 'CINF' 'CSCO' 'CMS' 'CMCSA' 'CPRT' 'COST' 'DAL' 'DXCM' 'DIS'
#  'DG' 'ECL' 'ELV' 'ENPH' 'ETR' 'EPAM' 'EQR' 'ESS' 'EL' 'ES' 'FDS' 'FE'
#  'FISV' 'FLT' 'FTNT' 'IT' 'GIS' 'GPN' 'HCA' 'PEAK' 'HWM' 'IEX' 'INTU' 'J'
#  'KMB' 'LHX' 'LDOS' 'LIN' 'LYV' 'MKTX' 'MA' 'MKC' 'MCD' 'MTD' 'MAA' 'MOH'
#  'MSI' 'MSCI' 'NEE' 'NVR' 'ORLY' 'PAYC' 'PYPL' 'PGR' 'RSG' 'ROP' 'ROST'
#  'SBAC' 'SRE' 'NOW' 'SBUX' 'SNPS' 'TMUS' 'TSCO' 'TT' 'TDG' 'UDR' 'ULTA'
#  'UNP' 'VRSN' 'VRSK' 'V' 'WMT' 'WBD' 'WM' 'WEC' 'WELL' 'WST' 'WTW' 'XEL']
# 2019-07-26 00:00:00
# 12989.388362210093
# ['ADBE' 'AFL' 'ALLE' 'AMD' 'AEE' 'AEP' 'AXP' 'AMT' 'AWK' 'AON' 'ACGL'
#  'AJG' 'ADSK' 'AZO' 'AVB' 'WRB' 'CDW' 'CHTR' 'CMG' 'CHD' 'CINF' 'CSCO'
#  'CMS' 'CMCSA' 'CPRT' 'COST' 'DAL' 'DIS' 'DG' 'ECL' 'ENPH' 'ETR' 'EPAM'
#  'EQR' 'ESS' 'EL' 'ES' 'FDS' 'FE' 'FIS' 'FISV' 'FLT' 'FTNT' 'IT' 'GPN'
#  'HCA' 'PEAK' 'HWM' 'INTU' 'J' 'KMB' 'LDOS' 'LIN' 'LYV' 'MKTX' 'MA' 'MKC'
#  'MCD' 'MTD' 'MAA' 'MDLZ' 'MSI' 'MSCI' 'NEE' 'NVR' 'OMC' 'PAYC' 'PYPL'
#  'PG' 'PGR' 'RSG' 'ROP' 'ROST' 'SRE' 'NOW' 'SBUX' 'SNPS' 'TMUS' 'TSCO'
#  'TT' 'TDG' 'UDR' 'ULTA' 'UNP' 'VRSN' 'VRSK' 'V' 'WMT' 'WBD' 'WM' 'WEC'
#  'WELL' 'WTW' 'XEL' 'YUM']
# ...
# 2022-08-25 00:00:00
# 17631.661640767183
# ['ADM' 'ADP' 'ALB' 'ANET' 'AJG' 'AZO' 'CHRW' 'CAH' 'CNC' 'CNP' 'CVX' 'CI'
#  'ED' 'CTVA' 'COST' 'FANG' 'DLTR' 'ELV' 'ENPH' 'EQT' 'FDS' 'GPC' 'HUM'
#  'LW' 'LMT' 'MTB' 'MCK' 'MOH' 'NI' 'NOC' 'ON' 'OKE' 'PCG' 'PSX' 'PGR'
#  'PWR' 'SRE' 'TRGP' 'TSLA' 'UNH' 'VRTX' 'GWW']
# 2022-08-26 00:00:00
# 17791.498902545958
# ['ADM' 'ADP' 'ALB' 'ABC' 'ANET' 'AJG' 'ATO' 'AZO' 'WRB' 'CHRW' 'CAH' 'CNC'
#  'CNP' 'CI' 'ED' 'CTVA' 'COST' 'CVS' 'EIX' 'ELV' 'ENPH' 'EQT' 'FDS' 'FSLR'
#  'GPC' 'HUM' 'IRM' 'LW' 'LMT' 'MTB' 'MCK' 'MOH' 'NI' 'NOC' 'NUE' 'ON'
#  'OKE' 'PCG' 'PGR' 'PWR' 'RSG' 'SRE' 'SO' 'STLD' 'TSLA' 'UNH' 'VRTX' 'GWW']
# 2022-08-30 00:00:00
# 17423.001649132024
# ['ALB' 'ABC' 'ANET' 'ATO' 'WRB' 'CHRW' 'CNC' 'ED' 'CTVA' 'CVS' 'EIX'
#  'ENPH' 'EQT' 'FSLR' 'GIS' 'HSY' 'HUM' 'IRM' 'LW' 'MOH' 'NI' 'NOC' 'NUE'
#  'ON' 'PCG' 'PGR' 'PWR' 'RSG' 'SO' 'STLD' 'TSLA' 'WMB']
# 2022-08-31 00:00:00
# 17129.400557147397
# ['ANET' 'CHRW' 'CPB' 'CNC' 'ED' 'CTVA' 'CTRA' 'DVN' 'ENPH' 'EOG' 'EQT'
#  'GIS' 'HSY' 'LW' 'MPC' 'NOC' 'ON' 'PGR' 'PWR' 'VLO' 'WMB']
# 2022-09-01 00:00:00
# 16963.826550953494
# ['ADM' 'ANET' 'AJG' 'AZO' 'CHRW' 'CPB' 'CAH' 'CNC' 'CNP' 'CF' 'CI' 'COP'
#  'ED' 'CTVA' 'CTRA' 'DVN' 'FANG' 'EOG' 'EQT' 'XOM' 'GIS' 'GPC' 'HSY' 'HES'
#  'LW' 'MTB' 'MRO' 'MPC' 'MCK' 'NOC' 'OXY' 'ON' 'PSX' 'PXD' 'PGR' 'PWR'
#  'SRE' 'UNH' 'VLO' 'VRTX' 'WMB' 'GWW']
# 2022-09-02 00:00:00
# 17214.583031887036
# ['ADM' 'ANET' 'AJG' 'AZO' 'CHRW' 'CAH' 'CNC' 'CNP' 'CF' 'CI' 'COP' 'ED'
#  'CTVA' 'CTRA' 'DVN' 'FANG' 'ELV' 'LLY' 'EOG' 'EQT' 'XOM' 'GIS' 'GPC'
#  'HSY' 'HES' 'HUM' 'LW' 'MTB' 'MRO' 'MPC' 'MCK' 'NOC' 'OXY' 'ON' 'PSX'
#  'PXD' 'PGR' 'PWR' 'SRE' 'UNH' 'VRTX' 'GWW']
# 2022-09-07 00:00:00
# 16757.07740348045
# ['ADM' 'ANET' 'AJG' 'AZO' 'CHRW' 'CNC' 'CNP' 'CF' 'CI' 'COP' 'CTVA' 'CTRA'
#  'DVN' 'FANG' 'ELV' 'LLY' 'ENPH' 'EOG' 'EQT' 'XOM' 'GIS' 'GPC' 'HSY' 'HES'
#  'HUM' 'LW' 'MTB' 'MRO' 'MPC' 'MCK' 'NOC' 'OXY' 'ON' 'PGR' 'PWR' 'SRE'
#  'TRGP' 'GWW']
# 2022-09-08 00:00:00
# 17084.571438519935
# ['ADM' 'ANET' 'AJG' 'WRB' 'CHRW' 'CNC' 'CF' 'COP' 'CTVA' 'DVN' 'LLY'
#  'ENPH' 'EQT' 'XOM' 'GIS' 'HSY' 'HES' 'LW' 'MTB' 'MPC' 'NOC' 'OXY' 'ON'
#  'PCG' 'PGR' 'PWR' 'TRGP' 'GWW']
# 2022-09-09 00:00:00
# 17407.649934078174
# ['ADM' 'ALB' 'WRB' 'CHRW' 'CAH' 'CF' 'COP' 'CTVA' 'DVN' 'EQT' 'XOM' 'GIS'
#  'HSY' 'HES' 'LW' 'MPC' 'NUE' 'OXY' 'ON' 'PCG' 'PWR' 'STLD' 'TRGP']
# 2022-09-13 00:00:00
# 17210.343480908436
# ['ALB' 'CAH' 'CF' 'COP' 'CTRA' 'DVN' 'FANG' 'EOG' 'EQT' 'XOM' 'GIS' 'HES'
#  'MRO' 'MPC' 'MOH' 'NUE' 'OXY' 'SLB' 'STLD']
# 2022-09-14 00:00:00
# 17167.095729898123
# ['CAH' 'CTRA' 'DVN' 'FANG' 'EOG' 'GIS' 'MRO' 'MCK' 'MOH' 'OXY' 'SLB']
# 2022-09-15 00:00:00
# 17154.00287721159
# ['ADM' 'CHRW' 'CAH' 'FSLR' 'GIS' 'GPC' 'LW' 'MCK' 'MOH']
# 2022-09-16 00:00:00
# 16945.607146452392
# ['ADM' 'CHRW' 'CAH' 'CI' 'ED' 'FSLR' 'GIS' 'GPC' 'LW' 'MCK' 'MOH' 'SRE'
#  'GWW']
# 2022-09-20 00:00:00
# 17166.265008657196
# ['ANET' 'CAH' 'CNP' 'CF' 'CI' 'ED' 'DVN' 'XOM' 'FSLR' 'GPC' 'LW' 'MPC'
#  'MCK' 'MOH' 'PGR' 'SRE' 'GWW']
# 2022-09-21 00:00:00
# 17323.29855679852
# ['ALB' 'ANET' 'AJG' 'AZO' 'CAH' 'CNP' 'CF' 'CI' 'ED' 'CTVA' 'DVN' 'ENPH'
#  'EOG' 'EQT' 'XOM' 'FSLR' 'GPC' 'HSY' 'HES' 'HII' 'LW' 'MTB' 'MRO' 'MPC'
#  'MCK' 'MOH' 'ON' 'PCG' 'PFG' 'PGR' 'RJF' 'SRE' 'SO' 'VRTX' 'GWW']
# 2022-09-22 00:00:00
# 16982.10244370045
# ['ADM' 'ALB' 'ANET' 'AJG' 'AZO' 'CAH' 'CNP' 'CI' 'COP' 'ED' 'CTVA' 'DVN'
#  'ENPH' 'EOG' 'EQT' 'FSLR' 'GPC' 'HSY' 'HES' 'HII' 'MTB' 'MRO' 'MCK' 'ON'
#  'PCG' 'PFG' 'PGR' 'RJF' 'SRE' 'SO' 'TSLA' 'VRTX']
# 2022-09-23 00:00:00
# 16407.074504137683
# ['ADM' 'ALB' 'CNP' 'CI' 'COP' 'ED' 'CTVA' 'LLY' 'ENPH' 'EQT' 'FSLR' 'GPC'
#  'HES' 'HII' 'MTB' 'ON' 'PCG' 'PFG' 'PGR' 'RJF' 'SRE' 'TSLA' 'UNH' 'VRTX']
# 2022-09-27 00:00:00
# 16193.802199535625
# ['CNP' 'CI' 'LLY' 'ENPH' 'FSLR' 'GPC' 'MTB' 'ON' 'PCG' 'PGR' 'SRE' 'UNH'
#  'VRTX']
# 2022-09-28 00:00:00
# 16201.745719508646
# ['CI' 'ENPH' 'FSLR' 'HUM' 'NOC' 'ON' 'PCG' 'PGR' 'VRTX']
# 2022-09-29 00:00:00
# 16464.799218975324
# ['ALB' 'CF' 'CI' 'COP' 'CTVA' 'ENPH' 'FSLR' 'HUM' 'MOH' 'NOC' 'ON' 'PCG'
#  'PGR']
# 2022-09-30 00:00:00
# 16153.99040144342
# ['ALB' 'CF' 'CI' 'COP' 'CTVA' 'ENPH' 'FSLR' 'GIS' 'GPC' 'HUM' 'MOH' 'NOC'
#  'ON' 'PCG' 'PGR']
# 2022-10-04 00:00:00
# 16978.21661301488
# ['ALB' 'CI' 'COP' 'ENPH' 'FSLR' 'GIS' 'GPC' 'HUM' 'NOC' 'ON' 'PCG']
# 2022-10-05 00:00:00
# 17049.521124397877
# ['GIS' 'HSY']
# 2022-10-06 00:00:00
# 16878.357502304512
# ['GIS' 'HSY']
# 2022-10-07 00:00:00
# 16511.404244020927
# ['GIS']
# 2022-10-11 00:00:00
# 16814.972312499118
# ['LLY' 'ENPH' 'FSLR' 'GIS']
# 2022-10-12 00:00:00
# 17126.54625507512
# ['LLY' 'ENPH' 'FSLR' 'GIS' 'HSY' 'HUM' 'MPC' 'ORLY' 'VRTX']
# 2022-10-13 00:00:00
# 16581.778353641563
# ['CAH' 'LLY' 'ENPH' 'FSLR' 'HSY' 'HUM' 'MPC' 'ORLY' 'OXY' 'REGN' 'VRTX']
# 2022-10-14 00:00:00
# 17319.06147375694
# ['CAH' 'DVN' 'LLY' 'ENPH' 'EOG' 'HES' 'MTB' 'MPC' 'ORLY' 'OXY' 'PCG' 'PXD'
#  'REGN' 'VLO' 'VRTX']
# 2022-10-18 00:00:00
# 17252.146938861224
# ['APA' 'AZO' 'CAH' 'CVX' 'CI' 'COP' 'DVN' 'FANG' 'LLY' 'ENPH' 'EOG' 'XOM'
#  'GPC' 'HES' 'MTB' 'MRO' 'MPC' 'MCK' 'MOH' 'OXY' 'PCG' 'PXD' 'REGN' 'SLB'
#  'STLD' 'UNH' 'VLO' 'VRTX']
# 2022-10-19 00:00:00
# 17156.73677564379
# ['ADM' 'APA' 'AZO' 'CAH' 'CF' 'CVX' 'CI' 'COP' 'CTVA' 'DVN' 'FANG' 'LLY'
#  'EOG' 'XOM' 'FMC' 'GPC' 'HES' 'LW' 'MRO' 'MPC' 'MCK' 'MOH' 'NOC' 'OXY'
#  'PCG' 'PXD' 'PGR' 'REGN' 'SLB' 'STLD' 'UNH' 'VLO' 'VRTX']
# 2022-10-20 00:00:00
# 17426.10133298803
# ['ADM' 'APA' 'CF' 'CVX' 'CI' 'COP' 'CTVA' 'CTRA' 'DVN' 'FANG' 'LLY' 'EOG'
#  'XOM' 'FMC' 'HAL' 'HES' 'LW' 'MRO' 'MPC' 'MOH' 'NOC' 'OXY' 'PCG' 'PXD'
#  'PGR' 'REGN' 'SLB' 'VRTX']
# 2022-10-21 00:00:00
# 17405.99956620693
# ['APA' 'CF' 'COP' 'CTVA' 'CTRA' 'DVN' 'FANG' 'XOM' 'HAL' 'HES' 'LW' 'MRO'
#  'MOH' 'NOC' 'PCG' 'PXD' 'PGR' 'REGN' 'SLB' 'VRTX']
# 2022-10-25 00:00:00
# 18031.20735636443
# ['AMGN' 'APA' 'AZO' 'WRB' 'CPB' 'CTRA' 'GIS' 'LW' 'MRO' 'MOH' 'PCG' 'PGR'
#  'REGN']
# 2022-10-26 00:00:00
# 18291.50537460679
# ['AMGN' 'AZO' 'WRB' 'CPB' 'CTRA' 'FMC' 'GIS' 'K' 'LW' 'REGN']
# 2022-10-27 00:00:00
# 18360.36789803592
# ['AMGN' 'WRB' 'CPB' 'CTRA' 'FMC' 'GIS' 'GL' 'K' 'LW' 'PSX' 'REGN']
# 2022-10-28 00:00:00
# 18404.42576321707
# ['WRB' 'CPB' 'GL' 'LW' 'PSX']
# 2022-11-01 00:00:00
# 18894.606163367986
# ['WRB' 'GL' 'LW' 'TRGP' 'VLO']
# 2022-11-02 00:00:00
# 18818.015417717957
# ['ABBV' 'APA' 'CF' 'CVX' 'COP' 'CTRA' 'DVN' 'FANG' 'EOG' 'FMC' 'GD' 'GL'
#  'HAL' 'HII' 'LMT' 'MOS' 'NOC' 'NUE' 'PXD' 'SLB' 'STLD' 'TRGP' 'VLO']
# 2022-11-03 00:00:00
# 18225.064135564746
# ['ABBV' 'ABC' 'APA' 'CAH' 'CF' 'CVX' 'COP' 'CTRA' 'DVN' 'FANG' 'ELV' 'LLY'
#  'EOG' 'XOM' 'FMC' 'GD' 'GL' 'HAL' 'HES' 'HII' 'LMT' 'MRO' 'MCK' 'MOS'
#  'NOC' 'NUE' 'OXY' 'PCG' 'PSX' 'PXD' 'SLB' 'STLD' 'UNH' 'VLO']
# 2022-11-04 00:00:00
# 18965.28510008412
# ['ABC' 'AMGN' 'APA' 'AZO' 'CPB' 'CAH' 'CF' 'CVX' 'CI' 'COP' 'CTVA' 'CTRA'
#  'DVN' 'FANG' 'DLTR' 'ELV' 'LLY' 'EOG' 'XOM' 'GD' 'GPC' 'GL' 'HAL' 'HSY'
#  'HES' 'HII' 'LMT' 'MRO' 'MCK' 'NOC' 'OXY' 'PCG' 'PSX' 'PXD' 'PWR' 'SLB'
#  'STLD' 'UNH' 'VLO' 'VRTX']
# 2022-11-08 00:00:00
# 19031.435479371576
# ['ADM' 'ABC' 'AMGN' 'APA' 'AZO' 'CPB' 'CAH' 'CF' 'CVX' 'CI' 'CTVA' 'DVN'
#  'FANG' 'DLTR' 'ELV' 'LLY' 'XOM' 'GD' 'GIS' 'GPC' 'GL' 'HAL' 'HSY' 'HES'
#  'HUM' 'HII' 'LW' 'LMT' 'MRO' 'MCK' 'NOC' 'NRG' 'ORLY' 'OXY' 'PCG' 'PSX'
#  'PXD' 'PGR' 'PWR' 'SLB' 'STLD' 'VLO' 'VRTX']
# 2022-11-09 00:00:00
# 18988.047485234332
# ['ABBV' 'ADM' 'ABC' 'AMGN' 'ACGL' 'AZO' 'BMY' 'CPB' 'CF' 'CVX' 'CI' 'CTVA'
#  'DVN' 'DLTR' 'ELV' 'LLY' 'XOM' 'FSLR' 'GD' 'GIS' 'GPC' 'GILD' 'GL' 'HAL'
#  'HSY' 'HES' 'HUM' 'HII' 'LW' 'LMT' 'MCK' 'MRK' 'MOS' 'NOC' 'NRG' 'ORLY'
#  'OXY' 'PCG' 'PSX' 'PXD' 'PFG' 'PGR' 'RJF' 'REGN' 'SLB' 'STLD' 'TMUS'
#  'VRTX']
# 2022-11-10 00:00:00
# 19072.90670577496
# ['ABBV' 'ADM' 'ABC' 'ACGL' 'AZO' 'WRB' 'BMY' 'CPB' 'CF' 'CVX' 'CI' 'COP'
#  'CTVA' 'DVN' 'DLTR' 'ELV' 'LLY' 'XOM' 'FSLR' 'GD' 'GIS' 'GPC' 'GILD' 'GL'
#  'HAL' 'HSY' 'HES' 'HUM' 'HII' 'LW' 'LMT' 'MPC' 'MCK' 'MRK' 'MOS' 'NOC'
#  'NRG' 'ORLY' 'OXY' 'PSX' 'PXD' 'PFG' 'PGR' 'RJF' 'REGN' 'SLB' 'STLD'
#  'TMUS' 'VRTX' 'GWW']
# 2022-11-11 00:00:00
# 19015.849739068355
# ['ADM' 'AFL' 'ABC' 'APA' 'ACGL' 'AZO' 'WRB' 'BMY' 'CPB' 'CAH' 'CVX' 'CI'
#  'COP' 'CTVA' 'DVN' 'FANG' 'DLTR' 'ELV' 'LLY' 'ENPH' 'XOM' 'FSLR' 'GD'
#  'GIS' 'GPC' 'GILD' 'GL' 'HAL' 'HSY' 'HES' 'HUM' 'HII' 'LW' 'LMT' 'MRO'
#  'MPC' 'MCK' 'MRK' 'MOS' 'NOC' 'NRG' 'ORLY' 'OXY' 'PSX' 'PXD' 'PFG' 'PGR'
#  'PWR' 'RJF' 'SLB' 'STLD' 'TMUS' 'VRTX' 'GWW']
# 2022-11-15 00:00:00
# 18783.41581432096
# ['ADM' 'AFL' 'ABC' 'APA' 'ACGL' 'AZO' 'WRB' 'BMY' 'CAH' 'CVX' 'CI' 'COP'
#  'DVN' 'FANG' 'LLY' 'ENPH' 'XOM' 'FSLR' 'GD' 'GIS' 'GPC' 'GILD' 'HAL'
#  'HES' 'HII' 'LW' 'LMT' 'MRO' 'MPC' 'MCK' 'NOC' 'NRG' 'ORLY' 'OXY' 'PXD'
#  'PFG' 'PGR' 'PWR' 'RJF' 'SLB' 'STLD' 'TMUS' 'VRTX' 'GWW']
# 2022-11-16 00:00:00
# 18688.534070995076
# ['ADM' 'AFL' 'ABC' 'APA' 'ACGL' 'AZO' 'BKR' 'WRB' 'BMY' 'CAH' 'CVX' 'CI'
#  'COP' 'LLY' 'EOG' 'XOM' 'FSLR' 'FMC' 'GD' 'GIS' 'GPC' 'GILD' 'HAL' 'HES'
#  'LW' 'LMT' 'MRO' 'MPC' 'MCK' 'NOC' 'ORLY' 'PGR' 'PWR' 'RJF' 'SLB' 'TMUS'
#  'VRTX' 'GWW']
# 2022-11-17 00:00:00
# 18554.477643040354
# ['ADM' 'AFL' 'ABC' 'AMGN' 'APA' 'ACGL' 'AZO' 'BKR' 'WRB' 'BMY' 'CPB' 'CAH'
#  'CF' 'CVX' 'CI' 'COP' 'CTVA' 'LLY' 'EOG' 'XOM' 'FSLR' 'FMC' 'GD' 'GIS'
#  'GPC' 'GILD' 'HAL' 'HSY' 'HES' 'LW' 'LMT' 'MRO' 'MPC' 'MCK' 'NOC' 'ORLY'
#  'PGR' 'PWR' 'RJF' 'SLB' 'TMUS' 'TRGP' 'VRTX' 'GWW']
# 2022-11-18 00:00:00
# 18788.52422465666
# ['ADM' 'AFL' 'ABC' 'AMGN' 'APA' 'ACGL' 'AZO' 'BKR' 'WRB' 'BMY' 'CPB' 'CAH'
#  'CF' 'CVX' 'CI' 'COP' 'CTVA' 'FANG' 'LLY' 'EOG' 'XOM' 'FMC' 'GD' 'GIS'
#  'GPC' 'GILD' 'HAL' 'HSY' 'HES' 'LW' 'LMT' 'MRO' 'MPC' 'MCK' 'MRK' 'NOC'
#  'ORLY' 'OXY' 'PFG' 'PGR' 'PWR' 'RJF' 'SLB' 'TMUS' 'TRGP' 'GWW']
# 2022-11-22 00:00:00
# 19076.160282428667
# ['ADM' 'AFL' 'ABC' 'AMGN' 'APA' 'ACGL' 'AZO' 'BKR' 'WRB' 'BMY' 'CAH' 'CF'
#  'CVX' 'CI' 'COP' 'CTVA' 'FANG' 'DLTR' 'LLY' 'EOG' 'XOM' 'FMC' 'GD' 'GPC'
#  'GILD' 'HAL' 'HES' 'HII' 'LMT' 'MRO' 'MPC' 'MCK' 'MRK' 'MET' 'NOC' 'ORLY'
#  'OXY' 'PSX' 'PFG' 'PGR' 'PWR' 'RJF' 'SLB' 'TMUS' 'TRGP' 'GWW']
# 2022-11-23 00:00:00
# 19069.962382342692
# ['AFL' 'AMGN' 'APA' 'ACGL' 'BKR' 'CVX' 'COP' 'CTVA' 'FANG' 'DLTR' 'EOG'
#  'EQT' 'FMC' 'GPC' 'GILD' 'HAL' 'HWM' 'HUM' 'HII' 'INCY' 'MRO' 'MET' 'PSX'
#  'PFG' 'RJF' 'SLB' 'TRGP' 'WMB' 'GWW']
# 2022-11-29 00:00:00
# 18797.77396628294
# ['AFL' 'AMGN' 'APA' 'ACGL' 'BKR' 'CVX' 'COP' 'CTVA' 'DVN' 'FANG' 'ENPH'
#  'EOG' 'EQT' 'FMC' 'GILD' 'HAL' 'HWM' 'HUM' 'IBM' 'INCY' 'MRO' 'ON' 'PSX'
#  'PXD' 'PFG' 'SLB' 'TRGP' 'VLO' 'WMB']
# 2022-11-30 00:00:00
# 18989.25191727861
# ['AFL' 'AMGN' 'APA' 'BKR' 'BIIB' 'CAT' 'CVX' 'COP' 'DVN' 'FANG' 'ENPH'
#  'EOG' 'XOM' 'FSLR' 'FMC' 'GILD' 'HAL' 'HES' 'IBM' 'MRO' 'NUE' 'OXY' 'ON'
#  'PCAR' 'PSX' 'PXD' 'PFG' 'SLB' 'STLD' 'TRGP' 'VLO']
# 2022-12-01 00:00:00
# 19226.614587496806
# ['AFL' 'ALL' 'AMGN' 'AJG' 'ATO' 'BKR' 'BIIB' 'CAT' 'CVX' 'COP' 'DVN'
#  'FANG' 'ENPH' 'EOG' 'XOM' 'FSLR' 'FMC' 'GPC' 'HES' 'IBM' 'MPC' 'MET'
#  'TAP' 'MNST' 'NUE' 'OXY' 'ON' 'PCAR' 'PSX' 'PFG' 'PWR' 'ROL' 'SLB' 'STLD'
#  'SYY' 'VLO' 'VRTX' 'GWW']
# 2022-12-02 00:00:00
# 18893.718419269368
# ['ABBV' 'AFL' 'ALL' 'AMGN' 'AJG' 'ATO' 'BIIB' 'CAT' 'CVX' 'COP' 'ED'
#  'ENPH' 'EOG' 'XOM' 'FSLR' 'GD' 'GPC' 'HES' 'IBM' 'KR' 'LW' 'MPC' 'MET'
#  'TAP' 'MNST' 'NOC' 'NUE' 'ORLY' 'OXY' 'PCAR' 'PSX' 'PFG' 'PGR' 'PWR'
#  'RJF' 'ROL' 'SLB' 'STLD' 'SYY' 'TMUS' 'VLO' 'VRTX' 'GWW']
# 2022-12-06 00:00:00
# 18716.05635439239
# ['ABBV' 'ADM' 'AFL' 'AMGN' 'AJG' 'ATO' 'WRB' 'BIIB' 'CPB' 'CF' 'CVX' 'COP'
#  'ED' 'ENPH' 'EOG' 'RE' 'XOM' 'FSLR' 'GD' 'GPC' 'HSY' 'IBM' 'JKHY' 'KR'
#  'LW' 'MPC' 'MRK' 'MET' 'TAP' 'MNST' 'NOC' 'NUE' 'ORLY' 'OXY' 'PCAR' 'PSX'
#  'PXD' 'PFG' 'PGR' 'RJF' 'STLD' 'SYY' 'TMUS' 'TRV' 'VLO' 'VRTX' 'GWW']
# 2022-12-07 00:00:00
# 18552.901436315387
# ['ABBV' 'ADM' 'AFL' 'ABC' 'AMGN' 'APA' 'ATO' 'AZO' 'WRB' 'BIIB' 'BMY'
#  'CPB' 'CAH' 'CF' 'CVX' 'COP' 'CTVA' 'DE' 'ENPH' 'EOG' 'RE' 'XOM' 'FSLR'
#  'FMC' 'GD' 'GPC' 'GILD' 'GL' 'HSY' 'HWM' 'IBM' 'JKHY' 'LW' 'LDOS' 'LMT'
#  'MRO' 'MPC' 'MCK' 'MRK' 'MET' 'NUE' 'ORLY' 'PCG' 'PSX' 'PXD' 'PFG' 'PGR'
#  'SRE' 'STLD' 'TMUS' 'TRGP' 'TRV' 'VLO' 'VRTX' 'VICI' 'WMB']
# 2022-12-08 00:00:00
# 18726.60943937213
# ['ADM' 'AFL' 'ABC' 'APA' 'ACGL' 'ATO' 'AZO' 'WRB' 'BIIB' 'BMY' 'CAH' 'CF'
#  'CVX' 'CAG' 'COP' 'CTVA' 'DE' 'ELV' 'LLY' 'ENPH' 'EOG' 'RE' 'XOM' 'FSLR'
#  'FMC' 'GD' 'GPC' 'GILD' 'GL' 'HAL' 'HSY' 'HES' 'HWM' 'IBM' 'LW' 'LDOS'
#  'LMT' 'MRO' 'MPC' 'MCK' 'MRK' 'MET' 'NUE' 'ORLY' 'PCG' 'PSX' 'PFG' 'PGR'
#  'SRE' 'TMUS' 'TRGP' 'TRV' 'VLO' 'VRTX' 'VICI' 'WMB']
# 2022-12-09 00:00:00
# 18485.38301491461
# ['ADM' 'AFL' 'ABC' 'ACGL' 'ATO' 'AZO' 'WRB' 'BIIB' 'BMY' 'CAH' 'CF' 'CVX'
#  'CAG' 'CTVA' 'DE' 'ELV' 'LLY' 'ENPH' 'EOG' 'RE' 'XOM' 'FSLR' 'GD' 'GPC'
#  'GILD' 'GL' 'HAL' 'HES' 'HWM' 'HUM' 'IBM' 'KHC' 'LW' 'LDOS' 'LMT' 'MPC'
#  'MCK' 'MRK' 'MET' 'NUE' 'ORLY' 'PCG' 'PSX' 'PFG' 'PGR' 'SRE' 'TMUS'
#  'TRGP' 'TRV' 'VRTX']
# 2022-12-13 00:00:00
# 18727.731224330935
# ['ABBV' 'ADM' 'AFL' 'ABC' 'AMGN' 'ACGL' 'ATO' 'AZO' 'WRB' 'BIIB' 'BMY'
#  'CAH' 'CVX' 'CTVA' 'ELV' 'ENPH' 'EOG' 'RE' 'XOM' 'FSLR' 'GD' 'GIS' 'GPC'
#  'GILD' 'GL' 'HAL' 'HES' 'HWM' 'HUM' 'KHC' 'LW' 'LVS' 'LDOS' 'LMT' 'MPC'
#  'MCK' 'NOC' 'NUE' 'ORLY' 'PCG' 'PSX' 'PFG' 'PGR' 'SLB' 'SRE' 'TRGP' 'TRV'
#  'VRTX']
# 2022-12-14 00:00:00
# 18514.54761018417
# ['ABBV' 'AES' 'AFL' 'ALL' 'ABC' 'AMGN' 'APA' 'ACGL' 'ATO' 'BIIB' 'CAH'
#  'CVX' 'COP' 'CTVA' 'FANG' 'ELV' 'ENPH' 'EOG' 'RE' 'FSLR' 'FMC' 'GD' 'GIS'
#  'GILD' 'GL' 'HAL' 'HSY' 'HES' 'HWM' 'INCY' 'LW' 'LVS' 'MRO' 'MPC' 'MCK'
#  'NOC' 'NUE' 'PCG' 'PSX' 'PFG' 'PWR' 'SLB' 'SRE' 'STLD' 'TRGP' 'TRV'
#  'VICI' 'WMB']
# 2022-12-15 00:00:00
# 18270.70286251661
# ['ABBV' 'AES' 'AFL' 'ALL' 'ABC' 'AMGN' 'APA' 'ACGL' 'BIIB' 'CAH' 'CVX'
#  'CI' 'COP' 'CTVA' 'DE' 'FANG' 'LLY' 'ENPH' 'EOG' 'RE' 'FSLR' 'FMC' 'GD'
#  'GIS' 'GILD' 'GL' 'HAL' 'HSY' 'HES' 'HWM' 'HII' 'INCY' 'LW' 'LVS' 'MRO'
#  'MCK' 'MRK' 'NOC' 'NUE' 'PSX' 'PFG' 'PWR' 'SLB' 'SRE' 'STLD' 'TMUS'
#  'VICI' 'WMB']
# 2022-12-16 00:00:00
# 17973.769032420714
# ['ABBV' 'ATVI' 'AFL' 'ABC' 'AMGN' 'ACGL' 'WRB' 'BIIB' 'BMY' 'CAH' 'CI'
#  'DE' 'LLY' 'ENPH' 'GIS' 'GPC' 'GILD' 'GL' 'HSY' 'HWM' 'HII' 'LW' 'LVS'
#  'LMT' 'MCK' 'MRK' 'NOC' 'NUE' 'PGR' 'PWR' 'SRE' 'STLD' 'TMUS' 'VRTX'
#  'WMB']
# 2022-12-20 00:00:00
# 18012.46285110936
# ['ABBV' 'ATVI' 'ABC' 'AMGN' 'ACGL' 'WRB' 'BMY' 'CAH' 'CI' 'DE' 'LLY'
#  'ENPH' 'GIS' 'GPC' 'GL' 'HSY' 'HWM' 'HII' 'LW' 'LVS' 'LMT' 'MCK' 'MRK'
#  'NOC' 'PGR' 'PWR' 'STLD' 'VRTX']
# 2022-12-21 00:00:00
# 18117.898251709124
# ['ABBV' 'AES' 'ABC' 'AMGN' 'WRB' 'CPB' 'CAH' 'CI' 'DE' 'LLY' 'ENPH' 'RE'
#  'FMC' 'GIS' 'GPC' 'HSY' 'HWM' 'LVS' 'LDOS' 'MCK' 'MRK' 'NOC' 'PCAR' 'PCG'
#  'PFG' 'PGR' 'PWR' 'RTX' 'REGN' 'STLD' 'TRV' 'ULTA' 'VICI']
# 2022-12-22 00:00:00
# 18210.74417818624
# ['ABBV' 'AES' 'AMGN' 'CPB' 'CI' 'DE' 'ENPH' 'RE' 'FMC' 'GIS' 'GPC' 'HSY'
#  'HWM' 'LVS' 'LDOS' 'MRK' 'NUE' 'PCAR' 'PCG' 'PFG' 'PWR' 'RTX' 'REGN'
#  'STLD' 'TRV' 'ULTA' 'VICI']
# 2022-12-23 00:00:00
# 18129.75580229394
# ['ABBV' 'AES' 'CPB' 'CI' 'ENPH' 'GIS' 'GPC' 'HSY' 'HWM' 'LVS' 'NUE' 'PCG'
#  'PFG' 'PWR' 'STLD']
# 2022-12-27 00:00:00
# 18237.556609799427
# ['ABBV' 'AES' 'BKR' 'CPB' 'CI' 'ENPH' 'GIS' 'HSY' 'HWM' 'LVS' 'PCG' 'PWR'
#  'STLD' 'WMB']
# 2022-12-28 00:00:00
# 18209.747562611126
# ['ABBV' 'AES' 'BKR' 'CPB' 'FSLR' 'GIS' 'LVS' 'PCG' 'PWR' 'SRE' 'STLD'
#  'WMB']
# 2022-12-29 00:00:00
# 17917.343136546715
# ['CPB' 'CAH' 'FSLR' 'LVS' 'PCG' 'SRE']
# 2022-12-30 00:00:00
# 17791.339940109854
# ['ABC' 'CPB' 'CAH' 'FSLR' 'LVS' 'MRO']
# 2023-01-03 00:00:00
# 17993.360548751098
# ['ADM' 'ABC' 'ACGL' 'CPB' 'CAH' 'DE' 'FSLR' 'GIS' 'HSY' 'MRO' 'MCK' 'STLD']
# 2023-01-04 00:00:00
# 17703.02322776981
# ['ADM' 'ABC' 'APA' 'ACGL' 'CPB' 'CAH' 'CI' 'DE' 'EOG' 'FSLR' 'GIS' 'GPC'
#  'GL' 'HAL' 'HSY' 'HES' 'LW' 'LMT' 'MPC' 'MCK' 'MRK' 'PCG' 'SLB' 'STLD'
#  'TRV']
# 2023-01-05 00:00:00
# 17804.70313339498
# ['ABC' 'APA' 'ACGL' 'WRB' 'CPB' 'CAH' 'CVX' 'CI' 'COP' 'LLY' 'EOG' 'RE'
#  'XOM' 'FSLR' 'GPC' 'GL' 'HAL' 'HES' 'LW' 'LMT' 'MPC' 'MCK' 'MRK' 'NOC'
#  'PCG' 'PSX' 'SLB' 'STLD' 'TRGP' 'TRV' 'VLO']
# 2023-01-06 00:00:00
# 18172.76448283203
# ['ABC' 'APA' 'ACGL' 'WRB' 'CPB' 'CAH' 'CVX' 'CI' 'COP' 'LLY' 'EOG' 'RE'
#  'XOM' 'FSLR' 'GPC' 'GL' 'HAL' 'HES' 'LMT' 'MPC' 'MCK' 'MRK' 'NOC' 'ORLY'
#  'PCG' 'PSX' 'SLB' 'STLD' 'TRGP' 'VLO']
# 2023-01-10 00:00:00
# 18209.18273950843
# ['ABC' 'APA' 'ACGL' 'AZO' 'WRB' 'CPB' 'CAH' 'CVX' 'CI' 'COP' 'LLY' 'EOG'
#  'XOM' 'GPC' 'HAL' 'HES' 'LMT' 'MPC' 'MCK' 'NOC' 'ORLY' 'PCG' 'SLB' 'TRGP'
#  'VLO']
# 2023-01-11 00:00:00
# 18342.017038784154
# ['APA' 'ACGL' 'AZO' 'CPB' 'CVX' 'CI' 'COP' 'LLY' 'EOG' 'XOM' 'GPC' 'LMT'
#  'MPC' 'ORLY' 'PCG']

# %%
spy['benchmark-spy(%)'] = spy['Close']/spy['Close'].iloc[0]*100
result['benchmark-spy(%)'] =  spy.set_index('Date')['benchmark-spy(%)']

# %%
# plot the return and calculate the annualized return and MDD (maximum draw down) for both strategy
plt.rcParams["figure.figsize"] = (15,6)
plt.plot(result.Return_without_trailing, label='Return without Annualized_return of Portfolio based on EMA and SMA cross-over strategy')
plt.plot(result['benchmark-spy(%)'], label='benchmark-spy(%)')
plt.legend()
print('Annualized_return of Portfolio based on EMA and SMA cross-over strategy:',annualized (result,'Return_without_trailing'))
print('MDD of Portfolio based on EMA AND SMA cross-over strategy:', MDD(result,'Return_without_trailing'))

print('Annualized_return of benchmark-spy:',annualized (result,'benchmark-spy(%)'))
print('MDD of benchmark-spy:', MDD(result,'benchmark-spy(%)'))
# Out:
# Annualized_return of Portfolio based on EMA and SMA cross-over strategy: 34.18380965324579
# MDD of Portfolio based on EMA AND SMA cross-over strategy: -41.41821104812868
# Annualized_return of benchmark-spy: 24.85905370367394
# MDD of benchmark-spy: -32.37571510071729
