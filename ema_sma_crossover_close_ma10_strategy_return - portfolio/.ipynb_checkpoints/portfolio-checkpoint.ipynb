# %%
# Import necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
import datetime 
from pandas_datareader import data as pdr
import pandas_ta as ta
import seaborn as sns
import yfinance as yf

# %%
# data = dataframe in pandas format to calculate sma
# sma_value = is an array to calcuate the lenth of sma 
# variable = variable used to calculate sma, it can be a "Close", or "Adj Close" in string format
def sma(data,sma_value,variable):
     # auto assign a variable name based on length of sma 
    variable_name = 'SMA'+ str(sma_value)
    # calculate sma 
    data[variable_name] =ta.sma(data[variable], length=sma_value)
    # return sma variable calculated 
    return data[variable_name]
# sym =  string format, ticker name
# ema value = is an array to calcuate the lenth of ema 
# sma_value = is an array to calcuate the lenth of sma 
# close = variable use for calcuate sma and ema, either "Close"or "Adj Close" in string format
def getdata(sym,sma_value,ema_value,close):
    yf.pdr_override()
    today = datetime.datetime.now()
    df = pdr.get_data_yahoo(sym, start=datetime.datetime(today.year-10,today.month, 1),
                                    end=datetime.datetime(today.year, today.month, today.day)).reset_index()
    df['ticker'] =sym
        
    for i in sma_value:
        variable_name = 'SMA'+ str(i)
        df[variable_name] = sma(df,i,close)
    
    for i in ema_value:
        variable_name = 'EMA'+ str(i)
        df[variable_name] = ema(df,i,close)
        
    df['Bearish_engulfing'] = np.nan
    df['Bearish swing'] = np.nan
    df['Bearish pinbar'] = np.nan
    for i in range(2,df.shape[0]):
        current = df.iloc[i,:]
        prev = df.iloc[i-1,:]
        prev_2 = df.iloc[i-2,:]
        realbody = abs(current['Open'] - current['Close'])
        candle_range = current['High'] - current['Low']
        idx = df.index[i]
        df.loc[idx,'Bearish_engulfing'] = current['High'] > prev['High'] and current['Low'] < prev['Low'] and realbody >= 0.8 * candle_range and current['Close'] < current['Open']
        df.loc[idx,'Bearish swing'] = current['High'] < prev['High'] and prev['High'] > prev_2['High']
        df.loc[idx,'Bearish pinbar'] = realbody <= candle_range/3 and max(current['Open'] , current['Close']) < (current['High'] + current['Low'])/2 and current['High'] > prev['High']        
    return df
# data = dataframe in pandas format to calculate ema
# ema_value = is an array to calcuate the lenth of ema 
# variable = variable used to calculate sma, it can be a "Close", or "Adj Close" in string format
def ema(data,ema_value,variable):
    # auto assign a variable name based on length of ema 
    variable_name = 'EMA'+ str(ema_value)
    # calculate ema 
    data[variable_name] = data[variable].ewm(span=ema_value, adjust=False).mean()
     # return ema variable calculated 
    return data[variable_name]

# %%
# buy when price > SMA120 and SMA10>EMA10, annual return> 20 and (RSI <70 or RSI >30)
# sell when sma10 < ema10 or bearish engulfing candles or annual return < 20 or price< sma120
############input###########
#data = dataframe with variable needed
#sma_selected, cross over sma selected
#ema_selected, cross over ema selected
def Generate_signal(data, sma_selected,ema_selected):    
    #table start
    df_init =  data.copy()
    
    '''To make sure row arrange in an ascending order'''
    df.sort_values(by = 'Date',inplace=True)
    
    '''Process data by remove Null value in moving average varaible that your want to used for triggered''' 
    df_init.dropna(subset=[ema_selected,sma_selected],inplace=True)
    '''generate as 1 if Adj close is higher than variable you want to test, generate as -1 if Adj close is less than the
    variable you want to test in a signal variable  
    '''
    # create a signal variable
    df_init['signal'] = np.nan 
    # trigger a buy only if it is a up trend 
    df_init.loc[(df_init[sma_selected]>=df_init[ema_selected]) &(df_init['Price']>df_init['SMA120'])&((df_init['RSI']<70)|(df_init['RSI']>30)),'signal'] = 1
    
    # just triggered sell as close is less than variable triggered
    df_init.loc[((df_init[sma_selected]<df_init[ema_selected]) )| (df_init['Bearish_engulfing']==True)|(df_init['Price']<=df_init['SMA120']),'signal'] = -1
    
    # if close > variable triggered but sma20<= sma 200, let it be do nothing
    df_init['signal'].fillna(0,inplace=True) 
    
    ''' move the signal of today to tmr, thus, we need to define a shift(1), as the signal buy is based on yesterday'''
    df_init['signal'] = df_init['signal'].shift(1)
    
    '''after we have a buy and sell signal, lets create a hold signal which is equal to 2 after a buy signal and
    a do nothing signal which is equal to 0 after a sell signal'''
    
    # In order to make a decision on a hold or do nothing signal based on yesterday signal we need to create a for loop 
    # a calendar date should be created to used for a a for loop 
    date_list = df_init.Date.unique()
    
    # declare a first day, the first date is a null in signal as there is no yesterday data for first data
    first_date = date_list[0]
    
    # declare a previous day 
    prev = first_date 
    
    for i in date_list:
        if i == first_date:
            df_init.loc[df_init.Date == i,'signal'] = 0 
        else:
            # if you have a sell signal yesterday, you should have a do nothing signal today
            if (df_init.loc[df_init.Date == prev,'signal'].values[0]==-1):
                df_init.loc[df_init.Date == i,'signal']=0 
            # if you have a buy signal yesterday, you should have a hold signal today
            elif (df_init.loc[df_init.Date == prev,'signal'].values[0]==1):
                df_init.loc[df_init.Date == i,'signal'] = 2
              
            # if you have a hold signal yesterday and you do not have a sell signal today, you should have a hold signal today
            elif ((df_init.loc[df_init.Date == prev,'signal'].values[0]==2)&(df_init.loc[df_init.Date == i,'signal'].values[0]!=-1) ):
                df_init.loc[df_init.Date == i,'signal'] = 2
                
            # if you have a do nothing signal yesterday and today is a sell signal, you should equal to have a do nothing signal
            elif ((df_init.loc[df_init.Date == prev,'signal'].values[0]==0)&(df_init.loc[df_init.Date == i,'signal'].values[0]==-1) ):
                df_init.loc[df_init.Date == i,'signal'] = 0
                
        # redeclare your previous date before to next day in for loop
        prev = i
    
    return df_init

# %%
# data = dataframe with signal to trigger
# capital = assume starting capital
from statistics import mean
def backtest_strategy(data,capital):   
    
    #table start
    df_init =  data.copy()
    df_init.set_index('Date',inplace=True) 
    
    #assign dummy row - day before the trade
    start_date = pd.DataFrame(columns=data.columns,index=[df_init.index.min()- datetime.timedelta(days=1)])
    df_init = df_init.append(start_date)
    
    #initiat 2 variable: cash and units which represent each status of cash and units of apple holding for each day
    df_init = df_init.assign(cash=np.nan,units = 0)
    
    #assign capital for first dummy day assigned to be capital defined in function
    df_init.loc[pd.Series(df_init.index.min()), 'cash'] = capital
    
    # obtain list of calendar 
    calendar = pd.Series(df_init.index.sort_values().unique()).iloc[1:]
    
    ''' assign a variable which is trade, earn trade and lost trade to calculate total number of trade, total earn trade 
    and total lost trade'''
    trade = 0
    earn_trade = 0
    loss_trade = 0
    
    ''' create an array to keep all earn value and lost value for each trade'''
    earn_value =[]
    lost_value =[]

    for date in calendar:
        
        #get yesterday data
        prev_date = df_init.index[df_init.index<date].unique().sort_values()[-1]
        
        # calculate total stock value of yesterday 
        stock_holding = df_init.loc[(df_init.index==prev_date), 'units'].values[0]*df_init.loc[(df_init.index==date),'Price'].values[0]
        
        # total portfolio value by add cash and stock value of yesterday 
        port_value = stock_holding + df_init.loc[prev_date, 'cash'].sum()
        
        
        # if signal is do nothing, mean our cash = portfolio value and units=0
        if df_init.loc[(df_init.index==date), 'signal'].values[0] == 0:          
            df_init.loc[(df_init.index==date), 'units'] = 0
            df_init.loc[(df_init.index==date), 'cash'] =port_value        
        #if we have a buy signal 
        #start to calculate the trade
        #we start to calculate start_cap which represent the starting capital for each trade
        #unit_buy is total unit buy based on port_value available
        elif df_init.loc[(df_init.index==date), 'signal'].values[0] == 1:
            trade+=1
            start_cap = port_value 
            unit_buy = port_value/df_init.loc[(df_init.index==date), 'Price'].values[0]
            df_init.loc[(df_init.index==date), 'units'] = unit_buy
            df_init.loc[(df_init.index==date), 'cash'] = port_value - unit_buy*df_init.loc[(df_init.index==date), 'Price'].values[0]        
#             df_init.loc[(df_init.index==date), 'CL_price'] = df_init.loc[(df_init.index==date), 'Price'].values[0] * 0.95
#             df_init.loc[(df_init.index==date), 'CL_based_price'] = df_init.loc[(df_init.index==date), 'Price'].values[0]
        #if we have a hold signal or do nothing signal,
        #mean today units hold and cash are same as yesterday units hold and yesterday cash
        elif ((df_init.loc[(df_init.index==date), 'signal'].values[0] == 2) | (df_init.loc[(df_init.index==date), 'signal'].values[0] == 0)): 
            df_init.loc[(df_init.index==date), 'units'] = df_init.loc[(df_init.index==prev_date), 'units'].values[0]
            df_init.loc[(df_init.index==date), 'cash'] =df_init.loc[(df_init.index==prev_date), 'cash'].values[0]
#             if  df_init.loc[(df_init.index==date), 'Price'].values[0] > df_init.loc[(df_init.index==prev_date), 'CL_based_price'].values[0]:
#                 df_init.loc[(df_init.index==date), 'CL_price'] = df_init.loc[(df_init.index==date), 'Price'].values[0] * 0.95
#                 df_init.loc[(df_init.index==date), 'CL_based_price'] = df_init.loc[(df_init.index==date), 'Price'].values[0]
#             else:
#                 df_init.loc[(df_init.index==date), 'CL_price'] = df_init.loc[(df_init.index==prev_date), 'CL_price'].values[0]
#                 df_init.loc[(df_init.index==date), 'CL_based_price'] =  df_init.loc[(df_init.index==prev_date), 'CL_based_price'].values[0]
        #if we have a sell signal,
        #1. we sell all the units at the today open price and thus units =0 and cash = port_value
        #2. we calculate the total earn/lost of this trade by using port_value - start cap of the trade and store as v variable
        #3. if v> 0, we store as earn_value array
        #4. if v<0, we store as lost trade
        elif (df_init.loc[(df_init.index==date), 'signal'].values[0] == -1) :
            df_init.loc[(df_init.index==date), 'units'] = 0
            df_init.loc[(df_init.index==date), 'cash'] =port_value 
            if (start_cap is None):
                0
            else:
                v = port_value  - start_cap 
                if v>= 0: 
                    earn_value.append(v)
                    earn_trade +=1
                elif v<0: 
                    lost_value.append(v)
                    loss_trade+=1

    # calculate current value of the strategy, the formula = unit holding * Price + cash available
    df_init['Total_value_todate'] = df_init['units']*df_init['Price'] + df_init['cash'] 
    
    # append 0 to earn value array to prevent later calculation fail if there is no any earn trade
    earn_value.append(0)
    #remove dummy rows
    df_init.drop(df_init[df_init.index == df_init.index.min()].index,axis=0,inplace=True)
  
    # get summarize of total portfolio value, return by date, benchmark_index
    total_port_value = pd.DataFrame(df_init.groupby([df_init.index])['Total_value_todate'].sum())
    total_port_value['Return_without_trailing'] = total_port_value['Total_value_todate']/total_port_value['Total_value_todate'].iloc[0] *100
    total_port_value['Return_trailing_12m'] = total_port_value['Total_value_todate']/total_port_value['Total_value_todate'].shift(12)*100

    # to print out statistic to know how your strategy perform and the win change of this strategy
    print('total_trade:',trade)
    print('earn_trade:',earn_trade)
    print('lost_trade:',loss_trade)
    print('win_chance:',earn_trade/trade)
    print('Max earning:',max(earn_value))
    print('Max lost:',min(lost_value))
    print('Average lost:',mean(lost_value))
    print('Average Win:',mean(earn_value))
    # Create a dictionary with the data for the new data frame
#     data = {
#         'ticket': [data.ticker.values[0]],
#         'total_trade' : [trade],
#         'Average Win': [mean(earn_value)],
#         'Average lost' :  [mean(lost_value)],
#         'win_chance': [earn_trade/trade]
#     }

    # Create the new data frame
    df = pd.DataFrame(data)
    #result_data =  pd.concat([df , result_data])
    return total_port_value, df_init

# %%
def backtest_strategy_portfolio(data,capital):   
    
    #table start
    df_init =  data.copy()
    df_init.set_index('Date',inplace=True) 
    df_init =df_init[df_init['Return_trailing_12m_hold'].notna()]
    #stock_pick_df = stock_pick_data.copy()
    
    
    #assign dummy row - day before the trade
    start_date = pd.DataFrame(columns=data.columns,index=[df_init.index.min()- datetime.timedelta(days=1)])
    df_init = df_init.append(start_date)
    
    #initiat 2 variable: cash and units which represent each status of cash and units of apple holding for each day
    df_init = df_init.assign(cash=np.nan,units = 0)
    
    #assign capital for first dummy day assigned to be capital defined in function
    df_init.loc[pd.Series(df_init.index.min()), 'cash'] = capital
    
    # obtain list of calendar 
    calendar = pd.Series(df_init[df_init['ticker']!='spy'].index.sort_values().unique()).iloc[1:]
    #sp_calendar = pd.Series(stock_pick_df.index.sort_values().unique())
    i=0
    
    for date in calendar:
        
        #emp = stock_pick_df[(stock_pick_df['Return_without_trailing']>=stock_pick_df['hold_without_sell_return (%)'])&(stock_pick_df['Return_trailing_12m']>100)&(stock_pick_df['Return_without_trailing']>120)&(stock_pick_df.index==date)].sort_values(by='Return_without_trailing',ascending=False)[:10]
        #temp = stock_pick_df.sort_values(by='RSI',ascending=False)[:10]
        #stock_pick = stock_pick_df[(stock_pick_df['Return_trailing_12m']>120)&(stock_pick_df.index==date)].sort_values(by='Return_trailing_12m_hold',ascending=False)[:10]
        #stock_pick = df_init[(df_init.index==date)].ticker.unique() 
        stock_pick = df_init[(df_init.index==date) &((df_init.signal==1)|(df_init.signal==2))& (df_init.Return_trailing_12m_hold >120)].sort_values(by='Return_trailing_12m_hold',ascending=False).ticker.unique()[:5]
        
        
        
        #get yesterday data
        prev_date = df_init.index[df_init.index<date].unique().sort_values()[-1]
        
        
        # calculate total stock value of yesterday 
        total_stock_holding=[]
        cash = []
        for stock in  df_init.loc[(df_init.index==prev_date) &((df_init.signal==1)|(df_init.signal==2))].ticker.unique():
#             print(stock)
#             print(prev_date)
#             print("unit")
#             print(df_init.loc[(df_init.index==prev_date)&(df_init['ticker']==stock), 'units'].values[0])
#             print("Price")
#             print(date)
#             print(df_init.loc[(df_init.index==date)&(df_init['ticker']==stock),'Price'].values[0])
            stock_holding = df_init.loc[(df_init.index==prev_date)&(df_init['ticker']==stock), 'units'].values[0]*df_init.loc[(df_init.index==date)&(df_init['ticker']==stock),'Price'].values[0]
            total_stock_holding.append(stock_holding)
            cash_value = df_init.loc[(df_init.index==prev_date)&(df_init['ticker']==stock), 'cash'].values[0]
            cash.append(cash_value)
        
        # total portfolio value by add cash and stock value of yesterday 
        port_value = sum(total_stock_holding) + df_init.loc[prev_date, 'cash'].sum()
        
        # reallocation to each stock
        if len(df_init.loc[(df_init.index==date) &((df_init.signal==1)|(df_init.signal==2))& (df_init.ticker.isin(stock_pick))].ticker.unique())==0:
            number_stock =1 
            df_init.loc[((df_init.index==date)&(df_init['ticker']=='spy')), 'signal'] = 1
            stock_pick = np.append(stock_pick,'spy')
            
        else: 
            number_stock = len(df_init.loc[(df_init.index==date) &((df_init.signal==1)|(df_init.signal==2))& (df_init.ticker.isin(stock_pick))].ticker.unique())

        allocation_each = port_value/number_stock
        print(date)
        print(port_value)
        print(stock_pick)
        
        
        for stock in stock_pick:
            # if signal is do nothing or sell, mean our cash = portfolio value and units=0
            if ((df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'signal'].values[0] == 0)|(df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'signal'].values[0] == -1)):          
                df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'units'] = 0
                df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'cash'] = 0
            #if we have a buy signal 
            #start to calculate the trade
            #we start to calculate start_cap which represent the starting capital for each trade
            #unit_buy is total unit buy based on port_value available
            elif ((df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'signal'].values[0] == 1)|(df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'signal'].values[0] == 2)):
                unit_buy = allocation_each /df_init.loc[((df_init.index==date)&(df_init['ticker']==stock)), 'Price'].values[0]
                df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'units'] = unit_buy
                df_init.loc[(df_init.index==date)&(df_init['ticker']==stock), 'cash'] = allocation_each - unit_buy*df_init.loc[((df_init.index==date)&(df_init['ticker']==stock)), 'Price'].values[0]
        
        i=i+1
    # calculate current value of the strategy, the formula = unit holding * Price + cash available
    df_init['Total_value_todate'] = df_init['units']*df_init['Price'] + df_init['cash'] 
    
    #remove dummy rows
    df_init.drop(df_init[df_init.index == df_init.index.min()].index,axis=0,inplace=True)
  
    # get summarize of total portfolio value, return by date, benchmark_index
    total_port_value = pd.DataFrame(df_init.groupby([df_init.index])['Total_value_todate'].sum())
    total_port_value['Return_without_trailing'] = total_port_value['Total_value_todate']/total_port_value['Total_value_todate'].iloc[0] *100
    total_port_value['Return_trailing_12m'] = total_port_value['Total_value_todate']/total_port_value['Total_value_todate'].shift(12)*100

    return total_port_value, df_init

# %%
# annualized return 
# df =data with return 
# variable = variable name of return
def annualized(df,variable):
    days_held =df.shape[0]
    Return = (df.iloc[-1][variable] - df.iloc[0][variable])/df.iloc[0][variable]
    ar = ((1+Return) ** (365/days_held))-1
    # get annualized in %
    return ar*100
# maximum drawdown 
# df =data with return 
# variable = variable name of return
def MDD(df,variable):
    window = 252
    Roll_Max = df[variable].rolling(window, min_periods=1).max()
    Drawdown = df[variable]/Roll_Max - 1.0
    mdd = Drawdown.min()
    # get drawdown in %
    return mdd*100

# %%
# Function to calculate RSI
def RSI(prices, n=14):
  # Get the difference in price from previous step
    delta = prices.diff()

  # Get rid of the first row, which is NaN since it did not have a previous
  # row to calculate the differences
    delta = delta[1:]

  # Make the positive gains (up) and negative gains (down) Series
    up, down = delta.copy(), delta.copy()
    up[up < 0] = 0
    down[down > 0] = 0

  # Calculate the SMA
    roll_up = up.rolling(n).mean()
    roll_down = down.abs().rolling(n).mean()

  # Calculate the RSI based on SMA
    RS = roll_up / roll_down
    RSI = 100.0 - (100.0 / (1.0 + RS))

    return RSI

# %%
def Calculate_Return (df): 
    
    df['12_months_date'] = pd.to_datetime(df.Date) +  pd.DateOffset(months=12) 
    
    df_12_ago = df[['ticker','Date','12_months_date','Close']].rename(
    columns={'Close':'df_ago','Date':'Date_12_ago','12_months_date':'Date'})
    
    df_uptodate = df.rename(
    columns={'Close':'Price'})
    
    df_12 = df_12_ago.merge(df_uptodate,how = 'left', on=['ticker','Date'])
    df_12.drop(df_12[df_12.Price.isna()].index,axis=0)
    df_12.set_index('Date',inplace=True) 
    
    df_12['Return'] = ((df_12['Price'] - df_12['df_ago']) /  df_12['df_ago'])*100
    
    return df_12

# %%
table=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df = table[0]
ticker = df['Symbol'].values
result_data = pd.DataFrame()

# %%
summary = pd.DataFrame()
all_signal = pd.DataFrame()
for i in ticker:
    # Read in the data
    try:
        print(i)
        df = getdata(i,sma_value = [5,10,15,20,50,60,120,150,200],ema_value = [5,10,15,20,50,60,120,150,200],close = "Close")
        if df is not None:
            df['RSI'] = RSI(df['Close'])
            #df =Calculate_Return (df)
            df['Price']=df['Close']
            df.reset_index(inplace=True)
            df_signal = Generate_signal(df,'SMA10','EMA10')
            # back test your strategy using Open price as price action to buy sell on particular day
            df_signal['Price']=df_signal['Open']
            df_backtest = df_signal[['Date','Price','signal','Open']].copy()
            #result, hold_detail = backtest_strategy(df_backtest,1000)
            # calculate the return without trailing of hold without sell 
            df_signal['hold_without_sell_return (%)'] = df_signal['Close']/df_signal['Close'].iloc[0]*100
            df_signal['Return_trailing_12m_hold'] =df_signal['Close']/df_signal['Close'].shift(250)*100
            df_signal['Return_trailing_12m_hold'] = df_signal['Return_trailing_12m_hold'].shift(1)
    #         result['hold_without_sell_return (%)'] = df_signal.set_index('Date')['hold_without_sell_return (%)']
    #         result['Return_trailing_12m_hold'] = df_signal.set_index('Date')['Return_trailing_12m_hold']
            df_signal['ticker']=i
            all_signal = pd.concat([all_signal,df_signal])
            #summary = pd.concat([result,summary])
            df= None
    except:
        pass # doing nothing on exception
# Out:
# MMM
# [*********************100%***********************]  1 of 1 completed
# AOS
# [*********************100%***********************]  1 of 1 completed
# ABT
# [*********************100%***********************]  1 of 1 completed
# ABBV
# [*********************100%***********************]  1 of 1 completed
# ACN
# [*********************100%***********************]  1 of 1 completed
# ATVI
# [*********************100%***********************]  1 of 1 completed
# ADM
# [*********************100%***********************]  1 of 1 completed
# ADBE
# [*********************100%***********************]  1 of 1 completed
# ADP
# [*********************100%***********************]  1 of 1 completed
# AAP
# [*********************100%***********************]  1 of 1 completed
# AES
# [*********************100%***********************]  1 of 1 completed
# AFL
# [*********************100%***********************]  1 of 1 completed
# A
# [*********************100%***********************]  1 of 1 completed
# APD
# [*********************100%***********************]  1 of 1 completed
# AKAM
# [*********************100%***********************]  1 of 1 completed
# ALK
# [*********************100%***********************]  1 of 1 completed
# ALB
# [*********************100%***********************]  1 of 1 completed
# ARE
# [*********************100%***********************]  1 of 1 completed
# ALGN
# [*********************100%***********************]  1 of 1 completed
# ALLE
# [*********************100%***********************]  1 of 1 completed
# LNT
# [*********************100%***********************]  1 of 1 completed
# ALL
# [*********************100%***********************]  1 of 1 completed
# GOOGL
# [*********************100%***********************]  1 of 1 completed
# GOOG
# [*********************100%***********************]  1 of 1 completed
# MO
# [*********************100%***********************]  1 of 1 completed
# AMZN
# [*********************100%***********************]  1 of 1 completed
# AMCR
# [*********************100%***********************]  1 of 1 completed
# AMD
# [*********************100%***********************]  1 of 1 completed
# AEE
# [*********************100%***********************]  1 of 1 completed
# AAL
# [*********************100%***********************]  1 of 1 completed
# AEP
# [*********************100%***********************]  1 of 1 completed
# AXP
# [*********************100%***********************]  1 of 1 completed
# AIG
# [*********************100%***********************]  1 of 1 completed
# AMT
# [*********************100%***********************]  1 of 1 completed
# AWK
# [*********************100%***********************]  1 of 1 completed
# AMP
# [*********************100%***********************]  1 of 1 completed
# ABC
# [*********************100%***********************]  1 of 1 completed
# AME
# [*********************100%***********************]  1 of 1 completed
# AMGN
# [*********************100%***********************]  1 of 1 completed
# APH
# [*********************100%***********************]  1 of 1 completed
# ADI
# [*********************100%***********************]  1 of 1 completed
# ANSS
# [*********************100%***********************]  1 of 1 completed
# AON
# [*********************100%***********************]  1 of 1 completed
# APA
# [*********************100%***********************]  1 of 1 completed
# AAPL
# [*********************100%***********************]  1 of 1 completed
# AMAT
# [*********************100%***********************]  1 of 1 completed
# APTV
# [*********************100%***********************]  1 of 1 completed
# ACGL
# [*********************100%***********************]  1 of 1 completed
# ANET
# [*********************100%***********************]  1 of 1 completed
# AJG
# [*********************100%***********************]  1 of 1 completed
# AIZ
# [*********************100%***********************]  1 of 1 completed
# T
# [*********************100%***********************]  1 of 1 completed
# ATO
# [*********************100%***********************]  1 of 1 completed
# ADSK
# [*********************100%***********************]  1 of 1 completed
# AZO
# [*********************100%***********************]  1 of 1 completed
# AVB
# [*********************100%***********************]  1 of 1 completed
# AVY
# [*********************100%***********************]  1 of 1 completed
# BKR
# [*********************100%***********************]  1 of 1 completed
# BALL
# [*********************100%***********************]  1 of 1 completed
# BAC
# [*********************100%***********************]  1 of 1 completed
# BBWI
# [*********************100%***********************]  1 of 1 completed
# BAX
# [*********************100%***********************]  1 of 1 completed
# BDX
# [*********************100%***********************]  1 of 1 completed
# WRB
# [*********************100%***********************]  1 of 1 completed
# BRK.B
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BRK.B: No data found, symbol may be delisted
# BBY
# [*********************100%***********************]  1 of 1 completed
# BIO
# [*********************100%***********************]  1 of 1 completed
# TECH
# [*********************100%***********************]  1 of 1 completed
# BIIB
# [*********************100%***********************]  1 of 1 completed
# BLK
# [*********************100%***********************]  1 of 1 completed
# BK
# [*********************100%***********************]  1 of 1 completed
# BA
# [*********************100%***********************]  1 of 1 completed
# BKNG
# [*********************100%***********************]  1 of 1 completed
# BWA
# [*********************100%***********************]  1 of 1 completed
# BXP
# [*********************100%***********************]  1 of 1 completed
# BSX
# [*********************100%***********************]  1 of 1 completed
# BMY
# [*********************100%***********************]  1 of 1 completed
# AVGO
# [*********************100%***********************]  1 of 1 completed
# BR
# [*********************100%***********************]  1 of 1 completed
# BRO
# [*********************100%***********************]  1 of 1 completed
# BF.B
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
# CHRW
# [*********************100%***********************]  1 of 1 completed
# CDNS
# [*********************100%***********************]  1 of 1 completed
# CZR
# [*********************100%***********************]  1 of 1 completed
# CPT
# [*********************100%***********************]  1 of 1 completed
# CPB
# [*********************100%***********************]  1 of 1 completed
# COF
# [*********************100%***********************]  1 of 1 completed
# CAH
# [*********************100%***********************]  1 of 1 completed
# KMX
# [*********************100%***********************]  1 of 1 completed
# CCL
# [*********************100%***********************]  1 of 1 completed
# CARR
# [*********************100%***********************]  1 of 1 completed
# CTLT
# [*********************100%***********************]  1 of 1 completed
# CAT
# [*********************100%***********************]  1 of 1 completed
# CBOE
# [*********************100%***********************]  1 of 1 completed
# CBRE
# [*********************100%***********************]  1 of 1 completed
# CDW
# [*********************100%***********************]  1 of 1 completed
# CE
# [*********************100%***********************]  1 of 1 completed
# CNC
# [*********************100%***********************]  1 of 1 completed
# CNP
# [*********************100%***********************]  1 of 1 completed
# CDAY
# [*********************100%***********************]  1 of 1 completed
# CF
# [*********************100%***********************]  1 of 1 completed
# CRL
# [*********************100%***********************]  1 of 1 completed
# SCHW
# [*********************100%***********************]  1 of 1 completed
# CHTR
# [*********************100%***********************]  1 of 1 completed
# CVX
# [*********************100%***********************]  1 of 1 completed
# CMG
# [*********************100%***********************]  1 of 1 completed
# CB
# [*********************100%***********************]  1 of 1 completed
# CHD
# [*********************100%***********************]  1 of 1 completed
# CI
# [*********************100%***********************]  1 of 1 completed
# CINF
# [*********************100%***********************]  1 of 1 completed
# CTAS
# [*********************100%***********************]  1 of 1 completed
# CSCO
# [*********************100%***********************]  1 of 1 completed
# C
# [*********************100%***********************]  1 of 1 completed
# CFG
# [*********************100%***********************]  1 of 1 completed
# CLX
# [*********************100%***********************]  1 of 1 completed
# CME
# [*********************100%***********************]  1 of 1 completed
# CMS
# [*********************100%***********************]  1 of 1 completed
# KO
# [*********************100%***********************]  1 of 1 completed
# CTSH
# [*********************100%***********************]  1 of 1 completed
# CL
# [*********************100%***********************]  1 of 1 completed
# CMCSA
# [*********************100%***********************]  1 of 1 completed
# CMA
# [*********************100%***********************]  1 of 1 completed
# CAG
# [*********************100%***********************]  1 of 1 completed
# COP
# [*********************100%***********************]  1 of 1 completed
# ED
# [*********************100%***********************]  1 of 1 completed
# STZ
# [*********************100%***********************]  1 of 1 completed
# CEG
# [*********************100%***********************]  1 of 1 completed
# COO
# [*********************100%***********************]  1 of 1 completed
# CPRT
# [*********************100%***********************]  1 of 1 completed
# GLW
# [*********************100%***********************]  1 of 1 completed
# CTVA
# [*********************100%***********************]  1 of 1 completed
# CSGP
# [*********************100%***********************]  1 of 1 completed
# COST
# [*********************100%***********************]  1 of 1 completed
# CTRA
# [*********************100%***********************]  1 of 1 completed
# CCI
# [*********************100%***********************]  1 of 1 completed
# CSX
# [*********************100%***********************]  1 of 1 completed
# CMI
# [*********************100%***********************]  1 of 1 completed
# CVS
# [*********************100%***********************]  1 of 1 completed
# DHI
# [*********************100%***********************]  1 of 1 completed
# DHR
# [*********************100%***********************]  1 of 1 completed
# DRI
# [*********************100%***********************]  1 of 1 completed
# DVA
# [*********************100%***********************]  1 of 1 completed
# DE
# [*********************100%***********************]  1 of 1 completed
# DAL
# [*********************100%***********************]  1 of 1 completed
# XRAY
# [*********************100%***********************]  1 of 1 completed
# DVN
# [*********************100%***********************]  1 of 1 completed
# DXCM
# [*********************100%***********************]  1 of 1 completed
# FANG
# [*********************100%***********************]  1 of 1 completed
# DLR
# [*********************100%***********************]  1 of 1 completed
# DFS
# [*********************100%***********************]  1 of 1 completed
# DISH
# [*********************100%***********************]  1 of 1 completed
# DIS
# [*********************100%***********************]  1 of 1 completed
# DG
# [*********************100%***********************]  1 of 1 completed
# DLTR
# [*********************100%***********************]  1 of 1 completed
# D
# [*********************100%***********************]  1 of 1 completed
# DPZ
# [*********************100%***********************]  1 of 1 completed
# DOV
# [*********************100%***********************]  1 of 1 completed
# DOW
# [*********************100%***********************]  1 of 1 completed
# DTE
# [*********************100%***********************]  1 of 1 completed
# DUK
# [*********************100%***********************]  1 of 1 completed
# DD
# [*********************100%***********************]  1 of 1 completed
# DXC
# [*********************100%***********************]  1 of 1 completed
# EMN
# [*********************100%***********************]  1 of 1 completed
# ETN
# [*********************100%***********************]  1 of 1 completed
# EBAY
# [*********************100%***********************]  1 of 1 completed
# ECL
# [*********************100%***********************]  1 of 1 completed
# EIX
# [*********************100%***********************]  1 of 1 completed
# EW
# [*********************100%***********************]  1 of 1 completed
# EA
# [*********************100%***********************]  1 of 1 completed
# ELV
# [*********************100%***********************]  1 of 1 completed
# LLY
# [*********************100%***********************]  1 of 1 completed
# EMR
# [*********************100%***********************]  1 of 1 completed
# ENPH
# [*********************100%***********************]  1 of 1 completed
# ETR
# [*********************100%***********************]  1 of 1 completed
# EOG
# [*********************100%***********************]  1 of 1 completed
# EPAM
# [*********************100%***********************]  1 of 1 completed
# EQT
# [*********************100%***********************]  1 of 1 completed
# EFX
# [*********************100%***********************]  1 of 1 completed
# EQIX
# [*********************100%***********************]  1 of 1 completed
# EQR
# [*********************100%***********************]  1 of 1 completed
# ESS
# [*********************100%***********************]  1 of 1 completed
# EL
# [*********************100%***********************]  1 of 1 completed
# ETSY
# [*********************100%***********************]  1 of 1 completed
# RE
# [*********************100%***********************]  1 of 1 completed
# EVRG
# [*********************100%***********************]  1 of 1 completed
# ES
# [*********************100%***********************]  1 of 1 completed
# EXC
# [*********************100%***********************]  1 of 1 completed
# EXPE
# [*********************100%***********************]  1 of 1 completed
# EXPD
# [*********************100%***********************]  1 of 1 completed
# EXR
# [*********************100%***********************]  1 of 1 completed
# XOM
# [*********************100%***********************]  1 of 1 completed
# FFIV
# [*********************100%***********************]  1 of 1 completed
# FDS
# [*********************100%***********************]  1 of 1 completed
# FAST
# [*********************100%***********************]  1 of 1 completed
# FRT
# [*********************100%***********************]  1 of 1 completed
# FDX
# [*********************100%***********************]  1 of 1 completed
# FITB
# [*********************100%***********************]  1 of 1 completed
# FRC
# [*********************100%***********************]  1 of 1 completed
# FSLR
# [*********************100%***********************]  1 of 1 completed
# FE
# [*********************100%***********************]  1 of 1 completed
# FIS
# [*********************100%***********************]  1 of 1 completed
# FISV
# [*********************100%***********************]  1 of 1 completed
# FLT
# [*********************100%***********************]  1 of 1 completed
# FMC
# [*********************100%***********************]  1 of 1 completed
# F
# [*********************100%***********************]  1 of 1 completed
# FTNT
# [*********************100%***********************]  1 of 1 completed
# FTV
# [*********************100%***********************]  1 of 1 completed
# FOXA
# [*********************100%***********************]  1 of 1 completed
# FOX
# [*********************100%***********************]  1 of 1 completed
# BEN
# [*********************100%***********************]  1 of 1 completed
# FCX
# [*********************100%***********************]  1 of 1 completed
# GRMN
# [*********************100%***********************]  1 of 1 completed
# IT
# [*********************100%***********************]  1 of 1 completed
# GEHC
# [*********************100%***********************]  1 of 1 completed
# GEN
# [*********************100%***********************]  1 of 1 completed
# GNRC
# [*********************100%***********************]  1 of 1 completed
# GD
# [*********************100%***********************]  1 of 1 completed
# GE
# [*********************100%***********************]  1 of 1 completed
# GIS
# [*********************100%***********************]  1 of 1 completed
# GM
# [*********************100%***********************]  1 of 1 completed
# GPC
# [*********************100%***********************]  1 of 1 completed
# GILD
# [*********************100%***********************]  1 of 1 completed
# GL
# [*********************100%***********************]  1 of 1 completed
# GPN
# [*********************100%***********************]  1 of 1 completed
# GS
# [*********************100%***********************]  1 of 1 completed
# HAL
# [*********************100%***********************]  1 of 1 completed
# HIG
# [*********************100%***********************]  1 of 1 completed
# HAS
# [*********************100%***********************]  1 of 1 completed
# HCA
# [*********************100%***********************]  1 of 1 completed
# PEAK
# [*********************100%***********************]  1 of 1 completed
# HSIC
# [*********************100%***********************]  1 of 1 completed
# HSY
# [*********************100%***********************]  1 of 1 completed
# HES
# [*********************100%***********************]  1 of 1 completed
# HPE
# [*********************100%***********************]  1 of 1 completed
# HLT
# [*********************100%***********************]  1 of 1 completed
# HOLX
# [*********************100%***********************]  1 of 1 completed
# HD
# [*********************100%***********************]  1 of 1 completed
# HON
# [*********************100%***********************]  1 of 1 completed
# HRL
# [*********************100%***********************]  1 of 1 completed
# HST
# [*********************100%***********************]  1 of 1 completed
# HWM
# [*********************100%***********************]  1 of 1 completed
# HPQ
# [*********************100%***********************]  1 of 1 completed
# HUM
# [*********************100%***********************]  1 of 1 completed
# HBAN
# [*********************100%***********************]  1 of 1 completed
# HII
# [*********************100%***********************]  1 of 1 completed
# IBM
# [*********************100%***********************]  1 of 1 completed
# IEX
# [*********************100%***********************]  1 of 1 completed
# IDXX
# [*********************100%***********************]  1 of 1 completed
# ITW
# [*********************100%***********************]  1 of 1 completed
# ILMN
# [*********************100%***********************]  1 of 1 completed
# INCY
# [*********************100%***********************]  1 of 1 completed
# IR
# [*********************100%***********************]  1 of 1 completed
# INTC
# [*********************100%***********************]  1 of 1 completed
# ICE
# [*********************100%***********************]  1 of 1 completed
# IP
# [*********************100%***********************]  1 of 1 completed
# IPG
# [*********************100%***********************]  1 of 1 completed
# IFF
# [*********************100%***********************]  1 of 1 completed
# INTU
# [*********************100%***********************]  1 of 1 completed
# ISRG
# [*********************100%***********************]  1 of 1 completed
# IVZ
# [*********************100%***********************]  1 of 1 completed
# INVH
# [*********************100%***********************]  1 of 1 completed
# IQV
# [*********************100%***********************]  1 of 1 completed
# IRM
# [*********************100%***********************]  1 of 1 completed
# JBHT
# [*********************100%***********************]  1 of 1 completed
# JKHY
# [*********************100%***********************]  1 of 1 completed
# J
# [*********************100%***********************]  1 of 1 completed
# JNJ
# [*********************100%***********************]  1 of 1 completed
# JCI
# [*********************100%***********************]  1 of 1 completed
# JPM
# [*********************100%***********************]  1 of 1 completed
# JNPR
# [*********************100%***********************]  1 of 1 completed
# K
# [*********************100%***********************]  1 of 1 completed
# KDP
# [*********************100%***********************]  1 of 1 completed
# KEY
# [*********************100%***********************]  1 of 1 completed
# KEYS
# [*********************100%***********************]  1 of 1 completed
# KMB
# [*********************100%***********************]  1 of 1 completed
# KIM
# [*********************100%***********************]  1 of 1 completed
# KMI
# [*********************100%***********************]  1 of 1 completed
# KLAC
# [*********************100%***********************]  1 of 1 completed
# KHC
# [*********************100%***********************]  1 of 1 completed
# KR
# [*********************100%***********************]  1 of 1 completed
# LHX
# [*********************100%***********************]  1 of 1 completed
# LH
# [*********************100%***********************]  1 of 1 completed
# LRCX
# [*********************100%***********************]  1 of 1 completed
# LW
# [*********************100%***********************]  1 of 1 completed
# LVS
# [*********************100%***********************]  1 of 1 completed
# LDOS
# [*********************100%***********************]  1 of 1 completed
# LEN
# [*********************100%***********************]  1 of 1 completed
# LNC
# [*********************100%***********************]  1 of 1 completed
# LIN
# [*********************100%***********************]  1 of 1 completed
# LYV
# [*********************100%***********************]  1 of 1 completed
# LKQ
# [*********************100%***********************]  1 of 1 completed
# LMT
# [*********************100%***********************]  1 of 1 completed
# L
# [*********************100%***********************]  1 of 1 completed
# LOW
# [*********************100%***********************]  1 of 1 completed
# LUMN
# [*********************100%***********************]  1 of 1 completed
# LYB
# [*********************100%***********************]  1 of 1 completed
# MTB
# [*********************100%***********************]  1 of 1 completed
# MRO
# [*********************100%***********************]  1 of 1 completed
# MPC
# [*********************100%***********************]  1 of 1 completed
# MKTX
# [*********************100%***********************]  1 of 1 completed
# MAR
# [*********************100%***********************]  1 of 1 completed
# MMC
# [*********************100%***********************]  1 of 1 completed
# MLM
# [*********************100%***********************]  1 of 1 completed
# MAS
# [*********************100%***********************]  1 of 1 completed
# MA
# [*********************100%***********************]  1 of 1 completed
# MTCH
# [*********************100%***********************]  1 of 1 completed
# MKC
# [*********************100%***********************]  1 of 1 completed
# MCD
# [*********************100%***********************]  1 of 1 completed
# MCK
# [*********************100%***********************]  1 of 1 completed
# MDT
# [*********************100%***********************]  1 of 1 completed
# MRK
# [*********************100%***********************]  1 of 1 completed
# META
# [*********************100%***********************]  1 of 1 completed
# MET
# [*********************100%***********************]  1 of 1 completed
# MTD
# [*********************100%***********************]  1 of 1 completed
# MGM
# [*********************100%***********************]  1 of 1 completed
# MCHP
# [*********************100%***********************]  1 of 1 completed
# MU
# [*********************100%***********************]  1 of 1 completed
# MSFT
# [*********************100%***********************]  1 of 1 completed
# MAA
# [*********************100%***********************]  1 of 1 completed
# MRNA
# [*********************100%***********************]  1 of 1 completed
# MHK
# [*********************100%***********************]  1 of 1 completed
# MOH
# [*********************100%***********************]  1 of 1 completed
# TAP
# [*********************100%***********************]  1 of 1 completed
# MDLZ
# [*********************100%***********************]  1 of 1 completed
# MPWR
# [*********************100%***********************]  1 of 1 completed
# MNST
# [*********************100%***********************]  1 of 1 completed
# MCO
# [*********************100%***********************]  1 of 1 completed
# MS
# [*********************100%***********************]  1 of 1 completed
# MOS
# [*********************100%***********************]  1 of 1 completed
# MSI
# [*********************100%***********************]  1 of 1 completed
# MSCI
# [*********************100%***********************]  1 of 1 completed
# NDAQ
# [*********************100%***********************]  1 of 1 completed
# NTAP
# [*********************100%***********************]  1 of 1 completed
# NFLX
# [*********************100%***********************]  1 of 1 completed
# NWL
# [*********************100%***********************]  1 of 1 completed
# NEM
# [*********************100%***********************]  1 of 1 completed
# NWSA
# [*********************100%***********************]  1 of 1 completed
# NWS
# [*********************100%***********************]  1 of 1 completed
# NEE
# [*********************100%***********************]  1 of 1 completed
# NKE
# [*********************100%***********************]  1 of 1 completed
# NI
# [*********************100%***********************]  1 of 1 completed
# NDSN
# [*********************100%***********************]  1 of 1 completed
# NSC
# [*********************100%***********************]  1 of 1 completed
# NTRS
# [*********************100%***********************]  1 of 1 completed
# NOC
# [*********************100%***********************]  1 of 1 completed
# NCLH
# [*********************100%***********************]  1 of 1 completed
# NRG
# [*********************100%***********************]  1 of 1 completed
# NUE
# [*********************100%***********************]  1 of 1 completed
# NVDA
# [*********************100%***********************]  1 of 1 completed
# NVR
# [*********************100%***********************]  1 of 1 completed
# NXPI
# [*********************100%***********************]  1 of 1 completed
# ORLY
# [*********************100%***********************]  1 of 1 completed
# OXY
# [*********************100%***********************]  1 of 1 completed
# ODFL
# [*********************100%***********************]  1 of 1 completed
# OMC
# [*********************100%***********************]  1 of 1 completed
# ON
# [*********************100%***********************]  1 of 1 completed
# OKE
# [*********************100%***********************]  1 of 1 completed
# ORCL
# [*********************100%***********************]  1 of 1 completed
# OGN
# [*********************100%***********************]  1 of 1 completed
# OTIS
# [*********************100%***********************]  1 of 1 completed
# PCAR
# [*********************100%***********************]  1 of 1 completed
# PKG
# [*********************100%***********************]  1 of 1 completed
# PARA
# [*********************100%***********************]  1 of 1 completed
# PH
# [*********************100%***********************]  1 of 1 completed
# PAYX
# [*********************100%***********************]  1 of 1 completed
# PAYC
# [*********************100%***********************]  1 of 1 completed
# PYPL
# [*********************100%***********************]  1 of 1 completed
# PNR
# [*********************100%***********************]  1 of 1 completed
# PEP
# [*********************100%***********************]  1 of 1 completed
# PKI
# [*********************100%***********************]  1 of 1 completed
# PFE
# [*********************100%***********************]  1 of 1 completed
# PCG
# [*********************100%***********************]  1 of 1 completed
# PM
# [*********************100%***********************]  1 of 1 completed
# PSX
# [*********************100%***********************]  1 of 1 completed
# PNW
# [*********************100%***********************]  1 of 1 completed
# PXD
# [*********************100%***********************]  1 of 1 completed
# PNC
# [*********************100%***********************]  1 of 1 completed
# POOL
# [*********************100%***********************]  1 of 1 completed
# PPG
# [*********************100%***********************]  1 of 1 completed
# PPL
# [*********************100%***********************]  1 of 1 completed
# PFG
# [*********************100%***********************]  1 of 1 completed
# PG
# [*********************100%***********************]  1 of 1 completed
# PGR
# [*********************100%***********************]  1 of 1 completed
# PLD
# [*********************100%***********************]  1 of 1 completed
# PRU
# [*********************100%***********************]  1 of 1 completed
# PEG
# [*********************100%***********************]  1 of 1 completed
# PTC
# [*********************100%***********************]  1 of 1 completed
# PSA
# [*********************100%***********************]  1 of 1 completed
# PHM
# [*********************100%***********************]  1 of 1 completed
# QRVO
# [*********************100%***********************]  1 of 1 completed
# PWR
# [*********************100%***********************]  1 of 1 completed
# QCOM
# [*********************100%***********************]  1 of 1 completed
# DGX
# [*********************100%***********************]  1 of 1 completed
# RL
# [*********************100%***********************]  1 of 1 completed
# RJF
# [*********************100%***********************]  1 of 1 completed
# RTX
# [*********************100%***********************]  1 of 1 completed
# O
# [*********************100%***********************]  1 of 1 completed
# REG
# [*********************100%***********************]  1 of 1 completed
# REGN
# [*********************100%***********************]  1 of 1 completed
# RF
# [*********************100%***********************]  1 of 1 completed
# RSG
# [*********************100%***********************]  1 of 1 completed
# RMD
# [*********************100%***********************]  1 of 1 completed
# RHI
# [*********************100%***********************]  1 of 1 completed
# ROK
# [*********************100%***********************]  1 of 1 completed
# ROL
# [*********************100%***********************]  1 of 1 completed
# ROP
# [*********************100%***********************]  1 of 1 completed
# ROST
# [*********************100%***********************]  1 of 1 completed
# RCL
# [*********************100%***********************]  1 of 1 completed
# SPGI
# [*********************100%***********************]  1 of 1 completed
# CRM
# [*********************100%***********************]  1 of 1 completed
# SBAC
# [*********************100%***********************]  1 of 1 completed
# SLB
# [*********************100%***********************]  1 of 1 completed
# STX
# [*********************100%***********************]  1 of 1 completed
# SEE
# [*********************100%***********************]  1 of 1 completed
# SRE
# [*********************100%***********************]  1 of 1 completed
# NOW
# [*********************100%***********************]  1 of 1 completed
# SHW
# [*********************100%***********************]  1 of 1 completed
# SBNY
# [*********************100%***********************]  1 of 1 completed
# SPG
# [*********************100%***********************]  1 of 1 completed
# SWKS
# [*********************100%***********************]  1 of 1 completed
# SJM
# [*********************100%***********************]  1 of 1 completed
# SNA
# [*********************100%***********************]  1 of 1 completed
# SEDG
# [*********************100%***********************]  1 of 1 completed
# SO
# [*********************100%***********************]  1 of 1 completed
# LUV
# [*********************100%***********************]  1 of 1 completed
# SWK
# [*********************100%***********************]  1 of 1 completed
# SBUX
# [*********************100%***********************]  1 of 1 completed
# STT
# [*********************100%***********************]  1 of 1 completed
# STLD
# [*********************100%***********************]  1 of 1 completed
# STE
# [*********************100%***********************]  1 of 1 completed
# SYK
# [*********************100%***********************]  1 of 1 completed
# SIVB
# [*********************100%***********************]  1 of 1 completed
# SYF
# [*********************100%***********************]  1 of 1 completed
# SNPS
# [*********************100%***********************]  1 of 1 completed
# SYY
# [*********************100%***********************]  1 of 1 completed
# TMUS
# [*********************100%***********************]  1 of 1 completed
# TROW
# [*********************100%***********************]  1 of 1 completed
# TTWO
# [*********************100%***********************]  1 of 1 completed
# TPR
# [*********************100%***********************]  1 of 1 completed
# TRGP
# [*********************100%***********************]  1 of 1 completed
# TGT
# [*********************100%***********************]  1 of 1 completed
# TEL
# [*********************100%***********************]  1 of 1 completed
# TDY
# [*********************100%***********************]  1 of 1 completed
# TFX
# [*********************100%***********************]  1 of 1 completed
# TER
# [*********************100%***********************]  1 of 1 completed
# TSLA
# [*********************100%***********************]  1 of 1 completed
# TXN
# [*********************100%***********************]  1 of 1 completed
# TXT
# [*********************100%***********************]  1 of 1 completed
# TMO
# [*********************100%***********************]  1 of 1 completed
# TJX
# [*********************100%***********************]  1 of 1 completed
# TSCO
# [*********************100%***********************]  1 of 1 completed
# TT
# [*********************100%***********************]  1 of 1 completed
# TDG
# [*********************100%***********************]  1 of 1 completed
# TRV
# [*********************100%***********************]  1 of 1 completed
# TRMB
# [*********************100%***********************]  1 of 1 completed
# TFC
# [*********************100%***********************]  1 of 1 completed
# TYL
# [*********************100%***********************]  1 of 1 completed
# TSN
# [*********************100%***********************]  1 of 1 completed
# USB
# [*********************100%***********************]  1 of 1 completed
# UDR
# [*********************100%***********************]  1 of 1 completed
# ULTA
# [*********************100%***********************]  1 of 1 completed
# UNP
# [*********************100%***********************]  1 of 1 completed
# UAL
# [*********************100%***********************]  1 of 1 completed
# UPS
# [*********************100%***********************]  1 of 1 completed
# URI
# [*********************100%***********************]  1 of 1 completed
# UNH
# [*********************100%***********************]  1 of 1 completed
# UHS
# [*********************100%***********************]  1 of 1 completed
# VLO
# [*********************100%***********************]  1 of 1 completed
# VTR
# [*********************100%***********************]  1 of 1 completed
# VRSN
# [*********************100%***********************]  1 of 1 completed
# VRSK
# [*********************100%***********************]  1 of 1 completed
# VZ
# [*********************100%***********************]  1 of 1 completed
# VRTX
# [*********************100%***********************]  1 of 1 completed
# VFC
# [*********************100%***********************]  1 of 1 completed
# VTRS
# [*********************100%***********************]  1 of 1 completed
# VICI
# [*********************100%***********************]  1 of 1 completed
# V
# [*********************100%***********************]  1 of 1 completed
# VMC
# [*********************100%***********************]  1 of 1 completed
# WAB
# [*********************100%***********************]  1 of 1 completed
# WBA
# [*********************100%***********************]  1 of 1 completed
# WMT
# [*********************100%***********************]  1 of 1 completed
# WBD
# [*********************100%***********************]  1 of 1 completed
# WM
# [*********************100%***********************]  1 of 1 completed
# WAT
# [*********************100%***********************]  1 of 1 completed
# WEC
# [*********************100%***********************]  1 of 1 completed
# WFC
# [*********************100%***********************]  1 of 1 completed
# WELL
# [*********************100%***********************]  1 of 1 completed
# WST
# [*********************100%***********************]  1 of 1 completed
# WDC
# [*********************100%***********************]  1 of 1 completed
# WRK
# [*********************100%***********************]  1 of 1 completed
# WY
# [*********************100%***********************]  1 of 1 completed
# WHR
# [*********************100%***********************]  1 of 1 completed
# WMB
# [*********************100%***********************]  1 of 1 completed
# WTW
# [*********************100%***********************]  1 of 1 completed
# GWW
# [*********************100%***********************]  1 of 1 completed
# WYNN
# [*********************100%***********************]  1 of 1 completed
# XEL
# [*********************100%***********************]  1 of 1 completed
# XYL
# [*********************100%***********************]  1 of 1 completed
# YUM
# [*********************100%***********************]  1 of 1 completed
# ZBRA
# [*********************100%***********************]  1 of 1 completed
# ZBH
# [*********************100%***********************]  1 of 1 completed
# ZION
# [*********************100%***********************]  1 of 1 completed
# ZTS
# [*********************100%***********************]  1 of 1 completed

# %%
# summary = pd.DataFrame()
# all_signal = pd.DataFrame()
# for i in ticker:
#     print(i)
#     df = getdata(i,sma_value = [5,10,15,20,50,60,120,150,200],ema_value = [5,10,15,20,50,60,120,150,200],close = "Close")
#     if df is not None:
#         df['RSI'] = RSI(df['Close'])
#         #df =Calculate_Return (df)
#         df['Price']=df['Close']
#         df.reset_index(inplace=True)
#         df_signal = Generate_signal(df,'SMA10','EMA10')
#         # back test your strategy using Open price as price action to buy sell on particular day
#         df_signal['Price']=df_signal['Open']
#         df_backtest = df_signal[['Date','Price','signal','Open']].copy()
#         df_signal['hold_without_sell_return (%)'] = df_signal['Close']/df_signal['Close'].iloc[0]*100
#         df_signal['Return_trailing_12m_hold'] =df_signal['Close']/df_signal['Close'].shift(250)*100
#         #result['ticker'] = i
#         df_signal['ticker']=i
#         all_signal = pd.concat([all_signal,df_signal])
#         df= None

# %%
spy = getdata('spy',sma_value = [20,50,200],ema_value =[20,50,200],close = "Close")
spy['signal'] = 0 
spy['ticker'] = 'spy'
spy['Price']=spy['Open']
spy =spy[spy['Date']>=all_signal.Date.min()]
spy =spy[spy['Date'].isin(all_signal.Date.unique())]
spy['Return_trailing_12m_hold'] =120
signal_etf_stock = pd.concat([spy,all_signal])
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#signal_etf_stock[signal_etf_stock.Date>'2020-03-24']

# %%
result, hold_detail= backtest_strategy_portfolio(signal_etf_stock[signal_etf_stock.Date>'2019-01-23'],10000)
# Out:
# 2019-01-24 00:00:00
# 10000.0
# ['ETSY' 'DXCM' 'CMG' 'NRG' 'KEYS' 'HCA' 'MOH' 'AES' 'LLY' 'VRSN']
# 2019-01-25 00:00:00
# 10090.190417416976
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'KEYS' 'MOH' 'HCA' 'VRSN' 'AES' 'LLY']
# 2019-01-28 00:00:00
# 10054.621755973216
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'KEYS' 'MOH' 'VRSN' 'ZBRA' 'HCA' 'CZR']
# 2019-01-29 00:00:00
# 10142.330972396456
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'KEYS' 'NRG' 'MOH' 'VRSN' 'CZR' 'ZBRA']
# 2019-01-30 00:00:00
# 10134.704669022853
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'NRG' 'KEYS' 'MOH' 'VRSN' 'AES' 'ZBRA']
# 2019-01-31 00:00:00
# 10170.9046304699
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'NRG' 'MOH' 'VRSN' 'LLY' 'AES' 'ZBRA']
# 2019-02-01 00:00:00
# 10240.734885328991
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'NRG' 'VRSN' 'LLY' 'ZBRA' 'BSX' 'HCA']
# 2019-02-04 00:00:00
# 10222.904195296102
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'NRG' 'ZBRA' 'CHD' 'BALL' 'BSX' 'ORLY']
# 2019-02-05 00:00:00
# 10227.644709410077
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'NRG' 'MTCH' 'MOH' 'ZBRA' 'BSX' 'BALL']
# 2019-02-06 00:00:00
# 10289.671134046099
# ['ENPH' 'ETSY' 'CMG' 'MOH' 'MTCH' 'NRG' 'ZBRA' 'BALL' 'BSX' 'DPZ']
# 2019-02-07 00:00:00
# 10402.423555509224
# ['ENPH' 'ETSY' 'CMG' 'NRG' 'MTCH' 'STE' 'DPZ' 'WELL' 'BALL' 'ULTA']
# 2019-02-08 00:00:00
# 10386.741103935168
# ['ENPH' 'ETSY' 'MTCH' 'DPZ' 'CZR' 'WELL' 'ULTA' 'PEAK' 'BALL' 'EW']
# 2019-02-11 00:00:00
# 10604.806799562819
# ['ENPH' 'ETSY' 'KEYS' 'MTCH' 'CZR' 'HCA' 'DPZ' 'UAL' 'EPAM' 'WELL']
# 2019-02-12 00:00:00
# 10756.79027844598
# ['ENPH' 'ETSY' 'KEYS' 'LLY' 'CZR' 'VRSN' 'MTCH' 'O' 'WELL' 'HCA']
# 2019-02-13 00:00:00
# 10788.059886332885
# ['ETSY' 'ENPH' 'KEYS' 'FTNT' 'AES' 'NOW' 'VRSN' 'LLY' 'CZR' 'TDG']
# 2019-02-14 00:00:00
# 10671.706156540487
# ['MOH' 'KEYS' 'FTNT' 'AES' 'NOW' 'LLY' 'VRSN' 'TDG' 'CZR' 'CRM']
# 2019-02-15 00:00:00
# 10802.50332427884
# ['PAYC' 'MOH' 'KEYS' 'FTNT' 'AES' 'LLY' 'NOW' 'VRSN' 'CZR' 'TDG']
# 2019-02-19 00:00:00
# 10789.364201802393
# ['ENPH' 'DXCM' 'AMD' 'PAYC' 'MOH' 'KEYS' 'FTNT' 'AES' 'NOW' 'TDG']
# 2019-02-20 00:00:00
# 10801.951193182907
# ['ENPH' 'DXCM' 'AMD' 'MOH' 'PAYC' 'KEYS' 'FTNT' 'AES' 'VRSN' 'NOW']
# 2019-02-21 00:00:00
# 10731.129890483166
# ['ENPH' 'DXCM' 'MOH' 'CMG' 'PAYC' 'KEYS' 'FTNT' 'NRG' 'AES' 'VRSN']
# 2019-02-22 00:00:00
# 10931.73382306754
# ['ENPH' 'DXCM' 'CMG' 'PAYC' 'FTNT' 'AES' 'NRG' 'ORLY' 'VRSN' 'BSX']
# 2019-02-25 00:00:00
# 10982.08422655546
# ['ENPH' 'CMG' 'PAYC' 'FTNT' 'AES' 'NRG' 'ORLY' 'ULTA' 'BSX' 'TDG']
# 2019-02-26 00:00:00
# 10880.600155622817
# ['ENPH' 'CMG' 'PAYC' 'AES' 'NRG' 'ULTA' 'TDG' 'NOW' 'ORLY' 'TSCO']
# 2019-02-27 00:00:00
# 10883.410721996946
# ['DXCM' 'CMG' 'PAYC' 'NRG' 'ORLY' 'AES' 'VRSN' 'ULTA' 'TDG' 'MRK']
# 2019-02-28 00:00:00
# 10900.268930176255
# ['DXCM' 'AMD' 'CMG' 'PAYC' 'NRG' 'AES' 'VRSN' 'ULTA' 'ORLY' 'NOW']
# 2019-03-01 00:00:00
# 11028.450527578663
# ['DXCM' 'AMD' 'CMG' 'PAYC' 'AES' 'ULTA' 'NRG' 'VRSN' 'ORLY' 'TDG']
# 2019-03-04 00:00:00
# 11102.500603840941
# ['DXCM' 'AMD' 'CMG' 'MOH' 'PAYC' 'FTNT' 'ULTA' 'AES' 'VRSN' 'ORLY']
# 2019-03-05 00:00:00
# 10877.060156160736
# ['AMD' 'CMG' 'MOH' 'PAYC' 'KEYS' 'FTNT' 'ULTA' 'AES' 'TDG' 'VRSN']
# 2019-03-06 00:00:00
# 10907.132172557927
# ['AMD' 'MOH' 'PAYC' 'KEYS' 'FTNT' 'AES' 'ULTA' 'VRSN' 'CDNS' 'TDG']
# 2019-03-07 00:00:00
# 10781.588604286968
# ['PAYC' 'AES' 'KEYS' 'FTNT' 'ULTA' 'ORLY' 'VRSN' 'TDG' 'CDNS' 'MRK']
# 2019-03-08 00:00:00
# 10651.352067624206
# ['ETSY' 'ENPH' 'PAYC' 'KEYS' 'LLY' 'FTNT' 'ORLY' 'VRSN' 'TDG' 'CDNS']
# 2019-03-11 00:00:00
# 10788.700766510829
# ['ETSY' 'ENPH' 'PAYC' 'LLY' 'KEYS' 'CDNS' 'ULTA' 'FTNT' 'VRSN' 'TDG']
# 2019-03-12 00:00:00
# 10992.589064244048
# ['ETSY' 'ENPH' 'AMD' 'CMG' 'MOH' 'PAYC' 'LLY' 'KEYS' 'CDNS' 'FTNT']
# 2019-03-13 00:00:00
# 11155.81361573499
# ['ETSY' 'ENPH' 'AMD' 'CMG' 'MOH' 'PAYC' 'KEYS' 'LLY' 'CDNS' 'FTNT']
# 2019-03-14 00:00:00
# 11168.049765111675
# ['ETSY' 'ENPH' 'LLY' 'KEYS' 'CDNS' 'ULTA' 'FTNT' 'MRK' 'TSCO' 'AZO']
# 2019-03-15 00:00:00
# 11236.980960994768
# ['ETSY' 'KEYS' 'CDNS' 'LLY' 'ULTA' 'ORLY' 'MRK' 'AZO' 'BSX' 'TSCO']
# 2019-03-18 00:00:00
# 11275.149472587495
# ['ETSY' 'KEYS' 'CDNS' 'LLY' 'AZO' 'ORLY' 'LYV' 'GRMN' 'MSI' 'CSGP']
# 2019-03-19 00:00:00
# 11351.440521444609
# ['ETSY' 'KEYS' 'CDNS' 'LLY' 'LYV' 'GRMN' 'TJX' 'CSGP' 'DHR' 'UDR']
# 2019-03-20 00:00:00
# 11323.300372253056
# ['AES' 'CDNS' 'WELL' 'LYV' 'GRMN' 'O' 'BSX' 'PEAK' 'AEE' 'KMI']
# 2019-03-21 00:00:00
# 11349.735613238665
# ['AES' 'CDNS' 'LYV' 'WELL' 'O' 'GRMN' 'BSX' 'PEAK' 'CHD' 'AEE']
# 2019-03-22 00:00:00
# 11576.78502835674
# ['ETSY' 'DXCM' 'ENPH' 'AES' 'CDNS' 'LYV' 'WELL' 'O' 'GRMN' 'BSX']
# 2019-03-25 00:00:00
# 11307.969800852698
# ['ETSY' 'ENPH' 'DXCM' 'CDNS' 'PAYC' 'AES' 'KEYS' 'VRSN' 'ZBRA' 'LYV']
# 2019-03-26 00:00:00
# 11409.285573884978
# ['ETSY' 'MOH' 'ENPH' 'AES' 'CDNS' 'KEYS' 'PAYC' 'WELL' 'VRSN' 'BALL']
# 2019-03-27 00:00:00
# 11254.486746556324
# ['ETSY' 'PAYC' 'ENPH' 'CDNS' 'AES' 'MOH' 'ULTA' 'KEYS' 'FTNT' 'VRSN']
# 2019-03-28 00:00:00
# 11179.401023009215
# ['ETSY' 'ENPH' 'PAYC' 'CDNS' 'ULTA' 'MOH' 'KEYS' 'AES' 'AZO' 'FTNT']
# 2019-03-29 00:00:00
# 11374.01226112834
# ['AMD' 'ETSY' 'ENPH' 'PAYC' 'CDNS' 'MOH' 'ULTA' 'KEYS' 'AES' 'AZO']
# 2019-04-01 00:00:00
# 11553.517414350155
# ['AMD' 'ETSY' 'ENPH' 'MOH' 'CDNS' 'ULTA' 'LLY' 'KEYS' 'AZO' 'LYV']
# 2019-04-02 00:00:00
# 11597.58667972808
# ['AMD' 'ENPH' 'MOH' 'LYV' 'LLY' 'FTNT' 'VRSN' 'AES' 'AAP' 'MRK']
# 2019-04-03 00:00:00
# 11709.234014996828
# ['AMD' 'CMG' 'MOH' 'LLY' 'AES' 'FTNT' 'ZBRA' 'MRK' 'AAP' 'NOW']
# 2019-04-04 00:00:00
# 11737.496646163705
# ['AMD' 'CMG' 'LLY' 'AES' 'MRK' 'NOW' 'AAP' 'BALL' 'WELL' 'NRG']
# 2019-04-05 00:00:00
# 11696.928150772936
# ['CMG' 'ULTA' 'LLY' 'AES' 'MRK' 'BALL' 'NOW' 'NRG' 'CZR' 'WELL']
# 2019-04-08 00:00:00
# 11715.04233131261
# ['CMG' 'PAYC' 'LYV' 'ULTA' 'LLY' 'AES' 'BALL' 'CHD' 'NOW' 'MRK']
# 2019-04-09 00:00:00
# 11692.716448421033
# ['CMG' 'CDNS' 'LYV' 'PAYC' 'LLY' 'ULTA' 'AES' 'INTU' 'EPAM' 'CHD']
# 2019-04-10 00:00:00
# 11771.993013574183
# ['CMG' 'CDNS' 'AZO' 'LYV' 'PAYC' 'ULTA' 'LLY' 'INTU' 'EPAM' 'GRMN']
# 2019-04-11 00:00:00
# 11861.595599486733
# ['ETSY' 'CMG' 'CDNS' 'AZO' 'LYV' 'KEYS' 'PAYC' 'AAP' 'ULTA' 'LLY']
# 2019-04-12 00:00:00
# 11873.632186676163
# ['AMD' 'ETSY' 'CMG' 'TSCO' 'AZO' 'MOH' 'CDNS' 'PAYC' 'AAP' 'KEYS']
# 2019-04-15 00:00:00
# 11705.553792200388
# ['AMD' 'ENPH' 'ETSY' 'CMG' 'ORLY' 'AZO' 'TSCO' 'CDNS' 'KEYS' 'AAP']
# 2019-04-16 00:00:00
# 11733.842528923635
# ['AMD' 'ENPH' 'ETSY' 'CMG' 'ORLY' 'AZO' 'CDNS' 'KEYS' 'LLY' 'ULTA']
# 2019-04-17 00:00:00
# 11665.366750145648
# ['AMD' 'ENPH' 'ETSY' 'ORLY' 'AZO' 'CDNS' 'KEYS' 'ULTA' 'AES' 'VRSN']
# 2019-04-18 00:00:00
# 11487.080907168085
# ['AMD' 'ETSY' 'ENPH' 'ORLY' 'AZO' 'TSCO' 'CDNS' 'AAP' 'KEYS' 'ULTA']
# 2019-04-22 00:00:00
# 11379.711446737581
# ['AMD' 'ETSY' 'CMG' 'ENPH' 'ORLY' 'AZO' 'CDNS' 'TSCO' 'AAP' 'KEYS']
# 2019-04-23 00:00:00
# 11461.01140935509
# ['AMD' 'ETSY' 'CMG' 'ENPH' 'ORLY' 'CDNS' 'AZO' 'KEYS' 'ZBRA' 'TSCO']
# 2019-04-24 00:00:00
# 11595.570638805384
# ['ETSY' 'ENPH' 'CMG' 'ORLY' 'AZO' 'KEYS' 'ZBRA' 'TSCO' 'CDNS' 'FTNT']
# 2019-04-25 00:00:00
# 11603.758085452326
# ['ETSY' 'ENPH' 'CMG' 'ORLY' 'KEYS' 'ZBRA' 'AZO' 'FTNT' 'TSCO' 'CHD']
# 2019-04-26 00:00:00
# 11514.226548069943
# ['ZBRA' 'AZO' 'FTNT' 'KEYS' 'CMG' 'CHD' 'TSCO' 'VRSN' 'AAP' 'MSCI']
# 2019-04-29 00:00:00
# 11544.499258940175
# ['ZBRA' 'FTNT' 'AZO' 'KEYS' 'CHD' 'CMG' 'TSCO' 'MSCI' 'PYPL' 'CDW']
# 2019-04-30 00:00:00
# 11498.023241583658
# ['AMD' 'ZBRA' 'FTNT' 'KEYS' 'LYV' 'AZO' 'CMG' 'CHD' 'TSCO' 'MSCI']
# 2019-05-01 00:00:00
# 11542.15679653274
# ['AMD' 'KEYS' 'QCOM' 'FTNT' 'MTCH' 'LYV' 'AZO' 'CMG' 'ZBRA' 'TSCO']
# 2019-05-02 00:00:00
# 11298.302010297986
# ['MTCH' 'QCOM' 'KEYS' 'FTNT' 'CMG' 'AZO' 'LYV' 'ZBRA' 'TSCO' 'MSCI']
# 2019-05-03 00:00:00
# 11373.173192051936
# ['QCOM' 'KEYS' 'MTCH' 'FTNT' 'AZO' 'BALL' 'LYV' 'TSCO' 'ZBRA' 'EPAM']
# 2019-05-06 00:00:00
# 11157.223599586297
# ['AMD' 'MTCH' 'QCOM' 'KEYS' 'BALL' 'FTNT' 'TSCO' 'ZBRA' 'EPAM' 'MSCI']
# 2019-05-07 00:00:00
# 11301.315993440418
# ['AMD' 'MTCH' 'CDNS' 'KEYS' 'QCOM' 'VRSN' 'TSCO' 'NOW' 'FTNT' 'ZBRA']
# 2019-05-08 00:00:00
# 11140.958025018164
# ['AMD' 'ETSY' 'PAYC' 'CDNS' 'MTCH' 'QCOM' 'VRSN' 'AZO' 'CHD' 'TSCO']
# 2019-05-09 00:00:00
# 11135.957639724253
# ['ETSY' 'AMD' 'PAYC' 'CDNS' 'QCOM' 'VRSN' 'CHD' 'AZO' 'TSCO' 'LYV']
# 2019-05-10 00:00:00
# 11169.119852800162
# ['AMD' 'ETSY' 'PAYC' 'CDNS' 'VRSN' 'AZO' 'QCOM' 'CHD' 'TSCO' 'NOW']
# 2019-05-13 00:00:00
# 11047.419635835875
# ['ETSY' 'PAYC' 'CDNS' 'QCOM' 'VRSN' 'CHD' 'NOW' 'AZO' 'TSCO' 'CDAY']
# 2019-05-14 00:00:00
# 10962.351966300897
# ['ENPH' 'PAYC' 'CMG' 'CDNS' 'CHD' 'KEYS' 'NOW' 'VRSN' 'QCOM' 'AZO']
# 2019-05-15 00:00:00
# 11051.538308304265
# ['ENPH' 'AMD' 'PAYC' 'CDNS' 'CMG' 'NOW' 'KEYS' 'CHD' 'QCOM' 'AZO']
# 2019-05-16 00:00:00
# 11205.292750116905
# ['ENPH' 'AMD' 'ETSY' 'PAYC' 'CDNS' 'BALL' 'NOW' 'CMG' 'CHD' 'KEYS']
# 2019-05-17 00:00:00
# 11251.066515495257
# ['ENPH' 'ETSY' 'PAYC' 'CDNS' 'BALL' 'NOW' 'CMG' 'KEYS' 'VRSN' 'AZO']
# 2019-05-20 00:00:00
# 11073.991785305087
# ['ENPH' 'ETSY' 'PAYC' 'CMG' 'BALL' 'CDNS' 'KEYS' 'AZO' 'MKC' 'MSCI']
# 2019-05-21 00:00:00
# 11095.504870801495
# ['ENPH' 'BALL' 'CDNS' 'MKC' 'DRI' 'LYV' 'FDS' 'TDG' 'QCOM' 'TT']
# 2019-05-22 00:00:00
# 11024.167147463713
# ['ENPH' 'MTCH' 'BALL' 'NOW' 'CDNS' 'MKC' 'LYV' 'TDG' 'SBUX' 'TT']
# 2019-05-23 00:00:00
# 10957.999273009695
# ['ENPH' 'MTCH' 'BALL' 'NOW' 'CDNS' 'MKC' 'AMT' 'LYV' 'TDG' 'SBUX']
# 2019-05-24 00:00:00
# 10944.73181279978
# ['ENPH' 'AMD' 'MTCH' 'BALL' 'CMG' 'MKC' 'CDNS' 'NOW' 'AMT' 'PG']
# 2019-05-28 00:00:00
# 11007.389122036278
# ['ENPH' 'AMD' 'MTCH' 'BALL' 'CMG' 'NOW' 'CDNS' 'AMT' 'PG' 'WELL']
# 2019-05-29 00:00:00
# 11018.322976647494
# ['ENPH' 'PAYC' 'MTCH' 'BALL' 'CMG' 'CDNS' 'NOW' 'VRSN' 'AMT' 'CHTR']
# 2019-05-30 00:00:00
# 11038.825121684255
# ['PAYC' 'MTCH' 'BALL' 'CMG' 'CHD' 'CDNS' 'VRSN' 'NOW' 'MKC' 'AMT']
# 2019-05-31 00:00:00
# 11018.608584977397
# ['PAYC' 'ETSY' 'MTCH' 'BALL' 'CHD' 'CMG' 'MKC' 'CDNS' 'VRSN' 'AMT']
# 2019-06-03 00:00:00
# 11091.40034608911
# ['ENPH' 'PAYC' 'ETSY' 'BALL' 'MTCH' 'CHD' 'MKC' 'CMG' 'VRSN' 'HSY']
# 2019-06-04 00:00:00
# 11058.634443399427
# ['ENPH' 'ETSY' 'PAYC' 'AZO' 'MTCH' 'HSY' 'CMG' 'WELL' 'CINF' 'CHTR']
# 2019-06-05 00:00:00
# 11216.225373294876
# ['ENPH' 'PAYC' 'ETSY' 'MTCH' 'AZO' 'HSY' 'CMG' 'VRSN' 'CINF' 'PG']
# 2019-06-06 00:00:00
# 11424.688830372315
# ['ENPH' 'ETSY' 'MTCH' 'AZO' 'AWK' 'CINF' 'WELL' 'NOW' 'XEL' 'AEP']
# 2019-06-07 00:00:00
# 11535.394228002986
# ['ENPH' 'ETSY' 'WELL' 'SRE' 'CDAY' 'NEE' 'MRK' 'TMUS' 'PEAK' 'CPRT']
# 2019-06-10 00:00:00
# 11660.574657938709
# ['ENPH' 'ETSY' 'CDAY' 'PEAK' 'CPRT' 'FLT' 'INTU']
# 2019-06-11 00:00:00
# 11780.848559816703
# ['ENPH' 'CPRT']
# 2019-06-12 00:00:00
# 11982.875387404638
# ['ENPH' 'AMT' 'CPRT' 'ELV']
# 2019-06-13 00:00:00
# 12092.598718345318
# ['AMT' 'CHD' 'MOH' 'SBAC' 'WELL' 'DG' 'PEAK' 'PGR' 'CPRT' 'ACGL']
# 2019-06-14 00:00:00
# 12070.899785900709
# ['CHD' 'MOH' 'AMT' 'HSY' 'MKC' 'AWK' 'MKTX' 'SBAC' 'WELL' 'ES']
# 2019-06-17 00:00:00
# 12125.075565468109
# ['AMD' 'BALL' 'CHD' 'AMT' 'MOH' 'CINF' 'MKTX' 'MKC' 'HSY' 'AWK']
# 2019-06-18 00:00:00
# 12149.101275376053
# ['PAYC' 'BALL' 'AMD' 'AMT' 'CHD' 'MOH' 'CINF' 'HSY' 'MKTX' 'MKC']
# 2019-06-19 00:00:00
# 12137.584385640786
# ['PAYC' 'BALL' 'AMD' 'AZO' 'MTCH' 'AMT' 'CINF' 'MOH' 'HSY' 'MKTX']
# 2019-06-20 00:00:00
# 12285.363090303304
# ['PAYC' 'BALL' 'AMD' 'MTCH' 'AZO' 'SBUX' 'CMG' 'MKTX' 'AMT' 'CINF']
# 2019-06-21 00:00:00
# 12189.942925751966
# ['BALL' 'SBUX' 'AZO' 'CMG' 'MTCH' 'ETSY' 'MKTX' 'CHD' 'VRSN' 'HSY']
# 2019-06-24 00:00:00
# 12102.452536284947
# ['ENPH' 'BALL' 'SBUX' 'AZO' 'MKTX' 'MTCH' 'CMG' 'ETSY' 'VRSN' 'DXCM']
# 2019-06-25 00:00:00
# 12060.972931076172
# ['ENPH' 'AMD' 'BALL' 'MTCH' 'SBUX' 'AZO' 'MKTX' 'CMG' 'DXCM' 'VRSN']
# 2019-06-26 00:00:00
# 11914.693904199848
# ['ENPH' 'AMD' 'SBUX' 'MTCH' 'AZO' 'NOW' 'CDNS' 'CMG' 'CINF' 'VRSN']
# 2019-06-27 00:00:00
# 11874.50516145333
# ['ENPH' 'PAYC' 'AMD' 'MTCH' 'SBUX' 'NOW' 'CDNS' 'AZO' 'CMG' 'CINF']
# 2019-06-28 00:00:00
# 12045.492519361474
# ['ENPH' 'PAYC' 'MTCH' 'SBUX' 'CMG' 'CDNS' 'NOW' 'AZO' 'MKTX' 'DXCM']
# 2019-07-01 00:00:00
# 12304.879098215028
# ['ENPH' 'PAYC' 'MTCH' 'SBUX' 'CMG' 'AZO' 'CDNS' 'MKTX' 'IQV' 'NOW']
# 2019-07-02 00:00:00
# 12238.475173822108
# ['ENPH' 'PAYC' 'MTCH' 'SBUX' 'CDNS' 'AZO' 'CMG' 'IQV' 'MKTX' 'NOW']
# 2019-07-03 00:00:00
# 12453.938774048955
# ['PAYC' 'SBUX' 'CDNS' 'MKTX' 'AZO' 'NOW' 'CMG' 'IQV' 'CINF' 'CDAY']
# 2019-07-05 00:00:00
# 12523.895314233896
# ['CMG' 'IQV' 'DXCM' 'DHR' 'ULTA' 'AMT' 'PG' 'TDG' 'YUM' 'WM']
# 2019-07-08 00:00:00
# 12566.534435158932
# ['IQV' 'DXCM' 'DHR' 'ALLE' 'AMT' 'MOH' 'ULTA' 'WM' 'YUM' 'TT']
# 2019-07-09 00:00:00
# 12518.452281692898
# ['IQV' 'HWM' 'WM' 'ALLE' 'TMO' 'YUM' 'TT' 'MRK' 'COO' 'TDY']
# 2019-07-10 00:00:00
# 12618.560936935155
# ['BALL' 'IQV' 'KEYS' 'HWM' 'APD' 'ZBRA' 'ALLE' 'YUM' 'TMO' 'MRK']
# 2019-07-11 00:00:00
# 12527.696826014704
# ['BALL' 'IQV' 'HWM' 'KEYS' 'MTD' 'DHR' 'ZBRA' 'APD' 'TMO' 'TSCO']
# 2019-07-12 00:00:00
# 12409.671828221948
# ['BALL' 'KEYS' 'IQV' 'HWM' 'MTD' 'APD' 'CDAY' 'DHR' 'TSCO' 'MSCI']
# 2019-07-15 00:00:00
# 12422.191554805073
# ['ENPH' 'BALL' 'CDNS' 'CINF' 'KEYS' 'SNPS' 'HWM' 'IQV' 'CDAY' 'MSCI']
# 2019-07-16 00:00:00
# 12386.448927339643
# ['ENPH' 'PAYC' 'BALL' 'CDNS' 'NOW' 'CINF' 'KEYS' 'SNPS' 'VRSN' 'IQV']
# 2019-07-17 00:00:00
# 12311.168789438225
# ['ENPH' 'PAYC' 'MTCH' 'BALL' 'SBUX' 'CDNS' 'NOW' 'CINF' 'HSY' 'KEYS']
# 2019-07-18 00:00:00
# 12285.713813197533
# ['ENPH' 'PAYC' 'MTCH' 'BALL' 'SBUX' 'AZO' 'CDNS' 'HSY' 'NOW' 'CINF']
# 2019-07-19 00:00:00
# 12497.013061031505
# ['ENPH' 'PAYC' 'AMD' 'BALL' 'CDNS' 'AZO' 'NOW' 'CINF' 'ETSY' 'SNPS']
# 2019-07-22 00:00:00
# 12425.135541876132
# ['ENPH' 'PAYC' 'AMD' 'BALL' 'CMG' 'AZO' 'CDNS' 'NOW' 'CINF' 'ETSY']
# 2019-07-23 00:00:00
# 12513.153345861432
# ['ENPH' 'PAYC' 'AMD' 'SBUX' 'MKTX' 'AZO' 'CMG' 'CDNS' 'ETSY' 'NOW']
# 2019-07-24 00:00:00
# 12349.471659117164
# ['ENPH' 'PAYC' 'AMD' 'SBUX' 'MKTX' 'AZO' 'CMG' 'CDNS' 'NOW' 'CINF']
# 2019-07-25 00:00:00
# 12432.913291866063
# ['ENPH' 'AMD' 'PAYC' 'SBUX' 'CMG' 'AZO' 'MKTX' 'CDNS' 'NOW' 'CINF']
# 2019-07-26 00:00:00
# 12523.291337958946
# ['ENPH' 'PAYC' 'AMD' 'SBUX' 'CMG' 'MKTX' 'AZO' 'NOW' 'CINF' 'SNPS']
# 2019-07-29 00:00:00
# 12618.437068709462
# ['ENPH' 'PAYC' 'AMD' 'MKTX' 'AZO' 'NOW' 'EPAM' 'SNPS' 'GPN' 'CINF']
# 2019-07-30 00:00:00
# 12402.641013242594
# ['ENPH' 'PAYC' 'MTCH' 'MKTX' 'AMD' 'AZO' 'NOW' 'EPAM' 'PG' 'AMT']
# 2019-07-31 00:00:00
# 12757.995738489353
# ['PAYC' 'MTCH' 'MKTX' 'AZO' 'NOW' 'HSY' 'EPAM' 'ULTA' 'EL' 'TSCO']
# 2019-08-01 00:00:00
# 12671.560003682182
# ['MTCH' 'BALL' 'MKTX' 'DXCM' 'ETSY' 'AZO' 'HSY' 'NOW' 'SNPS' 'EPAM']
# 2019-08-02 00:00:00
# 12523.249595767977
# ['MTCH' 'BALL' 'MKTX' 'CDNS' 'ETSY' 'AMD' 'HSY' 'AZO' 'EPAM' 'NOW']
# 2019-08-05 00:00:00
# 12033.580586670305
# ['MTCH' 'MKTX' 'AMD' 'CDNS' 'HSY' 'AZO' 'EPAM' 'KEYS' 'EW' 'NOW']
# 2019-08-06 00:00:00
# 12013.518626662884
# ['MTCH' 'SBUX' 'PAYC' 'CMG' 'CDNS' 'HSY' 'AZO' 'EW' 'KEYS' 'CSGP']
# 2019-08-07 00:00:00
# 12254.659099114157
# ['MTCH' 'SBUX' 'PAYC' 'CMG' 'CDNS' 'HSY' 'EW' 'AZO' 'CINF' 'ULTA']
# 2019-08-08 00:00:00
# 12500.921257879454
# ['SBUX' 'PAYC' 'SEDG' 'CMG' 'HSY' 'CDNS' 'EW' 'AMD' 'AZO' 'ULTA']
# 2019-08-09 00:00:00
# 12737.203453483999
# ['SBUX' 'AMD' 'CMG' 'SBAC' 'HSY' 'CDNS' 'EW' 'CDAY' 'CSGP' 'AZO']
# 2019-08-12 00:00:00
# 12795.236072950833
# ['SBUX' 'CMG' 'SBAC' 'HSY' 'EW' 'CDNS' 'CDAY' 'AZO' 'KEYS' 'APD']
# 2019-08-13 00:00:00
# 12689.085871462165
# ['ENPH' 'SBUX' 'CMG' 'SBAC' 'EW' 'CDAY' 'CDNS' 'KEYS' 'PG' 'CTLT']
# 2019-08-14 00:00:00
# 12811.982637083373
# ['ENPH' 'SBUX' 'EW' 'YUM' 'FISV' 'CDW' 'ACGL' 'HOLX' 'TER' 'LHX']
# 2019-08-15 00:00:00
# 12644.844984890899
# ['ENPH' 'SBUX' 'TFX' 'EW' 'AMT' 'YUM' 'FISV' 'LHX' 'ETR' 'EXR']
# 2019-08-16 00:00:00
# 12855.45628178702
# ['ENPH' 'SBUX' 'MTCH' 'TFX' 'EW' 'AMT' 'TSN' 'MSI' 'YUM' 'WELL']
# 2019-08-19 00:00:00
# 13045.091103577317
# ['ENPH' 'MTCH' 'TFX' 'TDG' 'AMT' 'MSI' 'TSN' 'YUM' 'STE' 'NVR']
# 2019-08-20 00:00:00
# 13019.712671521205
# ['ENPH' 'SEDG' 'MTCH' 'CMG' 'AMD' 'TFX' 'TDG' 'AMT' 'LYV' 'CINF']
# 2019-08-21 00:00:00
# 13151.198683932475
# ['ENPH' 'BALL' 'SEDG' 'SBUX' 'MTCH' 'SBAC' 'CMG' 'HSY' 'AMT' 'TFX']
# 2019-08-22 00:00:00
# 13155.107764811815
# ['ENPH' 'BALL' 'SEDG' 'SBUX' 'MTCH' 'SBAC' 'HSY' 'CMG' 'AMT' 'AMD']
# 2019-08-23 00:00:00
# 13078.929606455993
# ['ENPH' 'BALL' 'SBUX' 'SEDG' 'SBAC' 'HSY' 'CMG' 'AMT' 'EW' 'TDG']
# 2019-08-26 00:00:00
# 13001.117462268337
# ['BALL' 'SBUX' 'SEDG' 'SBAC' 'HSY' 'CMG' 'AMT' 'EW' 'TDG' 'TFX']
# 2019-08-27 00:00:00
# 13123.041444604094
# ['BALL' 'SBUX' 'SEDG' 'SBAC' 'CMG' 'EW' 'TDG' 'TFX' 'CINF' 'PG']
# 2019-08-28 00:00:00
# 13058.152317147862
# ['ENPH' 'BALL' 'SBUX' 'SEDG' 'SBAC' 'EW' 'TFX' 'PG' 'AWK' 'TDG']
# 2019-08-29 00:00:00
# 13275.903235595155
# ['ENPH' 'BALL' 'SBUX' 'SEDG' 'MTCH' 'SBAC' 'AMT' 'EW' 'TDG' 'PG']
# 2019-08-30 00:00:00
# 13250.718697376293
# ['ENPH' 'BALL' 'SEDG' 'MTCH' 'SBAC' 'PAYC' 'HSY' 'AMT' 'EW' 'TDG']
# 2019-09-03 00:00:00
# 13012.671016097163
# ['ENPH' 'MKTX' 'BALL' 'SEDG' 'MTCH' 'SBAC' 'PAYC' 'HSY' 'AMT' 'TDG']
# 2019-09-04 00:00:00
# 13028.26039111882
# ['ENPH' 'MKTX' 'BALL' 'SBAC' 'SEDG' 'MTCH' 'HSY' 'PAYC' 'TFX' 'CDAY']
# 2019-09-05 00:00:00
# 13265.831060259236
# ['ENPH' 'MKTX' 'SBUX' 'CMG' 'SEDG' 'MTCH' 'PAYC' 'HSY' 'CDAY' 'EL']
# 2019-09-06 00:00:00
# 12903.381558296807
# ['ENPH' 'MKTX' 'SBUX' 'CMG' 'PAYC' 'MTCH' 'HSY' 'KEYS' 'EL' 'CDAY']
# 2019-09-09 00:00:00
# 12898.811021991802
# ['ENPH' 'MKTX' 'BALL' 'SBUX' 'CMG' 'SBAC' 'PAYC' 'MTCH' 'HSY' 'KEYS']
# 2019-09-10 00:00:00
# 12194.436103426011
# ['ENPH' 'MKTX' 'SEDG' 'BALL' 'CMG' 'SBUX' 'SBAC' 'AMT' 'HSY' 'KEYS']
# 2019-09-11 00:00:00
# 11894.567434211804
# ['ENPH' 'MKTX' 'SEDG' 'BALL' 'SBUX' 'CMG' 'SBAC' 'EW' 'KEYS' 'AMT']
# 2019-09-12 00:00:00
# 12168.16938640929
# ['ENPH' 'MKTX' 'SEDG' 'BALL' 'SBUX' 'CMG' 'SBAC' 'EW' 'KEYS' 'CINF']
# 2019-09-13 00:00:00
# 11908.61082324773
# ['ENPH' 'MKTX' 'SBUX' 'BALL' 'CMG' 'SBAC' 'EW' 'KEYS' 'AZO' 'CINF']
# 2019-09-16 00:00:00
# 11879.124506243468
# ['ENPH' 'MKTX' 'SBUX' 'BALL' 'CMG' 'AZO' 'SBAC' 'KEYS' 'EW' 'AMT']
# 2019-09-17 00:00:00
# 11924.187029787796
# ['MKTX' 'SBUX' 'CMG' 'BALL' 'LRCX' 'SBAC' 'KEYS' 'AZO' 'EW' 'AMT']
# 2019-09-18 00:00:00
# 12153.668410225355
# ['MKTX' 'CMG' 'BALL' 'SBUX' 'AZO' 'SBAC' 'KEYS' 'TER' 'LRCX' 'EW']
# 2019-09-19 00:00:00
# 12179.796945002285
# ['MKTX' 'SBUX' 'TER' 'KEYS' 'LRCX' 'AZO' 'HSY' 'CPRT' 'EW' 'CINF']
# 2019-09-20 00:00:00
# 12173.958563609727
# ['TER' 'KEYS' 'LRCX' 'AZO' 'CPRT' 'DG' 'PG' 'EW' 'NVR' 'GNRC']
# 2019-09-23 00:00:00
# 12106.773406723041
# ['CPRT' 'KEYS' 'TER' 'LRCX' 'AZO' 'DG' 'NVR' 'GNRC' 'PHM' 'ACGL']
# 2019-09-24 00:00:00
# 12165.064619711768
# ['CPRT' 'LRCX' 'KEYS' 'TER' 'AZO' 'DG' 'PHM' 'GNRC' 'NVR' 'DLTR']
# 2019-09-25 00:00:00
# 11996.174129399886
# ['CPRT' 'LRCX' 'TER' 'KEYS' 'AZO' 'MLM' 'PHM' 'NVR' 'GNRC' 'ESS']
# 2019-09-26 00:00:00
# 12175.100978217339
# ['LRCX' 'TER' 'CPRT' 'KEYS' 'MLM' 'TSN' 'NVR' 'PHM' 'GNRC' 'AZO']
# 2019-09-27 00:00:00
# 12179.624539362934
# ['LRCX' 'TER' 'CPRT' 'KEYS' 'MLM' 'TSN' 'GNRC' 'TDG' 'NVR' 'WTW']
# 2019-09-30 00:00:00
# 11932.953427637964
# ['ENPH' 'SEDG' 'CMG' 'TER' 'CPRT' 'LRCX' 'AMT' 'MLM' 'SBAC' 'KEYS']
# 2019-10-01 00:00:00
# 12043.472165740914
# ['ENPH' 'SEDG' 'CMG' 'BALL' 'SBUX' 'KLAC' 'TER' 'LRCX' 'AMT' 'SBAC']
# 2019-10-02 00:00:00
# 11775.541800041676
# ['ENPH' 'SEDG' 'CMG' 'BALL' 'TER' 'KLAC' 'SBUX' 'CPRT' 'AMT' 'LRCX']
# 2019-10-03 00:00:00
# 11708.150147069038
# ['ENPH' 'SEDG' 'CMG' 'TER' 'BALL' 'AMT' 'SBAC' 'KLAC' 'HSY' 'PHM']
# 2019-10-04 00:00:00
# 11900.53519255176
# ['ENPH' 'SEDG' 'CMG' 'TER' 'BALL' 'AMT' 'KLAC' 'SBAC' 'LRCX' 'CPRT']
# 2019-10-07 00:00:00
# 12068.094241024424
# ['ENPH' 'SEDG' 'CMG' 'TER' 'KLAC' 'BALL' 'LRCX' 'PHM' 'DG' 'SBAC']
# 2019-10-08 00:00:00
# 11950.67034783712
# ['SEDG' 'CMG' 'KLAC' 'LRCX' 'BALL' 'CPRT' 'SBAC' 'DG' 'PHM' 'SNPS']
# 2019-10-09 00:00:00
# 12039.719290828627
# ['CMG' 'LRCX' 'KLAC' 'PHM' 'DG' 'SNPS' 'PG' 'CINF' 'WHR' 'CDW']
# 2019-10-10 00:00:00
# 12054.393237938231
# ['CMG' 'KLAC' 'PHM' 'SNPS' 'NVR' 'KEYS' 'DG' 'MLM' 'CINF' 'PG']
# 2019-10-11 00:00:00
# 12206.093642094105
# ['CMG' 'KLAC' 'CINF' 'MLM' 'PHM' 'NVR' 'PG' 'CDW' 'WHR' 'ACGL']
# 2019-10-14 00:00:00
# 12127.599588788253
# ['KLAC' 'PHM' 'NVR' 'EL' 'PG' 'ACGL' 'WHR' 'HSY' 'WELL' 'PEAK']
# 2019-10-15 00:00:00
# 12167.025652590755
# ['NVR' 'PHM' 'EL' 'PG' 'HSY' 'PEAK' 'ETR' 'AKAM' 'INVH' 'O']
# 2019-10-16 00:00:00
# 12127.430025144255
# ['NVR' 'AMT' 'PG' 'HSY' 'PEAK' 'EQIX' 'ETR' 'INVH' 'SO' 'EQR']
# 2019-10-17 00:00:00
# 12204.075938351263
# ['SEDG' 'MKTX' 'NVR' 'EPAM' 'EW' 'CINF' 'AMT' 'HSY' 'WELL' 'PG']
# 2019-10-18 00:00:00
# 12243.308809109727
# ['SEDG' 'TER' 'MKTX' 'EPAM' 'EW' 'XRAY' 'AMT' 'CINF' 'CSGP' 'POOL']
# 2019-10-21 00:00:00
# 12308.107597266815
# ['ENPH' 'SEDG' 'TER' 'MKTX' 'VMC' 'EPAM' 'CDW' 'CSGP' 'SNPS' 'AMT']
# 2019-10-22 00:00:00
# 12415.238257455272
# ['ENPH' 'SEDG' 'TER' 'MKTX' 'VMC' 'EPAM' 'SNPS' 'CSGP' 'CDW' 'EL']
# 2019-10-23 00:00:00
# 11998.640279125728
# ['ENPH' 'SEDG' 'TER' 'MKTX' 'GNRC' 'MLM' 'VMC' 'BALL' 'AMAT' 'TDG']
# 2019-10-24 00:00:00
# 12117.909499205643
# ['ENPH' 'SEDG' 'TER' 'CMG' 'KLAC' 'GNRC' 'LRCX' 'MKTX' 'BALL' 'MLM']
# 2019-10-25 00:00:00
# 12270.557015478267
# ['ENPH' 'TER' 'KLAC' 'CMG' 'LRCX' 'AMAT' 'MKTX' 'BALL' 'AMD' 'MLM']
# 2019-10-28 00:00:00
# 12508.906737748122
# ['ENPH' 'AMD' 'CMG' 'MLM' 'NVR' 'BALL' 'TDG' 'MKTX' 'EW' 'MAS']
# 2019-10-29 00:00:00
# 12604.070043323843
# ['ENPH' 'CMG' 'TDG' 'NVR' 'MKTX' 'BALL' 'MAS' 'CTAS' 'SNPS' 'NXPI']
# 2019-10-30 00:00:00
# 12422.190358982449
# ['NVR' 'BALL' 'PHM' 'MCO' 'MAS' 'EQIX' 'ACGL' 'SBAC' 'MCHP' 'VMC']
# 2019-10-31 00:00:00
# 12484.905368074114
# ['KEYS' 'NVR' 'PHM' 'XRAY' 'EQIX' 'MCO' 'SBAC' 'ACGL' 'DHI' 'DG']
# 2019-11-01 00:00:00
# 12474.95791372839
# ['SEDG' 'KEYS' 'CPRT' 'CMG' 'PHM' 'XRAY' 'NVR' 'MLM' 'SBAC' 'EQIX']
# 2019-11-04 00:00:00
# 12507.024717011798
# ['SEDG' 'KEYS' 'TER' 'PHM' 'CPRT' 'NVR' 'CMG' 'CTAS' 'MLM' 'DHI']
# 2019-11-05 00:00:00
# 12162.281244312962
# ['SEDG' 'KEYS' 'GNRC' 'TER' 'CPRT' 'PHM' 'CTAS' 'MLM' 'FLT' 'INVH']
# 2019-11-06 00:00:00
# 12178.852405480162
# ['SEDG' 'LRCX' 'KLAC' 'KEYS' 'GNRC' 'TER' 'CPRT' 'AMAT' 'PHM' 'EW']
# 2019-11-07 00:00:00
# 12171.975030942496
# ['SEDG' 'LRCX' 'KLAC' 'TER' 'KEYS' 'MKTX' 'GNRC' 'CPRT' 'AMAT' 'PHM']
# 2019-11-08 00:00:00
# 12061.59040443429
# ['SEDG' 'LRCX' 'KLAC' 'KEYS' 'TER' 'MKTX' 'GNRC' 'CPRT' 'AMAT' 'PHM']
# 2019-11-11 00:00:00
# 12077.557236593768
# ['SEDG' 'LRCX' 'KLAC' 'TER' 'KEYS' 'GNRC' 'MKTX' 'AMAT' 'CPRT' 'PHM']
# 2019-11-12 00:00:00
# 12377.194332997053
# ['SEDG' 'LRCX' 'KLAC' 'KEYS' 'GNRC' 'AMAT' 'MKTX' 'CPRT' 'MSCI' 'PHM']
# 2019-11-13 00:00:00
# 12251.27909070859
# ['LRCX' 'AMD' 'KLAC' 'MKTX' 'CPRT' 'MSCI' 'EW' 'PHM' 'GPN' 'TDY']
# 2019-11-14 00:00:00
# 12412.286648066218
# ['KLAC' 'LRCX' 'AMD' 'MSCI' 'QRVO' 'GPN' 'XRAY' 'TDY' 'CDW' 'FLT']
# 2019-11-15 00:00:00
# 12597.926758242174
# ['LRCX' 'KLAC' 'AMD' 'GNRC' 'MSCI' 'QCOM' 'AMAT' 'QRVO' 'XRAY' 'TDY']
# 2019-11-18 00:00:00
# 12579.957304614878
# ['LRCX' 'AMD' 'AMAT' 'GNRC' 'MSCI' 'QCOM' 'QRVO' 'HWM' 'CDW' 'XRAY']
# 2019-11-19 00:00:00
# 12730.43042749167
# ['MSCI' 'GNRC' 'QCOM' 'QRVO' 'TDY' 'CDW' 'FTNT' 'XRAY' 'GE' 'MAS']
# 2019-11-20 00:00:00
# 12678.25806993865
# ['DXCM' 'GNRC' 'QRVO' 'TDY' 'QCOM' 'CZR' 'CHTR' 'FTNT' 'GE' 'APD']
# 2019-11-21 00:00:00
# 12607.723395851706
# ['KEYS' 'KLAC' 'DXCM' 'TER' 'EPAM' 'GNRC' 'TDY' 'QRVO' 'CHTR' 'QCOM']
# 2019-11-22 00:00:00
# 12480.686967208696
# ['KEYS' 'LRCX' 'DXCM' 'TER' 'GNRC' 'KLAC' 'EPAM' 'AMAT' 'TDY' 'GE']
# 2019-11-25 00:00:00
# 12537.798063123975
# ['AMD' 'LRCX' 'KEYS' 'DXCM' 'GNRC' 'TER' 'GPN' 'KLAC' 'EPAM' 'TDY']
# 2019-11-26 00:00:00
# 12688.919967946906
# ['AMD' 'LRCX' 'DXCM' 'MKTX' 'KEYS' 'TER' 'EPAM' 'KLAC' 'GPN' 'TDG']
# 2019-11-27 00:00:00
# 12720.541163584166
# ['MKTX' 'AMD' 'DXCM' 'LRCX' 'TER' 'KEYS' 'EPAM' 'KLAC' 'GPN' 'TDG']
# 2019-11-29 00:00:00
# 12694.55711212879
# ['MKTX' 'AMD' 'TER' 'LRCX' 'KEYS' 'DXCM' 'KLAC' 'EPAM' 'MSCI' 'GPN']
# 2019-12-02 00:00:00
# 12614.929755770065
# ['MKTX' 'AMD' 'DXCM' 'TER' 'KEYS' 'LRCX' 'KLAC' 'CSGP' 'MSCI' 'EPAM']
# 2019-12-03 00:00:00
# 12239.516157762322
# ['PAYC' 'MKTX' 'TER' 'CPRT' 'TGT' 'KEYS' 'DXCM' 'AMD' 'LRCX' 'KLAC']
# 2019-12-04 00:00:00
# 12508.911417147698
# ['PAYC' 'AMD' 'MKTX' 'TGT' 'DXCM' 'CPRT' 'LRCX' 'KEYS' 'GPN' 'MSCI']
# 2019-12-05 00:00:00
# 12553.377804109805
# ['PAYC' 'AMD' 'TGT' 'MKTX' 'CPRT' 'DXCM' 'MSCI' 'KEYS' 'QRVO' 'GPN']
# 2019-12-06 00:00:00
# 12553.031333210549
# ['PAYC' 'AMD' 'DXCM' 'CPRT' 'TGT' 'MSCI' 'KEYS' 'GPN' 'MKTX' 'TDY']
# 2019-12-09 00:00:00
# 12497.097364240688
# ['PAYC' 'AMD' 'CPRT' 'TGT' 'DXCM' 'MSCI' 'KEYS' 'CMG' 'EPAM' 'GPN']
# 2019-12-10 00:00:00
# 12432.66075030141
# ['ENPH' 'SEDG' 'PAYC' 'AMD' 'GNRC' 'TGT' 'CPRT' 'DXCM' 'CMG' 'MSCI']
# 2019-12-11 00:00:00
# 12380.218350487045
# ['ENPH' 'SEDG' 'PAYC' 'GNRC' 'TGT' 'CPRT' 'CMG' 'DXCM' 'GE' 'EPAM']
# 2019-12-12 00:00:00
# 12405.306543164104
# ['ENPH' 'SEDG' 'PAYC' 'TGT' 'GNRC' 'CPRT' 'CMG' 'DXCM' 'KEYS' 'CDAY']
# 2019-12-13 00:00:00
# 12361.23795700135
# ['SEDG' 'PAYC' 'GNRC' 'TGT' 'CDAY' 'EPAM' 'MSCI' 'GPN' 'FLT' 'ANSS']
# 2019-12-16 00:00:00
# 12597.437251617279
# ['SEDG' 'PAYC' 'GNRC' 'CDAY' 'MSCI' 'DXCM' 'ANSS' 'FLT' 'MKTX' 'TSN']
# 2019-12-17 00:00:00
# 12747.696722590706
# ['ENPH' 'PAYC' 'GNRC' 'CMG' 'DXCM' 'CDAY' 'MSCI' 'MKTX' 'ANSS' 'FLT']
# 2019-12-18 00:00:00
# 12734.081381276417
# ['ENPH' 'PAYC' 'GNRC' 'CMG' 'DXCM' 'CDAY' 'MSCI' 'ANSS' 'TDY' 'FLT']
# 2019-12-19 00:00:00
# 12642.616941471508
# ['PAYC' 'GNRC' 'CMG' 'DXCM' 'CDAY' 'MSCI' 'ANSS' 'TDG' 'MCO' 'TDY']
# 2019-12-20 00:00:00
# 12822.535977118674
# ['PAYC' 'GNRC' 'CMG' 'MSCI' 'HWM' 'ANSS' 'MCO' 'TDG' 'TDY' 'ZBRA']
# 2019-12-23 00:00:00
# 12861.471922795412
# ['QRVO' 'HWM' 'MSCI' 'KEYS' 'BBY' 'TDY' 'ZBRA' 'DOV' 'AMP' 'SPGI']
# 2019-12-24 00:00:00
# 12887.476092315117
# ['QRVO' 'HWM' 'MSCI' 'KEYS' 'TDY' 'BBY' 'DOV' 'ZBRA' 'SPGI' 'AMP']
# 2019-12-26 00:00:00
# 12886.225957970986
# ['TER' 'LRCX' 'KLAC' 'TGT' 'QRVO' 'AMAT' 'HWM' 'SWKS' 'IR' 'MSCI']
# 2019-12-27 00:00:00
# 12917.953086910302
# ['SEDG' 'TER' 'LRCX' 'KLAC' 'TGT' 'QRVO' 'AMAT' 'HWM' 'SWKS' 'IR']
# 2019-12-30 00:00:00
# 12835.845529833676
# ['ENPH' 'SEDG' 'TER' 'LRCX' 'GNRC' 'KLAC' 'TGT' 'QRVO' 'CPRT' 'AMAT']
# 2019-12-31 00:00:00
# 12682.398900619144
# ['ENPH' 'SEDG' 'TER' 'LRCX' 'GNRC' 'KLAC' 'TGT' 'CPRT' 'QRVO' 'CMG']
# 2020-01-02 00:00:00
# 12872.878303775859
# ['ENPH' 'AMD' 'SEDG' 'TER' 'LRCX' 'QRVO' 'KLAC' 'GNRC' 'SWKS' 'TGT']
# 2020-01-03 00:00:00
# 12926.801033347965
# ['ENPH' 'SEDG' 'AMD' 'TER' 'LRCX' 'KLAC' 'GNRC' 'MTCH' 'QRVO' 'SWKS']
# 2020-01-06 00:00:00
# 12838.553619084472
# ['TER' 'LRCX' 'GNRC' 'MTCH' 'CDAY' 'KLAC' 'QRVO' 'LDOS' 'SWKS' 'CDW']
# 2020-01-07 00:00:00
# 12893.472770952842
# ['TER' 'LRCX' 'GNRC' 'CDAY' 'KLAC' 'MTCH' 'QRVO' 'LDOS' 'AMAT' 'SWKS']
# 2020-01-08 00:00:00
# 13004.7561405734
# ['AMD' 'TER' 'LRCX' 'CDAY' 'GNRC' 'KLAC' 'MTCH' 'QRVO' 'LDOS' 'AMAT']
# 2020-01-09 00:00:00
# 13148.311737186144
# ['AMD' 'TER' 'LRCX' 'CDAY' 'MTCH' 'KLAC' 'GNRC' 'QRVO' 'LDOS' 'TGT']
# 2020-01-10 00:00:00
# 13158.085815230535
# ['AMD' 'TER' 'LRCX' 'CDAY' 'MTCH' 'KLAC' 'GNRC' 'LDOS' 'AMAT' 'TGT']
# 2020-01-13 00:00:00
# 13120.624110223203
# ['AMD' 'TER' 'LRCX' 'CDAY' 'MTCH' 'KLAC' 'GNRC' 'QRVO' 'LDOS' 'AMAT']
# 2020-01-14 00:00:00
# 13247.862447919644
# ['AMD' 'LRCX' 'KLAC' 'GNRC' 'TGT' 'CDW' 'CMG' 'TYL' 'IR' 'PCG']
# 2020-01-15 00:00:00
# 13350.985995368534
# ['ENPH' 'SEDG' 'AMD' 'KLAC' 'GNRC' 'WDC' 'PCG' 'MKTX' 'CMG' 'TYL']
# 2020-01-16 00:00:00
# 13454.256397031932
# ['ENPH' 'SEDG' 'AMD' 'AAPL' 'CDAY' 'KLAC' 'WDC' 'LDOS' 'CSGP' 'MKTX']
# 2020-01-17 00:00:00
# 13574.458620673702
# ['ENPH' 'SEDG' 'AMD' 'AAPL' 'CDAY' 'LDOS' 'WDC' 'CHTR' 'CSGP' 'CMG']
# 2020-01-21 00:00:00
# 13554.93911660546
# ['ENPH' 'SEDG' 'AMD' 'PAYC' 'CDAY' 'LDOS' 'WDC' 'CHTR' 'HWM' 'TSLA']
# 2020-01-22 00:00:00
# 13783.924477298991
# ['ENPH' 'SEDG' 'PAYC' 'CDAY' 'TSLA' 'WDC' 'CHTR' 'MU' 'CDW' 'TYL']
# 2020-01-23 00:00:00
# 13876.513532632005
# ['ENPH' 'SEDG' 'AAPL' 'TSLA' 'CDAY' 'MTCH' 'CHTR' 'EPAM' 'WDC' 'EL']
# 2020-01-24 00:00:00
# 13986.658582553067
# ['ENPH' 'AAPL' 'CDAY' 'LDOS' 'CHTR' 'CDW' 'MTCH' 'CSGP' 'TDY' 'SNPS']
# 2020-01-27 00:00:00
# 13506.765678949707
# ['AAPL' 'NVDA' 'CDAY' 'LDOS' 'QCOM' 'CHTR' 'CSGP' 'CTLT' 'SWKS' 'SNPS']
# 2020-01-28 00:00:00
# 13696.487795057892
# ['AMD' 'SEDG' 'AAPL' 'TER' 'TSLA' 'NVDA' 'CDAY' 'LRCX' 'GPN' 'QCOM']
# 2020-01-29 00:00:00
# 13891.397977149954
# ['ENPH' 'SEDG' 'AMD' 'TER' 'AAPL' 'TSLA' 'NVDA' 'CDAY' 'QCOM' 'LRCX']
# 2020-01-30 00:00:00
# 13891.723244647821
# ['ENPH' 'SEDG' 'CPRT' 'AAPL' 'AMD' 'TER' 'TSLA' 'QCOM' 'GPN' 'CDAY']
# 2020-01-31 00:00:00
# 14081.029075094515
# ['SEDG' 'CPRT' 'AMD' 'AAPL' 'TER' 'LRCX' 'QCOM' 'RMD' 'GPN' 'LDOS']
# 2020-02-03 00:00:00
# 13712.60146143388
# ['SEDG' 'PAYC' 'CPRT' 'AMD' 'AAPL' 'TER' 'LRCX' 'QCOM' 'GPN' 'RMD']
# 2020-02-04 00:00:00
# 14189.945737857952
# ['ENPH' 'SEDG' 'PAYC' 'AMD' 'GNRC' 'CPRT' 'TER' 'LRCX' 'AAPL' 'GPN']
# 2020-02-05 00:00:00
# 14767.629218002032
# ['ENPH' 'SEDG' 'AMD' 'GNRC' 'PAYC' 'CPRT' 'TER' 'AAPL' 'GPN' 'RMD']
# 2020-02-06 00:00:00
# 14359.12855940159
# ['AMD' 'GNRC' 'CPRT' 'TER' 'AAPL' 'GPN' 'NVDA' 'PHM' 'QRVO' 'KMX']
# 2020-02-07 00:00:00
# 14292.259114888837
# ['GNRC' 'CPRT' 'PHM' 'DHI' 'KMX' 'SPGI' 'EQIX' 'NVR' 'DHR' 'COST']
# 2020-02-10 00:00:00
# 14333.432039567419
# ['GNRC' 'CPRT' 'HWM' 'PHM' 'PAYC' 'BRO' 'DHI' 'DXCM' 'KMX' 'SPGI']
# 2020-02-11 00:00:00
# 14591.979029587683
# ['GNRC' 'CPRT' 'AAPL' 'HWM' 'PAYC' 'PHM' 'BRO' 'CSGP' 'ANSS' 'DXCM']
# 2020-02-12 00:00:00
# 14644.700471199383
# ['TSLA' 'CPRT' 'AAPL' 'MSCI' 'PHM' 'PAYC' 'QRVO' 'ANSS' 'BRO' 'CSGP']
# 2020-02-13 00:00:00
# 14637.018216765928
# ['TSLA' 'CPRT' 'MSCI' 'PAYC' 'BRO' 'TYL' 'CDAY' 'EPAM' 'NOW' 'DHR']
# 2020-02-14 00:00:00
# 14944.466331960104
# ['TSLA' 'CPRT' 'MSFT' 'PAYC' 'BRO' 'CDAY' 'TYL' 'CHTR' 'EPAM' 'NOW']
# 2020-02-18 00:00:00
# 15129.775334046535
# ['TSLA' 'CPRT' 'PAYC' 'MSFT' 'ANSS' 'BRO' 'TYL' 'CHTR' 'EPAM' 'NOW']
# 2020-02-19 00:00:00
# 15421.569500605052
# ['ENPH' 'TSLA' 'CPRT' 'AAPL' 'LRCX' 'RMD' 'MSFT' 'QCOM' 'ANSS' 'TDY']
# 2020-02-20 00:00:00
# 15677.256069763887
# ['ENPH' 'AAPL' 'LRCX' 'CPRT' 'RMD' 'QCOM' 'MSFT' 'TDY' 'PHM' 'TER']
# 2020-02-21 00:00:00
# 15582.251122045971
# ['AAPL' 'LRCX' 'RMD' 'QCOM' 'CPRT' 'PHM' 'TDY' 'MSFT' 'TER' 'BRO']
# 2020-02-24 00:00:00
# 14806.52916390322
# ['AMD' 'AAPL' 'LRCX' 'MSCI' 'RMD' 'PHM' 'QCOM' 'ANSS' 'BRO' 'TDY']
# 2020-02-25 00:00:00
# 14968.214297649174
# ['GNRC' 'AMD' 'HWM' 'LDOS' 'NVDA' 'CSGP' 'AAPL' 'MSCI' 'RMD' 'LRCX']
# 2020-02-26 00:00:00
# 14386.736933599903
# ['TSLA' 'GNRC' 'LDOS' 'HWM' 'NVDA' 'MSCI' 'LRCX' 'AAPL' 'RMD' 'SBAC']
# 2020-02-27 00:00:00
# 14056.496142756894
# ['TSLA' 'GNRC' 'DXCM' 'NVDA' 'HWM' 'LDOS' 'AAPL' 'LRCX' 'MSCI' 'RMD']
# 2020-02-28 00:00:00
# 13316.548606303715
# ['ENPH' 'SEDG' 'TSLA' 'GNRC' 'DXCM' 'AMD' 'HWM' 'LDOS' 'LRCX' 'NVDA']
# 2020-03-02 00:00:00
# 14290.612855701658
# ['ENPH' 'SEDG' 'TSLA' 'GNRC' 'DXCM' 'AMD' 'NVDA' 'LRCX' 'LDOS' 'PAYC']
# 2020-03-03 00:00:00
# 14947.32489327181
# ['ENPH' 'SEDG' 'TSLA' 'GNRC' 'AMD' 'DXCM' 'NVDA' 'LDOS' 'LRCX' 'AAPL']
# 2020-03-04 00:00:00
# 14722.395629578332
# ['ENPH' 'SEDG' 'TSLA' 'GNRC' 'AMD' 'DXCM' 'NVDA' 'LDOS' 'LRCX' 'AAPL']
# 2020-03-05 00:00:00
# 14703.297356423907
# ['ENPH' 'SEDG' 'TSLA' 'GNRC' 'DXCM' 'NVDA' 'LDOS' 'SBAC' 'DVA' 'BRO']
# 2020-03-06 00:00:00
# 14466.54504906988
# ['ENPH' 'SEDG' 'TSLA' 'DXCM' 'NEM' 'WST' 'CHTR' 'EQIX' 'ODFL' 'CDAY']
# 2020-03-09 00:00:00
# 13359.502308253985
# ['ENPH' 'SEDG' 'DXCM' 'MRNA' 'DPZ' 'CDAY' 'DG' 'STE' 'TMUS']
# 2020-03-10 00:00:00
# 13495.236589830063
# ['ENPH' 'SEDG' 'DXCM' 'LDOS' 'TYL' 'SBAC' 'DPZ' 'MRNA' 'CDAY' 'NOW']
# 2020-03-11 00:00:00
# 13077.79419787325
# ['ENPH' 'SEDG' 'DXCM' 'LDOS' 'SBAC' 'TYL' 'MSCI' 'DPZ' 'EPAM' 'NOW']
# 2020-03-12 00:00:00
# 11463.113000771644
# ['ENPH' 'SEDG' 'GNRC' 'DXCM' 'LDOS' 'RMD' 'NVDA' 'BRO' 'MSCI' 'CSGP']
# 2020-03-13 00:00:00
# 12069.277287334005
# ['ENPH' 'TSLA' 'GNRC' 'DXCM' 'RMD' 'NEM' 'CSGP' 'DPZ' 'BRO' 'DVA']
# 2020-03-16 00:00:00
# 10472.442651228817
# ['ENPH' 'TSLA' 'AMD' 'GNRC' 'DXCM' 'AAPL' 'SBAC' 'DVA' 'NVDA' 'CSGP']
# 2020-03-17 00:00:00
# 10489.613785661888
# ['AMD' 'CPB' 'SBAC' 'MRNA' 'AAPL' 'KR' 'EQIX']
# 2020-03-18 00:00:00
# 10472.633894146458
# ['RMD' 'AMD' 'CPB' 'SBAC' 'MRNA' 'KR' 'NEM' 'AWK' 'WEC' 'COST']
# 2020-03-19 00:00:00
# 10671.26114947212
# ['RMD' 'KR' 'DVA' 'CPB' 'SBAC' 'WEC' 'BIIB' 'COST' 'WMT' 'AWK']
# 2020-03-20 00:00:00
# 10065.011438438232
# ['DPZ' 'DVA']
# 2020-03-23 00:00:00
# 9356.773722494632
# ['DPZ']
# 2020-03-24 00:00:00
# 10265.937309623403
# ['spy']
# 2020-03-25 00:00:00
# 10723.573238274399
# ['KR']
# 2020-03-26 00:00:00
# 10012.005767364102
# ['spy']
# 2020-03-27 00:00:00
# 10162.4747517531
# ['MRNA']
# 2020-03-30 00:00:00
# 10957.705146659351
# ['MRNA']
# 2020-03-31 00:00:00
# 10961.287348651495
# ['MRNA' 'KR']
# 2020-04-01 00:00:00
# 10996.181808158355
# ['MRNA' 'KR']
# 2020-04-02 00:00:00
# 11084.110830530139
# ['KR']
# 2020-04-03 00:00:00
# 11590.10107256994
# ['AMD']
# 2020-04-06 00:00:00
# 11590.10107256994
# ['AMD' 'DPZ' 'NEM' 'NVDA']
# 2020-04-07 00:00:00
# 12305.486490438305
# ['ENPH' 'DXCM' 'TSLA' 'AMD' 'MSCI' 'NVDA' 'ODFL' 'NEM' 'DPZ' 'FTNT']
# 2020-04-08 00:00:00
# 11914.853992164506
# ['ENPH' 'DXCM' 'TSLA' 'AMD' 'ODFL' 'NEM' 'NVDA' 'DPZ' 'MSCI' 'BIIB']
# 2020-04-09 00:00:00
# 12284.338018303562
# ['DXCM' 'AMD' 'LDOS' 'TYL' 'EQIX' 'DVA' 'CTLT' 'NVDA' 'MSCI' 'BIIB']
# 2020-04-13 00:00:00
# 12307.099407389658
# ['DXCM' 'EQIX' 'LDOS' 'CTLT' 'TYL' 'NVDA' 'DVA' 'BIIB' 'HUM' 'DPZ']
# 2020-04-14 00:00:00
# 12533.10141108986
# ['DXCM' 'RMD' 'NVDA' 'EQIX' 'BIIB' 'VRTX' 'REGN' 'ATVI' 'WST' 'TTWO']
# 2020-04-15 00:00:00
# 12517.584624157109
# ['DXCM' 'RMD' 'WST' 'VRTX' 'MRNA' 'REGN' 'TTWO' 'AKAM' 'CPB' 'LLY']
# 2020-04-16 00:00:00
# 12775.009206876266
# ['MRNA' 'WST' 'DG' 'TTWO' 'KR']
# 2020-04-17 00:00:00
# 13617.279845970674
# ['EQIX' 'WST' 'DG' 'ODFL' 'HRL' 'KR' 'GILD' 'FTNT']
# 2020-04-20 00:00:00
# 13560.206486316163
# ['RMD' 'MKTX' 'EQIX' 'LDOS' 'WST' 'DG' 'BMY' 'AMT' 'ODFL' 'ZTS']
# 2020-04-21 00:00:00
# 13286.437250984829
# ['ENPH' 'MKTX' 'RMD' 'VRTX' 'SBAC' 'EQIX' 'LDOS' 'WST' 'HUM' 'DG']
# 2020-04-22 00:00:00
# 13265.27306174203
# ['ENPH' 'NEM' 'MKTX' 'RMD' 'VRTX' 'EQIX' 'SBAC' 'HUM' 'WST' 'BIO']
# 2020-04-23 00:00:00
# 13548.60439477917
# ['ENPH' 'TSLA' 'AMD' 'NEM' 'MKTX' 'RMD' 'VRTX' 'SBAC' 'NVDA' 'EQIX']
# 2020-04-24 00:00:00
# 13517.193891416648
# ['ENPH' 'TSLA' 'SEDG' 'AMD' 'NEM' 'NVDA' 'VRTX' 'MKTX' 'RMD' 'SBAC']
# 2020-04-27 00:00:00
# 13716.10327682778
# ['ENPH' 'TSLA' 'SEDG' 'NEM' 'AMD' 'NVDA' 'VRTX' 'RMD' 'SBAC' 'EQIX']
# 2020-04-28 00:00:00
# 14006.723975875797
# ['ENPH' 'TSLA' 'DXCM' 'AMD' 'NEM' 'MRNA' 'NVDA' 'REGN' 'VRTX' 'MKTX']
# 2020-04-29 00:00:00
# 13942.086182879335
# ['ENPH' 'TSLA' 'DXCM' 'AMD' 'NEM' 'MRNA' 'MKTX' 'REGN' 'RMD' 'SBAC']
# 2020-04-30 00:00:00
# 13977.09154842294
# ['TSLA' 'DXCM' 'NEM' 'AMD' 'MRNA' 'MKTX' 'REGN' 'MSCI' 'VRTX' 'RMD']
# 2020-05-01 00:00:00
# 13663.104946318637
# ['TSLA' 'DXCM' 'NEM' 'AMD' 'MRNA' 'NVDA' 'REGN' 'HUM' 'TYL' 'VRTX']
# 2020-05-04 00:00:00
# 13664.505029939992
# ['DXCM' 'TSLA' 'NEM' 'AMD' 'MRNA' 'NVDA' 'REGN' 'HUM' 'VRTX' 'TYL']
# 2020-05-05 00:00:00
# 14315.583485150648
# ['TSLA' 'MRNA' 'NEM' 'AMD' 'NVDA' 'REGN' 'VRTX' 'WST' 'HUM' 'BIO']
# 2020-05-06 00:00:00
# 14361.531786604215
# ['TSLA' 'NEM' 'MRNA' 'SEDG' 'AMD' 'REGN' 'NVDA' 'WST' 'VRTX' 'HUM']
# 2020-05-07 00:00:00
# 14568.739075763006
# ['TSLA' 'SEDG' 'MRNA' 'NEM' 'AMD' 'NVDA' 'WST' 'ODFL' 'HUM' 'MSCI']
# 2020-05-08 00:00:00
# 14579.560794204695
# ['TSLA' 'NEM' 'MRNA' 'SEDG' 'AMD' 'NVDA' 'WST' 'CTLT' 'DVA' 'ODFL']
# 2020-05-11 00:00:00
# 14827.952219859097
# ['TSLA' 'SEDG' 'AMD' 'WST' 'MPWR' 'CTLT' 'ODFL' 'HUM' 'DVA' 'KLAC']
# 2020-05-12 00:00:00
# 15331.04848598838
# ['TSLA' 'SEDG' 'CTLT' 'ODFL' 'HUM' 'DVA' 'AMGN' 'SPGI' 'QRVO' 'LDOS']
# 2020-05-13 00:00:00
# 15013.446072030172
# ['SEDG' 'NEM' 'ODFL' 'CTLT' 'HUM' 'DVA' 'MSFT' 'SPGI' 'QRVO' 'MCO']
# 2020-05-14 00:00:00
# 14606.659178523489
# ['NEM' 'DVA' 'CTLT' 'HUM' 'ODFL' 'MSFT' 'EQIX' 'MOH' 'CHTR' 'NOW']
# 2020-05-15 00:00:00
# 14743.173919324781
# ['AAPL' 'DVA' 'HUM' 'CTLT' 'ODFL' 'MSFT' 'CLX' 'MOH' 'NOW' 'EQIX']
# 2020-05-18 00:00:00
# 15327.26295178697
# ['TSLA' 'DXCM' 'SEDG' 'REGN' 'ATVI' 'AAPL' 'MKTX' 'DVA' 'CTLT' 'BIO']
# 2020-05-19 00:00:00
# 15190.06541615244
# ['ENPH' 'TSLA' 'DXCM' 'SEDG' 'REGN' 'AAPL' 'MKTX' 'VRTX' 'ATVI' 'MPWR']
# 2020-05-20 00:00:00
# 15425.175646091393
# ['ENPH' 'TSLA' 'DXCM' 'SEDG' 'FTNT' 'REGN' 'AAPL' 'ATVI' 'MPWR' 'CTLT']
# 2020-05-21 00:00:00
# 15201.58432823484
# ['ENPH' 'TSLA' 'DXCM' 'FTNT' 'REGN' 'WST' 'AAPL' 'MPWR' 'ATVI' 'SWKS']
# 2020-05-22 00:00:00
# 15055.697825683354
# ['TSLA' 'ENPH' 'DXCM' 'MRNA' 'NEM' 'FTNT' 'WST' 'REGN' 'AAPL' 'ATVI']
# 2020-05-26 00:00:00
# 14996.63752714667
# ['TSLA' 'ENPH' 'DXCM' 'MRNA' 'NEM' 'AMD' 'REGN' 'FTNT' 'WST' 'AAPL']
# 2020-05-27 00:00:00
# 14135.896603337684
# ['TSLA' 'ENPH' 'MRNA' 'AMD' 'NEM' 'AAPL' 'WST' 'REGN' 'MPWR' 'MKTX']
# 2020-05-28 00:00:00
# 14240.309278252218
# ['TSLA' 'ENPH' 'NVDA' 'MRNA' 'AMD' 'NEM' 'AAPL' 'REGN' 'DVA' 'WST']
# 2020-05-29 00:00:00
# 14459.888025236885
# ['TSLA' 'ENPH' 'DXCM' 'MRNA' 'SEDG' 'NVDA' 'REGN' 'AMD' 'FTNT' 'DVA']
# 2020-06-01 00:00:00
# 15047.814746343389
# ['TSLA' 'ENPH' 'DXCM' 'MRNA' 'SEDG' 'NVDA' 'FTNT' 'GNRC' 'AMD' 'WST']
# 2020-06-02 00:00:00
# 15183.867832851725
# ['ENPH' 'MRNA' 'DXCM' 'SEDG' 'NVDA' 'FTNT' 'GNRC' 'WST' 'AMD' 'AAPL']
# 2020-06-03 00:00:00
# 15112.13353990345
# ['ENPH' 'MRNA' 'DXCM' 'SEDG' 'NVDA' 'FTNT' 'GNRC' 'SWKS' 'AMD' 'WST']
# 2020-06-04 00:00:00
# 14984.51947459586
# ['ENPH' 'MRNA' 'DXCM' 'NVDA' 'FTNT' 'GNRC' 'ODFL' 'AAPL' 'CTLT' 'AMD']
# 2020-06-05 00:00:00
# 14839.423135506675
# ['ENPH' 'DXCM' 'NVDA' 'GNRC' 'ODFL' 'AAPL' 'AMD' 'BIO' 'CTLT' 'HUM']
# 2020-06-08 00:00:00
# 14890.645426701369
# ['ENPH' 'DXCM' 'NVDA' 'GNRC' 'ODFL' 'WST' 'TYL' 'HUM' 'BIO' 'NEM']
# 2020-06-09 00:00:00
# 15002.783557196019
# ['ENPH' 'SEDG' 'GNRC' 'ODFL' 'WST' 'HUM' 'TYL' 'BIO' 'VRTX' 'CTLT']
# 2020-06-10 00:00:00
# 15059.73908930684
# ['ENPH' 'SEDG' 'REGN' 'GNRC' 'ODFL' 'WST' 'TYL' 'VRTX' 'HUM' 'BIO']
# 2020-06-11 00:00:00
# 14745.852484313593
# ['ENPH' 'SEDG' 'REGN' 'FTNT' 'ODFL' 'WST' 'TYL' 'VRTX' 'MKTX' 'BIO']
# 2020-06-12 00:00:00
# 14654.203093100065
# ['MRNA' 'ENPH' 'SEDG' 'NVDA' 'REGN' 'QRVO' 'FTNT' 'SWKS' 'WST' 'MPWR']
# 2020-06-15 00:00:00
# 14178.002074598227
# ['MRNA' 'ENPH' 'SEDG' 'NVDA' 'REGN' 'QRVO' 'SWKS' 'FTNT' 'KLAC' 'ODFL']
# 2020-06-16 00:00:00
# 15140.372450928748
# ['ENPH' 'SEDG' 'REGN' 'FTNT' 'ODFL' 'WST' 'GNRC' 'QRVO' 'MPWR' 'KLAC']
# 2020-06-17 00:00:00
# 15114.573028925253
# ['SEDG' 'REGN' 'FTNT' 'GNRC' 'MPWR' 'KLAC' 'QRVO' 'ODFL' 'SWKS' 'TER']
# 2020-06-18 00:00:00
# 15013.023012762671
# ['TSLA' 'SEDG' 'REGN' 'FTNT' 'QRVO' 'MPWR' 'SWKS' 'LRCX' 'KLAC' 'TER']
# 2020-06-19 00:00:00
# 15231.317882140656
# ['TSLA' 'ENPH' 'SEDG' 'NVDA' 'REGN' 'AMD' 'AAPL' 'QRVO' 'MPWR' 'TER']
# 2020-06-22 00:00:00
# 15329.773005633775
# ['TSLA' 'ENPH' 'NVDA' 'AMD' 'AAPL' 'MPWR' 'QRVO' 'KLAC' 'CDAY' 'MU']
# 2020-06-23 00:00:00
# 15558.079304876615
# ['TSLA' 'AMD' 'AAPL' 'QRVO' 'KLAC' 'TYL' 'MU' 'PAYC' 'ADSK' 'KR']
# 2020-06-24 00:00:00
# 15373.360823647574
# ['MRNA' 'TSLA' 'AMD' 'SWKS' 'TYL' 'KR' 'NDSN' 'DPZ' 'SBAC' 'EFX']
# 2020-06-25 00:00:00
# 15256.509133225443
# ['MRNA' 'TSLA' 'AMD' 'SWKS' 'NDSN' 'CHTR' 'EFX' 'LEN' 'CRL']
# 2020-06-26 00:00:00
# 15257.669883031745
# ['TSLA' 'MRNA' 'DXCM' 'SEDG' 'AMD' 'SWKS' 'QRVO' 'KLAC' 'NOW' 'ADSK']
# 2020-06-29 00:00:00
# 14991.629122813343
# ['TSLA' 'MRNA' 'DXCM' 'NVDA' 'SEDG' 'FTNT' 'TER' 'ODFL' 'ATVI' 'LRCX']
# 2020-06-30 00:00:00
# 15281.371192889068
# ['TSLA' 'MRNA' 'DXCM' 'NVDA' 'SEDG' 'REGN' 'AAPL' 'TER' 'FTNT' 'ODFL']
# 2020-07-01 00:00:00
# 15665.190460240681
# ['TSLA' 'MRNA' 'DXCM' 'NVDA' 'SEDG' 'REGN' 'TER' 'AAPL' 'LRCX' 'FTNT']
# 2020-07-02 00:00:00
# 15840.530529244057
# ['MRNA' 'DXCM' 'NVDA' 'SEDG' 'REGN' 'AAPL' 'TER' 'FTNT' 'LRCX' 'AMD']
# 2020-07-06 00:00:00
# 16030.007163530554
# ['MRNA' 'DXCM' 'NVDA' 'SEDG' 'REGN' 'AAPL' 'TER' 'LRCX' 'FTNT' 'ETSY']
# 2020-07-07 00:00:00
# 16170.522291568332
# ['MRNA' 'REGN' 'TER' 'AAPL' 'ETSY' 'VRTX' 'RMD' 'MKTX' 'PYPL' 'ADBE']
# 2020-07-08 00:00:00
# 16384.21954230548
# ['MRNA' 'TER' 'AAPL' 'ETSY' 'VRTX' 'RMD' 'PYPL' 'ADBE' 'EA' 'TGT']
# 2020-07-09 00:00:00
# 16505.61792187285
# ['MRNA' 'ETSY' 'RMD' 'KR' 'TMUS' 'TGT' 'DG' 'JKHY' 'MTCH' 'TSCO']
# 2020-07-10 00:00:00
# 16698.925213273433
# ['ETSY' 'RMD' 'LLY' 'KR' 'ABBV' 'DG' 'TMUS' 'MTCH' 'JKHY' 'MAS']
# 2020-07-13 00:00:00
# 16751.254322080265
# ['ETSY' 'NEM' 'RMD' 'KR' 'LLY' 'FAST' 'ABBV' 'MTCH' 'HUM' 'DG']
# 2020-07-14 00:00:00
# 16348.339399044702
# ['REGN' 'TER' 'WST' 'GNRC' 'MPWR' 'ETSY' 'VRTX' 'TYL' 'NEM' 'RMD']
# 2020-07-15 00:00:00
# 16928.467280235927
# ['DXCM' 'REGN' 'TER' 'WST' 'GNRC' 'MPWR' 'ODFL' 'ATVI' 'VRTX' 'ETSY']
# 2020-07-16 00:00:00
# 16816.93868775116
# ['DXCM' 'NVDA' 'REGN' 'WST' 'TER' 'ODFL' 'ATVI' 'MPWR' 'VRTX' 'CDAY']
# 2020-07-17 00:00:00
# 16977.010312256225
# ['TSLA' 'DXCM' 'NVDA' 'REGN' 'WST' 'TER' 'ATVI' 'ODFL' 'LRCX' 'MPWR']
# 2020-07-20 00:00:00
# 17153.847948383813
# ['TSLA' 'DXCM' 'NVDA' 'REGN' 'AAPL' 'TER' 'ODFL' 'ATVI' 'MPWR' 'VRTX']
# 2020-07-21 00:00:00
# 17628.45447464279
# ['TSLA' 'DXCM' 'NVDA' 'AAPL' 'TER' 'ATVI' 'VRTX' 'MPWR' 'AMD' 'LRCX']
# 2020-07-22 00:00:00
# 17402.749318203743
# ['TSLA' 'DXCM' 'SEDG' 'NVDA' 'AAPL' 'ATVI' 'VRTX' 'MSCI' 'AMD' 'LRCX']
# 2020-07-23 00:00:00
# 17692.933740208333
# ['TSLA' 'DXCM' 'SEDG' 'NVDA' 'AAPL' 'ATVI' 'VRTX' 'MSCI' 'MPWR' 'FTNT']
# 2020-07-24 00:00:00
# 16937.525615863833
# ['TSLA' 'MRNA' 'SEDG' 'NVDA' 'GNRC' 'AAPL' 'VRTX' 'ATVI' 'MPWR' 'MSCI']
# 2020-07-27 00:00:00
# 17452.391153034223
# ['TSLA' 'MRNA' 'ENPH' 'SEDG' 'NVDA' 'REGN' 'GNRC' 'AAPL' 'VRTX' 'ODFL']
# 2020-07-28 00:00:00
# 17743.139338538596
# ['TSLA' 'MRNA' 'ENPH' 'SEDG' 'NVDA' 'REGN' 'GNRC' 'AAPL' 'MSCI' 'LRCX']
# 2020-07-29 00:00:00
# 17463.710803258597
# ['MRNA' 'TSLA' 'DXCM' 'SEDG' 'NVDA' 'REGN' 'ENPH' 'GNRC' 'AAPL' 'LRCX']
# 2020-07-30 00:00:00
# 17595.151920199343
# ['TSLA' 'MRNA' 'DXCM' 'SEDG' 'NVDA' 'REGN' 'GNRC' 'ENPH' 'AAPL' 'LRCX']
# 2020-07-31 00:00:00
# 18050.402909815002
# ['TSLA' 'MRNA' 'DXCM' 'SEDG' 'NVDA' 'REGN' 'ENPH' 'WST' 'AAPL' 'LRCX']
# 2020-08-03 00:00:00
# 18053.79831905147
# ['MRNA' 'DXCM' 'SEDG' 'ENPH' 'REGN' 'WST' 'NEM' 'MSCI' 'AMZN' 'ATVI']
# 2020-08-04 00:00:00
# 18438.60362142762
# ['MRNA' 'SEDG' 'ENPH' 'WST' 'ATVI' 'NEM' 'MSCI' 'NOW' 'ODFL' 'BIO']
# 2020-08-05 00:00:00
# 18686.338157453716
# ['TSLA' 'MRNA' 'WST' 'NEM' 'NOW' 'MSCI' 'ODFL' 'BIO' 'FAST' 'RMD']
# 2020-08-06 00:00:00
# 18516.768651619008
# ['TSLA' 'WST' 'NEM' 'MSCI' 'BIO' 'ALGN' 'RMD' 'KR' 'TMO' 'LOW']
# 2020-08-07 00:00:00
# 18373.23281680564
# ['WST' 'NEM' 'MSCI' 'ALGN' 'BIO' 'LOW' 'BBY' 'TMO' 'KR' 'MAS']
# 2020-08-10 00:00:00
# 18417.843712007354
# ['MRNA' 'REGN' 'WST' 'LRCX' 'NEM' 'POOL' 'TER' 'NOW' 'MSCI' 'BIO']
# 2020-08-11 00:00:00
# 17973.7526985588
# ['TSLA' 'MRNA' 'DXCM' 'AMD' 'REGN' 'WST' 'SWKS' 'LRCX' 'PYPL' 'NEM']
# 2020-08-12 00:00:00
# 18079.813681931668
# ['TSLA' 'MRNA' 'NVDA' 'DXCM' 'AMD' 'ETSY' 'GNRC' 'REGN' 'MPWR' 'SWKS']
# 2020-08-13 00:00:00
# 18497.381741358007
# ['MRNA' 'NVDA' 'AMD' 'DXCM' 'GNRC' 'ETSY' 'AAPL' 'REGN' 'SWKS' 'MPWR']
# 2020-08-14 00:00:00
# 18617.53346975257
# ['MRNA' 'NVDA' 'DXCM' 'AMD' 'ETSY' 'GNRC' 'ENPH' 'AAPL' 'REGN' 'SWKS']
# 2020-08-17 00:00:00
# 18738.40234396176
# ['MRNA' 'NVDA' 'SEDG' 'DXCM' 'AMD' 'ETSY' 'GNRC' 'ENPH' 'AAPL' 'REGN']
# 2020-08-18 00:00:00
# 18896.595357031147
# ['MRNA' 'AMD' 'DXCM' 'SEDG' 'GNRC' 'ETSY' 'ENPH' 'AAPL' 'REGN' 'SWKS']
# 2020-08-19 00:00:00
# 18837.185648880735
# ['MRNA' 'AMD' 'DXCM' 'SEDG' 'ETSY' 'GNRC' 'AAPL' 'ENPH' 'WST' 'SWKS']
# 2020-08-20 00:00:00
# 18705.369912960392
# ['SEDG' 'AMD' 'GNRC' 'ETSY' 'ENPH' 'AAPL' 'SWKS' 'QRVO' 'PYPL' 'LRCX']
# 2020-08-21 00:00:00
# 18848.679550203564
# ['AMD' 'SEDG' 'GNRC' 'ETSY' 'AAPL' 'ENPH' 'SWKS' 'QRVO' 'MPWR' 'LRCX']
# 2020-08-24 00:00:00
# 19235.64316420807
# ['SEDG' 'ETSY' 'ENPH' 'SWKS' 'QRVO' 'MPWR' 'BBWI' 'LRCX' 'ROL' 'CRL']
# 2020-08-25 00:00:00
# 19023.07224778752
# ['SEDG' 'ENPH' 'SWKS' 'QRVO' 'WST' 'MPWR' 'LRCX' 'ROL' 'TER' 'URI']
# 2020-08-26 00:00:00
# 19118.549585277833
# ['SEDG' 'DXCM' 'GNRC' 'ENPH' 'REGN' 'SWKS' 'QRVO' 'WST' 'ODFL' 'MPWR']
# 2020-08-27 00:00:00
# 19198.675566604263
# ['SEDG' 'DXCM' 'GNRC' 'ENPH' 'ETSY' 'REGN' 'SWKS' 'WST' 'DPZ' 'ODFL']
# 2020-08-28 00:00:00
# 18987.464140694832
# ['NVDA' 'SEDG' 'DXCM' 'ENPH' 'GNRC' 'ETSY' 'REGN' 'WST' 'SWKS' 'DPZ']
# 2020-08-31 00:00:00
# 19179.251383645613
# ['TSLA' 'NVDA' 'SEDG' 'ENPH' 'GNRC' 'DXCM' 'ETSY' 'REGN' 'ODFL' 'WST']
# 2020-09-01 00:00:00
# 19638.110510654915
# ['TSLA' 'NVDA' 'ENPH' 'SEDG' 'DXCM' 'GNRC' 'ETSY' 'ODFL' 'BBWI' 'MPWR']
# 2020-09-02 00:00:00
# 20228.426602123924
# ['DXCM' 'ETSY' 'GNRC' 'BBWI' 'QRVO' 'BBY' 'ADSK' 'DPZ' 'ROL' 'POOL']
# 2020-09-03 00:00:00
# 20024.163084818214
# ['ETSY' 'AAPL' 'GNRC' 'BBWI' 'ADSK' 'BBY' 'DPZ' 'FTNT' 'POOL' 'SNPS']
# 2020-09-04 00:00:00
# 19036.708694193163
# ['TSLA' 'NVDA' 'ENPH' 'AMD' 'SEDG' 'ETSY' 'AAPL' 'GNRC' 'NOW' 'AMZN']
# 2020-09-08 00:00:00
# 18025.5009393073
# ['TSLA' 'MRNA' 'ENPH' 'NVDA' 'DXCM' 'AMD' 'SEDG' 'AAPL' 'ETSY' 'GNRC']
# 2020-09-09 00:00:00
# 18433.549276295154
# ['TSLA' 'MRNA' 'DXCM' 'AMD' 'ENPH' 'NVDA' 'SEDG' 'GNRC' 'ETSY' 'AAPL']
# 2020-09-10 00:00:00
# 18942.11379546921
# ['TSLA' 'ENPH' 'NVDA' 'DXCM' 'AMD' 'SEDG' 'GNRC' 'AAPL' 'ETSY' 'WST']
# 2020-09-11 00:00:00
# 18576.72102981346
# ['TSLA' 'ENPH' 'NVDA' 'SEDG' 'GNRC' 'ETSY' 'WST' 'NOW' 'EPAM' 'PYPL']
# 2020-09-14 00:00:00
# 18515.55879724498
# ['TSLA' 'ENPH' 'NVDA' 'SEDG' 'GNRC' 'WST' 'ETSY' 'EPAM' 'PYPL' 'AMZN']
# 2020-09-15 00:00:00
# 19234.7256916504
# ['TSLA' 'NVDA' 'ENPH' 'DXCM' 'AMD' 'SEDG' 'GNRC' 'AAPL' 'WST' 'ETSY']
# 2020-09-16 00:00:00
# 19244.204337470703
# ['NVDA' 'AMD' 'DXCM' 'SEDG' 'AAPL' 'ETSY' 'EPAM' 'NOW' 'ADBE' 'PYPL']
# 2020-09-17 00:00:00
# 18203.570263396432
# ['NVDA' 'DXCM' 'AMD' 'AAPL' 'ALGN' 'PYPL' 'NFLX' 'CRM' 'FCX' 'MOH']
# 2020-09-18 00:00:00
# 18441.390950598343
# ['ALGN' 'NFLX' 'PYPL' 'CRM' 'CMG' 'HUM' 'META' 'UNH' 'ISRG' 'GOOGL']
# 2020-09-21 00:00:00
# 17941.521791629802
# ['NFLX' 'ALGN' 'PYPL' 'AMZN' 'NEM' 'ODFL' 'CMG' 'META' 'NKE' 'ISRG']
# 2020-09-22 00:00:00
# 18363.794606488384
# ['ALGN' 'AMZN' 'ODFL' 'NEM' 'FCX' 'ROL' 'DVA' 'CMG' 'MAS' 'META']
# 2020-09-23 00:00:00
# 18454.511052401063
# ['GNRC' 'WST' 'ALGN' 'EPAM' 'NEM' 'CRL' 'ODFL' 'FCX' 'ROL' 'TMO']
# 2020-09-24 00:00:00
# 17870.883155913743
# ['TSLA' 'GNRC' 'WST' 'ALGN' 'EPAM' 'FDX' 'CRL' 'ODFL' 'ROL' 'CMG']
# 2020-09-25 00:00:00
# 18012.36141100081
# ['TSLA' 'MRNA' 'NVDA' 'GNRC' 'WST' 'ALGN' 'EPAM' 'SWKS' 'QRVO' 'ADBE']
# 2020-09-28 00:00:00
# 18844.4278354512
# ['TSLA' 'MRNA' 'NVDA' 'GNRC' 'WST' 'EPAM' 'ALGN' 'SWKS' 'ADBE' 'CTLT']
# 2020-09-29 00:00:00
# 18976.875387657332
# ['TSLA' 'MRNA' 'GNRC' 'WST' 'EPAM' 'FDX' 'CTLT' 'ALGN' 'QRVO' 'CRL']
# 2020-09-30 00:00:00
# 19034.09968563236
# ['TSLA' 'MRNA' 'WST' 'QRVO' 'FDX' 'ALGN' 'FCX' 'BBWI' 'BIO' 'TMO']
# 2020-10-01 00:00:00
# 19284.528511350894
# ['TSLA' 'MRNA' 'QRVO' 'FCX' 'BBWI' 'BIO' 'CHTR' 'MTD' 'CZR' 'FDS']
# 2020-10-02 00:00:00
# 18915.450098528316
# ['MRNA' 'CZR' 'MTD' 'FDS' 'HOLX' 'DG' 'UNP' 'NSC' 'STE' 'PGR']
# 2020-10-05 00:00:00
# 19391.12077799125
# ['MRNA' 'CZR' 'ATVI' 'EA' 'HOLX' 'FDS' 'DG' 'TTWO' 'NSC' 'CHRW']
# 2020-10-06 00:00:00
# 19562.640902785708
# ['DPZ' 'MSCI' 'ATVI' 'CZR' 'EA' 'NKE' 'EBAY' 'FDS' 'TTWO' 'NSC']
# 2020-10-07 00:00:00
# 19283.29602109215
# ['DPZ' 'MSCI' 'ATVI' 'LRCX' 'CZR' 'NKE' 'TTWO' 'EBAY' 'NSC' 'SHW']
# 2020-10-08 00:00:00
# 19310.124009868046
# ['PYPL' 'DPZ' 'POOL' 'MSFT' 'LRCX' 'ATVI' 'TGT' 'IDXX' 'SPGI' 'MNST']
# 2020-10-09 00:00:00
# 19470.886644228805
# ['TSLA' 'MRNA' 'AAPL' 'PYPL' 'BBWI' 'AMZN' 'NOW' 'ADBE' 'POOL' 'SNPS']
# 2020-10-12 00:00:00
# 19872.978544720347
# ['TSLA' 'MRNA' 'NVDA' 'AMD' 'AAPL' 'PYPL' 'AMZN' 'NOW' 'BBWI' 'SWKS']
# 2020-10-13 00:00:00
# 20201.727103359484
# ['TSLA' 'NVDA' 'AMD' 'GNRC' 'PYPL' 'NOW' 'SWKS' 'BBWI' 'CDAY' 'MOH']
# 2020-10-14 00:00:00
# 20336.258761171473
# ['ENPH' 'SEDG' 'NVDA' 'AMD' 'GNRC' 'CDAY' 'BBWI' 'SWKS' 'BBY' 'MOH']
# 2020-10-15 00:00:00
# 19939.90471297014
# ['ENPH' 'SEDG' 'NVDA' 'AMD' 'GNRC' 'CDAY' 'PAYC' 'BBWI' 'SWKS' 'QRVO']
# 2020-10-16 00:00:00
# 20679.495476837375
# ['ENPH' 'SEDG' 'NVDA' 'AMD' 'ETSY' 'GNRC' 'WST' 'BBWI' 'CDAY' 'CTLT']
# 2020-10-19 00:00:00
# 20560.873409406868
# ['MRNA' 'ENPH' 'SEDG' 'NVDA' 'AMD' 'ETSY' 'GNRC' 'MPWR' 'WST' 'REGN']
# 2020-10-20 00:00:00
# 20422.716553050697
# ['ENPH' 'MRNA' 'SEDG' 'NVDA' 'ETSY' 'AMD' 'GNRC' 'MPWR' 'CDAY' 'WST']
# 2020-10-21 00:00:00
# 20484.1187934905
# ['TSLA' 'ENPH' 'MRNA' 'SEDG' 'NVDA' 'AMD' 'ETSY' 'GNRC' 'NOW' 'MPWR']
# 2020-10-22 00:00:00
# 19693.790450270684
# ['TSLA' 'MRNA' 'SEDG' 'NVDA' 'AMD' 'ETSY' 'GNRC' 'NOW' 'MPWR' 'WST']
# 2020-10-23 00:00:00
# 19836.84399003464
# ['TSLA' 'MRNA' 'SEDG' 'NVDA' 'AMD' 'ETSY' 'GNRC' 'NOW' 'MPWR' 'PCG']
# 2020-10-26 00:00:00
# 19728.097263991538
# ['TSLA' 'MRNA' 'ENPH' 'SEDG' 'DXCM' 'PCG' 'NVDA' 'AMD' 'ETSY' 'NOW']
# 2020-10-27 00:00:00
# 19752.14356772408
# ['TSLA' 'MRNA' 'ENPH' 'SEDG' 'DXCM' 'NVDA' 'ETSY' 'AMD' 'MPWR' 'NOW']
# 2020-10-28 00:00:00
# 19153.655901013488
# ['TSLA' 'ENPH' 'MRNA' 'SEDG' 'ETSY' 'NVDA' 'AMD' 'GNRC' 'MPWR' 'NOW']
# 2020-10-29 00:00:00
# 19216.076812305528
# ['TSLA' 'ENPH' 'ETSY' 'SEDG' 'NVDA' 'AMD' 'GNRC' 'MPWR' 'NOW' 'WST']
# 2020-10-30 00:00:00
# 19030.18621106705
# ['TSLA' 'ENPH' 'SEDG' 'ETSY' 'NVDA' 'AMD' 'MPWR' 'NOW' 'BBWI' 'WST']
# 2020-11-02 00:00:00
# 18795.933891777982
# ['TSLA' 'ENPH' 'SEDG' 'ETSY' 'NVDA' 'AMD' 'NOW' 'MPWR' 'WST' 'BBWI']
# 2020-11-03 00:00:00
# 18543.19096186768
# ['TSLA' 'ENPH' 'SEDG' 'ETSY' 'NVDA' 'GNRC' 'AMD' 'NOW' 'MPWR' 'BBWI']
# 2020-11-04 00:00:00
# 18999.433884884776
# ['ETSY' 'SEDG' 'NVDA' 'GNRC' 'AMD' 'NOW' 'MPWR' 'CTLT' 'WST' 'BBWI']
# 2020-11-05 00:00:00
# 19885.08148083914
# ['ETSY' 'SEDG' 'ALGN' 'PAYC' 'BBWI' 'MTCH' 'CDAY' 'AMZN' 'DHR' 'CMG']
# 2020-11-06 00:00:00
# 19882.325181634234
# ['SEDG' 'BBWI' 'ALGN' 'DHR' 'PAYC' 'FSLR' 'ATVI' 'NEE' 'CAG' 'DLR']
# 2020-11-09 00:00:00
# 20489.194396042913
# ['SEDG' 'ALGN' 'FSLR']
# 2020-11-10 00:00:00
# 18794.44817425026
# ['SEDG' 'ALGN' 'POOL' 'HOLX']
# 2020-11-11 00:00:00
# 18888.49347597552
# ['SEDG' 'GNRC' 'ALGN' 'POOL' 'DHR' 'BIO' 'TMO' 'ROL' 'PKI' 'HOLX']
# 2020-11-12 00:00:00
# 19337.81652236638
# ['GNRC' 'MPWR' 'ALGN' 'IDXX' 'NEM' 'CRL' 'DHR' 'POOL' 'BIO' 'TMO']
# 2020-11-13 00:00:00
# 19304.386169774232
# ...
# 23192.31833715845
# ['DVN' 'OXY' 'MRO' 'APA' 'TRGP' 'COP' 'MOS' 'EQT' 'CTRA' 'FANG']
# 2022-05-17 00:00:00
# 24039.46688317389
# ['DVN' 'MRO' 'APA' 'COP' 'TRGP' 'MOS' 'EQT' 'PXD' 'CTRA' 'FANG']
# 2022-05-18 00:00:00
# 24275.68088898554
# ['DVN' 'COP' 'CTRA' 'FANG' 'VLO' 'MCK' 'MPC' 'EOG' 'XOM' 'ALB']
# 2022-05-19 00:00:00
# 23151.96041053039
# ['CTRA' 'FANG' 'VLO' 'MCK' 'EOG' 'ALB' 'WMB' 'NOC' 'ELV']
# 2022-05-20 00:00:00
# 23689.847227418497
# ['FANG' 'MCK' 'VLO' 'EOG' 'ALB' 'NOC']
# 2022-05-23 00:00:00
# 23762.518067621397
# ['MCK' 'ABBV' 'ABC']
# 2022-05-24 00:00:00
# 23593.09618557165
# ['CF' 'MCK' 'ABC' 'ABBV' 'HSY']
# 2022-05-25 00:00:00
# 23694.29949508635
# ['DVN' 'OXY' 'CF' 'MCK' 'MOS' 'MPC' 'VLO' 'KR' 'ABC' 'ABBV']
# 2022-05-26 00:00:00
# 24251.9960492434
# ['DVN' 'OXY' 'CF' 'PXD' 'CVX' 'MOS' 'MPC' 'VLO' 'BKR' 'NRG']
# 2022-05-27 00:00:00
# 24144.03302527515
# ['DVN' 'OXY' 'TRGP' 'CF' 'PXD' 'CVX' 'MPC' 'MOS' 'VLO' 'ALB']
# 2022-05-31 00:00:00
# 25116.038990341855
# ['DVN' 'OXY' 'TRGP' 'CF' 'PXD' 'MOS' 'ALB' 'VLO' 'BKR' 'NRG']
# 2022-06-01 00:00:00
# 24677.169326146446
# ['CF' 'MOS' 'PXD' 'BKR' 'NRG' 'REGN' 'ABBV' 'MRK' 'HOLX']
# 2022-06-02 00:00:00
# 24316.406265342906
# ['CF' 'PXD' 'NRG' 'REGN' 'MRK' 'HOLX']
# 2022-06-03 00:00:00
# 24219.767569146854
# ['CF' 'MCK' 'PXD' 'ALB' 'CTVA' 'PFE' 'NRG' 'SNPS' 'VRTX' 'ED']
# 2022-06-06 00:00:00
# 24450.722270951668
# ['EQT' 'PXD' 'MCK' 'CVX' 'XOM' 'EXC' 'BKR' 'ALB' 'PFE' 'LLY']
# 2022-06-07 00:00:00
# 24282.654095173035
# ['OXY' 'EQT' 'APA' 'CTRA' 'COP' 'HAL' 'MCK' 'PXD' 'CVX' 'XOM']
# 2022-06-08 00:00:00
# 25056.960555608275
# ['OXY' 'MRO' 'APA' 'EQT' 'CTRA' 'COP' 'HAL' 'PXD' 'CF' 'CVX']
# 2022-06-09 00:00:00
# 24564.871808251737
# ['DVN' 'OXY' 'MRO' 'EQT' 'CTRA' 'FANG' 'HAL' 'PXD' 'EOG' 'CVX']
# 2022-06-10 00:00:00
# 23902.312515470097
# ['DVN' 'MRO' 'OXY' 'EQT' 'CTRA' 'FANG' 'HAL' 'PXD' 'CF' 'EOG']
# 2022-06-13 00:00:00
# 22917.390788838155
# ['DVN' 'EQT' 'MRO' 'OXY' 'APA' 'CTRA' 'COP' 'FANG' 'EOG' 'HAL']
# 2022-06-14 00:00:00
# 22901.672986140504
# ['DVN' 'EQT' 'MRO' 'APA' 'CTRA' 'OXY' 'COP' 'FANG' 'PXD' 'VLO']
# 2022-06-15 00:00:00
# 22280.43439425084
# ['DVN' 'MRO' 'OXY' 'APA' 'EQT' 'CTRA' 'COP' 'CF' 'FANG' 'VLO']
# 2022-06-16 00:00:00
# 21228.34416236997
# ['DVN' 'MRO' 'APA' 'OXY' 'EQT' 'CTRA' 'COP' 'CF' 'FANG' 'VLO']
# 2022-06-17 00:00:00
# 20202.803984946124
# ['DVN' 'OXY' 'MRO' 'EQT' 'APA' 'CTRA' 'COP' 'MCK' 'MPC' 'PXD']
# 2022-06-21 00:00:00
# 19623.54531740529
# ['OXY' 'MRO' 'APA' 'EQT' 'MCK' 'DLTR' 'MPC' 'VRTX' 'VLO' 'WRB']
# 2022-06-22 00:00:00
# 18995.596024523744
# ['OXY' 'APA' 'MRO' 'EQT' 'MCK' 'DLTR' 'MPC' 'VLO' 'XOM' 'WRB']
# 2022-06-23 00:00:00
# 19400.510561968706
# ['OXY' 'EQT' 'CTRA' 'DLTR' 'MPC' 'AZO' 'VLO' 'XOM' 'PWR' 'CTVA']
# 2022-06-24 00:00:00
# 18944.614462051646
# ['OXY' 'CTRA' 'EQT' 'AZO' 'MPC' 'XOM' 'PWR' 'VLO']
# 2022-06-27 00:00:00
# 19415.773884578317
# ['EQT' 'MPC' 'XOM' 'VLO']
# 2022-06-28 00:00:00
# 20285.417169035973
# ['MPC' 'VLO' 'XOM' 'HES']
# 2022-06-29 00:00:00
# 20771.536998294458
# ['HES']
# 2022-06-30 00:00:00
# 19328.842660758186
# ['spy']
# 2022-07-01 00:00:00
# 19345.282622964918
# ['spy']
# 2022-07-05 00:00:00
# 19310.348879126428
# ['VRTX' 'HSY']
# 2022-07-06 00:00:00
# 19399.798383558897
# ['VRTX' 'AZO' 'ABBV' 'HSY' 'UNH']
# 2022-07-07 00:00:00
# 19443.583159534603
# ['MCK' 'VRTX' 'AZO' 'LLY' 'ABBV' 'UNH' 'HSY' 'AJG']
# 2022-07-08 00:00:00
# 19447.22939854196
# ['MCK' 'VRTX' 'LLY' 'AZO' 'WRB' 'ABBV' 'ED' 'UNH' 'HSY' 'ELV']
# 2022-07-11 00:00:00
# 19492.56555690492
# ['MCK' 'VRTX' 'LLY' 'AZO' 'PFE' 'WRB' 'ABBV' 'GIS' 'ED' 'UNH']
# 2022-07-12 00:00:00
# 19452.208269788043
# ['OXY' 'MCK' 'LLY' 'XOM' 'AZO' 'WRB' 'PFE' 'ABBV' 'NOC' 'GIS']
# 2022-07-13 00:00:00
# 19223.62388475013
# ['OXY' 'MCK' 'XOM' 'LLY' 'AZO' 'WRB' 'PFE' 'ABBV' 'NOC' 'GIS']
# 2022-07-14 00:00:00
# 18944.625744491736
# ['OXY' 'MCK' 'VRTX' 'LLY' 'AZO' 'ABBV' 'PFE' 'WRB' 'GIS' 'NOC']
# 2022-07-15 00:00:00
# 19240.335850722007
# ['OXY' 'MCK' 'PWR' 'VRTX' 'LLY' 'AZO' 'PFE' 'NOC' 'GIS' 'ED']
# 2022-07-18 00:00:00
# 19354.28626597751
# ['OXY' 'MCK' 'DLTR' 'PWR' 'VRTX' 'LLY' 'AZO' 'NOC' 'UNH' 'PFE']
# 2022-07-19 00:00:00
# 19131.63428365909
# ['OXY' 'DLTR' 'VRTX' 'PWR' 'LLY' 'AZO' 'UNH' 'GIS' 'ELV' 'MRK']
# 2022-07-20 00:00:00
# 19251.34085994286
# ['DLTR' 'VRTX' 'PWR' 'LLY' 'GIS' 'HSY' 'MRK']
# 2022-07-21 00:00:00
# 19062.771735920465
# ['DLTR' 'MCK' 'PWR' 'VRTX' 'LLY' 'NOC' 'GIS' 'SYY' 'HSY']
# 2022-07-22 00:00:00
# 19168.5507009614
# ['MCK' 'PWR' 'VRTX' 'LLY' 'AZO' 'NOC' 'GIS' 'PFE' 'HSY']
# 2022-07-25 00:00:00
# 19140.363661249263
# ['MCK' 'VRTX' 'LLY' 'AZO' 'NOC' 'ED' 'GIS' 'PFE' 'HSY']
# 2022-07-26 00:00:00
# 19231.919365878544
# ['DLTR' 'VRTX' 'AZO' 'GIS' 'ED' 'HSY']
# 2022-07-27 00:00:00
# 19244.89529027833
# ['DLTR' 'VRTX' 'AZO' 'GIS']
# 2022-07-28 00:00:00
# 19372.241010650883
# ['DLTR' 'ON' 'VRTX' 'AZO' 'COST']
# 2022-07-29 00:00:00
# 19449.502745485875
# ['OXY' 'ON' 'DLTR' 'VRTX' 'CNC' 'UNH' 'AZO' 'COST' 'TAP']
# 2022-08-01 00:00:00
# 19644.656521008517
# ['OXY' 'EQT' 'DLTR' 'VRTX' 'CNC' 'AZO' 'UNH' 'COST']
# 2022-08-02 00:00:00
# 19604.392788784495
# ['OXY' 'EQT' 'DLTR' 'MPC' 'VRTX' 'CNC' 'AZO' 'MTB' 'LLY' 'COST']
# 2022-08-03 00:00:00
# 19622.065781799043
# ['OXY' 'EQT' 'CTRA' 'MPC' 'DLTR' 'VRTX' 'CNC' 'MTB' 'LLY']
# 2022-08-04 00:00:00
# 19310.129821855997
# ['EQT' 'OXY' 'CTRA' 'DLTR' 'MCK' 'PWR' 'CNC' 'VRTX' 'MTB']
# 2022-08-05 00:00:00
# 18866.699672095663
# ['EQT' 'MCK' 'XOM' 'PWR' 'CNC' 'VRTX' 'UNH' 'MTB' 'AJG' 'CDNS']
# 2022-08-08 00:00:00
# 19397.436819635415
# ['EQT' 'CF' 'MCK' 'MPC' 'XOM' 'PWR' 'VRTX' 'CNC' 'UNH' 'MTB']
# 2022-08-09 00:00:00
# 19525.250554472153
# ['OXY' 'EQT' 'CF' 'MCK' 'ENPH' 'MPC' 'XOM' 'ON' 'PWR' 'CNC']
# 2022-08-10 00:00:00
# 19902.94232299487
# ['OXY' 'EQT' 'CF' 'VLO' 'ENPH' 'MPC' 'XOM' 'CNC' 'ON' 'PWR']
# 2022-08-11 00:00:00
# 20297.20207724315
# ['OXY' 'EQT' 'CF' 'ENPH' 'VLO' 'MPC' 'XOM' 'ON' 'HES' 'PWR']
# 2022-08-12 00:00:00
# 20290.749854933598
# ['OXY' 'CF' 'CTRA' 'FANG' 'ENPH' 'XOM' 'HES' 'TRGP' 'CVX' 'ON']
# 2022-08-15 00:00:00
# 19970.597971682037
# ['CF' 'CTRA' 'FANG' 'ENPH' 'ON' 'TRGP' 'CVX' 'ANET' 'WMB' 'ADM']
# 2022-08-16 00:00:00
# 20357.532794524854
# ['CF' 'ENPH' 'ON' 'ANET' 'TSLA' 'SNPS' 'GWW' 'NOC' 'ED' 'CDNS']
# 2022-08-17 00:00:00
# 20167.07778230614
# ['CF' 'ENPH' 'ON' 'ANET' 'GWW' 'NOC' 'TSLA' 'SNPS' 'MOH' 'GIS']
# 2022-08-18 00:00:00
# 20358.897351499374
# ['CF' 'ENPH' 'ON' 'CI' 'ANET' 'GWW' 'GIS' 'F' 'MOH' 'FSLR']
# 2022-08-19 00:00:00
# 20241.407242419744
# ['CF' 'ENPH' 'VRTX' 'CTVA' 'CNC' 'ANET' 'CI' 'GWW' 'CHRW' 'GIS']
# 2022-08-22 00:00:00
# 20069.686558344052
# ['CF' 'MCK' 'ENPH' 'DLTR' 'VRTX' 'CNC' 'CTVA' 'CI' 'ANET' 'MTB']
# 2022-08-23 00:00:00
# 20104.814168765486
# ['CF' 'MCK' 'ENPH' 'DLTR' 'CNC' 'VRTX' 'ADM' 'CTVA' 'PWR' 'CI']
# 2022-08-24 00:00:00
# 20117.84573905173
# ['EQT' 'CF' 'MCK' 'FANG' 'ENPH' 'CVX' 'ON' 'TRGP' 'DLTR' 'CNC']
# 2022-08-25 00:00:00
# 20348.347933748384
# ['EQT' 'FANG' 'MCK' 'DLTR' 'ENPH' 'CVX' 'ON' 'TRGP' 'CNC' 'ADM']
# 2022-08-26 00:00:00
# 20425.527331334288
# ['EQT' 'MCK' 'ENPH' 'ON' 'ADM' 'CNC' 'VRTX' 'AZO' 'CTVA' 'PWR']
# 2022-08-29 00:00:00
# 19666.124443330955
# ['EQT' 'ENPH' 'ON' 'WMB' 'CTVA' 'CNC' 'PWR' 'PCG' 'WRB' 'GIS']
# 2022-08-30 00:00:00
# 19843.535218995377
# ['EQT' 'VLO' 'ENPH' 'ON' 'CNC' 'WMB' 'PWR' 'CTVA' 'PCG' 'GIS']
# 2022-08-31 00:00:00
# 19400.011610317975
# ['DVN' 'EQT' 'CTRA' 'VLO' 'EOG' 'MCK' 'MPC' 'ENPH' 'ON' 'ADM']
# 2022-09-01 00:00:00
# 19368.34313813873
# ['OXY' 'EQT' 'DVN' 'CF' 'MRO' 'COP' 'VLO' 'CTRA' 'MCK' 'EOG']
# 2022-09-02 00:00:00
# 19595.498328401274
# ['OXY' 'DVN' 'EQT' 'CF' 'MRO' 'COP' 'MCK' 'EOG' 'FANG' 'XOM']
# 2022-09-06 00:00:00
# 19656.419276057004
# ['OXY' 'DVN' 'EQT' 'CF' 'MRO' 'COP' 'EOG' 'FANG' 'MCK' 'XOM']
# 2022-09-07 00:00:00
# 18807.787709949185
# ['OXY' 'DVN' 'CF' 'MRO' 'EQT' 'COP' 'FANG' 'ENPH' 'EOG' 'XOM']
# 2022-09-08 00:00:00
# 19279.305709676613
# ['OXY' 'DVN' 'EQT' 'CF' 'COP' 'XOM' 'HES' 'MPC' 'ON' 'ADM']
# 2022-09-09 00:00:00
# 19730.80159266838
# ['OXY' 'DVN' 'EQT' 'CF' 'COP' 'XOM' 'HES' 'MPC' 'ADM' 'ON']
# 2022-09-12 00:00:00
# 20015.19607916945
# ['OXY' 'EQT' 'DVN' 'CF' 'MRO' 'COP' 'EOG' 'XOM' 'FANG' 'HES']
# 2022-09-13 00:00:00
# 19872.816375695947
# ['OXY' 'DVN' 'MRO' 'CF' 'APA' 'COP' 'HES' 'EOG' 'FANG' 'XOM']
# 2022-09-14 00:00:00
# 19943.11750245236
# ['OXY' 'DVN' 'APA' 'VLO' 'MCK' 'PXD' 'PSX' 'WMB' 'GIS' 'CAH']
# 2022-09-15 00:00:00
# 19860.19643251554
# ['MCK' 'ADM' 'FSLR' 'GIS' 'CAH' 'GPC' 'LW' 'CHRW']
# 2022-09-16 00:00:00
# 19581.308317032912
# ['MCK' 'CI' 'ADM' 'ED' 'GWW' 'SRE' 'GIS' 'FSLR' 'GPC' 'CAH']
# 2022-09-19 00:00:00
# 19575.928636572633
# ['DVN' 'CF' 'XOM' 'MCK' 'MPC' 'CI' 'FSLR' 'PGR' 'ED' 'ANET']
# 2022-09-20 00:00:00
# 19914.424743754258
# ['DVN' 'CF' 'ENPH' 'XOM' 'MCK' 'MPC' 'CTVA' 'FSLR' 'CI' 'NOC']
# 2022-09-21 00:00:00
# 20181.942082673908
# ['EQT' 'MRO' 'DVN' 'ENPH' 'MCK' 'HES' 'XOM' 'MPC' 'EOG' 'VRTX']
# 2022-09-22 00:00:00
# 19749.539810091504
# ['EQT' 'MRO' 'DVN' 'ENPH' 'COP' 'MCK' 'HES' 'EOG' 'VRTX' 'FSLR']
# 2022-09-23 00:00:00
# 18615.910188115868
# ['EQT' 'ENPH' 'COP' 'VRTX' 'HES' 'FSLR' 'ADM' 'CI' 'LLY' 'PGR']
# 2022-09-26 00:00:00
# 18231.422432482294
# ['ENPH' 'VRTX' 'LLY' 'FSLR' 'CI' 'PGR' 'ON' 'UNH' 'PCG' 'SRE']
# 2022-09-27 00:00:00
# 18257.3840351439
# ['ENPH' 'CI' 'FSLR' 'ON' 'NOC' 'PGR' 'PCG' 'ALB' 'GPC']
# 2022-09-28 00:00:00
# 18088.096110843708
# ['ENPH' 'FSLR' 'ON' 'CI' 'PGR' 'NOC' 'PCG' 'HUM' 'ALB']
# 2022-09-29 00:00:00
# 18411.36696927506
# ['ENPH' 'CF' 'COP' 'ON' 'FSLR' 'CI' 'CTVA' 'NOC' 'PCG' 'PGR']
# 2022-09-30 00:00:00
# 18055.810691495823
# ['ENPH' 'CF' 'COP' 'CI' 'ON' 'FSLR' 'CTVA' 'NOC' 'PGR' 'PCG']
# 2022-10-03 00:00:00
# 18378.450930279298
# ['ENPH' 'COP' 'FSLR' 'CI' 'ON' 'NOC' 'PCG' 'HUM' 'GIS' 'REGN']
# 2022-10-04 00:00:00
# 19169.261263695953
# ['PCG' 'NOC' 'HSY' 'HUM' 'GIS' 'LW']
# 2022-10-05 00:00:00
# 19426.89213616572
# ['LW' 'HSY' 'GIS']
# 2022-10-06 00:00:00
# 19404.798836136873
# ['GIS']
# 2022-10-07 00:00:00
# 18918.355548505057
# ['GIS']
# 2022-10-10 00:00:00
# 19089.744943187157
# ['ENPH' 'LLY' 'FSLR' 'GIS']
# 2022-10-11 00:00:00
# 19081.8244706398
# ['VRTX' 'ENPH' 'LLY' 'HSY' 'FSLR' 'GIS']
# 2022-10-12 00:00:00
# 19356.943651257257
# ['VRTX' 'MPC' 'ENPH' 'LLY' 'HSY' 'GIS' 'FSLR']
# 2022-10-13 00:00:00
# 18703.301557262464
# ['OXY' 'VRTX' 'MPC' 'ENPH' 'CAH' 'LLY' 'REGN']
# 2022-10-14 00:00:00
# 19578.405585428813
# ['OXY' 'DVN' 'MPC' 'VRTX' 'VLO' 'ENPH' 'HES' 'EOG' 'CAH' 'LLY']
# 2022-10-17 00:00:00
# 19328.063700623694
# ['OXY' 'MCK' 'DVN' 'MRO' 'VRTX' 'XOM' 'COP' 'MPC' 'APA' 'CVX']
# 2022-10-18 00:00:00
# 19402.7183408364
# ['OXY' 'MCK' 'DVN' 'MRO' 'CF' 'VRTX' 'XOM' 'MPC' 'COP' 'LW']
# 2022-10-19 00:00:00
# 19351.547534769797
# ['OXY' 'DVN' 'MRO' 'CF' 'VRTX' 'MPC' 'XOM' 'COP' 'LW' 'APA']
# 2022-10-20 00:00:00
# 19811.629029361557
# ['OXY' 'DVN' 'MRO' 'CF' 'XOM' 'MPC' 'COP' 'VRTX' 'APA' 'CVX']
# 2022-10-21 00:00:00
# 19820.527964328474
# ['DVN' 'CF' 'MRO' 'XOM' 'COP' 'VRTX' 'APA' 'HES' 'CTVA' 'LW']
# 2022-10-24 00:00:00
# 20277.46329716123
# ['MRO' 'APA' 'LW' 'CTRA' 'WRB' 'PGR' 'AZO' 'FMC' 'CPB' 'GIS']
# 2022-10-25 00:00:00
# 20290.57397164913
# ['LW' 'CTRA' 'WRB' 'AMGN' 'GIS' 'FMC' 'REGN' 'CPB']
# 2022-10-26 00:00:00
# 20582.575928032067
# ['LW' 'CTRA' 'PSX' 'FMC' 'WRB' 'CPB' 'GIS' 'REGN' 'AMGN' 'K']
# 2022-10-27 00:00:00
# 20720.683419176512
# ['LW' 'CTRA' 'PSX' 'WRB' 'AMGN' 'CPB' 'FMC' 'GIS' 'GL' 'TRGP']
# 2022-10-28 00:00:00
# 20749.15815715201
# ['LW' 'WRB' 'CPB' 'GL' 'TRGP' 'ACGL']
# 2022-10-31 00:00:00
# 20924.446016205235
# ['VLO' 'LW' 'WRB' 'GL' 'TRGP']
# 2022-11-01 00:00:00
# 21405.140690585533
# ['MPC' 'VLO' 'SLB' 'EOG' 'CTRA' 'PXD' 'HII' 'FMC' 'ABBV' 'GL']
# 2022-11-02 00:00:00
# 21332.661960696016
# ['MPC' 'CF' 'DVN' 'COP' 'VLO' 'APA' 'CVX' 'SLB' 'STLD' 'NOC']
# 2022-11-03 00:00:00
# 20536.60490633212
# ['OXY' 'MRO' 'CF' 'MCK' 'COP' 'HES' 'XOM' 'VLO' 'DVN' 'CVX']
# 2022-11-04 00:00:00
# 21771.033367846998
# ['OXY' 'MRO' 'MCK' 'CF' 'COP' 'HES' 'XOM' 'VLO' 'DVN' 'VRTX']
# 2022-11-07 00:00:00
# 21515.167633723897
# ['OXY' 'MRO' 'MCK' 'XOM' 'HES' 'CF' 'VLO' 'DVN' 'VRTX' 'CAH']
# 2022-11-08 00:00:00
# 21672.870406131893
# ['OXY' 'MCK' 'HES' 'XOM' 'VLO' 'CF' 'APA' 'DVN' 'SLB' 'CVX']
# 2022-11-09 00:00:00
# 21423.599088522267
# ['OXY' 'HES' 'MCK' 'XOM' 'CF' 'DVN' 'SLB' 'HAL' 'VRTX' 'CVX']
# 2022-11-10 00:00:00
# 21114.63019123851
# ['OXY' 'MRO' 'MPC' 'COP' 'MCK' 'HES' 'XOM' 'VRTX' 'CF' 'SLB']
# 2022-11-11 00:00:00
# 21291.608308154435
# ['OXY' 'MRO' 'MPC' 'COP' 'XOM' 'HES' 'VRTX' 'MCK' 'SLB' 'DVN']
# 2022-11-14 00:00:00
# 21418.009672772234
# ['OXY' 'MRO' 'COP' 'MPC' 'XOM' 'HES' 'SLB' 'DVN' 'HAL' 'APA']
# 2022-11-15 00:00:00
# 21468.470900683016
# ['OXY' 'MRO' 'MPC' 'COP' 'HES' 'XOM' 'SLB' 'MCK' 'VRTX' 'HAL']
# 2022-11-16 00:00:00
# 21352.523793765773
# ['MRO' 'MPC' 'HES' 'COP' 'XOM' 'APA' 'SLB' 'HAL' 'EOG' 'CVX']
# 2022-11-17 00:00:00
# 20718.552206326625
# ['MRO' 'MPC' 'HES' 'COP' 'XOM' 'APA' 'SLB' 'HAL' 'VRTX' 'CVX']
# 2022-11-18 00:00:00
# 20641.57119296987
# ['OXY' 'MRO' 'MPC' 'HES' 'COP' 'XOM' 'APA' 'SLB' 'HAL' 'EOG']
# 2022-11-21 00:00:00
# 20383.953763329824
# ['OXY' 'MRO' 'MPC' 'HES' 'XOM' 'COP' 'SLB' 'APA' 'MCK' 'HAL']
# 2022-11-22 00:00:00
# 20888.12191640168
# ['OXY' 'MPC' 'VLO' 'MRO' 'XOM' 'HES' 'COP' 'SLB' 'APA' 'CAH']
# 2022-11-23 00:00:00
# 20997.496250553
# ['EQT' 'VLO' 'MRO' 'COP' 'SLB' 'APA' 'HAL' 'CVX' 'EOG' 'PSX']
# 2022-11-25 00:00:00
# 20964.54665706367
# ['EQT' 'VLO' 'MRO' 'APA' 'COP' 'SLB' 'HAL' 'EOG' 'CVX' 'PSX']
# 2022-11-28 00:00:00
# 20203.5818890367
# ['OXY' 'VLO' 'MRO' 'HES' 'XOM' 'COP' 'APA' 'SLB' 'HAL' 'EOG']
# 2022-11-29 00:00:00
# 20576.529870085837
# ['OXY' 'VLO' 'MRO' 'HES' 'XOM' 'COP' 'APA' 'SLB' 'STLD' 'HAL']
# 2022-11-30 00:00:00
# 20918.19344962502
# ['OXY' 'VLO' 'MRO' 'HES' 'XOM' 'APA' 'SLB' 'COP' 'HAL' 'STLD']
# 2022-12-01 00:00:00
# 20943.525344667443
# ['OXY' 'MPC' 'VLO' 'HES' 'XOM' 'SLB' 'STLD' 'COP' 'FSLR' 'DVN']
# 2022-12-02 00:00:00
# 20534.694010224346
# ['OXY' 'MPC' 'VLO' 'HES' 'XOM' 'STLD' 'SLB' 'COP' 'FSLR' 'EOG']
# 2022-12-05 00:00:00
# 20779.473379106465
# ['OXY' 'MPC' 'STLD' 'VLO' 'XOM' 'CF' 'FSLR' 'COP' 'LW' 'EOG']
# 2022-12-06 00:00:00
# 19930.110181567587
# ['OXY' 'MPC' 'MRO' 'CF' 'STLD' 'XOM' 'MCK' 'VLO' 'CAH' 'FSLR']
# 2022-12-07 00:00:00
# 19642.09532074777
# ['STLD' 'MPC' 'MRO' 'CF' 'HES' 'VLO' 'MCK' 'XOM' 'APA' 'CAH']
# 2022-12-08 00:00:00
# 20017.610768117054
# ['MPC' 'CF' 'HES' 'VLO' 'MRO' 'APA' 'MCK' 'XOM' 'CAH' 'FSLR']
# 2022-12-09 00:00:00
# 19442.76919344935
# ['MPC' 'CAH' 'XOM' 'MCK' 'CF' 'FSLR' 'VRTX' 'COP' 'MRK' 'LLY']
# 2022-12-12 00:00:00
# 19109.78727784541
# ['MPC' 'XOM' 'MCK' 'CAH' 'SLB' 'FSLR' 'COP' 'LW' 'VRTX' 'ENPH']
# 2022-12-13 00:00:00
# 19703.351225583814
# ['MRO' 'MPC' 'VLO' 'HES' 'APA' 'XOM' 'SLB' 'MCK' 'CAH' 'ENPH']
# 2022-12-14 00:00:00
# 19678.745660473895
# ['STLD' 'MRO' 'APA' 'HES' 'MPC' 'VLO' 'SLB' 'HAL' 'FSLR' 'COP']
# 2022-12-15 00:00:00
# 19221.663426353527
# ['HES' 'FSLR' 'ENPH' 'STLD' 'SLB' 'HAL' 'MCK' 'CAH' 'COP' 'CI']
# 2022-12-16 00:00:00
# 18820.49155430188
# ['ENPH' 'STLD' 'CAH' 'MCK' 'CI' 'LW' 'MRK' 'VRTX' 'ACGL' 'NOC']
# 2022-12-19 00:00:00
# 18955.921668716754
# ['STLD' 'ENPH' 'CAH' 'MCK' 'CI' 'LW' 'ACGL' 'NOC' 'MRK' 'LMT']
# 2022-12-20 00:00:00
# 19001.28267861465
# ['STLD' 'ENPH' 'CAH' 'MCK' 'CI' 'MRK' 'LMT' 'ACGL' 'NOC' 'LLY']
# 2022-12-21 00:00:00
# 19131.76971314781
# ['STLD' 'ENPH' 'MCK' 'CAH' 'CI' 'MRK' 'NOC' 'WRB' 'LLY' 'CPB']
# 2022-12-22 00:00:00
# 19318.508876110995
# ['STLD' 'ENPH' 'CI' 'MRK' 'CPB' 'PCG' 'GPC' 'GIS' 'PWR' 'DE']
# 2022-12-23 00:00:00
# 19196.649340781118
# ['STLD' 'ENPH' 'CI' 'CPB' 'PCG' 'GIS' 'GPC' 'PWR' 'HII' 'HSY']
# 2022-12-27 00:00:00
# 19251.1632685698
# ['STLD' 'ENPH' 'CI' 'PCG' 'CPB' 'GIS' 'WMB' 'PWR' 'LVS' 'HSY']
# 2022-12-28 00:00:00
# 19200.40967129834
# ['FSLR' 'STLD' 'PCG' 'CPB' 'LVS' 'WMB' 'GIS' 'PWR' 'AES' 'BKR']
# 2022-12-29 00:00:00
# 18868.233596115504
# ['FSLR' 'CAH' 'PCG' 'CPB' 'LVS']
# 2022-12-30 00:00:00
# 18727.089797808407
# ['FSLR' 'MRO' 'CAH' 'CPB' 'LVS' 'ABC']
# 2023-01-03 00:00:00
# 18939.73584311854
# ['FSLR' 'MRO' 'STLD' 'MCK' 'CAH' 'ACGL' 'ADM' 'CPB' 'ABC' 'GIS']
# 2023-01-04 00:00:00
# 18620.605159988234
# ['FSLR' 'HES' 'MPC' 'SLB' 'MCK' 'STLD' 'HAL' 'APA' 'CAH' 'MRK']
# 2023-01-05 00:00:00
# 18849.317513367638
# ['FSLR' 'HES' 'MPC' 'XOM' 'SLB' 'VLO' 'HAL' 'MCK' 'COP' 'STLD']
# 2023-01-06 00:00:00
# 19541.234653250827
# ['FSLR' 'HES' 'MPC' 'XOM' 'VLO' 'SLB' 'STLD' 'MCK' 'HAL' 'COP']
# 2023-01-09 00:00:00
# 20077.93901876553
# ['HES' 'MPC' 'XOM' 'VLO' 'SLB' 'MCK' 'HAL' 'COP' 'CAH' 'APA']
# 2023-01-10 00:00:00
# 19836.32624375643
# ['HES' 'MPC' 'VLO' 'XOM' 'HAL' 'CAH' 'APA' 'COP' 'CVX' 'TRGP']
# 2023-01-11 00:00:00
# 20082.25490188562
# ['MPC' 'XOM' 'COP' 'CVX' 'ACGL' 'MRK' 'APA' 'LLY' 'PCG' 'LMT']
# 2023-01-12 00:00:00
# 20118.880738367727
# ['LLY' 'CVX' 'MRK' 'ACGL' 'APA' 'CI' 'LMT' 'PCG' 'CPB' 'ORLY']
# 2023-01-13 00:00:00
# 20046.317695556347
# ['LLY' 'CVX' 'MRK' 'ACGL' 'CI' 'LMT' 'PCG']

# %%
spy_select = spy[spy.Date>'2019-01-23']
spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100
result['benchmark-spy(%)'] =  spy_select.set_index('Date')['benchmark-spy(%)']
# Out:
# C:\Users\CHIN\AppData\Local\Temp/ipykernel_20500/3295031919.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20500/3295031919.py in <module>
#       1 spy_select = spy[spy.Date>'2019-01-23']
#       2 spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100
# ----> 3 result['benchmark-spy(%)'] =  spy_select.set_index('Date')['benchmark-spy(%)']
#
# NameError: name 'result' is not defined

# %%
# plot the return and calculate the annualized return and MDD (maximum draw down) for both strategy
plt.rcParams["figure.figsize"] = (15,6)
plt.plot(result.Return_without_trailing, label='Return without Annualized_return of Portfolio based on EMA and SMA cross-over strategy')
plt.plot(result['benchmark-spy(%)'], label='benchmark-spy(%)')
plt.legend()
print('Annualized_return of Portfolio based on EMA and SMA cross-over strategy:',annualized (result,'Return_without_trailing'))
print('MDD of Portfolio based on EMA AND SMA cross-over strategy:', MDD(result,'Return_without_trailing'))

print('Annualized_return of benchmark-spy:',annualized (result,'benchmark-spy(%)'))
print('MDD of benchmark-spy:', MDD(result,'benchmark-spy(%)'))
# Out:
# Annualized_return of Portfolio based on EMA and SMA cross-over strategy: 28.83165534699257
# MDD of Portfolio based on EMA AND SMA cross-over strategy: -40.3162538083391
# Annualized_return of benchmark-spy: 16.25470077850062
# MDD of benchmark-spy: -34.104746893243956

# %% [markdown]
# # 5 STOCK

# %%
result, hold_detail= backtest_strategy_portfolio(signal_etf_stock[signal_etf_stock.Date>'2019-01-23'],10000)
# Out:
# 2019-01-24 00:00:00
# 10000.0
# ['ETSY' 'DXCM' 'CMG' 'NRG' 'KEYS']
# 2019-01-25 00:00:00
# 10198.61889002567
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'KEYS']
# 2019-01-28 00:00:00
# 10141.8954998328
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'KEYS']
# 2019-01-29 00:00:00
# 10242.191758354098
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'KEYS']
# 2019-01-30 00:00:00
# 10244.13799003059
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'NRG']
# 2019-01-31 00:00:00
# 10282.80102506389
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'NRG']
# 2019-02-01 00:00:00
# 10297.543611980942
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'NRG']
# 2019-02-04 00:00:00
# 10238.731203132233
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'NRG']
# 2019-02-05 00:00:00
# 10307.219529227421
# ['ENPH' 'ETSY' 'DXCM' 'CMG' 'NRG']
# 2019-02-06 00:00:00
# 10450.952779986876
# ['ENPH' 'ETSY' 'CMG' 'MOH' 'MTCH']
# 2019-02-07 00:00:00
# 10622.93309785467
# ['ENPH' 'ETSY' 'CMG' 'NRG' 'MTCH']
# 2019-02-08 00:00:00
# 10576.22261379212
# ['ENPH' 'ETSY' 'MTCH' 'DPZ' 'CZR']
# 2019-02-11 00:00:00
# 10879.161821701457
# ['ENPH' 'ETSY' 'KEYS' 'MTCH' 'CZR']
# 2019-02-12 00:00:00
# 11095.075708928223
# ['ENPH' 'ETSY' 'KEYS' 'LLY' 'CZR']
# 2019-02-13 00:00:00
# 11198.780243020685
# ['ETSY' 'ENPH' 'KEYS' 'FTNT' 'AES']
# 2019-02-14 00:00:00
# 11070.276420041753
# ['MOH' 'KEYS' 'FTNT' 'AES' 'NOW']
# 2019-02-15 00:00:00
# 11183.563673227492
# ['PAYC' 'MOH' 'KEYS' 'FTNT' 'AES']
# 2019-02-19 00:00:00
# 11166.851710270335
# ['ENPH' 'DXCM' 'AMD' 'PAYC' 'MOH']
# 2019-02-20 00:00:00
# 11136.34844506145
# ['ENPH' 'DXCM' 'AMD' 'MOH' 'PAYC']
# 2019-02-21 00:00:00
# 11058.686478714215
# ['ENPH' 'DXCM' 'MOH' 'CMG' 'PAYC']
# 2019-02-22 00:00:00
# 11275.621646958982
# ['ENPH' 'DXCM' 'CMG' 'PAYC' 'FTNT']
# 2019-02-25 00:00:00
# 11308.757740869316
# ['ENPH' 'CMG' 'PAYC' 'FTNT' 'AES']
# 2019-02-26 00:00:00
# 11233.247085841009
# ['ENPH' 'CMG' 'PAYC' 'AES' 'NRG']
# 2019-02-27 00:00:00
# 11274.51505942833
# ['DXCM' 'CMG' 'PAYC' 'NRG' 'ORLY']
# 2019-02-28 00:00:00
# 11297.192745461603
# ['DXCM' 'AMD' 'CMG' 'PAYC' 'NRG']
# 2019-03-01 00:00:00
# 11398.829671084444
# ['DXCM' 'AMD' 'CMG' 'PAYC' 'AES']
# 2019-03-04 00:00:00
# 11474.965533212577
# ['DXCM' 'AMD' 'CMG' 'MOH' 'PAYC']
# 2019-03-05 00:00:00
# 11234.772448005104
# ['AMD' 'CMG' 'MOH' 'PAYC' 'KEYS']
# 2019-03-06 00:00:00
# 11279.774557543875
# ['AMD' 'MOH' 'PAYC' 'KEYS' 'FTNT']
# 2019-03-07 00:00:00
# 11024.646530793192
# ['PAYC' 'AES' 'KEYS' 'FTNT' 'ULTA']
# 2019-03-08 00:00:00
# 10842.843324759917
# ['ETSY' 'ENPH' 'PAYC' 'KEYS' 'LLY']
# 2019-03-11 00:00:00
# 11070.063436163644
# ['ETSY' 'ENPH' 'PAYC' 'LLY' 'KEYS']
# 2019-03-12 00:00:00
# 11339.256554021185
# ['ETSY' 'ENPH' 'AMD' 'CMG' 'MOH']
# 2019-03-13 00:00:00
# 11596.010444531526
# ['ETSY' 'ENPH' 'AMD' 'CMG' 'MOH']
# 2019-03-14 00:00:00
# 11645.144088812745
# ['ETSY' 'ENPH' 'LLY' 'KEYS' 'CDNS']
# 2019-03-15 00:00:00
# 11677.895512997371
# ['ETSY' 'KEYS' 'CDNS' 'LLY' 'ULTA']
# 2019-03-18 00:00:00
# 11766.574325157473
# ['ETSY' 'KEYS' 'CDNS' 'LLY' 'AZO']
# 2019-03-19 00:00:00
# 11850.441832003213
# ['ETSY' 'KEYS' 'CDNS' 'LLY' 'LYV']
# 2019-03-20 00:00:00
# 11820.10166870367
# ['AES' 'CDNS' 'WELL' 'LYV' 'GRMN']
# 2019-03-21 00:00:00
# 11854.443429374398
# ['AES' 'CDNS' 'LYV' 'WELL' 'O']
# 2019-03-22 00:00:00
# 12125.300348365166
# ['ETSY' 'DXCM' 'ENPH' 'AES' 'CDNS']
# 2019-03-25 00:00:00
# 11680.468335645393
# ['ETSY' 'ENPH' 'DXCM' 'CDNS' 'PAYC']
# 2019-03-26 00:00:00
# 11815.57332888835
# ['ETSY' 'MOH' 'ENPH' 'AES' 'CDNS']
# 2019-03-27 00:00:00
# 11513.853967105393
# ['ETSY' 'PAYC' 'ENPH' 'CDNS' 'AES']
# 2019-03-28 00:00:00
# 11426.49556042135
# ['ETSY' 'ENPH' 'PAYC' 'CDNS' 'ULTA']
# 2019-03-29 00:00:00
# 11667.414616388758
# ['AMD' 'ETSY' 'ENPH' 'PAYC' 'CDNS']
# 2019-04-01 00:00:00
# 11858.45749084847
# ['AMD' 'ETSY' 'ENPH' 'MOH' 'CDNS']
# 2019-04-02 00:00:00
# 11935.074105188134
# ['AMD' 'ENPH' 'MOH' 'LYV' 'LLY']
# 2019-04-03 00:00:00
# 12098.174257222146
# ['AMD' 'CMG' 'MOH' 'LLY' 'AES']
# 2019-04-04 00:00:00
# 12163.173369943352
# ['AMD' 'CMG' 'LLY' 'AES' 'MRK']
# 2019-04-05 00:00:00
# 12172.467159905998
# ['CMG' 'ULTA' 'LLY' 'AES' 'MRK']
# 2019-04-08 00:00:00
# 12198.065286281482
# ['CMG' 'PAYC' 'LYV' 'ULTA' 'LLY']
# 2019-04-09 00:00:00
# 12226.810118084268
# ['CMG' 'CDNS' 'LYV' 'PAYC' 'LLY']
# 2019-04-10 00:00:00
# 12306.740096056163
# ['CMG' 'CDNS' 'AZO' 'LYV' 'PAYC']
# 2019-04-11 00:00:00
# 12442.606822993312
# ['ETSY' 'CMG' 'CDNS' 'AZO' 'LYV']
# 2019-04-12 00:00:00
# 12413.436403112102
# ['AMD' 'ETSY' 'CMG' 'TSCO' 'AZO']
# 2019-04-15 00:00:00
# 12293.625460052139
# ['AMD' 'ENPH' 'ETSY' 'CMG' 'ORLY']
# 2019-04-16 00:00:00
# 12288.900612432806
# ['AMD' 'ENPH' 'ETSY' 'CMG' 'ORLY']
# 2019-04-17 00:00:00
# 12290.49169907984
# ['AMD' 'ENPH' 'ETSY' 'ORLY' 'AZO']
# 2019-04-18 00:00:00
# 12053.890087339496
# ['AMD' 'ETSY' 'ENPH' 'ORLY' 'AZO']
# 2019-04-22 00:00:00
# 11913.537718870157
# ['AMD' 'ETSY' 'CMG' 'ENPH' 'ORLY']
# 2019-04-23 00:00:00
# 11952.49404300062
# ['AMD' 'ETSY' 'CMG' 'ENPH' 'ORLY']
# 2019-04-24 00:00:00
# 12175.103635013369
# ['ETSY' 'ENPH' 'CMG' 'ORLY' 'AZO']
# 2019-04-25 00:00:00
# 12089.049394187517
# ['ETSY' 'ENPH' 'CMG' 'ORLY' 'KEYS']
# 2019-04-26 00:00:00
# 11941.37225404462
# ['ZBRA' 'AZO' 'FTNT' 'KEYS' 'CMG']
# 2019-04-29 00:00:00
# 11921.827656101435
# ['ZBRA' 'FTNT' 'AZO' 'KEYS' 'CHD']
# 2019-04-30 00:00:00
# 11853.004751837054
# ['AMD' 'ZBRA' 'FTNT' 'KEYS' 'LYV']
# 2019-05-01 00:00:00
# 11855.211863532388
# ['AMD' 'KEYS' 'QCOM' 'FTNT' 'MTCH']
# 2019-05-02 00:00:00
# 11574.094003000928
# ['MTCH' 'QCOM' 'KEYS' 'FTNT' 'CMG']
# 2019-05-03 00:00:00
# 11596.100565020333
# ['QCOM' 'KEYS' 'MTCH' 'FTNT' 'AZO']
# 2019-05-06 00:00:00
# 11347.469332322798
# ['AMD' 'MTCH' 'QCOM' 'KEYS' 'BALL']
# 2019-05-07 00:00:00
# 11560.16762040199
# ['AMD' 'MTCH' 'CDNS' 'KEYS' 'QCOM']
# 2019-05-08 00:00:00
# 11428.26804599018
# ['AMD' 'ETSY' 'PAYC' 'CDNS' 'MTCH']
# 2019-05-09 00:00:00
# 11491.473245884754
# ['ETSY' 'AMD' 'PAYC' 'CDNS' 'QCOM']
# 2019-05-10 00:00:00
# 11509.624083857576
# ['AMD' 'ETSY' 'PAYC' 'CDNS' 'VRSN']
# 2019-05-13 00:00:00
# 11320.561361811408
# ['ETSY' 'PAYC' 'CDNS' 'QCOM' 'VRSN']
# 2019-05-14 00:00:00
# 11249.20434843704
# ['ENPH' 'PAYC' 'CMG' 'CDNS' 'CHD']
# 2019-05-15 00:00:00
# 11318.023564909248
# ['ENPH' 'AMD' 'PAYC' 'CDNS' 'CMG']
# 2019-05-16 00:00:00
# 11583.815495804905
# ['ENPH' 'AMD' 'ETSY' 'PAYC' 'CDNS']
# 2019-05-17 00:00:00
# 11730.698182221411
# ['ENPH' 'ETSY' 'PAYC' 'CDNS' 'BALL']
# 2019-05-20 00:00:00
# 11577.406724678181
# ['ENPH' 'ETSY' 'PAYC' 'CMG' 'BALL']
# 2019-05-21 00:00:00
# 11670.921528909725
# ['ENPH' 'BALL' 'CDNS' 'MKC' 'DRI']
# 2019-05-22 00:00:00
# 11737.615414519376
# ['ENPH' 'MTCH' 'BALL' 'NOW' 'CDNS']
# 2019-05-23 00:00:00
# 11661.991536533993
# ['ENPH' 'MTCH' 'BALL' 'NOW' 'CDNS']
# 2019-05-24 00:00:00
# 11576.26929228266
# ['ENPH' 'AMD' 'MTCH' 'BALL' 'CMG']
# 2019-05-28 00:00:00
# 11705.456576058214
# ['ENPH' 'AMD' 'MTCH' 'BALL' 'CMG']
# 2019-05-29 00:00:00
# 11916.683950871233
# ['ENPH' 'PAYC' 'MTCH' 'BALL' 'CMG']
# 2019-05-30 00:00:00
# 11914.061482653075
# ['PAYC' 'MTCH' 'BALL' 'CMG' 'CHD']
# 2019-05-31 00:00:00
# 11888.512147041874
# ['PAYC' 'ETSY' 'MTCH' 'BALL' 'CHD']
# 2019-06-03 00:00:00
# 11992.846446403633
# ['ENPH' 'PAYC' 'ETSY' 'BALL' 'MTCH']
# 2019-06-04 00:00:00
# 11931.663882373217
# ['ENPH' 'ETSY' 'PAYC' 'AZO' 'MTCH']
# 2019-06-05 00:00:00
# 12182.746870342995
# ['ENPH' 'PAYC' 'ETSY' 'MTCH' 'AZO']
# 2019-06-06 00:00:00
# 12383.382518326396
# ['ENPH' 'ETSY' 'MTCH' 'AZO' 'AWK']
# 2019-06-07 00:00:00
# 12453.902015763797
# ['ENPH' 'ETSY' 'WELL' 'SRE' 'CDAY']
# 2019-06-10 00:00:00
# 12711.273606240895
# ['ENPH' 'ETSY' 'CDAY' 'PEAK' 'CPRT']
# 2019-06-11 00:00:00
# 12776.206990893545
# ['ENPH' 'CPRT']
# 2019-06-12 00:00:00
# 12995.302971448036
# ['ENPH' 'AMT' 'CPRT' 'ELV']
# 2019-06-13 00:00:00
# 13114.296775732222
# ['AMT' 'CHD' 'MOH' 'SBAC' 'WELL']
# 2019-06-14 00:00:00
# 13058.112508539252
# ['CHD' 'MOH' 'AMT' 'HSY' 'MKC']
# 2019-06-17 00:00:00
# 13061.927921716982
# ['AMD' 'BALL' 'CHD' 'AMT' 'MOH']
# 2019-06-18 00:00:00
# 13108.011141524643
# ['PAYC' 'BALL' 'AMD' 'AMT' 'CHD']
# 2019-06-19 00:00:00
# 13164.00953905016
# ['PAYC' 'BALL' 'AMD' 'AZO' 'MTCH']
# 2019-06-20 00:00:00
# 13299.099616738793
# ['PAYC' 'BALL' 'AMD' 'MTCH' 'AZO']
# 2019-06-21 00:00:00
# 13079.938830837276
# ['BALL' 'SBUX' 'AZO' 'CMG' 'MTCH']
# 2019-06-24 00:00:00
# 12956.931396340184
# ['ENPH' 'BALL' 'SBUX' 'AZO' 'MKTX']
# 2019-06-25 00:00:00
# 12858.074425480125
# ['ENPH' 'AMD' 'BALL' 'MTCH' 'SBUX']
# 2019-06-26 00:00:00
# 12687.289009854276
# ['ENPH' 'AMD' 'SBUX' 'MTCH' 'AZO']
# 2019-06-27 00:00:00
# 12720.891399280852
# ['ENPH' 'PAYC' 'AMD' 'MTCH' 'SBUX']
# 2019-06-28 00:00:00
# 13059.405423813208
# ['ENPH' 'PAYC' 'MTCH' 'SBUX' 'CMG']
# 2019-07-01 00:00:00
# 13349.534996680875
# ['ENPH' 'PAYC' 'MTCH' 'SBUX' 'CMG']
# 2019-07-02 00:00:00
# 13195.908675176912
# ['ENPH' 'PAYC' 'MTCH' 'SBUX' 'CDNS']
# 2019-07-03 00:00:00
# 13483.223936348917
# ['PAYC' 'SBUX' 'CDNS' 'MKTX' 'AZO']
# 2019-07-05 00:00:00
# 13597.82051136161
# ['CMG' 'IQV' 'DXCM' 'DHR' 'ULTA']
# 2019-07-08 00:00:00
# 13693.559216463294
# ['IQV' 'DXCM' 'DHR' 'ALLE' 'AMT']
# 2019-07-09 00:00:00
# 13621.88653744646
# ['IQV' 'HWM' 'WM' 'ALLE' 'TMO']
# 2019-07-10 00:00:00
# 13713.111323326293
# ['BALL' 'IQV' 'KEYS' 'HWM' 'APD']
# 2019-07-11 00:00:00
# 13602.90612204827
# ['BALL' 'IQV' 'HWM' 'KEYS' 'MTD']
# 2019-07-12 00:00:00
# 13585.781353999555
# ['BALL' 'KEYS' 'IQV' 'HWM' 'MTD']
# 2019-07-15 00:00:00
# 13529.964822089805
# ['ENPH' 'BALL' 'CDNS' 'CINF' 'KEYS']
# 2019-07-16 00:00:00
# 13473.068572223136
# ['ENPH' 'PAYC' 'BALL' 'CDNS' 'NOW']
# 2019-07-17 00:00:00
# 13456.15801852006
# ['ENPH' 'PAYC' 'MTCH' 'BALL' 'SBUX']
# 2019-07-18 00:00:00
# 13446.97920763555
# ['ENPH' 'PAYC' 'MTCH' 'BALL' 'SBUX']
# 2019-07-19 00:00:00
# 13793.192329863137
# ['ENPH' 'PAYC' 'AMD' 'BALL' 'CDNS']
# 2019-07-22 00:00:00
# 13676.386441932398
# ['ENPH' 'PAYC' 'AMD' 'BALL' 'CMG']
# 2019-07-23 00:00:00
# 13800.467996424804
# ['ENPH' 'PAYC' 'AMD' 'SBUX' 'MKTX']
# 2019-07-24 00:00:00
# 13397.798531918103
# ['ENPH' 'PAYC' 'AMD' 'SBUX' 'MKTX']
# 2019-07-25 00:00:00
# 13466.375133759757
# ['ENPH' 'AMD' 'PAYC' 'SBUX' 'CMG']
# 2019-07-26 00:00:00
# 13603.013140779418
# ['ENPH' 'PAYC' 'AMD' 'SBUX' 'CMG']
# 2019-07-29 00:00:00
# 13801.927769756916
# ['ENPH' 'PAYC' 'AMD' 'MKTX' 'AZO']
# 2019-07-30 00:00:00
# 13550.87462761336
# ['ENPH' 'PAYC' 'MTCH' 'MKTX' 'AMD']
# 2019-07-31 00:00:00
# 14311.867628214486
# ['PAYC' 'MTCH' 'MKTX' 'AZO' 'NOW']
# 2019-08-01 00:00:00
# 14213.059210657517
# ['MTCH' 'BALL' 'MKTX' 'DXCM' 'ETSY']
# 2019-08-02 00:00:00
# 14060.961888491333
# ['MTCH' 'BALL' 'MKTX' 'CDNS' 'ETSY']
# 2019-08-05 00:00:00
# 13466.145323777779
# ['MTCH' 'MKTX' 'AMD' 'CDNS' 'HSY']
# 2019-08-06 00:00:00
# 13446.055254458774
# ['MTCH' 'SBUX' 'PAYC' 'CMG' 'CDNS']
# 2019-08-07 00:00:00
# 13936.852363142905
# ['MTCH' 'SBUX' 'PAYC' 'CMG' 'CDNS']
# 2019-08-08 00:00:00
# 14286.489762782925
# ['SBUX' 'PAYC' 'SEDG' 'CMG' 'HSY']
# 2019-08-09 00:00:00
# 14504.212959690798
# ['SBUX' 'AMD' 'CMG' 'SBAC' 'HSY']
# 2019-08-12 00:00:00
# 14603.215023340828
# ['SBUX' 'CMG' 'SBAC' 'HSY' 'EW']
# 2019-08-13 00:00:00
# 14537.739427967981
# ['ENPH' 'SBUX' 'CMG' 'SBAC' 'EW']
# 2019-08-14 00:00:00
# 14737.728045903084
# ['ENPH' 'SBUX' 'EW' 'YUM' 'FISV']
# 2019-08-15 00:00:00
# 14498.367503583455
# ['ENPH' 'SBUX' 'TFX' 'EW' 'AMT']
# 2019-08-16 00:00:00
# 14674.061715436183
# ['ENPH' 'SBUX' 'MTCH' 'TFX' 'EW']
# 2019-08-19 00:00:00
# 15050.73850900402
# ['ENPH' 'MTCH' 'TFX' 'TDG' 'AMT']
# 2019-08-20 00:00:00
# 15003.860543826031
# ['ENPH' 'SEDG' 'MTCH' 'CMG' 'AMD']
# 2019-08-21 00:00:00
# 15234.328326038221
# ['ENPH' 'BALL' 'SEDG' 'SBUX' 'MTCH']
# 2019-08-22 00:00:00
# 15171.515229473513
# ['ENPH' 'BALL' 'SEDG' 'SBUX' 'MTCH']
# 2019-08-23 00:00:00
# 15048.270092468494
# ['ENPH' 'BALL' 'SBUX' 'SEDG' 'SBAC']
# 2019-08-26 00:00:00
# 15010.15125391404
# ['BALL' 'SBUX' 'SEDG' 'SBAC' 'HSY']
# 2019-08-27 00:00:00
# 15199.710408486102
# ['BALL' 'SBUX' 'SEDG' 'SBAC' 'CMG']
# 2019-08-28 00:00:00
# 15124.335352807982
# ['ENPH' 'BALL' 'SBUX' 'SEDG' 'SBAC']
# 2019-08-29 00:00:00
# 15393.11306296306
# ['ENPH' 'BALL' 'SBUX' 'SEDG' 'MTCH']
# 2019-08-30 00:00:00
# 15254.46007447479
# ['ENPH' 'BALL' 'SEDG' 'MTCH' 'SBAC']
# 2019-09-03 00:00:00
# 14785.122167667963
# ['ENPH' 'MKTX' 'BALL' 'SEDG' 'MTCH']
# 2019-09-04 00:00:00
# 14660.927700726159
# ['ENPH' 'MKTX' 'BALL' 'SBAC' 'SEDG']
# 2019-09-05 00:00:00
# 15050.13714305128
# ['ENPH' 'MKTX' 'SBUX' 'CMG' 'SEDG']
# 2019-09-06 00:00:00
# 14514.316891150662
# ['ENPH' 'MKTX' 'SBUX' 'CMG' 'PAYC']
# 2019-09-09 00:00:00
# 14548.840204603397
# ['ENPH' 'MKTX' 'BALL' 'SBUX' 'CMG']
# 2019-09-10 00:00:00
# 13690.998496268197
# ['ENPH' 'MKTX' 'SEDG' 'BALL' 'CMG']
# 2019-09-11 00:00:00
# 13347.972705109776
# ['ENPH' 'MKTX' 'SEDG' 'BALL' 'SBUX']
# 2019-09-12 00:00:00
# 13845.63572961344
# ['ENPH' 'MKTX' 'SEDG' 'BALL' 'SBUX']
# 2019-09-13 00:00:00
# 13197.75906641344
# ['ENPH' 'MKTX' 'SBUX' 'BALL' 'CMG']
# 2019-09-16 00:00:00
# 13141.058837162404
# ['ENPH' 'MKTX' 'SBUX' 'BALL' 'CMG']
# 2019-09-17 00:00:00
# 13200.123534506503
# ['MKTX' 'SBUX' 'CMG' 'BALL' 'LRCX']
# 2019-09-18 00:00:00
# 13469.478492329536
# ['MKTX' 'CMG' 'BALL' 'SBUX' 'AZO']
# 2019-09-19 00:00:00
# 13501.437128797967
# ['MKTX' 'SBUX' 'TER' 'KEYS' 'LRCX']
# 2019-09-20 00:00:00
# 13495.064709274335
# ['TER' 'KEYS' 'LRCX' 'AZO' 'CPRT']
# 2019-09-23 00:00:00
# 13398.521799974358
# ['CPRT' 'KEYS' 'TER' 'LRCX' 'AZO']
# 2019-09-24 00:00:00
# 13498.988191049526
# ['CPRT' 'LRCX' 'KEYS' 'TER' 'AZO']
# 2019-09-25 00:00:00
# 13129.618137732577
# ['CPRT' 'LRCX' 'TER' 'KEYS' 'AZO']
# 2019-09-26 00:00:00
# 13337.867984170129
# ['LRCX' 'TER' 'CPRT' 'KEYS' 'MLM']
# 2019-09-27 00:00:00
# 13315.184822286694
# ['LRCX' 'TER' 'CPRT' 'KEYS' 'MLM']
# 2019-09-30 00:00:00
# 13005.742116100719
# ['ENPH' 'SEDG' 'CMG' 'TER' 'CPRT']
# 2019-10-01 00:00:00
# 13149.785714336276
# ['ENPH' 'SEDG' 'CMG' 'BALL' 'SBUX']
# 2019-10-02 00:00:00
# 12807.262008346042
# ['ENPH' 'SEDG' 'CMG' 'BALL' 'TER']
# 2019-10-03 00:00:00
# 12769.001711528923
# ['ENPH' 'SEDG' 'CMG' 'TER' 'BALL']
# 2019-10-04 00:00:00
# 13025.453215432122
# ['ENPH' 'SEDG' 'CMG' 'TER' 'BALL']
# 2019-10-07 00:00:00
# 13317.724789082473
# ['ENPH' 'SEDG' 'CMG' 'TER' 'KLAC']
# 2019-10-08 00:00:00
# 13161.27507196264
# ['SEDG' 'CMG' 'KLAC' 'LRCX' 'BALL']
# 2019-10-09 00:00:00
# 13286.33612816281
# ['CMG' 'LRCX' 'KLAC' 'PHM' 'DG']
# 2019-10-10 00:00:00
# 13349.472055015614
# ['CMG' 'KLAC' 'PHM' 'SNPS' 'NVR']
# 2019-10-11 00:00:00
# 13479.914915911826
# ['CMG' 'KLAC' 'CINF' 'MLM' 'PHM']
# 2019-10-14 00:00:00
# 13346.618315798576
# ['KLAC' 'PHM' 'NVR' 'EL' 'PG']
# 2019-10-15 00:00:00
# 13362.991431264465
# ['NVR' 'PHM' 'EL' 'PG' 'HSY']
# 2019-10-16 00:00:00
# 13250.087797415967
# ['NVR' 'AMT' 'PG' 'HSY' 'PEAK']
# 2019-10-17 00:00:00
# 13305.887930210223
# ['SEDG' 'MKTX' 'NVR' 'EPAM' 'EW']
# 2019-10-18 00:00:00
# 13382.274425273841
# ['SEDG' 'TER' 'MKTX' 'EPAM' 'EW']
# 2019-10-21 00:00:00
# 13424.472372849432
# ['ENPH' 'SEDG' 'TER' 'MKTX' 'VMC']
# 2019-10-22 00:00:00
# 13599.711148201573
# ['ENPH' 'SEDG' 'TER' 'MKTX' 'VMC']
# 2019-10-23 00:00:00
# 13422.916308679965
# ['ENPH' 'SEDG' 'TER' 'MKTX' 'GNRC']
# 2019-10-24 00:00:00
# 13613.397726664807
# ['ENPH' 'SEDG' 'TER' 'CMG' 'KLAC']
# 2019-10-25 00:00:00
# 13740.907239845215
# ['ENPH' 'TER' 'KLAC' 'CMG' 'LRCX']
# 2019-10-28 00:00:00
# 14064.288180358642
# ['ENPH' 'AMD' 'CMG' 'MLM' 'NVR']
# 2019-10-29 00:00:00
# 14201.444424537767
# ['ENPH' 'CMG' 'TDG' 'NVR' 'MKTX']
# 2019-10-30 00:00:00
# 13665.17524885773
# ['NVR' 'BALL' 'PHM' 'MCO' 'MAS']
# 2019-10-31 00:00:00
# 13755.740945517182
# ['KEYS' 'NVR' 'PHM' 'XRAY' 'EQIX']
# 2019-11-01 00:00:00
# 13681.872580818901
# ['SEDG' 'KEYS' 'CPRT' 'CMG' 'PHM']
# 2019-11-04 00:00:00
# 13705.491447964088
# ['SEDG' 'KEYS' 'TER' 'PHM' 'CPRT']
# 2019-11-05 00:00:00
# 13356.564457377197
# ['SEDG' 'KEYS' 'GNRC' 'TER' 'CPRT']
# 2019-11-06 00:00:00
# 13554.283109531503
# ['SEDG' 'LRCX' 'KLAC' 'KEYS' 'GNRC']
# 2019-11-07 00:00:00
# 13414.09028405305
# ['SEDG' 'LRCX' 'KLAC' 'TER' 'KEYS']
# 2019-11-08 00:00:00
# 13302.057724388043
# ['SEDG' 'LRCX' 'KLAC' 'KEYS' 'TER']
# 2019-11-11 00:00:00
# 13327.362068977585
# ['SEDG' 'LRCX' 'KLAC' 'TER' 'KEYS']
# 2019-11-12 00:00:00
# 13612.282117293142
# ['SEDG' 'LRCX' 'KLAC' 'KEYS' 'GNRC']
# 2019-11-13 00:00:00
# 13394.91973087321
# ['LRCX' 'AMD' 'KLAC' 'MKTX' 'CPRT']
# 2019-11-14 00:00:00
# 13626.620918127273
# ['KLAC' 'LRCX' 'AMD' 'MSCI' 'QRVO']
# 2019-11-15 00:00:00
# 13908.516185420074
# ['LRCX' 'KLAC' 'AMD' 'GNRC' 'MSCI']
# 2019-11-18 00:00:00
# 13856.665014696506
# ['LRCX' 'AMD' 'AMAT' 'GNRC' 'MSCI']
# 2019-11-19 00:00:00
# 14103.825874744256
# ['MSCI' 'GNRC' 'QCOM' 'QRVO' 'TDY']
# 2019-11-20 00:00:00
# 14001.364573811019
# ['DXCM' 'GNRC' 'QRVO' 'TDY' 'QCOM']
# 2019-11-21 00:00:00
# 13949.123145768954
# ['KEYS' 'KLAC' 'DXCM' 'TER' 'EPAM']
# 2019-11-22 00:00:00
# 13704.121489928144
# ['KEYS' 'LRCX' 'DXCM' 'TER' 'GNRC']
# 2019-11-25 00:00:00
# 13754.746838065668
# ['AMD' 'LRCX' 'KEYS' 'DXCM' 'GNRC']
# 2019-11-26 00:00:00
# 13994.163948883463
# ['AMD' 'LRCX' 'DXCM' 'MKTX' 'KEYS']
# 2019-11-27 00:00:00
# 14017.147037636349
# ['MKTX' 'AMD' 'DXCM' 'LRCX' 'TER']
# 2019-11-29 00:00:00
# 13993.85525126732
# ['MKTX' 'AMD' 'TER' 'LRCX' 'KEYS']
# 2019-12-02 00:00:00
# 13920.348487871626
# ['MKTX' 'AMD' 'DXCM' 'TER' 'KEYS']
# 2019-12-03 00:00:00
# 13574.085022456427
# ['PAYC' 'MKTX' 'TER' 'CPRT' 'TGT']
# 2019-12-04 00:00:00
# 13815.366630506476
# ['PAYC' 'AMD' 'MKTX' 'TGT' 'DXCM']
# 2019-12-05 00:00:00
# 13855.915600646036
# ['PAYC' 'AMD' 'TGT' 'MKTX' 'CPRT']
# 2019-12-06 00:00:00
# 13813.276544145167
# ['PAYC' 'AMD' 'DXCM' 'CPRT' 'TGT']
# 2019-12-09 00:00:00
# 13703.435950083544
# ['PAYC' 'AMD' 'CPRT' 'TGT' 'DXCM']
# 2019-12-10 00:00:00
# 13657.299685991464
# ['ENPH' 'SEDG' 'PAYC' 'AMD' 'GNRC']
# 2019-12-11 00:00:00
# 13647.965674042714
# ['ENPH' 'SEDG' 'PAYC' 'GNRC' 'TGT']
# 2019-12-12 00:00:00
# 13675.804940108288
# ['ENPH' 'SEDG' 'PAYC' 'TGT' 'GNRC']
# 2019-12-13 00:00:00
# 13685.551674567085
# ['SEDG' 'PAYC' 'GNRC' 'TGT' 'CDAY']
# 2019-12-16 00:00:00
# 13917.155638441507
# ['SEDG' 'PAYC' 'GNRC' 'CDAY' 'MSCI']
# 2019-12-17 00:00:00
# 14082.693894434811
# ['ENPH' 'PAYC' 'GNRC' 'CMG' 'DXCM']
# 2019-12-18 00:00:00
# 14134.188187442418
# ['ENPH' 'PAYC' 'GNRC' 'CMG' 'DXCM']
# 2019-12-19 00:00:00
# 14137.38318030725
# ['PAYC' 'GNRC' 'CMG' 'DXCM' 'CDAY']
# 2019-12-20 00:00:00
# 14287.845888938897
# ['PAYC' 'GNRC' 'CMG' 'MSCI' 'HWM']
# 2019-12-23 00:00:00
# 14308.912770677234
# ['QRVO' 'HWM' 'MSCI' 'KEYS' 'BBY']
# 2019-12-24 00:00:00
# 14319.878910661948
# ['QRVO' 'HWM' 'MSCI' 'KEYS' 'TDY']
# 2019-12-26 00:00:00
# 14325.252839397319
# ['TER' 'LRCX' 'KLAC' 'TGT' 'QRVO']
# 2019-12-27 00:00:00
# 14383.588607320422
# ['SEDG' 'TER' 'LRCX' 'KLAC' 'TGT']
# 2019-12-30 00:00:00
# 14275.298858763188
# ['ENPH' 'SEDG' 'TER' 'LRCX' 'GNRC']
# 2019-12-31 00:00:00
# 14025.128965248423
# ['ENPH' 'SEDG' 'TER' 'LRCX' 'GNRC']
# 2020-01-02 00:00:00
# 14317.281216076999
# ['ENPH' 'AMD' 'SEDG' 'TER' 'LRCX']
# 2020-01-03 00:00:00
# 14699.27193019736
# ['ENPH' 'SEDG' 'AMD' 'TER' 'LRCX']
# 2020-01-06 00:00:00
# 14682.527875294096
# ['TER' 'LRCX' 'GNRC' 'MTCH' 'CDAY']
# 2020-01-07 00:00:00
# 14765.006141283333
# ['TER' 'LRCX' 'GNRC' 'CDAY' 'KLAC']
# 2020-01-08 00:00:00
# 14933.756828842957
# ['AMD' 'TER' 'LRCX' 'CDAY' 'GNRC']
# 2020-01-09 00:00:00
# 15067.538661568917
# ['AMD' 'TER' 'LRCX' 'CDAY' 'MTCH']
# 2020-01-10 00:00:00
# 15092.314569524797
# ['AMD' 'TER' 'LRCX' 'CDAY' 'MTCH']
# 2020-01-13 00:00:00
# 15123.840006530423
# ['AMD' 'TER' 'LRCX' 'CDAY' 'MTCH']
# 2020-01-14 00:00:00
# 15242.326300868785
# ['AMD' 'LRCX' 'KLAC' 'GNRC' 'TGT']
# 2020-01-15 00:00:00
# 15113.083685434345
# ['ENPH' 'SEDG' 'AMD' 'KLAC' 'GNRC']
# 2020-01-16 00:00:00
# 15262.677267851568
# ['ENPH' 'SEDG' 'AMD' 'AAPL' 'CDAY']
# 2020-01-17 00:00:00
# 15385.872402587564
# ['ENPH' 'SEDG' 'AMD' 'AAPL' 'CDAY']
# 2020-01-21 00:00:00
# 15522.875189778775
# ['ENPH' 'SEDG' 'AMD' 'PAYC' 'CDAY']
# 2020-01-22 00:00:00
# 15751.794028827968
# ['ENPH' 'SEDG' 'PAYC' 'CDAY' 'TSLA']
# 2020-01-23 00:00:00
# 15859.277436319633
# ['ENPH' 'SEDG' 'AAPL' 'TSLA' 'CDAY']
# 2020-01-24 00:00:00
# 16077.084997092696
# ['ENPH' 'AAPL' 'CDAY' 'LDOS' 'CHTR']
# 2020-01-27 00:00:00
# 15573.236367063011
# ['AAPL' 'NVDA' 'CDAY' 'LDOS' 'QCOM']
# 2020-01-28 00:00:00
# 15841.68662259732
# ['AMD' 'SEDG' 'AAPL' 'TER' 'TSLA']
# 2020-01-29 00:00:00
# 16079.461375554218
# ['ENPH' 'SEDG' 'AMD' 'TER' 'AAPL']
# 2020-01-30 00:00:00
# 15755.627891992042
# ['ENPH' 'SEDG' 'CPRT' 'AAPL' 'AMD']
# 2020-01-31 00:00:00
# 16112.812990765204
# ['SEDG' 'CPRT' 'AMD' 'AAPL' 'TER']
# 2020-02-03 00:00:00
# 15566.981989413733
# ['SEDG' 'PAYC' 'CPRT' 'AMD' 'AAPL']
# 2020-02-04 00:00:00
# 16073.93775495285
# ['ENPH' 'SEDG' 'PAYC' 'AMD' 'GNRC']
# 2020-02-05 00:00:00
# 16892.426772897696
# ['ENPH' 'SEDG' 'AMD' 'GNRC' 'PAYC']
# 2020-02-06 00:00:00
# 16114.686641482396
# ['AMD' 'GNRC' 'CPRT' 'TER' 'AAPL']
# 2020-02-07 00:00:00
# 16089.99847987234
# ['GNRC' 'CPRT' 'PHM' 'DHI' 'KMX']
# 2020-02-10 00:00:00
# 16194.803202902069
# ['GNRC' 'CPRT' 'HWM' 'PHM' 'PAYC']
# 2020-02-11 00:00:00
# 16480.018888523104
# ['GNRC' 'CPRT' 'AAPL' 'HWM' 'PAYC']
# 2020-02-12 00:00:00
# 16417.681742472294
# ['TSLA' 'CPRT' 'AAPL' 'MSCI' 'PHM']
# 2020-02-13 00:00:00
# 16254.114062288212
# ['TSLA' 'CPRT' 'MSCI' 'PAYC' 'BRO']
# 2020-02-14 00:00:00
# 16710.837508211433
# ['TSLA' 'CPRT' 'MSFT' 'PAYC' 'BRO']
# 2020-02-18 00:00:00
# 17109.64240445499
# ['TSLA' 'CPRT' 'PAYC' 'MSFT' 'ANSS']
# 2020-02-19 00:00:00
# 17557.26156399009
# ['ENPH' 'TSLA' 'CPRT' 'AAPL' 'LRCX']
# 2020-02-20 00:00:00
# 18012.550734270462
# ['ENPH' 'AAPL' 'LRCX' 'CPRT' 'RMD']
# 2020-02-21 00:00:00
# 17971.25874922108
# ['AAPL' 'LRCX' 'RMD' 'QCOM' 'CPRT']
# 2020-02-24 00:00:00
# 16974.374301994263
# ['AMD' 'AAPL' 'LRCX' 'MSCI' 'RMD']
# 2020-02-25 00:00:00
# 17444.669823009015
# ['GNRC' 'AMD' 'HWM' 'LDOS' 'NVDA']
# 2020-02-26 00:00:00
# 16595.76979283198
# ['TSLA' 'GNRC' 'LDOS' 'HWM' 'NVDA']
# 2020-02-27 00:00:00
# 16141.271731360399
# ['TSLA' 'GNRC' 'DXCM' 'NVDA' 'HWM']
# 2020-02-28 00:00:00
# 15216.208805573193
# ['ENPH' 'SEDG' 'TSLA' 'GNRC' 'DXCM']
# 2020-03-02 00:00:00
# 16275.908094028902
# ['ENPH' 'SEDG' 'TSLA' 'GNRC' 'DXCM']
# 2020-03-03 00:00:00
# 17252.578408702608
# ['ENPH' 'SEDG' 'TSLA' 'GNRC' 'AMD']
# 2020-03-04 00:00:00
# 17084.810473139292
# ['ENPH' 'SEDG' 'TSLA' 'GNRC' 'AMD']
# 2020-03-05 00:00:00
# 16977.906457703302
# ['ENPH' 'SEDG' 'TSLA' 'GNRC' 'DXCM']
# 2020-03-06 00:00:00
# 16986.53779127566
# ['ENPH' 'SEDG' 'TSLA' 'DXCM' 'NEM']
# 2020-03-09 00:00:00
# 15181.66605812532
# ['ENPH' 'SEDG' 'DXCM' 'MRNA' 'DPZ']
# 2020-03-10 00:00:00
# 15138.576807981099
# ['ENPH' 'SEDG' 'DXCM' 'LDOS' 'TYL']
# 2020-03-11 00:00:00
# 14638.780766780183
# ['ENPH' 'SEDG' 'DXCM' 'LDOS' 'SBAC']
# 2020-03-12 00:00:00
# 12412.845207765316
# ['ENPH' 'SEDG' 'GNRC' 'DXCM' 'LDOS']
# 2020-03-13 00:00:00
# 13317.616108326512
# ['ENPH' 'TSLA' 'GNRC' 'DXCM' 'RMD']
# 2020-03-16 00:00:00
# 11251.62270811711
# ['ENPH' 'TSLA' 'AMD' 'GNRC' 'DXCM']
# 2020-03-17 00:00:00
# 11134.239545654624
# ['AMD' 'CPB' 'SBAC' 'MRNA' 'AAPL']
# 2020-03-18 00:00:00
# 11034.492026255926
# ['RMD' 'AMD' 'CPB' 'SBAC' 'MRNA']
# 2020-03-19 00:00:00
# 11266.08739527383
# ['RMD' 'KR' 'DVA' 'CPB' 'SBAC']
# 2020-03-20 00:00:00
# 10662.171348946033
# ['DPZ' 'DVA']
# 2020-03-23 00:00:00
# 9911.913693565904
# ['DPZ']
# 2020-03-24 00:00:00
# 10875.018207602454
# ['spy']
# 2020-03-25 00:00:00
# 11359.805802386161
# ['KR']
# 2020-03-26 00:00:00
# 10606.020836756854
# ['spy']
# 2020-03-27 00:00:00
# 10765.417187577723
# ['MRNA']
# 2020-03-30 00:00:00
# 11607.828821607234
# ['MRNA']
# 2020-03-31 00:00:00
# 11611.623556633655
# ['MRNA' 'KR']
# 2020-04-01 00:00:00
# 11648.588314067525
# ['MRNA' 'KR']
# 2020-04-02 00:00:00
# 11741.7341896393
# ['KR']
# 2020-04-03 00:00:00
# 12277.744972589802
# ['AMD']
# 2020-04-06 00:00:00
# 12277.744972589802
# ['AMD' 'DPZ' 'NEM' 'NVDA']
# 2020-04-07 00:00:00
# 13035.574405025442
# ['ENPH' 'DXCM' 'TSLA' 'AMD' 'MSCI']
# 2020-04-08 00:00:00
# 12571.69099954734
# ['ENPH' 'DXCM' 'TSLA' 'AMD' 'ODFL']
# 2020-04-09 00:00:00
# 12975.406452010217
# ['DXCM' 'AMD' 'LDOS' 'TYL' 'EQIX']
# 2020-04-13 00:00:00
# 13112.792733022317
# ['DXCM' 'EQIX' 'LDOS' 'CTLT' 'TYL']
# 2020-04-14 00:00:00
# 13083.352037347846
# ['DXCM' 'RMD' 'NVDA' 'EQIX' 'BIIB']
# 2020-04-15 00:00:00
# 13102.647961063198
# ['DXCM' 'RMD' 'WST' 'VRTX' 'MRNA']
# 2020-04-16 00:00:00
# 13580.878988059627
# ['MRNA' 'WST' 'DG' 'TTWO' 'KR']
# 2020-04-17 00:00:00
# 14476.281522766198
# ['EQIX' 'WST' 'DG' 'ODFL' 'HRL']
# 2020-04-20 00:00:00
# 14393.196441584289
# ['RMD' 'MKTX' 'EQIX' 'LDOS' 'WST']
# 2020-04-21 00:00:00
# 14166.927925541437
# ['ENPH' 'MKTX' 'RMD' 'VRTX' 'SBAC']
# 2020-04-22 00:00:00
# 13957.018314967216
# ['ENPH' 'NEM' 'MKTX' 'RMD' 'VRTX']
# 2020-04-23 00:00:00
# 14215.174069458135
# ['ENPH' 'TSLA' 'AMD' 'NEM' 'MKTX']
# 2020-04-24 00:00:00
# 14165.78619260159
# ['ENPH' 'TSLA' 'SEDG' 'AMD' 'NEM']
# 2020-04-27 00:00:00
# 14336.639168697047
# ['ENPH' 'TSLA' 'SEDG' 'NEM' 'AMD']
# 2020-04-28 00:00:00
# 14735.46636816795
# ['ENPH' 'TSLA' 'DXCM' 'AMD' 'NEM']
# 2020-04-29 00:00:00
# 15000.136248915514
# ['ENPH' 'TSLA' 'DXCM' 'AMD' 'NEM']
# 2020-04-30 00:00:00
# 15376.946812879247
# ['TSLA' 'DXCM' 'NEM' 'AMD' 'MRNA']
# 2020-05-01 00:00:00
# 14769.549171736624
# ['TSLA' 'DXCM' 'NEM' 'AMD' 'MRNA']
# 2020-05-04 00:00:00
# 14727.336553521112
# ['DXCM' 'TSLA' 'NEM' 'AMD' 'MRNA']
# 2020-05-05 00:00:00
# 15635.805134949303
# ['TSLA' 'MRNA' 'NEM' 'AMD' 'NVDA']
# 2020-05-06 00:00:00
# 15480.110783171602
# ['TSLA' 'NEM' 'MRNA' 'SEDG' 'AMD']
# 2020-05-07 00:00:00
# 15837.642315756097
# ['TSLA' 'SEDG' 'MRNA' 'NEM' 'AMD']
# 2020-05-08 00:00:00
# 15831.240193564476
# ['TSLA' 'NEM' 'MRNA' 'SEDG' 'AMD']
# 2020-05-11 00:00:00
# 16357.989478635373
# ['TSLA' 'SEDG' 'AMD' 'WST' 'MPWR']
# 2020-05-12 00:00:00
# 17184.61792749007
# ['TSLA' 'SEDG' 'CTLT' 'ODFL' 'HUM']
# 2020-05-13 00:00:00
# 16940.374385920997
# ['SEDG' 'NEM' 'ODFL' 'CTLT' 'HUM']
# 2020-05-14 00:00:00
# 16447.861364946337
# ['NEM' 'DVA' 'CTLT' 'HUM' 'ODFL']
# 2020-05-15 00:00:00
# 16745.12312549358
# ['AAPL' 'DVA' 'HUM' 'CTLT' 'ODFL']
# 2020-05-18 00:00:00
# 17557.520837748023
# ['TSLA' 'DXCM' 'SEDG' 'REGN' 'ATVI']
# 2020-05-19 00:00:00
# 17251.819255686685
# ['ENPH' 'TSLA' 'DXCM' 'SEDG' 'REGN']
# 2020-05-20 00:00:00
# 17791.062819223996
# ['ENPH' 'TSLA' 'DXCM' 'SEDG' 'FTNT']
# 2020-05-21 00:00:00
# 17107.188611592937
# ['ENPH' 'TSLA' 'DXCM' 'FTNT' 'REGN']
# 2020-05-22 00:00:00
# 16952.697650810136
# ['TSLA' 'ENPH' 'DXCM' 'MRNA' 'NEM']
# 2020-05-26 00:00:00
# 16738.98389025907
# ['TSLA' 'ENPH' 'DXCM' 'MRNA' 'NEM']
# 2020-05-27 00:00:00
# 15431.016541032011
# ['TSLA' 'ENPH' 'MRNA' 'AMD' 'NEM']
# 2020-05-28 00:00:00
# 15504.624059212372
# ['TSLA' 'ENPH' 'NVDA' 'MRNA' 'AMD']
# 2020-05-29 00:00:00
# 15688.633743160968
# ['TSLA' 'ENPH' 'DXCM' 'MRNA' 'SEDG']
# 2020-06-01 00:00:00
# 16527.29674731621
# ['TSLA' 'ENPH' 'DXCM' 'MRNA' 'SEDG']
# 2020-06-02 00:00:00
# 16765.803667979246
# ['ENPH' 'MRNA' 'DXCM' 'SEDG' 'NVDA']
# 2020-06-03 00:00:00
# 16540.658989444237
# ['ENPH' 'MRNA' 'DXCM' 'SEDG' 'NVDA']
# 2020-06-04 00:00:00
# 16401.842559596855
# ['ENPH' 'MRNA' 'DXCM' 'NVDA' 'FTNT']
# 2020-06-05 00:00:00
# 15944.741101760354
# ['ENPH' 'DXCM' 'NVDA' 'GNRC' 'ODFL']
# 2020-06-08 00:00:00
# 16335.031366116076
# ['ENPH' 'DXCM' 'NVDA' 'GNRC' 'ODFL']
# 2020-06-09 00:00:00
# 16096.803799274781
# ['ENPH' 'SEDG' 'GNRC' 'ODFL' 'WST']
# 2020-06-10 00:00:00
# 16117.883160620182
# ['ENPH' 'SEDG' 'REGN' 'GNRC' 'ODFL']
# 2020-06-11 00:00:00
# 15434.5335584733
# ['ENPH' 'SEDG' 'REGN' 'FTNT' 'ODFL']
# 2020-06-12 00:00:00
# 15652.446274879767
# ['MRNA' 'ENPH' 'SEDG' 'NVDA' 'REGN']
# 2020-06-15 00:00:00
# 15184.86555329684
# ['MRNA' 'ENPH' 'SEDG' 'NVDA' 'REGN']
# 2020-06-16 00:00:00
# 16051.08155817139
# ['ENPH' 'SEDG' 'REGN' 'FTNT' 'ODFL']
# 2020-06-17 00:00:00
# 15990.249717505096
# ['SEDG' 'REGN' 'FTNT' 'GNRC' 'MPWR']
# 2020-06-18 00:00:00
# 15677.448432774294
# ['TSLA' 'SEDG' 'REGN' 'FTNT' 'QRVO']
# 2020-06-19 00:00:00
# 15907.141585741634
# ['TSLA' 'ENPH' 'SEDG' 'NVDA' 'REGN']
# 2020-06-22 00:00:00
# 16085.20507875826
# ['TSLA' 'ENPH' 'NVDA' 'AMD' 'AAPL']
# 2020-06-23 00:00:00
# 16270.415220822175
# ['TSLA' 'AMD' 'AAPL' 'QRVO' 'KLAC']
# 2020-06-24 00:00:00
# 16058.702266385972
# ['MRNA' 'TSLA' 'AMD' 'SWKS' 'TYL']
# 2020-06-25 00:00:00
# 16044.660277921237
# ['MRNA' 'TSLA' 'AMD' 'SWKS' 'NDSN']
# 2020-06-26 00:00:00
# 15841.44457486437
# ['TSLA' 'MRNA' 'DXCM' 'SEDG' 'AMD']
# 2020-06-29 00:00:00
# 15422.319767861412
# ['TSLA' 'MRNA' 'DXCM' 'NVDA' 'SEDG']
# 2020-06-30 00:00:00
# 15840.933358850902
# ['TSLA' 'MRNA' 'DXCM' 'NVDA' 'SEDG']
# 2020-07-01 00:00:00
# 16349.157343848017
# ['TSLA' 'MRNA' 'DXCM' 'NVDA' 'SEDG']
# 2020-07-02 00:00:00
# 16705.354241213005
# ['MRNA' 'DXCM' 'NVDA' 'SEDG' 'REGN']
# 2020-07-06 00:00:00
# 16919.0029353687
# ['MRNA' 'DXCM' 'NVDA' 'SEDG' 'REGN']
# 2020-07-07 00:00:00
# 17194.084056543845
# ['MRNA' 'REGN' 'TER' 'AAPL' 'ETSY']
# 2020-07-08 00:00:00
# 17397.449404827228
# ['MRNA' 'TER' 'AAPL' 'ETSY' 'VRTX']
# 2020-07-09 00:00:00
# 17504.85523534098
# ['MRNA' 'ETSY' 'RMD' 'KR' 'TMUS']
# 2020-07-10 00:00:00
# 17717.354121561213
# ['ETSY' 'RMD' 'LLY' 'KR' 'ABBV']
# 2020-07-13 00:00:00
# 17695.147770464722
# ['ETSY' 'NEM' 'RMD' 'KR' 'LLY']
# 2020-07-14 00:00:00
# 17074.137198323573
# ['REGN' 'TER' 'WST' 'GNRC' 'MPWR']
# 2020-07-15 00:00:00
# 17840.83515662747
# ['DXCM' 'REGN' 'TER' 'WST' 'GNRC']
# 2020-07-16 00:00:00
# 17703.864910781085
# ['DXCM' 'NVDA' 'REGN' 'WST' 'TER']
# 2020-07-17 00:00:00
# 17923.564940604825
# ['TSLA' 'DXCM' 'NVDA' 'REGN' 'WST']
# 2020-07-20 00:00:00
# 18215.35216598004
# ['TSLA' 'DXCM' 'NVDA' 'REGN' 'AAPL']
# 2020-07-21 00:00:00
# 18771.725627269367
# ['TSLA' 'DXCM' 'NVDA' 'AAPL' 'TER']
# 2020-07-22 00:00:00
# 18497.80173146041
# ['TSLA' 'DXCM' 'SEDG' 'NVDA' 'AAPL']
# 2020-07-23 00:00:00
# 18766.3954142272
# ['TSLA' 'DXCM' 'SEDG' 'NVDA' 'AAPL']
# 2020-07-24 00:00:00
# 17620.80896130316
# ['TSLA' 'MRNA' 'SEDG' 'NVDA' 'GNRC']
# 2020-07-27 00:00:00
# 18449.933651142237
# ['TSLA' 'MRNA' 'ENPH' 'SEDG' 'NVDA']
# 2020-07-28 00:00:00
# 18805.361257769313
# ['TSLA' 'MRNA' 'ENPH' 'SEDG' 'NVDA']
# 2020-07-29 00:00:00
# 18501.338449347262
# ['MRNA' 'TSLA' 'DXCM' 'SEDG' 'NVDA']
# 2020-07-30 00:00:00
# 18245.793554683813
# ['TSLA' 'MRNA' 'DXCM' 'SEDG' 'NVDA']
# 2020-07-31 00:00:00
# 18555.796246038044
# ['TSLA' 'MRNA' 'DXCM' 'SEDG' 'NVDA']
# 2020-08-03 00:00:00
# 18257.153044975563
# ['MRNA' 'DXCM' 'SEDG' 'ENPH' 'REGN']
# 2020-08-04 00:00:00
# 19095.02725907944
# ['MRNA' 'SEDG' 'ENPH' 'WST' 'ATVI']
# 2020-08-05 00:00:00
# 19434.105540840665
# ['TSLA' 'MRNA' 'WST' 'NEM' 'NOW']
# 2020-08-06 00:00:00
# 19304.917911266846
# ['TSLA' 'WST' 'NEM' 'MSCI' 'BIO']
# 2020-08-07 00:00:00
# 19216.085461739065
# ['WST' 'NEM' 'MSCI' 'ALGN' 'BIO']
# 2020-08-10 00:00:00
# 19151.307294254813
# ['MRNA' 'REGN' 'WST' 'LRCX' 'NEM']
# 2020-08-11 00:00:00
# 18509.625528096236
# ['TSLA' 'MRNA' 'DXCM' 'AMD' 'REGN']
# 2020-08-12 00:00:00
# 18896.252066819936
# ['TSLA' 'MRNA' 'NVDA' 'DXCM' 'AMD']
# 2020-08-13 00:00:00
# 19524.347246620928
# ['MRNA' 'NVDA' 'AMD' 'DXCM' 'GNRC']
# 2020-08-14 00:00:00
# 19507.74740266563
# ['MRNA' 'NVDA' 'DXCM' 'AMD' 'ETSY']
# 2020-08-17 00:00:00
# 19658.254860586225
# ['MRNA' 'NVDA' 'SEDG' 'DXCM' 'AMD']
# 2020-08-18 00:00:00
# 19942.09272617195
# ['MRNA' 'AMD' 'DXCM' 'SEDG' 'GNRC']
# 2020-08-19 00:00:00
# 19720.25324036276
# ['MRNA' 'AMD' 'DXCM' 'SEDG' 'ETSY']
# 2020-08-20 00:00:00
# 19563.25711187956
# ['SEDG' 'AMD' 'GNRC' 'ETSY' 'ENPH']
# 2020-08-21 00:00:00
# 19669.89169938026
# ['AMD' 'SEDG' 'GNRC' 'ETSY' 'AAPL']
# 2020-08-24 00:00:00
# 20208.886656852603
# ['SEDG' 'ETSY' 'ENPH' 'SWKS' 'QRVO']
# 2020-08-25 00:00:00
# 19960.286215149994
# ['SEDG' 'ENPH' 'SWKS' 'QRVO' 'WST']
# 2020-08-26 00:00:00
# 20186.815957409326
# ['SEDG' 'DXCM' 'GNRC' 'ENPH' 'REGN']
# 2020-08-27 00:00:00
# 20327.84265615332
# ['SEDG' 'DXCM' 'GNRC' 'ENPH' 'ETSY']
# 2020-08-28 00:00:00
# 19977.94084047426
# ['NVDA' 'SEDG' 'DXCM' 'ENPH' 'GNRC']
# 2020-08-31 00:00:00
# 20460.437772533707
# ['TSLA' 'NVDA' 'SEDG' 'ENPH' 'GNRC']
# 2020-09-01 00:00:00
# 21075.851305931694
# ['TSLA' 'NVDA' 'ENPH' 'SEDG' 'DXCM']
# 2020-09-02 00:00:00
# 21457.983467693422
# ['DXCM' 'ETSY' 'GNRC' 'BBWI' 'QRVO']
# 2020-09-03 00:00:00
# 21070.11797141473
# ['ETSY' 'AAPL' 'GNRC' 'BBWI' 'ADSK']
# 2020-09-04 00:00:00
# 20046.748971144898
# ['TSLA' 'NVDA' 'ENPH' 'AMD' 'SEDG']
# 2020-09-08 00:00:00
# 18638.63445860869
# ['TSLA' 'MRNA' 'ENPH' 'NVDA' 'DXCM']
# 2020-09-09 00:00:00
# 19116.675257610364
# ['TSLA' 'MRNA' 'DXCM' 'AMD' 'ENPH']
# 2020-09-10 00:00:00
# 19700.078571305894
# ['TSLA' 'ENPH' 'NVDA' 'DXCM' 'AMD']
# 2020-09-11 00:00:00
# 19250.660908183436
# ['TSLA' 'ENPH' 'NVDA' 'SEDG' 'GNRC']
# 2020-09-14 00:00:00
# 19349.90591708545
# ['TSLA' 'ENPH' 'NVDA' 'SEDG' 'GNRC']
# 2020-09-15 00:00:00
# 20584.13684342861
# ['TSLA' 'NVDA' 'ENPH' 'DXCM' 'AMD']
# 2020-09-16 00:00:00
# 20709.97681835469
# ['NVDA' 'AMD' 'DXCM' 'SEDG' 'AAPL']
# 2020-09-17 00:00:00
# 19675.995530668977
# ['NVDA' 'DXCM' 'AMD' 'AAPL' 'ALGN']
# 2020-09-18 00:00:00
# 20121.640302998952
# ['ALGN' 'NFLX' 'PYPL' 'CRM' 'CMG']
# 2020-09-21 00:00:00
# 19636.097606696065
# ['NFLX' 'ALGN' 'PYPL' 'AMZN' 'NEM']
# 2020-09-22 00:00:00
# 20428.473569980197
# ['ALGN' 'AMZN' 'ODFL' 'NEM' 'FCX']
# 2020-09-23 00:00:00
# 20417.181576642994
# ['GNRC' 'WST' 'ALGN' 'EPAM' 'NEM']
# 2020-09-24 00:00:00
# 19573.727055879255
# ['TSLA' 'GNRC' 'WST' 'ALGN' 'EPAM']
# 2020-09-25 00:00:00
# 19941.902310847494
# ['TSLA' 'MRNA' 'NVDA' 'GNRC' 'WST']
# 2020-09-28 00:00:00
# 21032.398744191505
# ['TSLA' 'MRNA' 'NVDA' 'GNRC' 'WST']
# 2020-09-29 00:00:00
# 21089.824394837702
# ['TSLA' 'MRNA' 'GNRC' 'WST' 'EPAM']
# 2020-09-30 00:00:00
# 21172.23559694696
# ['TSLA' 'MRNA' 'WST' 'QRVO' 'FDX']
# 2020-10-01 00:00:00
# 21353.297664975686
# ['TSLA' 'MRNA' 'QRVO' 'FCX' 'BBWI']
# 2020-10-02 00:00:00
# 20937.823507403227
# ['MRNA' 'CZR' 'MTD' 'FDS' 'HOLX']
# 2020-10-05 00:00:00
# 21520.75064852341
# ['MRNA' 'CZR' 'ATVI' 'EA' 'HOLX']
# 2020-10-06 00:00:00
# 21714.161093338775
# ['DPZ' 'MSCI' 'ATVI' 'CZR' 'EA']
# 2020-10-07 00:00:00
# 21337.39420873504
# ['DPZ' 'MSCI' 'ATVI' 'LRCX' 'CZR']
# 2020-10-08 00:00:00
# 21123.803487095494
# ['PYPL' 'DPZ' 'POOL' 'MSFT' 'LRCX']
# 2020-10-09 00:00:00
# 21392.151297376942
# ['TSLA' 'MRNA' 'AAPL' 'PYPL' 'BBWI']
# 2020-10-12 00:00:00
# 21739.578397210505
# ['TSLA' 'MRNA' 'NVDA' 'AMD' 'AAPL']
# 2020-10-13 00:00:00
# 22236.87904007498
# ['TSLA' 'NVDA' 'AMD' 'GNRC' 'PYPL']
# 2020-10-14 00:00:00
# 22468.275553330313
# ['ENPH' 'SEDG' 'NVDA' 'AMD' 'GNRC']
# 2020-10-15 00:00:00
# 22059.106417238047
# ['ENPH' 'SEDG' 'NVDA' 'AMD' 'GNRC']
# 2020-10-16 00:00:00
# 22807.317020526094
# ['ENPH' 'SEDG' 'NVDA' 'AMD' 'ETSY']
# 2020-10-19 00:00:00
# 22539.22591211132
# ['MRNA' 'ENPH' 'SEDG' 'NVDA' 'AMD']
# 2020-10-20 00:00:00
# 22509.076633756034
# ['ENPH' 'MRNA' 'SEDG' 'NVDA' 'ETSY']
# 2020-10-21 00:00:00
# 22447.32122314435
# ['TSLA' 'ENPH' 'MRNA' 'SEDG' 'NVDA']
# 2020-10-22 00:00:00
# 21449.45878887192
# ['TSLA' 'MRNA' 'SEDG' 'NVDA' 'AMD']
# 2020-10-23 00:00:00
# 21610.525226256108
# ['TSLA' 'MRNA' 'SEDG' 'NVDA' 'AMD']
# 2020-10-26 00:00:00
# 21302.989715106574
# ['TSLA' 'MRNA' 'ENPH' 'SEDG' 'DXCM']
# 2020-10-27 00:00:00
# 21436.673495331717
# ['TSLA' 'MRNA' 'ENPH' 'SEDG' 'DXCM']
# 2020-10-28 00:00:00
# 20550.136461712093
# ['TSLA' 'ENPH' 'MRNA' 'SEDG' 'ETSY']
# 2020-10-29 00:00:00
# 20670.31766777819
# ['TSLA' 'ENPH' 'ETSY' 'SEDG' 'NVDA']
# 2020-10-30 00:00:00
# 20310.93109136929
# ['TSLA' 'ENPH' 'SEDG' 'ETSY' 'NVDA']
# 2020-11-02 00:00:00
# 19754.103039387785
# ['TSLA' 'ENPH' 'SEDG' 'ETSY' 'NVDA']
# 2020-11-03 00:00:00
# 19397.452745957595
# ['TSLA' 'ENPH' 'SEDG' 'ETSY' 'NVDA']
# 2020-11-04 00:00:00
# 19800.63560944124
# ['ETSY' 'SEDG' 'NVDA' 'GNRC' 'AMD']
# 2020-11-05 00:00:00
# 20799.882119692666
# ['ETSY' 'SEDG' 'ALGN' 'PAYC' 'BBWI']
# 2020-11-06 00:00:00
# 21055.606855953534
# ['SEDG' 'BBWI' 'ALGN' 'DHR' 'PAYC']
# 2020-11-09 00:00:00
# 21895.607776945093
# ['SEDG' 'ALGN' 'FSLR']
# 2020-11-10 00:00:00
# 20084.531273078348
# ['SEDG' 'ALGN' 'POOL' 'HOLX']
# 2020-11-11 00:00:00
# 20185.03200531985
# ['SEDG' 'GNRC' 'ALGN' 'POOL' 'DHR']
# 2020-11-12 00:00:00
# 20435.915556979333
# ['GNRC' 'MPWR' 'ALGN' 'IDXX' 'NEM']
# 2020-11-13 00:00:00
# 20260.13057165831
# ['GNRC' 'MPWR' 'IDXX' 'NEM' 'ALGN']
# 2020-11-16 00:00:00
# 20077.265753684394
# ['TSLA' 'ETSY' 'NVDA' 'GNRC' 'BBWI']
# 2020-11-17 00:00:00
# 20687.582816695638
# ['ENPH' 'TSLA' 'ETSY' 'NVDA' 'GNRC']
# 2020-11-18 00:00:00
# 20815.4130997432
# ['ENPH' 'TSLA' 'ETSY' 'NVDA' 'GNRC']
# 2020-11-19 00:00:00
# 21194.837955609968
# ['ENPH' 'ETSY' 'NVDA' 'GNRC' 'AMD']
# 2020-11-20 00:00:00
# 21931.0055920788
# ['NVDA' 'GNRC' 'AMD' 'MPWR' 'ALB']
# 2020-11-23 00:00:00
# 22171.4653227558
# ['ALB' 'CTLT' 'WST' 'MTCH' 'FCX']
# 2020-11-24 00:00:00
# 22471.716771183437
# ['ALB' 'MTCH' 'CTLT' 'WST' 'AAPL']
# 2020-11-25 00:00:00
# 22258.097293069302
# ['MRNA' 'NVDA' 'ALB' 'IDXX' 'WST']
# 2020-11-27 00:00:00
# 23212.746645137297
# ['MRNA' 'NVDA' 'ALB' 'WST' 'CTLT']
# 2020-11-30 00:00:00
# 24640.20365553459
# ['NVDA' 'ALB' 'CTLT' 'WST' 'IDXX']
# 2020-12-01 00:00:00
# 24645.306661605257
# ['NVDA' 'BBWI' 'ALB' 'FDX' 'CTLT']
# 2020-12-02 00:00:00
# 24269.114327005373
# ['ENPH' 'ALB' 'BBWI' 'FDX' 'CTLT']
# 2020-12-03 00:00:00
# 24299.299940290268
# ['TSLA' 'ENPH' 'BBWI' 'GNRC' 'ALB']
# 2020-12-04 00:00:00
# 24142.95967019224
# ['TSLA' 'ENPH' 'SEDG' 'BBWI' 'ALB']
# 2020-12-07 00:00:00
# 24547.20431064387
# ['TSLA' 'ENPH' 'ETSY' 'SEDG' 'BBWI']
# 2020-12-08 00:00:00
# 25185.949955199263
# ['TSLA' 'ENPH' 'ETSY' 'SEDG' 'BBWI']
# 2020-12-09 00:00:00
# 26127.46631514263
# ['TSLA' 'ENPH' 'ETSY' 'SEDG' 'BBWI']
# 2020-12-10 00:00:00
# 24524.563870099526
# ['MRNA' 'TSLA' 'ETSY' 'SEDG' 'NVDA']
# 2020-12-11 00:00:00
# 25602.311395347835
# ['TSLA' 'MRNA' 'ETSY' 'SEDG' 'NVDA']
# 2020-12-14 00:00:00
# 26276.873121015724
# ['MRNA' 'TSLA' 'ETSY' 'SEDG' 'NVDA']
# 2020-12-15 00:00:00
# 26473.873559484236
# ['TSLA' 'MRNA' 'NVDA' 'AMD' 'BBWI']
# 2020-12-16 00:00:00
# 25842.740050444212
# ['TSLA' 'MRNA' 'NVDA' 'AMD' 'BBWI']
# 2020-12-17 00:00:00
# 25787.548713456563
# ['TSLA' 'MRNA' 'NVDA' 'BBWI' 'FDX']
# 2020-12-18 00:00:00
# 26148.80150570179
# ['TSLA' 'MRNA' 'BBWI' 'FDX' 'ALB']
# 2020-12-21 00:00:00
# 25686.038787607842
# ['TSLA' 'MRNA' 'BBWI' 'MTCH' 'ALB']
# 2020-12-22 00:00:00
# 25928.32942149204
# ['TSLA' 'MRNA' 'BBWI' 'ALB' 'FCX']
# 2020-12-23 00:00:00
# 25078.357966839365
# ['MRNA' 'BBWI' 'AMD' 'FCX' 'FDX']
# 2020-12-24 00:00:00
# 25444.133108199545
# ['MRNA' 'BBWI' 'AMD' 'FCX' 'FDX']
# 2020-12-28 00:00:00
# 25288.349734604264
# ['TSLA' 'MRNA' 'ETSY' 'SEDG' 'NVDA']
# 2020-12-29 00:00:00
# 24069.934624366902
# ['TSLA' 'MRNA' 'ETSY' 'SEDG' 'NVDA']
# 2020-12-30 00:00:00
# 24537.685943979694
# ['TSLA' 'MRNA' 'ENPH' 'ETSY' 'SEDG']
# 2020-12-31 00:00:00
# 24852.686096510668
# ['TSLA' 'ENPH' 'MRNA' 'ETSY' 'SEDG']
# 2021-01-04 00:00:00
# 24777.26658080744
# ['TSLA' 'ENPH' 'MRNA' 'ETSY' 'SEDG']
# 2021-01-05 00:00:00
# 24536.221545159577
# ['MRNA' 'ENPH' 'ETSY' 'SEDG' 'NVDA']
# 2021-01-06 00:00:00
# 25548.25413401284
# ['MRNA' 'ENPH' 'ETSY' 'SEDG' 'ALB']
# 2021-01-07 00:00:00
# 27200.775204887523
# ['ENPH' 'ETSY' 'SEDG' 'PYPL' 'MPWR']
# 2021-01-08 00:00:00
# 28210.933472929384
# ['ETSY' 'MPWR' 'PYPL' 'CDNS' 'FSLR']
# 2021-01-11 00:00:00
# 27734.26177448806
# ['ETSY' 'CDNS' 'IDXX' 'FSLR' 'SNPS']
# 2021-01-12 00:00:00
# 28273.350613038227
# ['CDNS' 'SNPS' 'NOW' 'TMUS' 'AAPL']
# 2021-01-13 00:00:00
# 28010.006724843304
# ['CDNS' 'SNPS' 'NOW' 'AAPL' 'TMUS']
# 2021-01-14 00:00:00
# 28164.95719401459
# ['CDNS' 'SNPS' 'IDXX' 'NOW' 'AAPL']
# 2021-01-15 00:00:00
# 27913.232494206262
# ['SEDG' 'ALGN' 'WST' 'CDNS' 'AMD']
# 2021-01-19 00:00:00
# 27645.118162647617
# ['TSLA' 'ENPH' 'SEDG' 'FCX' 'BBWI']
# 2021-01-20 00:00:00
# 28208.156102956884
# ['TSLA' 'ENPH' 'SEDG' 'GNRC' 'FCX']
# 2021-01-21 00:00:00
# 28183.995831226977
# ['TSLA' 'ENPH' 'SEDG' 'GNRC' 'FCX']
# 2021-01-22 00:00:00
# 27840.39025991067
# ['TSLA' 'ENPH' 'SEDG' 'GNRC' 'FCX']
# 2021-01-25 00:00:00
# 28819.51484808816
# ['TSLA' 'ENPH' 'SEDG' 'FCX' 'EQT']
# 2021-01-26 00:00:00
# 28409.573568563752
# ['TSLA' 'ENPH' 'ETSY' 'SEDG' 'FCX']
# 2021-01-27 00:00:00
# 25753.397323057357
# ['TSLA' 'ENPH' 'ETSY' 'SEDG' 'EQT']
# 2021-01-28 00:00:00
# 25993.602566354268
# ['TSLA' 'ENPH' 'ETSY' 'EQT' 'GNRC']
# 2021-01-29 00:00:00
# 26252.5556548765
# ['TSLA' 'ENPH' 'ETSY' 'EQT' 'FCX']
# 2021-02-01 00:00:00
# 26206.57773052573
# ['ENPH' 'TSLA' 'ETSY' 'EQT' 'GNRC']
# 2021-02-02 00:00:00
# 27138.975975078705
# ['ENPH' 'TSLA' 'ETSY' 'GNRC' 'FCX']
# 2021-02-03 00:00:00
# 27825.45241155883
# ['TSLA' 'ENPH' 'ETSY' 'GNRC' 'FCX']
# 2021-02-04 00:00:00
# 27708.951178142896
# ['TSLA' 'ENPH' 'ETSY' 'GNRC' 'NVDA']
# 2021-02-05 00:00:00
# 28004.472469178058
# ['MRNA' 'TSLA' 'GNRC' 'MPWR' 'SIVB']
# 2021-02-08 00:00:00
# 28135.541062097574
# ['MRNA' 'TSLA' 'ALB' 'FSLR' 'WST']
# 2021-02-09 00:00:00
# 28497.129421897458
# ['MRNA' 'TSLA' 'ALB' 'FSLR' 'WST']
# 2021-02-10 00:00:00
# 28407.63819585461
# ['MRNA' 'EQT' 'WST' 'AAPL' 'MKTX']
# 2021-02-11 00:00:00
# 28389.205747229422
# ['MRNA' 'EQT' 'CTLT' 'TTWO' 'WST']
# 2021-02-12 00:00:00
# 28513.363906632003
# ['MRNA' 'TSLA' 'EQT' 'CTLT' 'TTWO']
# 2021-02-16 00:00:00
# 29286.75398915527
# ['TSLA' 'EQT' 'TECH' 'TTWO' 'QRVO']
# 2021-02-17 00:00:00
# 28765.97483083973
# ['TSLA' 'ETSY' 'ALGN' 'BBWI' 'TECH']
# 2021-02-18 00:00:00
# 28462.56262156851
# ['MRNA' 'TSLA' 'ETSY' 'ENPH' 'ALGN']
# 2021-02-19 00:00:00
# 28918.851869155937
# ['MRNA' 'TSLA' 'ETSY' 'ENPH' 'PYPL']
# 2021-02-22 00:00:00
# 28179.43988952582
# ['MRNA' 'TSLA' 'ETSY' 'ENPH' 'ALGN']
# 2021-02-23 00:00:00
# 25398.17026269721
# ['MRNA' 'TSLA' 'ETSY' 'ENPH' 'ALGN']
# 2021-02-24 00:00:00
# 26256.95869406801
# ['MRNA' 'TSLA' 'ETSY' 'ENPH' 'GNRC']
# 2021-02-25 00:00:00
# 26288.48888961391
# ['MRNA' 'TSLA' 'ENPH' 'ETSY' 'EQT']
# 2021-02-26 00:00:00
# 26356.592256642678
# ['MRNA' 'TSLA' 'ENPH' 'ETSY' 'EQT']
# 2021-03-01 00:00:00
# 26554.07336451359
# ['MRNA' 'TSLA' 'ETSY' 'ENPH' 'FCX']
# 2021-03-02 00:00:00
# 27331.79558433119
# ['MRNA' 'TSLA' 'FCX' 'GNRC' 'EQT']
# 2021-03-03 00:00:00
# 26783.465094661504
# ['MRNA' 'FCX' 'EQT' 'PARA' 'GNRC']
# 2021-03-04 00:00:00
# 25643.404277959402
# ['MRNA' 'FCX' 'PARA' 'EQT' 'SIVB']
# 2021-03-05 00:00:00
# 25914.66607123119
# ['MRNA' 'TSLA' 'FCX' 'SIVB' 'EQT']
# 2021-03-08 00:00:00
# 25555.757943064444
# ['MRNA' 'TSLA' 'FCX' 'MRO' 'CZR']
# 2021-03-09 00:00:00
# 25200.42939422225
# ['MRNA' 'FCX' 'ETSY' 'CZR' 'SIVB']
# 2021-03-10 00:00:00
# 25679.06956023473
# ['MRNA' 'FCX' 'ETSY' 'CZR' 'SIVB']
# 2021-03-11 00:00:00
# 26456.498825105024
# ['CZR' 'MRNA' 'FCX' 'ETSY' 'ENPH']
# 2021-03-12 00:00:00
# 26567.296014202773
# ['CZR' 'ENPH' 'ETSY' 'BBWI' 'GNRC']
# 2021-03-15 00:00:00
# 27603.173574157154
# ['CZR' 'ETSY' 'BBWI' 'HAL' 'APA']
# 2021-03-16 00:00:00
# 27348.3202683696
# ['APA' 'TRGP' 'FANG' 'HAL' 'DVN']
# 2021-03-17 00:00:00
# 26660.307843799645
# ['TRGP' 'FANG' 'HAL' 'APA' 'DVN']
# 2021-03-18 00:00:00
# 26969.73470561529
# ['CZR' 'TRGP' 'HAL' 'FANG' 'APA']
# 2021-03-19 00:00:00
# 25566.478493032053
# ['CZR' 'TRGP' 'HAL' 'FANG' 'APA']
# 2021-03-22 00:00:00
# 25523.609220743074
# ['PARA' 'CZR' 'FCX' 'TRGP' 'APA']
# 2021-03-23 00:00:00
# 24393.281402646007
# ['PARA' 'TSLA' 'CZR' 'ETSY' 'FCX']
# 2021-03-24 00:00:00
# 23628.15817770683
# ['PARA' 'TSLA' 'ETSY' 'CZR' 'FCX']
# 2021-03-25 00:00:00
# 20991.326614993985
# ['TSLA' 'PARA' 'CZR' 'ETSY' 'MRNA']
# 2021-03-26 00:00:00
# 21825.118667832117
# ['TSLA' 'CZR' 'PARA' 'ETSY' 'FCX']
# 2021-03-29 00:00:00
# 20424.59716330268
# ['CZR' 'FCX' 'ETSY' 'BBWI' 'TRGP']
# 2021-03-30 00:00:00
# 19706.31070137657
# ['CZR' 'BBWI' 'ETSY' 'FCX' 'APA']
# 2021-03-31 00:00:00
# 20530.09634479316
# ['BBWI' 'ETSY' 'FCX' 'TPR' 'ON']
# 2021-04-01 00:00:00
# 20805.96437066267
# ['ETSY' 'MRNA' 'TPR' 'EXPE' 'SIVB']
# 2021-04-05 00:00:00
# 21104.31197676165
# ['ETSY' 'MRNA' 'TPR' 'NWSA' 'NWS']
# 2021-04-06 00:00:00
# 20980.94384761255
# ['ETSY' 'KMX' 'LOW' 'WBD' 'MTCH']
# 2021-04-07 00:00:00
# 21330.29621013318
# ['KMX' 'LOW' 'WBD' 'PXD' 'BBY']
# 2021-04-08 00:00:00
# 21190.36790340514
# ['URI' 'LEN' 'DRI' 'PH' 'FDX']
# 2021-04-09 00:00:00
# 21176.62994649453
# ['URI' 'CARR' 'EXPE' 'DE' 'HWM']
# 2021-04-12 00:00:00
# 21265.809232348485
# ['TRGP' 'URI' 'CARR' 'EXPE' 'AMAT']
# 2021-04-13 00:00:00
# 21107.895053269887
# ['TRGP' 'CARR' 'URI' 'ON' 'EXPE']
# 2021-04-14 00:00:00
# 21279.48563734578
# ['FCX' 'GNRC' 'CARR' 'URI' 'ON']
# 2021-04-15 00:00:00
# 21645.698535966592
# ['FCX' 'GNRC' 'CARR' 'URI' 'HAL']
# 2021-04-16 00:00:00
# 21764.090690009813
# ['CZR' 'GNRC' 'CARR' 'ON' 'URI']
# 2021-04-19 00:00:00
# 21598.74910358488
# ['CZR' 'GNRC' 'URI' 'ON' 'NWSA']
# 2021-04-20 00:00:00
# 21249.443244069145
# ['CZR' 'BBWI' 'ETSY' 'GNRC' 'ALGN']
# 2021-04-21 00:00:00
# 20695.10601501677
# ['BBWI' 'CZR' 'TSLA' 'ETSY' 'GNRC']
# 2021-04-22 00:00:00
# 21605.121865963447
# ['BBWI' 'CZR' 'TSLA' 'IVZ' 'ETSY']
# 2021-04-23 00:00:00
# 21521.046869324273
# ['BBWI' 'CZR' 'TSLA' 'FCX' 'TPR']
# 2021-04-26 00:00:00
# 22052.224309578385
# ['BBWI' 'CZR' 'TSLA' 'FCX' 'MRNA']
# 2021-04-27 00:00:00
# 22309.373691489716
# ['BBWI' 'TSLA' 'FCX' 'MRNA' 'IVZ']
# 2021-04-28 00:00:00
# 22328.90828253777
# ['BBWI' 'TSLA' 'FCX' 'MRNA' 'IVZ']
# 2021-04-29 00:00:00
# 22785.12719863143
# ['FCX' 'TSLA' 'MRNA' 'ETSY' 'IVZ']
# 2021-04-30 00:00:00
# 22010.119116220492
# ['MRNA' 'ETSY' 'ALGN' 'NWSA' 'NWS']
# 2021-05-03 00:00:00
# 22107.304187566322
# ['MRNA' 'ETSY' 'ALGN' 'NWSA' 'ON']
# 2021-05-04 00:00:00
# 21707.00575537116
# ['MRNA' 'MGM' 'ALGN' 'PWR' 'NWSA']
# 2021-05-05 00:00:00
# 21494.370185780277
# ['BBWI' 'CZR' 'MRNA' 'SIVB' 'MOS']
# 2021-05-06 00:00:00
# 20769.594111177445
# ['BBWI' 'CZR' 'GNRC' 'SIVB' 'MOS']
# 2021-05-07 00:00:00
# 20764.380013170234
# ['BBWI' 'CZR' 'TPR' 'SIVB' 'GNRC']
# 2021-05-10 00:00:00
# 21439.235285551993
# ['BBWI' 'CZR' 'TPR' 'MOS' 'SIVB']
# 2021-05-11 00:00:00
# 20481.676206897348
# ['BBWI' 'CZR' 'TPR' 'SIVB' 'MOS']
# 2021-05-12 00:00:00
# 20655.65974003444
# ['CZR' 'IVZ' 'TPR' 'SIVB' 'MOS']
# 2021-05-13 00:00:00
# 19882.468726957723
# ['CZR' 'IVZ' 'TPR' 'MOS' 'PWR']
# 2021-05-14 00:00:00
# 20281.822360862327
# ['BBWI' 'CZR' 'IVZ' 'TPR' 'MOS']
# 2021-05-17 00:00:00
# 20852.760146674464
# ['BBWI' 'FCX' 'IVZ' 'CZR' 'TPR']
# 2021-05-18 00:00:00
# 21446.577672826366
# ['FCX' 'IVZ' 'TPR' 'CZR' 'SIVB']
# 2021-05-19 00:00:00
# 20380.227400324573
# ['FCX' 'IVZ' 'TPR' 'CZR' 'SIVB']
# 2021-05-20 00:00:00
# 20328.119154121046
# ['FCX' 'IVZ' 'TPR' 'MOS' 'CZR']
# 2021-05-21 00:00:00
# 20476.862204120993
# ['FCX' 'BBWI' 'IVZ' 'TPR' 'MOS']
# 2021-05-24 00:00:00
# 20395.308180287764
# ['FCX' 'BBWI' 'IVZ' 'MOS' 'TPR']
# 2021-05-25 00:00:00
# 20735.976932831265
# ['FCX' 'BBWI' 'TPR' 'MOS' 'PWR']
# 2021-05-26 00:00:00
# 20457.39949351857
# ['FCX' 'BBWI' 'TPR' 'MOS' 'URI']
# 2021-05-27 00:00:00
# 21156.201582483787
# ['FCX' 'BBWI' 'IVZ' 'TPR' 'MOS']
# 2021-05-28 00:00:00
# 21504.71479860328
# ['FCX' 'BBWI' 'IVZ' 'TPR' 'MOS']
# 2021-06-01 00:00:00
# 21500.99083420954
# ['FCX' 'MOS' 'NUE' 'DXC' 'STLD']
# 2021-06-02 00:00:00
# 21959.854112788154
# ['ALGN' 'DXC' 'UPS' 'NWS' 'STX']
# 2021-06-03 00:00:00
# 21544.162744934838
# ['ALGN' 'FDX' 'EPAM' 'UPS' 'NWSA']
# 2021-06-04 00:00:00
# 21768.27506513182
# ['GNRC' 'AMAT' 'FDX' 'LRCX' 'NWSA']
# 2021-06-07 00:00:00
# 21981.51249011684
# ['BBWI' 'GNRC' 'CZR' 'AMAT' 'LRCX']
# 2021-06-08 00:00:00
# 22201.670052711048
# ['BBWI' 'FCX' 'GNRC' 'TPR' 'CZR']
# 2021-06-09 00:00:00
# 22394.835007092224
# ['BBWI' 'FCX' 'TPR' 'CZR' 'MOS']
# 2021-06-10 00:00:00
# 22333.718542650808
# ['BBWI' 'FCX' 'CZR' 'TPR' 'MOS']
# 2021-06-11 00:00:00
# 22251.2014896466
# ['BBWI' 'FCX' 'CZR' 'TPR' 'IVZ']
# 2021-06-14 00:00:00
# 22334.853914927728
# ['BBWI' 'FCX' 'CZR' 'IVZ' 'SIVB']
# 2021-06-15 00:00:00
# 21701.85529646984
# ['BBWI' 'FCX' 'MRNA' 'CZR' 'IVZ']
# 2021-06-16 00:00:00
# 21376.59502036776
# ['FCX' 'MRNA' 'DXC' 'IVZ' 'SIVB']
# 2021-06-17 00:00:00
# 21484.75066218837
# ['FCX' 'MRNA' 'CZR' 'DXC' 'SIVB']
# 2021-06-18 00:00:00
# 20515.064092449717
# ['MRNA' 'CZR' 'SIVB' 'DXC' 'IVZ']
# 2021-06-21 00:00:00
# 20471.48390845104
# ['BBWI' 'MRNA' 'CZR' 'SIVB' 'DXC']
# 2021-06-22 00:00:00
# 21090.995344346535
# ['BBWI' 'MRNA' 'FCX' 'TPR' 'SIVB']
# 2021-06-23 00:00:00
# 21660.135127625494
# ['FCX' 'MRNA' 'TPR' 'DVN' 'CZR']
# 2021-06-24 00:00:00
# 21697.590656278608
# ['MRNA' 'TPR' 'CZR' 'IVZ' 'GM']
# 2021-06-25 00:00:00
# 21955.14945007169
# ['TPR' 'CZR' 'IVZ' 'COF' 'TRGP']
# 2021-06-28 00:00:00
# 21727.988172922676
# ['GNRC' 'IVZ' 'DXC' 'TRGP' 'AMAT']
# 2021-06-29 00:00:00
# 21801.572906616497
# ['GNRC' 'TRGP' 'EPAM' 'CBRE' 'WAT']
# 2021-06-30 00:00:00
# 21719.82160745689
# ['GNRC' 'SBNY' 'TRGP' 'EPAM' 'CBRE']
# 2021-07-01 00:00:00
# 21973.90619631551
# ['GNRC' 'SBNY' 'TRGP' 'ALGN' 'CRL']
# 2021-07-02 00:00:00
# 22088.041293661438
# ['ENPH' 'GNRC' 'ALGN' 'CRL' 'EPAM']
# 2021-07-06 00:00:00
# 22187.33371167931
# ['BBWI' 'ENPH' 'GNRC' 'MGM' 'MRO']
# 2021-07-07 00:00:00
# 21951.956092730656
# ['BBWI' 'MRNA' 'ENPH' 'GNRC' 'DVN']
# 2021-07-08 00:00:00
# 20693.04533154474
# ['BBWI' 'GNRC' 'MRNA' 'ENPH' 'DVN']
# 2021-07-09 00:00:00
# 21678.347550833947
# ['BBWI' 'MRNA' 'ENPH' 'DVN' 'FCX']
# 2021-07-12 00:00:00
# 21855.860056424426
# ['BBWI' 'ENPH' 'MRNA' 'DVN' 'FCX']
# 2021-07-13 00:00:00
# 22229.419559971873
# ['BBWI' 'ENPH' 'TPR' 'MRNA' 'FCX']
# 2021-07-14 00:00:00
# 21997.191522503887
# ['BBWI' 'ENPH' 'TPR' 'MRNA' 'DXC']
# 2021-07-15 00:00:00
# 21638.338182405805
# ['BBWI' 'GNRC' 'MRNA' 'ENPH' 'DVN']
# 2021-07-16 00:00:00
# 22034.21986991375
# ['BBWI' 'GNRC' 'ENPH' 'DVN' 'MHK']
# 2021-07-19 00:00:00
# 20852.002491204756
# ['BBWI' 'GNRC' 'ENPH' 'DVN' 'SBNY']
# 2021-07-20 00:00:00
# 21332.01522397255
# ['BBWI' 'GNRC' 'ENPH' 'COF' 'DFS']
# 2021-07-21 00:00:00
# 22206.158305915058
# ['BBWI' 'GNRC' 'ENPH' 'SIVB' 'COF']
# 2021-07-22 00:00:00
# 22634.750919438757
# ['BBWI' 'GNRC' 'ENPH' 'SIVB' 'MGM']
# 2021-07-23 00:00:00
# 22525.878765247704
# ['BBWI' 'GNRC' 'MGM' 'COF' 'SIVB']
# 2021-07-26 00:00:00
# 22713.353753145297
# ['GNRC' 'SIVB' 'DVN' 'COF' 'DFS']
# 2021-07-27 00:00:00
# 22591.82928977661
# ['GNRC' 'SIVB' 'DFS' 'SBNY' 'STLD']
# 2021-07-28 00:00:00
# 22361.48993902278
# ['SIVB' 'SCHW' 'KIM' 'WFC' 'FRC']
# 2021-07-29 00:00:00
# 22593.30089329629
# ['MRNA' 'WFC' 'FRC' 'WELL' 'MAA']
# 2021-07-30 00:00:00
# 22689.239303873816
# ['MRNA' 'GNRC' 'HCA' 'CPT' 'WELL']
# 2021-08-02 00:00:00
# 22830.6874255391
# ['MRNA' 'GNRC' 'TGT' 'HCA' 'FTNT']
# 2021-08-03 00:00:00
# 22661.570081438305
# ['MRNA' 'DFS' 'COF' 'GNRC' 'TRGP']
# 2021-08-04 00:00:00
# 23116.512648304204
# ['MRNA' 'DFS' 'COF' 'SIVB' 'GNRC']
# 2021-08-05 00:00:00
# 23613.89290103472
# ['BBWI' 'COF' 'DFS' 'SIVB' 'GNRC']
# 2021-08-06 00:00:00
# 24048.153557760066
# ['BBWI' 'COF' 'SIVB' 'GNRC' 'STLD']
# 2021-08-09 00:00:00
# 24067.374579616957
# ['BBWI' 'ENPH' 'GNRC' 'COF' 'NUE']
# 2021-08-10 00:00:00
# 24564.138054571216
# ['BBWI' 'ENPH' 'NUE' 'STLD' 'CBRE']
# 2021-08-11 00:00:00
# 25724.482653550185
# ['BBWI' 'FCX' 'ENPH' 'TSLA' 'ALGN']
# 2021-08-12 00:00:00
# 25457.56128951439
# ['BBWI' 'TPR' 'FCX' 'ENPH' 'FTNT']
# 2021-08-13 00:00:00
# 25548.31464312784
# ['MRNA' 'BBWI' 'TPR' 'ENPH' 'FTNT']
# 2021-08-16 00:00:00
# 24934.62714653558
# ['MRNA' 'TPR' 'BBWI' 'FTNT' 'IT']
# 2021-08-17 00:00:00
# 24511.59462347256
# ['MRNA' 'TPR' 'BBWI' 'ALB' 'IT']
# 2021-08-18 00:00:00
# 24730.50032374815
# ['MRNA' 'BBWI' 'IT' 'SBNY' 'ALB']
# 2021-08-19 00:00:00
# 24475.936361358436
# ['MRNA' 'COF' 'DFS' 'SBNY' 'BBWI']
# 2021-08-20 00:00:00
# 24293.90384565517
# ['MRNA' 'COF' 'NUE' 'DFS' 'DVN']
# 2021-08-23 00:00:00
# 24980.092850210385
# ['MRNA' 'NUE' 'COF' 'DFS' 'ALB']
# 2021-08-24 00:00:00
# 25516.11219156056
# ['MRNA' 'NUE' 'COF' 'SBNY' 'ALB']
# 2021-08-25 00:00:00
# ...
# 2022-02-18 00:00:00
# 23615.354866238522
# ['TRGP' 'NUE' 'MRO' 'FANG' 'COP']
# 2022-02-22 00:00:00
# 24552.032360905723
# ['NUE' 'TRGP' 'MRO' 'COP' 'AZO']
# 2022-02-23 00:00:00
# 23624.05181165535
# ['NUE' 'MRO' 'TRGP' 'ANET' 'COP']
# 2022-02-24 00:00:00
# 22988.943071051785
# ['TRGP' 'NUE' 'MRO' 'FANG' 'COP']
# 2022-02-25 00:00:00
# 23075.087439503593
# ['DVN' 'NUE' 'TRGP' 'MRO' 'FANG']
# 2022-02-28 00:00:00
# 23769.001431573855
# ['DVN' 'NUE' 'TRGP' 'MRO' 'FANG']
# 2022-03-01 00:00:00
# 25024.59288088328
# ['ANET' 'MCK' 'AZO' 'RHI' 'SBNY']
# 2022-03-02 00:00:00
# 24193.26451383753
# ['ANET' 'ON' 'MCK' 'SEE' 'RHI']
# 2022-03-03 00:00:00
# 24744.174780573427
# ['ANET' 'ON' 'MCK' 'RHI' 'SBNY']
# 2022-03-04 00:00:00
# 24041.571684603445
# ['ANET' 'RHI' 'SEE' 'SBNY' 'MOH']
# 2022-03-07 00:00:00
# 23946.859257495722
# ['SEE' 'HSIC' 'SLB' 'LYV' 'WFC']
# 2022-03-08 00:00:00
# 23285.350787774776
# ['ABBV' 'HSIC' 'PEP']
# 2022-03-09 00:00:00
# 23071.965671756232
# ['NUE' 'FANG' 'ABBV' 'HES' 'JNPR']
# 2022-03-10 00:00:00
# 23234.433020389748
# ['DVN' 'NUE' 'ANET' 'COST' 'FANG']
# 2022-03-11 00:00:00
# 23433.85846005956
# ['DVN' 'TRGP' 'NUE' 'APA' 'COP']
# 2022-03-14 00:00:00
# 23052.417730057467
# ['DVN' 'TRGP' 'MRO' 'NUE' 'APA']
# 2022-03-15 00:00:00
# 21444.893213870477
# ['DVN' 'TRGP' 'OXY' 'MRO' 'CF']
# 2022-03-16 00:00:00
# 22035.928571793516
# ['DVN' 'OXY' 'MRO' 'TRGP' 'CF']
# 2022-03-17 00:00:00
# 22314.540946997964
# ['DVN' 'TRGP' 'MRO' 'NUE' 'APA']
# 2022-03-18 00:00:00
# 23010.293919731463
# ['DVN' 'MRO' 'TRGP' 'OXY' 'APA']
# 2022-03-21 00:00:00
# 23594.989914635833
# ['DVN' 'MRO' 'TRGP' 'APA' 'CF']
# 2022-03-22 00:00:00
# 24221.67805734877
# ['CF' 'OXY' 'APA' 'HAL' 'BKR']
# 2022-03-23 00:00:00
# 24648.87651607116
# ['OXY' 'CF' 'HAL' 'BKR' 'CVX']
# 2022-03-24 00:00:00
# 24679.65255329687
# ['OXY' 'HAL' 'BKR' 'CVX' 'KR']
# 2022-03-25 00:00:00
# 24495.368068019685
# ['OXY' 'BKR' 'PWR' 'CVX' 'LLY']
# 2022-03-28 00:00:00
# 24563.48589496085
# ['COST' 'LLY' 'ABBV' 'KR' 'SEE']
# 2022-03-29 00:00:00
# 24810.147314978873
# ['COST' 'KR' 'MCK' 'LLY' 'SEE']
# 2022-03-30 00:00:00
# 24738.185199440337
# ['OXY' 'STLD' 'IT' 'COST' 'MCK']
# 2022-03-31 00:00:00
# 24548.381156023093
# ['DVN' 'APA' 'MRO' 'OXY' 'CF']
# 2022-04-01 00:00:00
# 24606.25821276732
# ['DVN' 'APA' 'CF' 'MRO' 'OXY']
# 2022-04-04 00:00:00
# 25316.320244851533
# ['DVN' 'TRGP' 'MRO' 'APA' 'OXY']
# 2022-04-05 00:00:00
# 25251.1985040929
# ['DVN' 'APA' 'TRGP' 'MRO' 'OXY']
# 2022-04-06 00:00:00
# 24659.293436134565
# ['DVN' 'TRGP' 'APA' 'MRO' 'OXY']
# 2022-04-07 00:00:00
# 24511.634312498758
# ['DVN' 'TRGP' 'APA' 'OXY' 'MRO']
# 2022-04-08 00:00:00
# 24683.46434090536
# ['DVN' 'TRGP' 'OXY' 'APA' 'CF']
# 2022-04-11 00:00:00
# 25228.663353327633
# ['APA' 'TRGP' 'MRO' 'EQT' 'NUE']
# 2022-04-12 00:00:00
# 25501.463723763307
# ['MRO' 'APA' 'TRGP' 'EQT' 'NUE']
# 2022-04-13 00:00:00
# 26130.137958768108
# ['MRO' 'APA' 'TRGP' 'PXD' 'ANET']
# 2022-04-14 00:00:00
# 26247.921495083545
# ['APA' 'TRGP' 'ANET' 'FTNT' 'MPC']
# 2022-04-18 00:00:00
# 26047.18662351001
# ['TRGP' 'MPC' 'FTNT' 'COST' 'LLY']
# 2022-04-19 00:00:00
# 26021.37434723963
# ['FTNT' 'LLY' 'COST' 'KR' 'EXC']
# 2022-04-20 00:00:00
# 26360.959516743278
# ['CF' 'FTNT' 'MCK' 'ANET' 'ADM']
# 2022-04-21 00:00:00
# 26861.290245679767
# ['CF' 'MOS' 'EOG' 'BKR' 'MCK']
# 2022-04-22 00:00:00
# 25280.782287647406
# ['OXY' 'CF' 'HAL' 'MOS' 'FANG']
# 2022-04-25 00:00:00
# 23611.636565153727
# ['DVN' 'MRO' 'OXY' 'TRGP' 'APA']
# 2022-04-26 00:00:00
# 23849.203943635737
# ['DVN' 'TRGP' 'OXY' 'MRO' 'EQT']
# 2022-04-27 00:00:00
# 23636.821587871866
# ['DVN' 'TRGP' 'OXY' 'MRO' 'EQT']
# 2022-04-28 00:00:00
# 24066.5849975847
# ['DVN' 'OXY' 'MRO' 'TRGP' 'EQT']
# 2022-04-29 00:00:00
# 24663.999131553574
# ['DVN' 'MRO' 'OXY' 'TRGP' 'EQT']
# 2022-05-02 00:00:00
# 23711.768980550623
# ['DVN' 'MRO' 'OXY' 'TRGP' 'APA']
# 2022-05-03 00:00:00
# 24433.267172534077
# ['DVN' 'OXY' 'MRO' 'TRGP' 'EQT']
# 2022-05-04 00:00:00
# 26013.004537119272
# ['EQT' 'TRGP' 'MCK' 'NUE' 'EXC']
# 2022-05-05 00:00:00
# 26237.210129482377
# ['MCK' 'NUE' 'EXC' 'KR' 'DLTR']
# 2022-05-06 00:00:00
# 25363.232530660436
# ['EXC' 'DLTR' 'NUE' 'COST' 'IRM']
# 2022-05-09 00:00:00
# 24967.29618844949
# ['EXC' 'DLTR' 'NUE' 'AZO' 'ULTA']
# 2022-05-10 00:00:00
# 25071.149190615684
# ['TRGP' 'EQT' 'DLTR' 'NUE' 'STLD']
# 2022-05-11 00:00:00
# 24961.31991437258
# ['MRO' 'APA' 'EQT' 'TRGP' 'CF']
# 2022-05-12 00:00:00
# 24848.57002011482
# ['MRO' 'TRGP' 'APA' 'EQT' 'CF']
# 2022-05-13 00:00:00
# 25800.181349827704
# ['DVN' 'OXY' 'MRO' 'CF' 'TRGP']
# 2022-05-16 00:00:00
# 26997.341484215238
# ['DVN' 'OXY' 'MRO' 'APA' 'TRGP']
# 2022-05-17 00:00:00
# 28198.76725042455
# ['DVN' 'MRO' 'APA' 'COP' 'TRGP']
# 2022-05-18 00:00:00
# 28378.805267111296
# ['DVN' 'COP' 'CTRA' 'FANG' 'VLO']
# 2022-05-19 00:00:00
# 26830.665833268977
# ['CTRA' 'FANG' 'VLO' 'MCK' 'EOG']
# 2022-05-20 00:00:00
# 27509.183761277534
# ['FANG' 'MCK' 'VLO' 'EOG' 'ALB']
# 2022-05-23 00:00:00
# 27653.5897613653
# ['MCK' 'ABBV' 'ABC']
# 2022-05-24 00:00:00
# 27456.425335883556
# ['CF' 'MCK' 'ABC' 'ABBV' 'HSY']
# 2022-05-25 00:00:00
# 27574.200514248405
# ['DVN' 'OXY' 'CF' 'MCK' 'MOS']
# 2022-05-26 00:00:00
# 28212.952879389155
# ['DVN' 'OXY' 'CF' 'PXD' 'CVX']
# 2022-05-27 00:00:00
# 28086.5932231526
# ['DVN' 'OXY' 'TRGP' 'CF' 'PXD']
# 2022-05-31 00:00:00
# 29430.7654240426
# ['DVN' 'OXY' 'TRGP' 'CF' 'PXD']
# 2022-06-01 00:00:00
# 28994.072752164182
# ['CF' 'MOS' 'PXD' 'BKR' 'NRG']
# 2022-06-02 00:00:00
# 28500.716070038023
# ['CF' 'PXD' 'NRG' 'REGN' 'MRK']
# 2022-06-03 00:00:00
# 28296.899276946573
# ['CF' 'MCK' 'PXD' 'ALB' 'CTVA']
# 2022-06-06 00:00:00
# 28582.193952673115
# ['EQT' 'PXD' 'MCK' 'CVX' 'XOM']
# 2022-06-07 00:00:00
# 28521.238048258823
# ['OXY' 'EQT' 'APA' 'CTRA' 'COP']
# 2022-06-08 00:00:00
# 29619.66370999544
# ['OXY' 'MRO' 'APA' 'EQT' 'CTRA']
# 2022-06-09 00:00:00
# 28807.467397510918
# ['DVN' 'OXY' 'MRO' 'EQT' 'CTRA']
# 2022-06-10 00:00:00
# 27966.85583810867
# ['DVN' 'MRO' 'OXY' 'EQT' 'CTRA']
# 2022-06-13 00:00:00
# 26700.775587094984
# ['DVN' 'EQT' 'MRO' 'OXY' 'APA']
# 2022-06-14 00:00:00
# 26767.167532305593
# ['DVN' 'EQT' 'MRO' 'APA' 'CTRA']
# 2022-06-15 00:00:00
# 25706.40403471981
# ['DVN' 'MRO' 'OXY' 'APA' 'EQT']
# 2022-06-16 00:00:00
# 24582.380308643602
# ['DVN' 'MRO' 'APA' 'OXY' 'EQT']
# 2022-06-17 00:00:00
# 23327.774531041825
# ['DVN' 'OXY' 'MRO' 'EQT' 'APA']
# 2022-06-21 00:00:00
# 22689.03610697638
# ['OXY' 'MRO' 'APA' 'EQT' 'MCK']
# 2022-06-22 00:00:00
# 21624.11250284039
# ['OXY' 'APA' 'MRO' 'EQT' 'MCK']
# 2022-06-23 00:00:00
# 22106.311751133377
# ['OXY' 'EQT' 'CTRA' 'DLTR' 'MPC']
# 2022-06-24 00:00:00
# 21472.510830386564
# ['OXY' 'CTRA' 'EQT' 'AZO' 'MPC']
# 2022-06-27 00:00:00
# 22070.84525948411
# ['EQT' 'MPC' 'XOM' 'VLO']
# 2022-06-28 00:00:00
# 23059.410663897877
# ['MPC' 'VLO' 'XOM' 'HES']
# 2022-06-29 00:00:00
# 23612.006485878108
# ['HES']
# 2022-06-30 00:00:00
# 21972.026350665048
# ['spy']
# 2022-07-01 00:00:00
# 21990.714447471983
# ['spy']
# 2022-07-05 00:00:00
# 21951.0035784035
# ['VRTX' 'HSY']
# 2022-07-06 00:00:00
# 22052.685138077748
# ['VRTX' 'AZO' 'ABBV' 'HSY' 'UNH']
# 2022-07-07 00:00:00
# 22102.457401651984
# ['MCK' 'VRTX' 'AZO' 'LLY' 'ABBV']
# 2022-07-08 00:00:00
# 22157.468794898457
# ['MCK' 'VRTX' 'LLY' 'AZO' 'WRB']
# 2022-07-11 00:00:00
# 22343.063783489768
# ['MCK' 'VRTX' 'LLY' 'AZO' 'PFE']
# 2022-07-12 00:00:00
# 22223.559306558833
# ['OXY' 'MCK' 'LLY' 'XOM' 'AZO']
# 2022-07-13 00:00:00
# 21987.439617982833
# ['OXY' 'MCK' 'XOM' 'LLY' 'AZO']
# 2022-07-14 00:00:00
# 21710.5835935511
# ['OXY' 'MCK' 'VRTX' 'LLY' 'AZO']
# 2022-07-15 00:00:00
# 22305.274426048753
# ['OXY' 'MCK' 'PWR' 'VRTX' 'LLY']
# 2022-07-18 00:00:00
# 22499.563393238263
# ['OXY' 'MCK' 'DLTR' 'PWR' 'VRTX']
# 2022-07-19 00:00:00
# 22434.738599649165
# ['OXY' 'DLTR' 'VRTX' 'PWR' 'LLY']
# 2022-07-20 00:00:00
# 22659.586581815376
# ['DLTR' 'VRTX' 'PWR' 'LLY' 'GIS']
# 2022-07-21 00:00:00
# 22522.91586874605
# ['DLTR' 'MCK' 'PWR' 'VRTX' 'LLY']
# 2022-07-22 00:00:00
# 22724.985640006224
# ['MCK' 'PWR' 'VRTX' 'LLY' 'AZO']
# 2022-07-25 00:00:00
# 22695.67744981244
# ['MCK' 'VRTX' 'LLY' 'AZO' 'NOC']
# 2022-07-26 00:00:00
# 22786.779890477574
# ['DLTR' 'VRTX' 'AZO' 'GIS' 'ED']
# 2022-07-27 00:00:00
# 22764.082646635045
# ['DLTR' 'VRTX' 'AZO' 'GIS']
# 2022-07-28 00:00:00
# 22914.71524086488
# ['DLTR' 'ON' 'VRTX' 'AZO' 'COST']
# 2022-07-29 00:00:00
# 23006.105320710863
# ['OXY' 'ON' 'DLTR' 'VRTX' 'CNC']
# 2022-08-01 00:00:00
# 23293.663032191398
# ['OXY' 'EQT' 'DLTR' 'VRTX' 'CNC']
# 2022-08-02 00:00:00
# 23136.58856428288
# ['OXY' 'EQT' 'DLTR' 'MPC' 'VRTX']
# 2022-08-03 00:00:00
# 23239.57934064415
# ['OXY' 'EQT' 'CTRA' 'MPC' 'DLTR']
# 2022-08-04 00:00:00
# 22709.39344235062
# ['EQT' 'OXY' 'CTRA' 'DLTR' 'MCK']
# 2022-08-05 00:00:00
# 21931.66420125651
# ['EQT' 'MCK' 'XOM' 'PWR' 'CNC']
# 2022-08-08 00:00:00
# 22525.392135667433
# ['EQT' 'CF' 'MCK' 'MPC' 'XOM']
# 2022-08-09 00:00:00
# 22729.401393070286
# ['OXY' 'EQT' 'CF' 'MCK' 'ENPH']
# 2022-08-10 00:00:00
# 23364.73496363939
# ['OXY' 'EQT' 'CF' 'VLO' 'ENPH']
# 2022-08-11 00:00:00
# 23860.764927260272
# ['OXY' 'EQT' 'CF' 'ENPH' 'VLO']
# 2022-08-12 00:00:00
# 23779.108487259844
# ['OXY' 'CF' 'CTRA' 'FANG' 'ENPH']
# 2022-08-15 00:00:00
# 23290.830858129262
# ['CF' 'CTRA' 'FANG' 'ENPH' 'ON']
# 2022-08-16 00:00:00
# 23876.51217993433
# ['CF' 'ENPH' 'ON' 'ANET' 'TSLA']
# 2022-08-17 00:00:00
# 23452.0018625054
# ['CF' 'ENPH' 'ON' 'ANET' 'GWW']
# 2022-08-18 00:00:00
# 23761.592540275386
# ['CF' 'ENPH' 'ON' 'CI' 'ANET']
# 2022-08-19 00:00:00
# 23689.99785599642
# ['CF' 'ENPH' 'VRTX' 'CTVA' 'CNC']
# 2022-08-22 00:00:00
# 23577.57137721014
# ['CF' 'MCK' 'ENPH' 'DLTR' 'VRTX']
# 2022-08-23 00:00:00
# 23685.758861747545
# ['CF' 'MCK' 'ENPH' 'DLTR' 'CNC']
# 2022-08-24 00:00:00
# 23706.235947631514
# ['EQT' 'CF' 'MCK' 'FANG' 'ENPH']
# 2022-08-25 00:00:00
# 24428.496948076732
# ['EQT' 'FANG' 'MCK' 'DLTR' 'ENPH']
# 2022-08-26 00:00:00
# 24430.533919203248
# ['EQT' 'MCK' 'ENPH' 'ON' 'ADM']
# 2022-08-29 00:00:00
# 23465.24066948303
# ['EQT' 'ENPH' 'ON' 'WMB' 'CTVA']
# 2022-08-30 00:00:00
# 23491.951744098147
# ['EQT' 'VLO' 'ENPH' 'ON' 'CNC']
# 2022-08-31 00:00:00
# 22876.924570547744
# ['DVN' 'EQT' 'CTRA' 'VLO' 'EOG']
# 2022-09-01 00:00:00
# 23121.784701296987
# ['OXY' 'EQT' 'DVN' 'CF' 'MRO']
# 2022-09-02 00:00:00
# 23545.11987334818
# ['OXY' 'DVN' 'EQT' 'CF' 'MRO']
# 2022-09-06 00:00:00
# 23583.041901492383
# ['OXY' 'DVN' 'EQT' 'CF' 'MRO']
# 2022-09-07 00:00:00
# 22405.06308155835
# ['OXY' 'DVN' 'CF' 'MRO' 'EQT']
# 2022-09-08 00:00:00
# 22903.818407765182
# ['OXY' 'DVN' 'EQT' 'CF' 'COP']
# 2022-09-09 00:00:00
# 23195.88908269019
# ['OXY' 'DVN' 'EQT' 'CF' 'COP']
# 2022-09-12 00:00:00
# 23540.201867918655
# ['OXY' 'EQT' 'DVN' 'CF' 'MRO']
# 2022-09-13 00:00:00
# 23328.336615824737
# ['OXY' 'DVN' 'MRO' 'CF' 'APA']
# 2022-09-14 00:00:00
# 23488.332073607446
# ['OXY' 'DVN' 'APA' 'VLO' 'MCK']
# 2022-09-15 00:00:00
# 23401.46197241021
# ['MCK' 'ADM' 'FSLR' 'GIS' 'CAH']
# 2022-09-16 00:00:00
# 23136.186706385546
# ['MCK' 'CI' 'ADM' 'ED' 'GWW']
# 2022-09-19 00:00:00
# 22985.020255501
# ['DVN' 'CF' 'XOM' 'MCK' 'MPC']
# 2022-09-20 00:00:00
# 23606.49614090497
# ['DVN' 'CF' 'ENPH' 'XOM' 'MCK']
# 2022-09-21 00:00:00
# 23829.20193372207
# ['EQT' 'MRO' 'DVN' 'ENPH' 'MCK']
# 2022-09-22 00:00:00
# 23338.06169543792
# ['EQT' 'MRO' 'DVN' 'ENPH' 'COP']
# 2022-09-23 00:00:00
# 21489.335267789156
# ['EQT' 'ENPH' 'COP' 'VRTX' 'HES']
# 2022-09-26 00:00:00
# 20872.513748022982
# ['ENPH' 'VRTX' 'LLY' 'FSLR' 'CI']
# 2022-09-27 00:00:00
# 21026.764084020368
# ['ENPH' 'CI' 'FSLR' 'ON' 'NOC']
# 2022-09-28 00:00:00
# 20879.160294137073
# ['ENPH' 'FSLR' 'ON' 'CI' 'PGR']
# 2022-09-29 00:00:00
# 21197.157738841885
# ['ENPH' 'CF' 'COP' 'ON' 'FSLR']
# 2022-09-30 00:00:00
# 20692.30980701886
# ['ENPH' 'CF' 'COP' 'CI' 'ON']
# 2022-10-03 00:00:00
# 21145.842938176065
# ['ENPH' 'COP' 'FSLR' 'CI' 'ON']
# 2022-10-04 00:00:00
# 22244.477056184274
# ['PCG' 'NOC' 'HSY' 'HUM' 'GIS']
# 2022-10-05 00:00:00
# 22400.512004902936
# ['LW' 'HSY' 'GIS']
# 2022-10-06 00:00:00
# 22375.036945430977
# ['GIS']
# 2022-10-07 00:00:00
# 21814.135148688325
# ['GIS']
# 2022-10-10 00:00:00
# 22011.758637107363
# ['ENPH' 'LLY' 'FSLR' 'GIS']
# 2022-10-11 00:00:00
# 22002.625800051494
# ['VRTX' 'ENPH' 'LLY' 'HSY' 'FSLR']
# 2022-10-12 00:00:00
# 22297.526156751373
# ['VRTX' 'MPC' 'ENPH' 'LLY' 'HSY']
# 2022-10-13 00:00:00
# 21647.04023656688
# ['OXY' 'VRTX' 'MPC' 'ENPH' 'CAH']
# 2022-10-14 00:00:00
# 22651.989785995003
# ['OXY' 'DVN' 'MPC' 'VRTX' 'VLO']
# 2022-10-17 00:00:00
# 22335.079072957742
# ['OXY' 'MCK' 'DVN' 'MRO' 'VRTX']
# 2022-10-18 00:00:00
# 22480.380366374815
# ['OXY' 'MCK' 'DVN' 'MRO' 'CF']
# 2022-10-19 00:00:00
# 22404.37302137876
# ['OXY' 'DVN' 'MRO' 'CF' 'VRTX']
# 2022-10-20 00:00:00
# 22911.016353975912
# ['OXY' 'DVN' 'MRO' 'CF' 'XOM']
# 2022-10-21 00:00:00
# 22988.97794750299
# ['DVN' 'CF' 'MRO' 'XOM' 'COP']
# 2022-10-24 00:00:00
# 23460.884114402015
# ['MRO' 'APA' 'LW' 'CTRA' 'WRB']
# 2022-10-25 00:00:00
# 23473.96456632815
# ['LW' 'CTRA' 'WRB' 'AMGN' 'GIS']
# 2022-10-26 00:00:00
# 23744.786267433017
# ['LW' 'CTRA' 'PSX' 'FMC' 'WRB']
# 2022-10-27 00:00:00
# 23956.026284350475
# ['LW' 'CTRA' 'PSX' 'WRB' 'AMGN']
# 2022-10-28 00:00:00
# 24106.321581176875
# ['LW' 'WRB' 'CPB' 'GL' 'TRGP']
# 2022-10-31 00:00:00
# 24252.877732569792
# ['VLO' 'LW' 'WRB' 'GL' 'TRGP']
# 2022-11-01 00:00:00
# 24810.036051380906
# ['MPC' 'VLO' 'SLB' 'EOG' 'CTRA']
# 2022-11-02 00:00:00
# 24786.743647999137
# ['MPC' 'CF' 'DVN' 'COP' 'VLO']
# 2022-11-03 00:00:00
# 23599.451564839823
# ['OXY' 'MRO' 'CF' 'MCK' 'COP']
# 2022-11-04 00:00:00
# 25203.796559233433
# ['OXY' 'MRO' 'MCK' 'CF' 'COP']
# 2022-11-07 00:00:00
# 24877.51688162785
# ['OXY' 'MRO' 'MCK' 'XOM' 'HES']
# 2022-11-08 00:00:00
# 25133.596949120565
# ['OXY' 'MCK' 'HES' 'XOM' 'VLO']
# 2022-11-09 00:00:00
# 24781.105282070712
# ['OXY' 'HES' 'MCK' 'XOM' 'CF']
# 2022-11-10 00:00:00
# 24279.323904907164
# ['OXY' 'MRO' 'MPC' 'COP' 'MCK']
# 2022-11-11 00:00:00
# 24437.472216364553
# ['OXY' 'MRO' 'MPC' 'COP' 'XOM']
# 2022-11-14 00:00:00
# 24702.960358269313
# ['OXY' 'MRO' 'COP' 'MPC' 'XOM']
# 2022-11-15 00:00:00
# 24772.353200793506
# ['OXY' 'MRO' 'MPC' 'COP' 'HES']
# 2022-11-16 00:00:00
# 24615.617144986798
# ['MRO' 'MPC' 'HES' 'COP' 'XOM']
# 2022-11-17 00:00:00
# 23979.803596530983
# ['MRO' 'MPC' 'HES' 'COP' 'XOM']
# 2022-11-18 00:00:00
# 23874.038671248272
# ['OXY' 'MRO' 'MPC' 'HES' 'COP']
# 2022-11-21 00:00:00
# 23618.355783974625
# ['OXY' 'MRO' 'MPC' 'HES' 'XOM']
# 2022-11-22 00:00:00
# 24168.53109086351
# ['OXY' 'MPC' 'VLO' 'MRO' 'XOM']
# 2022-11-23 00:00:00
# 24345.044525494042
# ['EQT' 'VLO' 'MRO' 'COP' 'SLB']
# 2022-11-25 00:00:00
# 24131.32463500301
# ['EQT' 'VLO' 'MRO' 'APA' 'COP']
# 2022-11-28 00:00:00
# 23131.705686550293
# ['OXY' 'VLO' 'MRO' 'HES' 'XOM']
# 2022-11-29 00:00:00
# 23422.759891850208
# ['OXY' 'VLO' 'MRO' 'HES' 'XOM']
# 2022-11-30 00:00:00
# 23793.335792078815
# ['OXY' 'VLO' 'MRO' 'HES' 'XOM']
# 2022-12-01 00:00:00
# 23752.981591924876
# ['OXY' 'MPC' 'VLO' 'HES' 'XOM']
# 2022-12-02 00:00:00
# 23197.34570192748
# ['OXY' 'MPC' 'VLO' 'HES' 'XOM']
# 2022-12-05 00:00:00
# 23260.678635399323
# ['OXY' 'MPC' 'STLD' 'VLO' 'XOM']
# 2022-12-06 00:00:00
# 22138.292312693316
# ['OXY' 'MPC' 'MRO' 'CF' 'STLD']
# 2022-12-07 00:00:00
# 21812.180922316664
# ['STLD' 'MPC' 'MRO' 'CF' 'HES']
# 2022-12-08 00:00:00
# 22210.535336838348
# ['MPC' 'CF' 'HES' 'VLO' 'MRO']
# 2022-12-09 00:00:00
# 21441.09974769369
# ['MPC' 'CAH' 'XOM' 'MCK' 'CF']
# 2022-12-12 00:00:00
# 21094.387529167157
# ['MPC' 'XOM' 'MCK' 'CAH' 'SLB']
# 2022-12-13 00:00:00
# 21911.18921249748
# ['MRO' 'MPC' 'VLO' 'HES' 'APA']
# 2022-12-14 00:00:00
# 21934.905150895283
# ['STLD' 'MRO' 'APA' 'HES' 'MPC']
# 2022-12-15 00:00:00
# 21316.71143292029
# ['HES' 'FSLR' 'ENPH' 'STLD' 'SLB']
# 2022-12-16 00:00:00
# 20689.52212958011
# ['ENPH' 'STLD' 'CAH' 'MCK' 'CI']
# 2022-12-19 00:00:00
# 20913.15419575291
# ['STLD' 'ENPH' 'CAH' 'MCK' 'CI']
# 2022-12-20 00:00:00
# 20886.979445166056
# ['STLD' 'ENPH' 'CAH' 'MCK' 'CI']
# 2022-12-21 00:00:00
# 21048.258141245842
# ['STLD' 'ENPH' 'MCK' 'CAH' 'CI']
# 2022-12-22 00:00:00
# 21256.38273554539
# ['STLD' 'ENPH' 'CI' 'MRK' 'CPB']
# 2022-12-23 00:00:00
# 21085.139000593528
# ['STLD' 'ENPH' 'CI' 'CPB' 'PCG']
# 2022-12-27 00:00:00
# 21030.561090702322
# ['STLD' 'ENPH' 'CI' 'PCG' 'CPB']
# 2022-12-28 00:00:00
# 20835.743721561208
# ['FSLR' 'STLD' 'PCG' 'CPB' 'LVS']
# 2022-12-29 00:00:00
# 20454.63945156612
# ['FSLR' 'CAH' 'PCG' 'CPB' 'LVS']
# 2022-12-30 00:00:00
# 20301.628546200256
# ['FSLR' 'MRO' 'CAH' 'CPB' 'LVS']
# 2023-01-03 00:00:00
# 20610.048233546237
# ['FSLR' 'MRO' 'STLD' 'MCK' 'CAH']
# 2023-01-04 00:00:00
# 20137.126887448994
# ['FSLR' 'HES' 'MPC' 'SLB' 'MCK']
# 2023-01-05 00:00:00
# 20418.119202535123
# ['FSLR' 'HES' 'MPC' 'XOM' 'SLB']
# 2023-01-06 00:00:00
# 21228.7088047803
# ['FSLR' 'HES' 'MPC' 'XOM' 'VLO']
# 2023-01-09 00:00:00
# 21804.41298179197
# ['HES' 'MPC' 'XOM' 'VLO' 'SLB']
# 2023-01-10 00:00:00
# 21575.28069696377
# ['HES' 'MPC' 'VLO' 'XOM' 'HAL']
# 2023-01-11 00:00:00
# 21945.83681108426
# ['MPC' 'XOM' 'COP' 'CVX' 'ACGL']
# 2023-01-12 00:00:00
# 21897.732385022726
# ['LLY' 'CVX' 'MRK' 'ACGL' 'APA']
# 2023-01-13 00:00:00
# 22056.105495943753
# ['LLY' 'CVX' 'MRK' 'ACGL' 'CI']

# %%
spy_select = spy[spy.Date>'2019-01-23']
spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100
result['benchmark-spy(%)'] =  spy_select.set_index('Date')['benchmark-spy(%)']
# Out:
# C:\Users\CHIN\AppData\Local\Temp/ipykernel_20500/3295031919.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100

# %%
# plot the return and calculate the annualized return and MDD (maximum draw down) for both strategy
plt.rcParams["figure.figsize"] = (15,6)
plt.plot(result.Return_without_trailing, label='Return without Annualized_return of Portfolio based on EMA and SMA cross-over strategy')
plt.plot(result['benchmark-spy(%)'], label='benchmark-spy(%)')
plt.legend()
print('Annualized_return of Portfolio based on EMA and SMA cross-over strategy:',annualized (result,'Return_without_trailing'))
print('MDD of Portfolio based on EMA AND SMA cross-over strategy:', MDD(result,'Return_without_trailing'))

print('Annualized_return of benchmark-spy:',annualized (result,'benchmark-spy(%)'))
print('MDD of benchmark-spy:', MDD(result,'benchmark-spy(%)'))
# Out:
# Annualized_return of Portfolio based on EMA and SMA cross-over strategy: 33.39444596303587
# MDD of Portfolio based on EMA AND SMA cross-over strategy: -44.97218167603761
# Annualized_return of benchmark-spy: 16.25470077850062
# MDD of benchmark-spy: -34.104746893243956

# %%
result, hold_detail= backtest_strategy_portfolio(signal_etf_stock[signal_etf_stock.Date>'2022-01-23'],10000)
# Out:
# 2022-01-24 00:00:00
# 10000.0
# ['DVN' 'MRO' 'TRGP' 'SBNY' 'COP']
# 2022-01-25 00:00:00
# 10294.63000175819
# ['DVN' 'MRO' 'FANG' 'APA' 'TRGP']
# 2022-01-26 00:00:00
# 11158.717998175276
# ['DVN' 'MRO' 'APA' 'COP' 'FANG']
# 2022-01-27 00:00:00
# 11291.608726847433
# ['DVN' 'MRO' 'APA' 'FANG' 'COP']
# 2022-01-28 00:00:00
# 11135.29839468683
# ['MRO' 'FANG' 'COP' 'APA' 'EOG']
# 2022-01-31 00:00:00
# 11134.960109391286
# ['MRO' 'FANG' 'COP' 'EOG' 'APA']
# 2022-02-01 00:00:00
# 10979.773160075383
# ['COP' 'F' 'PXD' 'SBNY' 'WFC']
# 2022-02-02 00:00:00
# 11280.866047354351
# ['SBNY' 'CVX' 'ELV' 'LYV' 'AIG']
# 2022-02-03 00:00:00
# 11331.524838648167
# ['HSY' 'JBHT' 'KR' 'WELL' 'PG']
# 2022-02-04 00:00:00
# 11365.331469325538
# ['HAL' 'SLB' 'NOC']
# 2022-02-07 00:00:00
# 11287.347237196576
# ['HAL' 'CVX' 'SLB' 'SEE' 'TSN']
# 2022-02-08 00:00:00
# 11523.240020554716
# ['DVN' 'COP' 'APA' 'EOG' 'FANG']
# 2022-02-09 00:00:00
# 11279.34929819842
# ['DVN' 'COP' 'APA' 'EOG' 'FANG']
# 2022-02-10 00:00:00
# 11426.583477358085
# ['DVN' 'COP' 'APA' 'FANG' 'EOG']
# 2022-02-11 00:00:00
# 11577.27064326197
# ['DVN' 'MRO' 'TRGP' 'FANG' 'COP']
# 2022-02-14 00:00:00
# 11781.235157539566
# ['DVN' 'MRO' 'TRGP' 'FANG' 'COP']
# 2022-02-15 00:00:00
# 11143.336597408406
# ['DVN' 'MRO' 'TRGP' 'NUE' 'FANG']
# 2022-02-16 00:00:00
# 11413.901063835
# ['DVN' 'MRO' 'NUE' 'TRGP' 'FANG']
# 2022-02-17 00:00:00
# 11582.363815320488
# ['DVN' 'TRGP' 'MRO' 'NUE' 'FANG']
# 2022-02-18 00:00:00
# 11547.06559744649
# ['TRGP' 'NUE' 'MRO' 'FANG' 'COP']
# 2022-02-22 00:00:00
# 12005.067458347461
# ['NUE' 'TRGP' 'MRO' 'COP' 'AZO']
# 2022-02-23 00:00:00
# 11551.318093324464
# ['NUE' 'MRO' 'TRGP' 'ANET' 'COP']
# 2022-02-24 00:00:00
# 11240.77258889313
# ['TRGP' 'NUE' 'MRO' 'FANG' 'COP']
# 2022-02-25 00:00:00
# 11282.8941102083
# ['DVN' 'NUE' 'TRGP' 'MRO' 'FANG']
# 2022-02-28 00:00:00
# 11622.19328359809
# ['DVN' 'NUE' 'TRGP' 'MRO' 'FANG']
# 2022-03-01 00:00:00
# 12236.132684927872
# ['ANET' 'MCK' 'AZO' 'RHI' 'SBNY']
# 2022-03-02 00:00:00
# 11829.642787076747
# ['ANET' 'ON' 'MCK' 'SEE' 'RHI']
# 2022-03-03 00:00:00
# 12099.018243187324
# ['ANET' 'ON' 'MCK' 'RHI' 'SBNY']
# 2022-03-04 00:00:00
# 11755.470408141533
# ['ANET' 'RHI' 'SEE' 'SBNY' 'MOH']
# 2022-03-07 00:00:00
# 11709.159411973958
# ['SEE' 'HSIC' 'SLB' 'LYV' 'WFC']
# 2022-03-08 00:00:00
# 11385.705382322492
# ['ABBV' 'HSIC' 'PEP']
# 2022-03-09 00:00:00
# 11281.367677208966
# ['NUE' 'FANG' 'ABBV' 'HES' 'JNPR']
# 2022-03-10 00:00:00
# 11360.808411542219
# ['DVN' 'NUE' 'ANET' 'COST' 'FANG']
# 2022-03-11 00:00:00
# 11458.320333201253
# ['DVN' 'TRGP' 'NUE' 'APA' 'COP']
# 2022-03-14 00:00:00
# 11271.809431467187
# ['DVN' 'TRGP' 'MRO' 'NUE' 'APA']
# 2022-03-15 00:00:00
# 10485.787322417626
# ['DVN' 'TRGP' 'OXY' 'MRO' 'CF']
# 2022-03-16 00:00:00
# 10774.782515884079
# ['DVN' 'OXY' 'MRO' 'TRGP' 'CF']
# 2022-03-17 00:00:00
# 10911.01402250207
# ['DVN' 'TRGP' 'MRO' 'NUE' 'APA']
# 2022-03-18 00:00:00
# 11251.212391795165
# ['DVN' 'MRO' 'TRGP' 'OXY' 'APA']
# 2022-03-21 00:00:00
# 11537.107863024237
# ['DVN' 'MRO' 'TRGP' 'APA' 'CF']
# 2022-03-22 00:00:00
# 11843.535995653892
# ['CF' 'OXY' 'APA' 'HAL' 'BKR']
# 2022-03-23 00:00:00
# 12052.42079344483
# ['OXY' 'CF' 'HAL' 'BKR' 'CVX']
# 2022-03-24 00:00:00
# 12067.469177120944
# ['OXY' 'HAL' 'BKR' 'CVX' 'KR']
# 2022-03-25 00:00:00
# 11977.360641715044
# ['OXY' 'BKR' 'PWR' 'CVX' 'LLY']
# 2022-03-28 00:00:00
# 12010.667827675212
# ['COST' 'LLY' 'ABBV' 'KR' 'SEE']
# 2022-03-29 00:00:00
# 12131.276457672098
# ['COST' 'KR' 'MCK' 'LLY' 'SEE']
# 2022-03-30 00:00:00
# 12096.089551806777
# ['OXY' 'STLD' 'IT' 'COST' 'MCK']
# 2022-03-31 00:00:00
# 12003.282149486824
# ['DVN' 'APA' 'MRO' 'OXY' 'CF']
# 2022-04-01 00:00:00
# 12031.581964357196
# ['DVN' 'APA' 'CF' 'MRO' 'OXY']
# 2022-04-04 00:00:00
# 12378.776952921791
# ['DVN' 'TRGP' 'MRO' 'APA' 'OXY']
# 2022-04-05 00:00:00
# 12346.934746161864
# ['DVN' 'APA' 'TRGP' 'MRO' 'OXY']
# 2022-04-06 00:00:00
# 12057.51429553179
# ['DVN' 'TRGP' 'APA' 'MRO' 'OXY']
# 2022-04-07 00:00:00
# 11985.314254654075
# ['DVN' 'TRGP' 'APA' 'OXY' 'MRO']
# 2022-04-08 00:00:00
# 12069.33300520263
# ['DVN' 'TRGP' 'OXY' 'APA' 'CF']
# 2022-04-11 00:00:00
# 12335.915861812728
# ['APA' 'TRGP' 'MRO' 'EQT' 'NUE']
# 2022-04-12 00:00:00
# 12469.305505553879
# ['MRO' 'APA' 'TRGP' 'EQT' 'NUE']
# 2022-04-13 00:00:00
# 12776.704766422205
# ['MRO' 'APA' 'TRGP' 'PXD' 'ANET']
# 2022-04-14 00:00:00
# 12834.296711486639
# ['APA' 'TRGP' 'ANET' 'FTNT' 'MPC']
# 2022-04-18 00:00:00
# 12736.14452436586
# ['TRGP' 'MPC' 'FTNT' 'COST' 'LLY']
# 2022-04-19 00:00:00
# 12723.523242619225
# ['FTNT' 'LLY' 'COST' 'KR' 'EXC']
# 2022-04-20 00:00:00
# 12889.568269271971
# ['CF' 'FTNT' 'MCK' 'ANET' 'ADM']
# 2022-04-21 00:00:00
# 13134.212136796803
# ['CF' 'MOS' 'EOG' 'BKR' 'MCK']
# 2022-04-22 00:00:00
# 12361.400160349343
# ['OXY' 'CF' 'HAL' 'MOS' 'FANG']
# 2022-04-25 00:00:00
# 11545.247480937942
# ['DVN' 'MRO' 'OXY' 'TRGP' 'APA']
# 2022-04-26 00:00:00
# 11661.40944922862
# ['DVN' 'TRGP' 'OXY' 'MRO' 'EQT']
# 2022-04-27 00:00:00
# 11557.562058086864
# ['DVN' 'TRGP' 'OXY' 'MRO' 'EQT']
# 2022-04-28 00:00:00
# 11767.701025358154
# ['DVN' 'OXY' 'MRO' 'TRGP' 'EQT']
# 2022-04-29 00:00:00
# 12059.815212625457
# ['DVN' 'MRO' 'OXY' 'TRGP' 'EQT']
# 2022-05-02 00:00:00
# 11594.208657916555
# ['DVN' 'MRO' 'OXY' 'TRGP' 'APA']
# 2022-05-03 00:00:00
# 11946.995520466842
# ['DVN' 'OXY' 'MRO' 'TRGP' 'EQT']
# 2022-05-04 00:00:00
# 12719.430704224378
# ['EQT' 'TRGP' 'MCK' 'NUE' 'EXC']
# 2022-05-05 00:00:00
# 12829.059236041714
# ['MCK' 'NUE' 'EXC' 'KR' 'DLTR']
# 2022-05-06 00:00:00
# 12401.715386183947
# ['EXC' 'DLTR' 'NUE' 'COST' 'IRM']
# 2022-05-09 00:00:00
# 12208.116647489618
# ['EXC' 'DLTR' 'NUE' 'AZO' 'ULTA']
# 2022-05-10 00:00:00
# 12258.897058594905
# ['TRGP' 'EQT' 'DLTR' 'NUE' 'STLD']
# 2022-05-11 00:00:00
# 12205.194462784573
# ['MRO' 'APA' 'EQT' 'TRGP' 'CF']
# 2022-05-12 00:00:00
# 12150.063789014315
# ['MRO' 'TRGP' 'APA' 'EQT' 'CF']
# 2022-05-13 00:00:00
# 12615.36776220073
# ['DVN' 'OXY' 'MRO' 'CF' 'TRGP']
# 2022-05-16 00:00:00
# 13200.736336195085
# ['DVN' 'OXY' 'MRO' 'APA' 'TRGP']
# 2022-05-17 00:00:00
# 13788.190651891802
# ['DVN' 'MRO' 'APA' 'COP' 'TRGP']
# 2022-05-18 00:00:00
# 13876.222815731448
# ['DVN' 'COP' 'CTRA' 'FANG' 'VLO']
# 2022-05-19 00:00:00
# 13119.237892243053
# ['CTRA' 'FANG' 'VLO' 'MCK' 'EOG']
# 2022-05-20 00:00:00
# 13451.008939857475
# ['FANG' 'MCK' 'VLO' 'EOG' 'ALB']
# 2022-05-23 00:00:00
# 13521.618319437966
# ['MCK' 'ABBV' 'ABC']
# 2022-05-24 00:00:00
# 13425.211953011716
# ['CF' 'MCK' 'ABC' 'ABBV' 'HSY']
# 2022-05-25 00:00:00
# 13482.799811336647
# ['DVN' 'OXY' 'CF' 'MCK' 'MOS']
# 2022-05-26 00:00:00
# 13795.126918110254
# ['DVN' 'OXY' 'CF' 'PXD' 'CVX']
# 2022-05-27 00:00:00
# 13733.341556522475
# ['DVN' 'OXY' 'TRGP' 'CF' 'PXD']
# 2022-05-31 00:00:00
# 14390.593783552555
# ['DVN' 'OXY' 'TRGP' 'CF' 'PXD']
# 2022-06-01 00:00:00
# 14177.066654417044
# ['CF' 'MOS' 'PXD' 'BKR' 'NRG']
# 2022-06-02 00:00:00
# 13935.832846849165
# ['CF' 'PXD' 'NRG' 'REGN' 'MRK']
# 2022-06-03 00:00:00
# 13836.173710112973
# ['CF' 'MCK' 'PXD' 'ALB' 'CTVA']
# 2022-06-06 00:00:00
# 13975.672623166629
# ['EQT' 'PXD' 'MCK' 'CVX' 'XOM']
# 2022-06-07 00:00:00
# 13945.867361682722
# ['OXY' 'EQT' 'APA' 'CTRA' 'COP']
# 2022-06-08 00:00:00
# 14482.958302802737
# ['OXY' 'MRO' 'APA' 'EQT' 'CTRA']
# 2022-06-09 00:00:00
# 14085.823296727911
# ['DVN' 'OXY' 'MRO' 'EQT' 'CTRA']
# 2022-06-10 00:00:00
# 13674.794249170953
# ['DVN' 'MRO' 'OXY' 'EQT' 'CTRA']
# 2022-06-13 00:00:00
# 13055.726198197593
# ['DVN' 'EQT' 'MRO' 'OXY' 'APA']
# 2022-06-14 00:00:00
# 13088.189489595556
# ['DVN' 'EQT' 'MRO' 'APA' 'CTRA']
# 2022-06-15 00:00:00
# 12569.514002422968
# ['DVN' 'MRO' 'OXY' 'APA' 'EQT']
# 2022-06-16 00:00:00
# 12019.906521544342
# ['DVN' 'MRO' 'APA' 'OXY' 'EQT']
# 2022-06-17 00:00:00
# 11406.449078496797
# ['DVN' 'OXY' 'MRO' 'EQT' 'APA']
# 2022-06-21 00:00:00
# 11094.128788411394
# ['OXY' 'MRO' 'APA' 'EQT' 'MCK']
# 2022-06-22 00:00:00
# 10573.4191576276
# ['OXY' 'APA' 'MRO' 'EQT' 'MCK']
# 2022-06-23 00:00:00
# 10809.197378307177
# ['OXY' 'EQT' 'CTRA' 'DLTR' 'MPC']
# 2022-06-24 00:00:00
# 10499.291351104159
# ['OXY' 'CTRA' 'EQT' 'AZO' 'MPC']
# 2022-06-27 00:00:00
# 10791.855529840148
# ['EQT' 'MPC' 'XOM' 'VLO']
# 2022-06-28 00:00:00
# 11275.228726507683
# ['MPC' 'VLO' 'XOM' 'HES']
# 2022-06-29 00:00:00
# 11545.428358968125
# ['HES']
# 2022-06-30 00:00:00
# 10743.536610693473
# ['spy']
# 2022-07-01 00:00:00
# 10752.674422974651
# ['spy']
# 2022-07-05 00:00:00
# 10733.257225449453
# ['VRTX' 'HSY']
# 2022-07-06 00:00:00
# 10782.975878684168
# ['VRTX' 'AZO' 'ABBV' 'HSY' 'UNH']
# 2022-07-07 00:00:00
# 10807.31273898885
# ['MCK' 'VRTX' 'AZO' 'LLY' 'ABBV']
# 2022-07-08 00:00:00
# 10834.211346696506
# ['MCK' 'VRTX' 'LLY' 'AZO' 'WRB']
# 2022-07-11 00:00:00
# 10924.960671445593
# ['MCK' 'VRTX' 'LLY' 'AZO' 'PFE']
# 2022-07-12 00:00:00
# 10866.527247847846
# ['OXY' 'MCK' 'LLY' 'XOM' 'AZO']
# 2022-07-13 00:00:00
# 10751.073148247015
# ['OXY' 'MCK' 'XOM' 'LLY' 'AZO']
# 2022-07-14 00:00:00
# 10615.700434465276
# ['OXY' 'MCK' 'VRTX' 'LLY' 'AZO']
# 2022-07-15 00:00:00
# 10906.483024519328
# ['OXY' 'MCK' 'PWR' 'VRTX' 'LLY']
# 2022-07-18 00:00:00
# 11001.483394477975
# ['OXY' 'MCK' 'DLTR' 'PWR' 'VRTX']
# 2022-07-19 00:00:00
# 10969.786384284645
# ['OXY' 'DLTR' 'VRTX' 'PWR' 'LLY']
# 2022-07-20 00:00:00
# 11079.729021786086
# ['DLTR' 'VRTX' 'PWR' 'LLY' 'GIS']
# 2022-07-21 00:00:00
# 11012.901921452421
# ['DLTR' 'MCK' 'PWR' 'VRTX' 'LLY']
# 2022-07-22 00:00:00
# 11111.706826871736
# ['MCK' 'PWR' 'VRTX' 'LLY' 'AZO']
# 2022-07-25 00:00:00
# 11097.376168000548
# ['MCK' 'VRTX' 'LLY' 'AZO' 'NOC']
# 2022-07-26 00:00:00
# 11141.922009653419
# ['DLTR' 'VRTX' 'AZO' 'GIS' 'ED']
# 2022-07-27 00:00:00
# 11130.823867575291
# ['DLTR' 'VRTX' 'AZO' 'GIS']
# 2022-07-28 00:00:00
# 11204.477829437708
# ['DLTR' 'ON' 'VRTX' 'AZO' 'COST']
# 2022-07-29 00:00:00
# 11249.164316382954
# ['OXY' 'ON' 'DLTR' 'VRTX' 'CNC']
# 2022-08-01 00:00:00
# 11389.769773142969
# ['OXY' 'EQT' 'DLTR' 'VRTX' 'CNC']
# 2022-08-02 00:00:00
# 11312.96596498946
# ['OXY' 'EQT' 'DLTR' 'MPC' 'VRTX']
# 2022-08-03 00:00:00
# 11363.324778452634
# ['OXY' 'EQT' 'CTRA' 'MPC' 'DLTR']
# 2022-08-04 00:00:00
# 11104.082798769796
# ['EQT' 'OXY' 'CTRA' 'DLTR' 'MCK']
# 2022-08-05 00:00:00
# 10723.800960328957
# ['EQT' 'MCK' 'XOM' 'PWR' 'CNC']
# 2022-08-08 00:00:00
# 11014.112727588517
# ['EQT' 'CF' 'MCK' 'MPC' 'XOM']
# 2022-08-09 00:00:00
# 11113.865972503118
# ['OXY' 'EQT' 'CF' 'MCK' 'ENPH']
# 2022-08-10 00:00:00
# 11424.521410762463
# ['OXY' 'EQT' 'CF' 'VLO' 'ENPH']
# 2022-08-11 00:00:00
# 11667.06235756051
# ['OXY' 'EQT' 'CF' 'ENPH' 'VLO']
# 2022-08-12 00:00:00
# 11627.135273064867
# ['OXY' 'CF' 'CTRA' 'FANG' 'ENPH']
# 2022-08-15 00:00:00
# 11388.38494111889
# ['CF' 'CTRA' 'FANG' 'ENPH' 'ON']
# 2022-08-16 00:00:00
# 11674.762202031907
# ['CF' 'ENPH' 'ON' 'ANET' 'TSLA']
# 2022-08-17 00:00:00
# 11467.191809382311
# ['CF' 'ENPH' 'ON' 'ANET' 'GWW']
# 2022-08-18 00:00:00
# 11618.570600207884
# ['CF' 'ENPH' 'ON' 'CI' 'ANET']
# 2022-08-19 00:00:00
# 11583.563355113312
# ['CF' 'ENPH' 'VRTX' 'CTVA' 'CNC']
# 2022-08-22 00:00:00
# 11528.590819964542
# ['CF' 'MCK' 'ENPH' 'DLTR' 'VRTX']
# 2022-08-23 00:00:00
# 11581.490638233292
# ['CF' 'MCK' 'ENPH' 'DLTR' 'CNC']
# 2022-08-24 00:00:00
# 11591.503202316535
# ['EQT' 'CF' 'MCK' 'FANG' 'ENPH']
# 2022-08-25 00:00:00
# 11944.663050976758
# ['EQT' 'FANG' 'MCK' 'DLTR' 'ENPH']
# 2022-08-26 00:00:00
# 11945.659057149487
# ['EQT' 'MCK' 'ENPH' 'ON' 'ADM']
# 2022-08-29 00:00:00
# 11473.66511344522
# ['EQT' 'ENPH' 'ON' 'WMB' 'CTVA']
# 2022-08-30 00:00:00
# 11486.725875500502
# ['EQT' 'VLO' 'ENPH' 'ON' 'CNC']
# 2022-08-31 00:00:00
# 11185.99954056189
# ['DVN' 'EQT' 'CTRA' 'VLO' 'EOG']
# 2022-09-01 00:00:00
# 11305.727404401996
# ['OXY' 'EQT' 'DVN' 'CF' 'MRO']
# 2022-09-02 00:00:00
# 11512.723192907799
# ['OXY' 'DVN' 'EQT' 'CF' 'MRO']
# 2022-09-06 00:00:00
# 11531.26571107234
# ['OXY' 'DVN' 'EQT' 'CF' 'MRO']
# 2022-09-07 00:00:00
# 10955.276115183304
# ['OXY' 'DVN' 'CF' 'MRO' 'EQT']
# 2022-09-08 00:00:00
# 11199.14966700613
# ['OXY' 'DVN' 'EQT' 'CF' 'COP']
# 2022-09-09 00:00:00
# 11341.961801803693
# ['OXY' 'DVN' 'EQT' 'CF' 'COP']
# 2022-09-12 00:00:00
# 11510.318463797223
# ['OXY' 'EQT' 'DVN' 'CF' 'MRO']
# 2022-09-13 00:00:00
# 11406.723917892452
# ['OXY' 'DVN' 'MRO' 'CF' 'APA']
# 2022-09-14 00:00:00
# 11484.955985831926
# ['OXY' 'DVN' 'APA' 'VLO' 'MCK']
# 2022-09-15 00:00:00
# 11442.479607108718
# ['MCK' 'ADM' 'FSLR' 'GIS' 'CAH']
# 2022-09-16 00:00:00
# 11312.76947082167
# ['MCK' 'CI' 'ADM' 'ED' 'GWW']
# 2022-09-19 00:00:00
# 11238.854472110703
# ['DVN' 'CF' 'XOM' 'MCK' 'MPC']
# 2022-09-20 00:00:00
# 11542.733996963838
# ['DVN' 'CF' 'ENPH' 'XOM' 'MCK']
# 2022-09-21 00:00:00
# 11651.629180337382
# ['EQT' 'MRO' 'DVN' 'ENPH' 'MCK']
# 2022-09-22 00:00:00
# 11411.479134693967
# ['EQT' 'MRO' 'DVN' 'ENPH' 'COP']
# 2022-09-23 00:00:00
# 10507.517900458517
# ['EQT' 'ENPH' 'COP' 'VRTX' 'HES']
# 2022-09-26 00:00:00
# 10205.91419426822
# ['ENPH' 'VRTX' 'LLY' 'FSLR' 'CI']
# 2022-09-27 00:00:00
# 10281.337102722428
# ['ENPH' 'CI' 'FSLR' 'ON' 'NOC']
# 2022-09-28 00:00:00
# 10209.164118074596
# ['ENPH' 'FSLR' 'ON' 'CI' 'PGR']
# 2022-09-29 00:00:00
# 10364.653517858136
# ['ENPH' 'CF' 'COP' 'ON' 'FSLR']
# 2022-09-30 00:00:00
# 10117.800899359918
# ['ENPH' 'CF' 'COP' 'CI' 'ON']
# 2022-10-03 00:00:00
# 10339.562411975363
# ['ENPH' 'COP' 'FSLR' 'CI' 'ON']
# 2022-10-04 00:00:00
# 10876.7552807715
# ['PCG' 'NOC' 'HSY' 'HUM' 'GIS']
# 2022-10-05 00:00:00
# 10953.050801146019
# ['LW' 'HSY' 'GIS']
# 2022-10-06 00:00:00
# 10940.59440637712
# ['GIS']
# 2022-10-07 00:00:00
# 10666.33344873331
# ['GIS']
# 2022-10-10 00:00:00
# 10762.964280549995
# ['ENPH' 'LLY' 'FSLR' 'GIS']
# 2022-10-11 00:00:00
# 10758.498649219353
# ['VRTX' 'ENPH' 'LLY' 'HSY' 'FSLR']
# 2022-10-12 00:00:00
# 10902.694397401488
# ['VRTX' 'MPC' 'ENPH' 'LLY' 'HSY']
# 2022-10-13 00:00:00
# 10584.630001031817
# ['OXY' 'VRTX' 'MPC' 'ENPH' 'CAH']
# 2022-10-14 00:00:00
# 11076.014459791768
# ['OXY' 'DVN' 'MPC' 'VRTX' 'VLO']
# 2022-10-17 00:00:00
# 10921.056433003596
# ['OXY' 'MCK' 'DVN' 'MRO' 'VRTX']
# 2022-10-18 00:00:00
# 10992.103579065306
# ['OXY' 'MCK' 'DVN' 'MRO' 'CF']
# 2022-10-19 00:00:00
# 10954.938700386647
# ['OXY' 'DVN' 'MRO' 'CF' 'VRTX']
# 2022-10-20 00:00:00
# 11202.66920577795
# ['OXY' 'DVN' 'MRO' 'CF' 'XOM']
# 2022-10-21 00:00:00
# 11240.789642232861
# ['DVN' 'CF' 'MRO' 'XOM' 'COP']
# 2022-10-24 00:00:00
# 11471.534913514512
# ['MRO' 'APA' 'LW' 'CTRA' 'WRB']
# 2022-10-25 00:00:00
# 11477.930787609603
# ['LW' 'CTRA' 'WRB' 'AMGN' 'GIS']
# 2022-10-26 00:00:00
# 11610.352932675087
# ['LW' 'CTRA' 'PSX' 'FMC' 'WRB']
# 2022-10-27 00:00:00
# 11713.641760895858
# ['LW' 'CTRA' 'PSX' 'WRB' 'AMGN']
# 2022-10-28 00:00:00
# 11787.130796367574
# ['LW' 'WRB' 'CPB' 'GL' 'TRGP']
# 2022-10-31 00:00:00
# 11858.79152318827
# ['VLO' 'LW' 'WRB' 'GL' 'TRGP']
# 2022-11-01 00:00:00
# 12131.222053744157
# ['MPC' 'VLO' 'SLB' 'EOG' 'CTRA']
# 2022-11-02 00:00:00
# 12119.83289989511
# ['MPC' 'CF' 'DVN' 'COP' 'VLO']
# 2022-11-03 00:00:00
# 11539.289450718765
# ['OXY' 'MRO' 'CF' 'MCK' 'COP']
# 2022-11-04 00:00:00
# 12323.756887101976
# ['OXY' 'MRO' 'MCK' 'CF' 'COP']
# 2022-11-07 00:00:00
# 12164.217771057964
# ['OXY' 'MRO' 'MCK' 'XOM' 'HES']
# 2022-11-08 00:00:00
# 12289.431783478514
# ['OXY' 'MCK' 'HES' 'XOM' 'VLO']
# 2022-11-09 00:00:00
# 12117.075940213297
# ['OXY' 'HES' 'MCK' 'XOM' 'CF']
# 2022-11-10 00:00:00
# 11871.722757485224
# ['OXY' 'MRO' 'MPC' 'COP' 'MCK']
# 2022-11-11 00:00:00
# 11949.051636804103
# ['OXY' 'MRO' 'MPC' 'COP' 'XOM']
# 2022-11-14 00:00:00
# 12078.865861798076
# ['OXY' 'MRO' 'COP' 'MPC' 'XOM']
# 2022-11-15 00:00:00
# 12112.796484867631
# ['OXY' 'MRO' 'MPC' 'COP' 'HES']
# 2022-11-16 00:00:00
# 12036.158148152543
# ['MRO' 'MPC' 'HES' 'COP' 'XOM']
# 2022-11-17 00:00:00
# 11725.26801783904
# ['MRO' 'MPC' 'HES' 'COP' 'XOM']
# 2022-11-18 00:00:00
# 11673.552744574421
# ['OXY' 'MRO' 'MPC' 'HES' 'COP']
# 2022-11-21 00:00:00
# 11548.532939103949
# ['OXY' 'MRO' 'MPC' 'HES' 'XOM']
# 2022-11-22 00:00:00
# 11817.54902608317
# ['OXY' 'MPC' 'VLO' 'MRO' 'XOM']
# 2022-11-23 00:00:00
# 11903.8577951046
# ['EQT' 'VLO' 'MRO' 'COP' 'SLB']
# 2022-11-25 00:00:00
# 11799.356397223546
# ['EQT' 'VLO' 'MRO' 'APA' 'COP']
# 2022-11-28 00:00:00
# 11310.578412068815
# ['OXY' 'VLO' 'MRO' 'HES' 'XOM']
# 2022-11-29 00:00:00
# 11452.893529501818
# ['OXY' 'VLO' 'MRO' 'HES' 'XOM']
# 2022-11-30 00:00:00
# 11634.091917288486
# ['OXY' 'VLO' 'MRO' 'HES' 'XOM']
# 2022-12-01 00:00:00
# 11614.360153825713
# ['OXY' 'MPC' 'VLO' 'HES' 'XOM']
# 2022-12-02 00:00:00
# 11342.674036617795
# ['OXY' 'MPC' 'VLO' 'HES' 'XOM']
# 2022-12-05 00:00:00
# 11373.6415804646
# ['OXY' 'MPC' 'STLD' 'VLO' 'XOM']
# 2022-12-06 00:00:00
# 10824.834731388133
# ['OXY' 'MPC' 'MRO' 'CF' 'STLD']
# 2022-12-07 00:00:00
# 10665.377901792184
# ['STLD' 'MPC' 'MRO' 'CF' 'HES']
# 2022-12-08 00:00:00
# 10860.158991535212
# ['MPC' 'CF' 'HES' 'VLO' 'MRO']
# 2022-12-09 00:00:00
# 10483.932452862055
# ['MPC' 'CAH' 'XOM' 'MCK' 'CF']
# 2022-12-12 00:00:00
# 10314.402553631719
# ['MPC' 'XOM' 'MCK' 'CAH' 'SLB']
# 2022-12-13 00:00:00
# 10713.789421664933
# ['MRO' 'MPC' 'VLO' 'HES' 'APA']
# 2022-12-14 00:00:00
# 10725.385669019062
# ['STLD' 'MRO' 'APA' 'HES' 'MPC']
# 2022-12-15 00:00:00
# 10423.111006884224
# ['HES' 'FSLR' 'ENPH' 'STLD' 'SLB']
# 2022-12-16 00:00:00
# 10116.437824596393
# ['ENPH' 'STLD' 'CAH' 'MCK' 'CI']
# 2022-12-19 00:00:00
# 10225.785922578252
# ['STLD' 'ENPH' 'CAH' 'MCK' 'CI']
# 2022-12-20 00:00:00
# 10212.98740382911
# ['STLD' 'ENPH' 'CAH' 'MCK' 'CI']
# 2022-12-21 00:00:00
# 10291.84692949164
# ['STLD' 'ENPH' 'MCK' 'CAH' 'CI']
# 2022-12-22 00:00:00
# 10393.612427254902
# ['STLD' 'ENPH' 'CI' 'MRK' 'CPB']
# 2022-12-23 00:00:00
# 10309.880353278417
# ['STLD' 'ENPH' 'CI' 'CPB' 'PCG']
# 2022-12-27 00:00:00
# 10283.193703458634
# ['STLD' 'ENPH' 'CI' 'PCG' 'CPB']
# 2022-12-28 00:00:00
# 10187.934963806556
# ['FSLR' 'STLD' 'PCG' 'CPB' 'LVS']
# 2022-12-29 00:00:00
# 10001.588579006235
# ['FSLR' 'CAH' 'PCG' 'CPB' 'LVS']
# 2022-12-30 00:00:00
# 9926.771707890304
# ['FSLR' 'MRO' 'CAH' 'CPB' 'LVS']
# 2023-01-03 00:00:00
# 10077.57792619615
# ['FSLR' 'MRO' 'STLD' 'MCK' 'CAH']
# 2023-01-04 00:00:00
# 9846.336268522626
# ['FSLR' 'HES' 'MPC' 'SLB' 'MCK']
# 2023-01-05 00:00:00
# 9983.73148079261
# ['FSLR' 'HES' 'MPC' 'XOM' 'SLB']
# 2023-01-06 00:00:00
# 10380.080862910701
# ['FSLR' 'HES' 'MPC' 'XOM' 'VLO']
# 2023-01-09 00:00:00
# 10661.579656146347
# ['HES' 'MPC' 'XOM' 'VLO' 'SLB']
# 2023-01-10 00:00:00
# 10549.542147568121
# ['HES' 'MPC' 'VLO' 'XOM' 'HAL']
# 2023-01-11 00:00:00
# 10730.73086065417
# ['MPC' 'XOM' 'COP' 'CVX' 'ACGL']
# 2023-01-12 00:00:00
# 10707.20951336101
# ['LLY' 'CVX' 'MRK' 'ACGL' 'APA']
# 2023-01-13 00:00:00
# 10784.648311593563
# ['LLY' 'CVX' 'MRK' 'ACGL' 'CI']

# %%
spy_select = spy[spy.Date>'2022-01-23']
spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100
result['benchmark-spy(%)'] =  spy_select.set_index('Date')['benchmark-spy(%)']
# Out:
# C:\Users\CHIN\AppData\Local\Temp/ipykernel_20500/2272315422.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100

# %%
# plot the return and calculate the annualized return and MDD (maximum draw down) for both strategy
plt.rcParams["figure.figsize"] = (15,6)
plt.plot(result.Return_without_trailing, label='Return without Annualized_return of Portfolio based on EMA and SMA cross-over strategy')
plt.plot(result['benchmark-spy(%)'], label='benchmark-spy(%)')
plt.legend()
print('Annualized_return of Portfolio based on EMA and SMA cross-over strategy:',annualized (result,'Return_without_trailing'))
print('MDD of Portfolio based on EMA AND SMA cross-over strategy:', MDD(result,'Return_without_trailing'))

print('Annualized_return of benchmark-spy:',annualized (result,'benchmark-spy(%)'))
print('MDD of benchmark-spy:', MDD(result,'benchmark-spy(%)'))
# Out:
# Annualized_return of Portfolio based on EMA and SMA cross-over strategy: 11.86018937588682
# MDD of Portfolio based on EMA AND SMA cross-over strategy: -32.01432978912073
# Annualized_return of benchmark-spy: -13.62313753115918
# MDD of benchmark-spy: -22.747263137502017

# %%
result, hold_detail= backtest_strategy_portfolio(signal_etf_stock[(signal_etf_stock.Date>'2015-01-23') &(signal_etf_stock.Date<'2016-01-23')],10000)
# Out:
# 2015-01-26 00:00:00
# 10000.0
# ['AVGO' 'EW' 'NXPI' 'IRM' 'DXCM']
# 2015-01-27 00:00:00
# 10029.775700129585
# ['EW' 'NXPI' 'DXCM' 'ZBRA' 'AVB']
# 2015-01-28 00:00:00
# 10172.558673027188
# ['EW' 'MNST' 'NXPI' 'ELV' 'ZBRA']
# 2015-01-29 00:00:00
# 10052.936198428772
# ['AVGO' 'MNST' 'NXPI' 'IRM' 'KDP']
# 2015-01-30 00:00:00
# 10093.304327100985
# ['AVGO' 'CNC' 'MNST' 'IRM' 'KDP']
# 2015-02-02 00:00:00
# 9933.711634762158
# ['EW' 'AVGO' 'CNC' 'ALK' 'MNST']
# 2015-02-03 00:00:00
# 9892.168069461057
# ['SWKS' 'LUV' 'EW' 'AVGO' 'CNC']
# 2015-02-04 00:00:00
# 9970.467165016653
# ['SWKS' 'LUV' 'KR' 'AVGO' 'EW']
# 2015-02-05 00:00:00
# 10190.892209068228
# ['SWKS' 'LUV' 'KR' 'AVGO' 'CNC']
# 2015-02-06 00:00:00
# 10184.597203203688
# ['SWKS' 'LUV' 'AVGO' 'MNST' 'ALK']
# 2015-02-09 00:00:00
# 10019.207673116207
# ['SWKS' 'LUV' 'EA' 'AVGO' 'ALK']
# 2015-02-10 00:00:00
# 9961.172916518188
# ['SWKS' 'LUV' 'EA' 'KR' 'AVGO']
# 2015-02-11 00:00:00
# 10140.890576707072
# ['SWKS' 'LUV' 'EA' 'KR' 'ALK']
# 2015-02-12 00:00:00
# 10055.676522173912
# ['SWKS' 'LUV' 'EA' 'KR' 'ALK']
# 2015-02-13 00:00:00
# 10061.70362132145
# ['SWKS' 'LUV' 'EA' 'KR' 'ALK']
# 2015-02-17 00:00:00
# 10069.022077601328
# ['SWKS' 'LUV' 'EA' 'KR' 'ALK']
# 2015-02-18 00:00:00
# 10109.65946445585
# ['SWKS' 'EA' 'LUV' 'EW' 'KR']
# 2015-02-19 00:00:00
# 10252.415883493508
# ['EA' 'LUV' 'EW' 'KR' 'ENPH']
# 2015-02-20 00:00:00
# 10049.640550174432
# ['EA' 'EW' 'ENPH' 'KR' 'BBWI']
# 2015-02-23 00:00:00
# 10144.564303505957
# ['CNC' 'KR' 'ENPH' 'BBWI' 'ULTA']
# 2015-02-24 00:00:00
# 10321.295698420716
# ['CNC' 'KR' 'ENPH' 'BBWI' 'ULTA']
# 2015-02-25 00:00:00
# 10307.225141149886
# ['CNC' 'AVGO' 'KR' 'AAPL' 'MOH']
# 2015-02-26 00:00:00
# 10438.872545317436
# ['EA' 'EW' 'CNC' 'AVGO' 'KR']
# 2015-02-27 00:00:00
# 10483.217491110294
# ['EA' 'EW' 'CNC' 'AAPL' 'KR']
# 2015-03-02 00:00:00
# 10448.398694650685
# ['EA' 'CNC' 'EW' 'ENPH' 'AAPL']
# 2015-03-03 00:00:00
# 10491.02970977717
# ['EA' 'CNC' 'EW' 'AAPL' 'MOH']
# 2015-03-04 00:00:00
# 10384.366101070113
# ['CNC' 'EA' 'LUV' 'EW' 'AAPL']
# 2015-03-05 00:00:00
# 10451.66874471175
# ['CNC' 'EA' 'LUV' 'EW' 'EPAM']
# 2015-03-06 00:00:00
# 10452.70746118658
# ['SWKS' 'CNC' 'EA' 'LUV' 'EW']
# 2015-03-09 00:00:00
# 10362.25848994152
# ['SWKS' 'CNC' 'EA' 'LUV' 'EW']
# 2015-03-10 00:00:00
# 10343.556258535065
# ['SWKS' 'AVGO' 'CNC' 'EA' 'MNST']
# 2015-03-11 00:00:00
# 10307.313430515973
# ['SWKS' 'AVGO' 'CNC' 'MNST' 'EA']
# 2015-03-12 00:00:00
# 10352.524467628242
# ['SWKS' 'AVGO' 'MNST' 'EW' 'LUV']
# 2015-03-13 00:00:00
# 10493.487895702281
# ['SWKS' 'AVGO' 'MNST' 'EPAM' 'EA']
# 2015-03-16 00:00:00
# 10537.859277971456
# ['SWKS' 'AVGO' 'MNST' 'EPAM' 'EA']
# 2015-03-17 00:00:00
# 10632.531075072582
# ['AVGO' 'MNST' 'EA' 'NXPI' 'AAPL']
# 2015-03-18 00:00:00
# 10602.569194246586
# ['AVGO' 'MNST' 'EA' 'NXPI' 'VRTX']
# 2015-03-19 00:00:00
# 10758.394486553278
# ['AVGO' 'MNST' 'EA' 'KR' 'VRTX']
# 2015-03-20 00:00:00
# 10953.635448888974
# ['MNST' 'KR' 'ROST' 'KDP' 'MKTX']
# 2015-03-23 00:00:00
# 10942.750190043513
# ['MNST' 'EPAM' 'KR' 'BBY' 'CHTR']
# 2015-03-24 00:00:00
# 10992.551793365641
# ['MNST' 'EPAM' 'KR' 'BBY' 'CHTR']
# 2015-03-25 00:00:00
# 10967.984575400227
# ['LUV' 'EPAM' 'NXPI' 'KR' 'VRTX']
# 2015-03-26 00:00:00
# 10461.953251813104
# ['SWKS' 'CNC' 'EW' 'AVGO' 'LUV']
# 2015-03-27 00:00:00
# 10637.568353285124
# ['SWKS' 'CNC' 'EW' 'MNST' 'AVGO']
# 2015-03-30 00:00:00
# 11022.197621630741
# ['SWKS' 'CNC' 'AVGO' 'MNST' 'EW']
# 2015-03-31 00:00:00
# 11004.267767446512
# ['SWKS' 'CNC' 'AVGO' 'EW' 'LUV']
# 2015-04-01 00:00:00
# 10866.494555999463
# ['SWKS' 'CNC' 'AVGO' 'EW' 'LUV']
# 2015-04-02 00:00:00
# 10801.0142216733
# ['SWKS' 'CNC' 'MNST' 'AVGO' 'EW']
# 2015-04-06 00:00:00
# 10634.913229215343
# ['SWKS' 'CNC' 'MNST' 'AVGO' 'EA']
# 2015-04-07 00:00:00
# 10800.232730720185
# ['SWKS' 'CNC' 'AVGO' 'MNST' 'EA']
# 2015-04-08 00:00:00
# 10813.82684664076
# ['SWKS' 'CNC' 'MNST' 'AVGO' 'EA']
# 2015-04-09 00:00:00
# 10864.740990277189
# ['EA' 'MNST' 'EW' 'LUV' 'INCY']
# 2015-04-10 00:00:00
# 10873.843221911382
# ['MNST' 'EA' 'MOH' 'EW' 'LUV']
# 2015-04-13 00:00:00
# 10932.449162604078
# ['SWKS' 'CNC' 'EA' 'MNST' 'EW']
# 2015-04-14 00:00:00
# 10870.200934136128
# ['SWKS' 'CNC' 'MNST' 'EA' 'MOH']
# 2015-04-15 00:00:00
# 10822.368232735094
# ['CNC' 'EA' 'MOH' 'ENPH' 'NCLH']
# 2015-04-16 00:00:00
# 10650.147096877246
# ['CNC' 'EA' 'MOH' 'NCLH' 'BBWI']
# 2015-04-17 00:00:00
# 10576.238845292664
# ['SWKS' 'CNC' 'EA' 'EPAM' 'MOH']
# 2015-04-20 00:00:00
# 10543.069552907209
# ['SWKS' 'CNC' 'MNST' 'EPAM' 'EA']
# 2015-04-21 00:00:00
# 10708.526847759713
# ['SWKS' 'CNC' 'EPAM' 'MNST' 'EA']
# 2015-04-22 00:00:00
# 10793.60724483943
# ['SWKS' 'CNC' 'EPAM' 'VRTX' 'DXCM']
# 2015-04-23 00:00:00
# 10736.424239509373
# ['SWKS' 'EPAM' 'VRTX' 'DXCM' 'EW']
# 2015-04-24 00:00:00
# 10870.361792607677
# ['SWKS' 'EPAM' 'DXCM' 'ABC' 'ENPH']
# 2015-04-27 00:00:00
# 10708.385674293077
# ['INCY' 'SWKS' 'DXCM' 'AVGO' 'ENPH']
# 2015-04-28 00:00:00
# 10486.072817300514
# ['INCY' 'DXCM' 'AVGO' 'VRTX' 'ENPH']
# 2015-04-29 00:00:00
# 10310.129302148742
# ['EPAM' 'DXCM' 'INCY' 'VRTX' 'AVGO']
# 2015-04-30 00:00:00
# 10248.761499923989
# ['DXCM' 'INCY' 'EPAM' 'CNC' 'AVGO']
# 2015-05-01 00:00:00
# 10240.118817757091
# ['SWKS' 'DXCM' 'MNST' 'EA' 'PAYC']
# 2015-05-04 00:00:00
# 10368.75030390534
# ['SWKS' 'DXCM' 'MNST' 'EA' 'PAYC']
# 2015-05-05 00:00:00
# 10440.822302632681
# ['DXCM' 'PAYC' 'MNST' 'EA' 'EPAM']
# 2015-05-06 00:00:00
# 10344.731168834294
# ['DXCM' 'MNST' 'PAYC' 'EPAM' 'INCY']
# 2015-05-07 00:00:00
# 10520.719405599264
# ['DXCM' 'PAYC' 'MNST' 'INCY' 'VRTX']
# 2015-05-08 00:00:00
# 10729.91389316137
# ['MNST' 'DXCM' 'VRTX' 'FTNT' 'CNC']
# 2015-05-11 00:00:00
# 10755.09347030387
# ['FTNT' 'MNST' 'NFLX' 'MKTX' 'AAPL']
# 2015-05-12 00:00:00
# 10829.416014419185
# ['MNST' 'FTNT' 'EPAM' 'MKTX' 'TYL']
# 2015-05-13 00:00:00
# 10873.887176070515
# ['MNST' 'FTNT' 'EPAM' 'DPZ' 'VTRS']
# 2015-05-14 00:00:00
# 10965.92400879933
# ['MNST' 'EPAM' 'FTNT' 'ABC' 'VMC']
# 2015-05-15 00:00:00
# 11048.218120052617
# ['SWKS' 'MNST' 'FTNT' 'EPAM' 'ULTA']
# 2015-05-18 00:00:00
# 11014.266084247907
# ['SWKS' 'MNST' 'FTNT' 'ULTA' 'ABC']
# 2015-05-19 00:00:00
# 11217.342251042664
# ['PAYC' 'MNST' 'ULTA' 'ABC' 'BBWI']
# 2015-05-20 00:00:00
# 11225.139894881617
# ['PAYC' 'MNST' 'EA' 'ULTA' 'NXPI']
# 2015-05-21 00:00:00
# 11204.966521412493
# ['PAYC' 'EA' 'FTNT' 'ULTA' 'NXPI']
# 2015-05-22 00:00:00
# 11334.51554039002
# ['PAYC' 'EA' 'ULTA' 'FTNT' 'NXPI']
# 2015-05-26 00:00:00
# 11361.50195464437
# ['PAYC' 'INCY' 'DXCM' 'EA' 'FTNT']
# 2015-05-27 00:00:00
# 11326.166654910417
# ['PAYC' 'INCY' 'DXCM' 'EA' 'VRTX']
# 2015-05-28 00:00:00
# 11517.674099051066
# ['PAYC' 'INCY' 'EA' 'VRTX' 'MOH']
# 2015-05-29 00:00:00
# 11477.76571434717
# ['PAYC' 'INCY' 'CNC' 'EA' 'MKTX']
# 2015-06-01 00:00:00
# 11678.284561074459
# ['PAYC' 'INCY' 'CNC' 'EA' 'MKTX']
# 2015-06-02 00:00:00
# 11576.070876628008
# ['PAYC' 'SWKS' 'INCY' 'EA' 'MKTX']
# 2015-06-03 00:00:00
# 11623.35698968746
# ['PAYC' 'SWKS' 'INCY' 'EA' 'VRTX']
# 2015-06-04 00:00:00
# 11533.935749152151
# ['PAYC' 'SWKS' 'INCY' 'CNC' 'EA']
# 2015-06-05 00:00:00
# 11522.359875381604
# ['SWKS' 'INCY' 'AVGO' 'CNC' 'EA']
# 2015-06-08 00:00:00
# 11676.863588740054
# ['SWKS' 'INCY' 'AVGO' 'CNC' 'EA']
# 2015-06-09 00:00:00
# 11382.34228938531
# ['CNC' 'INCY' 'DXCM' 'AVGO' 'ULTA']
# 2015-06-10 00:00:00
# 11382.702652633792
# ['INCY' 'CNC' 'DXCM' 'AVGO' 'VRTX']
# 2015-06-11 00:00:00
# 11499.776804928037
# ['SWKS' 'DXCM' 'AVGO' 'INCY' 'CNC']
# 2015-06-12 00:00:00
# 11493.938027654085
# ['SWKS' 'CNC' 'DXCM' 'AVGO' 'INCY']
# 2015-06-15 00:00:00
# 11390.717480175308
# ['SWKS' 'CNC' 'AVGO' 'INCY' 'DXCM']
# 2015-06-16 00:00:00
# 11536.03687124933
# ['AVGO' 'INCY' 'VRTX' 'DXCM' 'NCLH']
# 2015-06-17 00:00:00
# 11591.145296417357
# ['AVGO' 'VRTX' 'INCY' 'DXCM' 'NCLH']
# 2015-06-18 00:00:00
# 11691.752146925948
# ['AVGO' 'VRTX' 'INCY' 'REGN' 'ULTA']
# 2015-06-19 00:00:00
# 11946.08545241165
# ['AVGO' 'REGN' 'DPZ' 'HUM' 'NFLX']
# 2015-06-22 00:00:00
# 12004.007473279782
# ['HUM' 'DPZ' 'NFLX' 'ZBRA' 'VTRS']
# 2015-06-23 00:00:00
# 11892.690801671479
# ['DPZ' 'NFLX' 'GILD' 'FDS' 'MTD']
# 2015-06-24 00:00:00
# 11999.608642713694
# ['AVGO' 'ULTA' 'DPZ' 'NFLX' 'AOS']
# 2015-06-25 00:00:00
# 11809.880264632407
# ['PAYC' 'CNC' 'AVGO' 'FTNT' 'ULTA']
# 2015-06-26 00:00:00
# 11925.829904370177
# ['PAYC' 'CNC' 'AVGO' 'ZTS' 'FTNT']
# 2015-06-29 00:00:00
# 11280.654697469608
# ['PAYC' 'SWKS' 'CNC' 'AVGO' 'INCY']
# 2015-06-30 00:00:00
# 11395.872327221367
# ['PAYC' 'SWKS' 'CNC' 'DXCM' 'MNST']
# 2015-07-01 00:00:00
# 11418.608974181865
# ['PAYC' 'SWKS' 'CNC' 'DXCM' 'MNST']
# 2015-07-02 00:00:00
# 11422.491114976561
# ['PAYC' 'SWKS' 'CNC' 'DXCM' 'MNST']
# 2015-07-06 00:00:00
# 10984.883032822889
# ['PAYC' 'SWKS' 'DXCM' 'INCY' 'MNST']
# 2015-07-07 00:00:00
# 11198.389694575382
# ['PAYC' 'DXCM' 'SWKS' 'MNST' 'MKTX']
# 2015-07-08 00:00:00
# 11071.997721800546
# ['PAYC' 'DXCM' 'SWKS' 'MKTX' 'MNST']
# 2015-07-09 00:00:00
# 11143.859404079054
# ['PAYC' 'DXCM' 'SWKS' 'MKTX' 'EA']
# 2015-07-10 00:00:00
# 11273.032391572478
# ['DXCM' 'MNST' 'CNC' 'NCLH' 'CI']
# 2015-07-13 00:00:00
# 11534.144322272288
# ['DXCM' 'MNST' 'CNC' 'CI' 'HCA']
# 2015-07-14 00:00:00
# 11520.900766950625
# ['DXCM' 'CNC' 'AVGO' 'HCA' 'CI']
# 2015-07-15 00:00:00
# 11631.654060426674
# ['DXCM' 'AVGO' 'CI' 'HCA' 'UHS']
# 2015-07-16 00:00:00
# 11594.016487948911
# ['DXCM' 'EPAM' 'CI' 'HCA' 'HOLX']
# 2015-07-17 00:00:00
# 11636.693173812368
# ['EPAM' 'HCA' 'HOLX' 'UHS' 'CAG']
# 2015-07-20 00:00:00
# 11620.163623377375
# ['MKTX' 'EPAM' 'WST' 'HCA' 'HOLX']
# 2015-07-21 00:00:00
# 11582.084399015774
# ['MKTX' 'EPAM' 'DRI' 'TYL' 'KR']
# 2015-07-22 00:00:00
# 11511.29374268634
# ['EA' 'EPAM' 'MKTX' 'ULTA' 'DRI']
# 2015-07-23 00:00:00
# 11621.38528923702
# ['INCY' 'EA' 'EPAM' 'ULTA' 'MKTX']
# 2015-07-24 00:00:00
# 11445.606871496706
# ['INCY' 'EA' 'EPAM' 'CNC' 'NCLH']
# 2015-07-27 00:00:00
# 11229.086017316753
# ['PAYC' 'INCY' 'DXCM' 'EA' 'EPAM']
# 2015-07-28 00:00:00
# 11025.711544467498
# ['PAYC' 'INCY' 'EA' 'DXCM' 'EPAM']
# 2015-07-29 00:00:00
# 11045.36629602825
# ['INCY' 'EA' 'DXCM' 'EPAM' 'AVGO']
# 2015-07-30 00:00:00
# 10959.485318991698
# ['DXCM' 'INCY' 'EA' 'EPAM' 'AVGO']
# 2015-07-31 00:00:00
# 11021.123397747058
# ['DXCM' 'INCY' 'EA' 'CNC' 'EPAM']
# 2015-08-03 00:00:00
# 11070.97756155227
# ['MNST' 'DXCM' 'INCY' 'EA' 'CNC']
# 2015-08-04 00:00:00
# 11177.845587533946
# ['MNST' 'INCY' 'DXCM' 'EA' 'FTNT']
# 2015-08-05 00:00:00
# 11248.084080005185
# ['MNST' 'DXCM' 'EA' 'FTNT' 'ULTA']
# 2015-08-06 00:00:00
# 11662.347053711543
# ['MNST' 'FTNT' 'ULTA' 'AMZN' 'EPAM']
# 2015-08-07 00:00:00
# 11400.065195338786
# ['MNST' 'FTNT' 'ULTA' 'EPAM' 'AMZN']
# 2015-08-10 00:00:00
# 11677.294950277148
# ['MNST' 'FTNT' 'EPAM' 'AMZN' 'DRI']
# 2015-08-11 00:00:00
# 11322.30836796496
# ['MNST' 'FTNT' 'NCLH' 'EPAM' 'GPN']
# 2015-08-12 00:00:00
# 11230.228494805608
# ['MNST' 'NCLH' 'FTNT' 'EPAM' 'MKTX']
# 2015-08-13 00:00:00
# 11220.179523213865
# ['MNST' 'NFLX' 'FTNT' 'MOH' 'NCLH']
# 2015-08-14 00:00:00
# 11394.781242604982
# ['MOH' 'NFLX' 'FTNT' 'NCLH' 'ALK']
# 2015-08-17 00:00:00
# 11441.79166058491
# ['EA' 'MOH' 'NFLX' 'FTNT' 'NCLH']
# 2015-08-18 00:00:00
# 11717.942078264372
# ['EA' 'MOH' 'CNC' 'NFLX' 'FTNT']
# 2015-08-19 00:00:00
# 11617.504065995512
# ['PAYC' 'DXCM' 'EA' 'CNC' 'FTNT']
# 2015-08-20 00:00:00
# 11385.307119645347
# ['PAYC' 'DXCM' 'EA' 'NFLX' 'NCLH']
# 2015-08-21 00:00:00
# 10557.011647539068
# ['PAYC' 'DXCM' 'EA' 'MOH' 'NCLH']
# 2015-08-24 00:00:00
# 9759.635509845699
# ['PAYC' 'DXCM' 'EA' 'MOH' 'FTNT']
# 2015-08-25 00:00:00
# 10863.45911940779
# ['PAYC' 'DXCM' 'ULTA' 'MOH' 'FTNT']
# 2015-08-26 00:00:00
# 10598.541731301706
# ['PAYC' 'DXCM' 'ALK' 'FTNT' 'MOH']
# 2015-08-27 00:00:00
# 10822.313183394741
# ['PAYC' 'DXCM' 'INCY' 'EA' 'NCLH']
# 2015-08-28 00:00:00
# 10854.428398412287
# ['PAYC' 'DXCM' 'INCY' 'EA' 'NCLH']
# 2015-08-31 00:00:00
# 11004.688753887767
# ['PAYC' 'DXCM' 'EA' 'MOH' 'FTNT']
# 2015-09-01 00:00:00
# 10664.901694580698
# ['PAYC' 'MOH' 'ULTA' 'FTNT' 'ALK']
# 2015-09-02 00:00:00
# 10740.996652337071
# ['PAYC' 'ALK' 'GPN' 'HOLX' 'ORLY']
# 2015-09-03 00:00:00
# 10935.936341095814
# ['LLY']
# 2015-09-04 00:00:00
# 10748.00569251542
# ['spy']
# 2015-09-08 00:00:00
# 10920.218796888741
# ['PAYC']
# 2015-09-09 00:00:00
# 11292.932669830367
# ['PAYC' 'DXCM' 'EPAM' 'NFLX' 'CDW']
# 2015-09-10 00:00:00
# 11205.863608662186
# ['INCY' 'PAYC' 'DXCM' 'EPAM' 'AMZN']
# 2015-09-11 00:00:00
# 11501.257414749109
# ['INCY' 'PAYC' 'AMZN' 'STZ' 'SBUX']
# 2015-09-14 00:00:00
# 11830.005863528175
# ['INCY' 'NFLX' 'STZ' 'EXR' 'AZO']
# 2015-09-15 00:00:00
# 11742.249540557754
# ['STZ' 'NFLX' 'AZO']
# 2015-09-16 00:00:00
# 11996.443489752895
# ['MKTX' 'STZ' 'BBWI' 'AZO']
# 2015-09-17 00:00:00
# 12099.396717314754
# ['ALK' 'VMC' 'MKTX' 'STZ' 'DHI']
# 2015-09-18 00:00:00
# 11966.318230483252
# ['ALK' 'VMC' 'MKTX' 'DHI' 'BBWI']
# 2015-09-21 00:00:00
# 12046.11469099492
# ['MOH' 'ALK' 'VMC' 'MKTX' 'MHK']
# 2015-09-22 00:00:00
# 11936.668809223056
# ['INCY' 'PAYC' 'EPAM' 'ALK' 'MOH']
# 2015-09-23 00:00:00
# 11835.86655362307
# ['INCY' 'DXCM' 'PAYC' 'EA' 'EPAM']
# 2015-09-24 00:00:00
# 11839.583239231308
# ['DXCM' 'INCY' 'PAYC' 'EA' 'FTNT']
# 2015-09-25 00:00:00
# 11749.848472445101
# ['DXCM' 'INCY' 'PAYC' 'EA' 'FTNT']
# 2015-09-28 00:00:00
# 11125.956559286997
# ['DXCM' 'EA' 'ALK' 'FTNT' 'TYL']
# 2015-09-29 00:00:00
# 10675.679236754897
# ['DXCM' 'EA' 'ALK' 'FTNT' 'TYL']
# 2015-09-30 00:00:00
# 10719.552089199306
# ['DXCM' 'ALK' 'FTNT' 'TYL' 'GPN']
# 2015-10-01 00:00:00
# 10797.367358643829
# ['INCY' 'PAYC' 'DXCM' 'ALK' 'EPAM']
# 2015-10-02 00:00:00
# 10901.322925563269
# ['INCY' 'CZR' 'PAYC' 'DXCM' 'EA']
# 2015-10-05 00:00:00
# 11388.730148090133
# ['CZR' 'DXCM' 'EA' 'ALK' 'FTNT']
# 2015-10-06 00:00:00
# 11303.250326259198
# ['DXCM' 'EA' 'FTNT' 'NCLH' 'HOLX']
# 2015-10-07 00:00:00
# 10955.303309285873
# ['FTNT' 'NCLH' 'ATVI' 'MKTX' 'ULTA']
# 2015-10-08 00:00:00
# 10910.811305029009
# ['ALK' 'ATVI' 'ULTA' 'EXR' 'TMUS']
# 2015-10-09 00:00:00
# 10858.607637836496
# ['ALK' 'EXR' 'NKE' 'NDAQ' 'ATO']
# 2015-10-12 00:00:00
# 10857.799976407041
# ['ALK' 'NKE' 'EXR' 'ACGL' 'ATO']
# 2015-10-13 00:00:00
# 10920.246532297058
# ['ALK' 'TYL' 'NKE' 'EW' 'AAP']
# 2015-10-14 00:00:00
# 10831.978894841073
# ['EPAM' 'ALK' 'TYL' 'NFLX' 'ORLY']
# 2015-10-15 00:00:00
# 10631.09323449058
# ['NFLX' 'EPAM' 'TYL' 'ALK' 'ORLY']
# 2015-10-16 00:00:00
# 10769.212166541416
# ['PAYC' 'INCY' 'NFLX' 'EPAM' 'TYL']
# 2015-10-19 00:00:00
# 10738.906569109213
# ['PAYC' 'INCY' 'EPAM' 'TYL' 'GPN']
# 2015-10-20 00:00:00
# 10731.666836656364
# ['PAYC' 'CZR' 'TYL' 'EPAM' 'GPN']
# 2015-10-21 00:00:00
# 10554.926576091006
# ['PAYC' 'CZR' 'TYL' 'EPAM' 'GPN']
# 2015-10-22 00:00:00
# 10555.501109418497
# ['PAYC' 'CZR' 'EPAM' 'GPN' 'SBUX']
# 2015-10-23 00:00:00
# 10757.419393594228
# ['PAYC' 'CZR' 'AMZN' 'EPAM' 'GPN']
# 2015-10-26 00:00:00
# 10675.903293290736
# ['PAYC' 'CZR' 'AMZN' 'GPN' 'EPAM']
# 2015-10-27 00:00:00
# 10526.476093596124
# ['CZR' 'PAYC' 'ATVI' 'GPN' 'EXPE']
# 2015-10-28 00:00:00
# 10520.604341355454
# ['CZR' 'EA' 'ATVI' 'GPN' 'TYL']
# 2015-10-29 00:00:00
# 10771.585503166627
# ['EA' 'DXCM' 'ATVI' 'GPN' 'TYL']
# 2015-10-30 00:00:00
# 10611.800162448277
# ['PAYC' 'EA' 'DXCM' 'ATVI' 'GPN']
# 2015-11-02 00:00:00
# 10512.440409771862
# ['PAYC' 'EA' 'ATVI' 'GPN' 'SBUX']
# 2015-11-03 00:00:00
# 10443.511366447943
# ['EA' 'ATVI' 'EPAM' 'SBUX' 'TYL']
# 2015-11-04 00:00:00
# 10698.447656135071
# ['EA' 'ATVI' 'SBUX' 'EPAM' 'TYL']
# 2015-11-05 00:00:00
# 10602.924631320877
# ['AMZN' 'EA' 'ATVI' 'GPN' 'SBUX']
# 2015-11-06 00:00:00
# 10629.849915006253
# ['AMZN' 'EA' 'INCY' 'GPN' 'SBUX']
# 2015-11-09 00:00:00
# 10344.72151666155
# ['AMZN' 'EA' 'SBUX' 'DXCM' 'TYL']
# 2015-11-10 00:00:00
# 10288.364625896964
# ['CZR' 'AMZN' 'EA' 'ATVI' 'DXCM']
# 2015-11-11 00:00:00
# 10404.2704720599
# ['CZR' 'AMZN' 'NFLX' 'EA' 'ATVI']
# 2015-11-12 00:00:00
# 10410.20378975126
# ['CZR' 'AMZN' 'NFLX' 'EA' 'ATVI']
# 2015-11-13 00:00:00
# 10227.426682451756
# ['CZR' 'AMZN' 'NFLX' 'ATVI' 'GPN']
# 2015-11-16 00:00:00
# 10034.705316128428
# ['CZR' 'AMZN' 'ATVI' 'GPN' 'PAYC']
# 2015-11-17 00:00:00
# 10063.936493491165
# ['AMZN' 'ATVI' 'PAYC' 'GPN' 'MKTX']
# 2015-11-18 00:00:00
# 10200.485622558726
# ['NFLX' 'AMZN' 'ATVI' 'GPN' 'PAYC']
# 2015-11-19 00:00:00
# 10367.612537942405
# ['NFLX' 'CZR' 'AMZN' 'GPN' 'DXCM']
# 2015-11-20 00:00:00
# 10366.46308860579
# ['CZR' 'AMZN' 'GPN' 'DXCM' 'PAYC']
# 2015-11-23 00:00:00
# 10351.561350542956
# ['AMZN' 'PAYC' 'NVDA' 'HOLX' 'META']
# 2015-11-24 00:00:00
# 10267.488767290024
# ['AMZN' 'TYL' 'PAYC' 'HOLX' 'META']
# 2015-11-25 00:00:00
# 10359.31118637085
# ['AMZN' 'TYL' 'PAYC' 'HOLX' 'MNST']
# 2015-11-27 00:00:00
# 10445.394501073819
# ['FANG' 'RCL' 'HII']
# 2015-11-30 00:00:00
# 10391.048028544095
# ['VMC' 'MLM' 'FANG' 'REGN' 'JKHY']
# 2015-12-01 00:00:00
# 10320.895389521193
# ['NFLX' 'ATVI' 'VMC' 'NVDA' 'INCY']
# 2015-12-02 00:00:00
# 10397.789444543856
# ['NFLX' 'ATVI' 'GPN' 'MKTX' 'VRSN']
# 2015-12-03 00:00:00
# 10508.823763840901
# ['NFLX' 'AMZN' 'ATVI' 'GPN' 'MKTX']
# 2015-12-04 00:00:00
# 10326.85325328815
# ['NFLX' 'AMZN' 'ATVI' 'MKTX' 'EPAM']
# 2015-12-07 00:00:00
# 10618.48091391505
# ['NFLX' 'AMZN' 'ATVI' 'VRSN' 'EPAM']
# 2015-12-08 00:00:00
# 10376.324912448357
# ['NFLX' 'AMZN' 'GPN' 'VRSN' 'EPAM']
# 2015-12-09 00:00:00
# 10589.082375193939
# ['NFLX' 'AMZN' 'GPN' 'EPAM' 'TYL']
# 2015-12-10 00:00:00
# 10422.36353957578
# ['NFLX' 'AMZN' 'GPN' 'EPAM' 'TYL']
# 2015-12-11 00:00:00
# 10298.002623931014
# ['NFLX' 'CZR' 'AMZN' 'ATVI' 'GPN']
# 2015-12-14 00:00:00
# 10174.028158107769
# ['NFLX' 'CZR' 'AMZN' 'ATVI' 'NVDA']
# 2015-12-15 00:00:00
# 10311.602299954524
# ['NFLX' 'CZR' 'AMZN' 'ATVI' 'EPAM']
# 2015-12-16 00:00:00
# 10377.102102780205
# ['NFLX' 'CZR' 'AMZN' 'ATVI' 'EPAM']
# 2015-12-17 00:00:00
# 10583.186356563247
# ['NFLX' 'CZR' 'AMZN' 'ATVI' 'EPAM']
# 2015-12-18 00:00:00
# 10559.610319049114
# ['NFLX' 'CZR' 'ATVI' 'EPAM' 'TYL']
# 2015-12-21 00:00:00
# 10478.904620017576
# ['NFLX' 'CZR' 'ATVI' 'EPAM' 'GPN']
# 2015-12-22 00:00:00
# 10414.745317843348
# ['NFLX' 'CZR' 'ATVI' 'EPAM' 'NVDA']
# 2015-12-23 00:00:00
# 10461.479317276395
# ['NFLX' 'EPAM' 'NVDA' 'GPN' 'VRSN']
# 2015-12-24 00:00:00
# 10472.131069788436
# ['EPAM' 'GPN' 'NVDA' 'VRSN' 'ULTA']
# 2015-12-28 00:00:00
# 10435.675227518874
# ['EPAM' 'GPN' 'HRL' 'EXR' 'ULTA']
# 2015-12-29 00:00:00
# 10533.865595830914
# ['ATVI' 'EPAM' 'HRL' 'FSLR' 'EXR']
# 2015-12-30 00:00:00
# 10539.304875695318
# ['ATVI' 'EPAM' 'HRL' 'EXR' 'EXPE']
# 2015-12-31 00:00:00
# 10438.7422803082
# ['ATVI' 'EPAM' 'TYL' 'HRL' 'MSCI']
# 2016-01-04 00:00:00
# 10208.729087293323
# ['ATVI' 'EPAM' 'TYL' 'FSLR' 'HRL']
# 2016-01-05 00:00:00
# 10251.738946046275
# ['AMZN' 'ATVI' 'NVDA' 'FSLR' 'TYL']
# 2016-01-06 00:00:00
# 10060.542105410179
# ['CZR' 'AMZN' 'ATVI' 'FSLR' 'NVDA']
# 2016-01-07 00:00:00
# 9813.123198654292
# ['CZR' 'NFLX' 'AMZN' 'ATVI' 'FSLR']
# 2016-01-08 00:00:00
# 9829.235518465752
# ['CZR' 'NFLX' 'AMZN' 'ATVI' 'HRL']
# 2016-01-11 00:00:00
# 9660.763827734012
# ['CZR' 'AMZN' 'ATVI' 'HRL' 'FSLR']
# 2016-01-12 00:00:00
# 9784.115861565611
# ['CZR' 'AMZN' 'ATVI' 'HRL' 'FSLR']
# 2016-01-13 00:00:00
# 9782.79214290974
# ['CZR' 'AMZN' 'ATVI' 'VLO' 'HRL']
# 2016-01-14 00:00:00
# 9369.357387239983
# ['CZR' 'ATVI' 'HRL' 'FSLR' 'NVDA']
# 2016-01-15 00:00:00
# 9120.901766088897
# ['CZR' 'ATVI' 'FSLR' 'VLO' 'MKTX']
# 2016-01-19 00:00:00
# 9410.045537309963
# ['CZR' 'FSLR' 'VLO' 'MKTX' 'GOOGL']
# 2016-01-20 00:00:00
# 9211.566688952247
# ['CZR' 'FSLR' 'HRL' 'MKTX' 'VLO']
# 2016-01-21 00:00:00
# 9282.902368016663
# ['CZR' 'FSLR' 'HRL' 'MKTX' 'NVDA']
# 2016-01-22 00:00:00
# 9496.80984442013
# ['FSLR' 'HRL' 'NVDA' 'ULTA' 'STZ']

# %%
spy_select = spy[(spy.Date>'2015-01-23')& (spy.Date<'2016-01-23')]
spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100
result['benchmark-spy(%)'] =  spy_select.set_index('Date')['benchmark-spy(%)']
# Out:
# C:\Users\CHIN\AppData\Local\Temp/ipykernel_20500/162043433.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100

# %%
# plot the return and calculate the annualized return and MDD (maximum draw down) for both strategy
plt.rcParams["figure.figsize"] = (15,6)
plt.plot(result.Return_without_trailing, label='Return without Annualized_return of Portfolio based on EMA and SMA cross-over strategy')
plt.plot(result['benchmark-spy(%)'], label='benchmark-spy(%)')
plt.legend()
print('Annualized_return of Portfolio based on EMA and SMA cross-over strategy:',annualized (result,'Return_without_trailing'))
print('MDD of Portfolio based on EMA AND SMA cross-over strategy:', MDD(result,'Return_without_trailing'))

print('Annualized_return of benchmark-spy:',annualized (result,'benchmark-spy(%)'))
print('MDD of benchmark-spy:', MDD(result,'benchmark-spy(%)'))
# Out:
# Annualized_return of Portfolio based on EMA and SMA cross-over strategy: -7.232911201168957
# MDD of Portfolio based on EMA AND SMA cross-over strategy: -24.616888104540802
# Annualized_return of benchmark-spy: -10.390743094019307
# MDD of benchmark-spy: -13.044499345908967

# %%
result, hold_detail= backtest_strategy_portfolio(signal_etf_stock[(signal_etf_stock.Date>'2014-01-23') &(signal_etf_stock.Date<'2015-01-23')],10000)
# Out:
# 2014-01-24 00:00:00
# 10000.0
# ['INCY' 'MU' 'DXCM' 'DAL' 'ENPH' 'AAL' 'STZ' 'BSX' 'MGM' 'UAL']
# 2014-01-27 00:00:00
# 9803.225875366315
# ['INCY' 'MU' 'DXCM' 'DAL' 'HII' 'ENPH' 'ALGN' 'AAL' 'STZ' 'BSX']
# 2014-01-28 00:00:00
# 9634.00893367012
# ['INCY' 'MU' 'DXCM' 'DAL' 'AAL' 'HII' 'BIIB' 'TYL' 'ALGN' 'STZ']
# 2014-01-29 00:00:00
# 9778.624604745402
# ['TSLA' 'INCY' 'MU' 'ILMN' 'DXCM' 'AAL' 'DAL' 'HII' 'LYV' 'NOW']
# 2014-01-30 00:00:00
# 10101.440738928128
# ['TSLA' 'INCY' 'MU' 'ILMN' 'DXCM' 'STZ' 'FANG' 'DAL' 'HII' 'NOW']
# 2014-01-31 00:00:00
# 10023.379185398366
# ['TSLA' 'INCY' 'MU' 'ILMN' 'STZ' 'NOW' 'FANG' 'DAL' 'HII' 'LYV']
# 2014-02-03 00:00:00
# 10164.762817901925
# ['TSLA' 'INCY' 'ILMN' 'MU' 'STZ' 'DAL' 'NOW' 'HII' 'LYV' 'GILD']
# 2014-02-04 00:00:00
# 10007.11607194823
# ['TSLA' 'INCY' 'ILMN' 'MU' 'STZ' 'DAL' 'HII' 'LYV' 'BIIB' 'MGM']
# 2014-02-05 00:00:00
# 10010.188448167075
# ['TSLA' 'INCY' 'ILMN' 'MU' 'STZ' 'NFLX' 'DAL' 'HII' 'LYV' 'BIIB']
# 2014-02-06 00:00:00
# 10011.970706441667
# ['TSLA' 'INCY' 'MU' 'ILMN' 'STZ' 'NFLX' 'DAL' 'HII' 'LYV' 'GILD']
# 2014-02-07 00:00:00
# 10175.566144174989
# ['TSLA' 'INCY' 'ILMN' 'NFLX' 'LYV' 'HII' 'EPAM' 'GILD' 'BIIB' 'UAL']
# 2014-02-10 00:00:00
# 10507.999600299807
# ['TSLA' 'INCY' 'ILMN' 'DXCM' 'NFLX' 'EPAM' 'HII' 'GILD' 'BIIB' 'CHTR']
# 2014-02-11 00:00:00
# 10652.001410051855
# ['INCY' 'ILMN' 'DXCM' 'AAL' 'STZ' 'NFLX' 'EPAM' 'HII' 'GILD' 'BIIB']
# 2014-02-12 00:00:00
# 10711.640721778105
# ['INCY' 'ILMN' 'DXCM' 'STZ' 'AAL' 'NFLX' 'GILD' 'BSX' 'CHTR' 'ALGN']
# 2014-02-13 00:00:00
# 10565.926522615837
# ['ILMN' 'DXCM' 'AAL' 'NFLX' 'META' 'NOW' 'CHTR' 'BSX' 'CMG' 'EA']
# 2014-02-14 00:00:00
# 10837.774171133891
# ['AAL' 'META' 'NOW' 'WYNN' 'CMG' 'TYL' 'EA' 'EQT' 'TSN' 'AIZ']
# 2014-02-18 00:00:00
# 10858.338242101563
# ['AAL' 'WYNN' 'CMG' 'TYL' 'EQT' 'EA' 'TSN' 'CTRA' 'CMCSA' 'DXC']
# 2014-02-19 00:00:00
# 10924.910432531535
# ['AAL' 'NFLX' 'WYNN' 'CMG' 'DISH' 'CTRA' 'XYL' 'CNC' 'CMCSA' 'A']
# 2014-02-20 00:00:00
# 10880.983954115616
# ['INCY' 'AAL' 'NFLX' 'DAL' 'NOW' 'EPAM' 'WYNN' 'LUV' 'CMG' 'SPGI']
# 2014-02-21 00:00:00
# 11027.659514888612
# ['MU' 'INCY' 'FANG' 'AAL' 'NFLX' 'DAL' 'NOW' 'EPAM' 'WYNN' 'LUV']
# 2014-02-24 00:00:00
# 11136.10391907242
# ['TSLA' 'FANG' 'MU' 'INCY' 'AAL' 'META' 'NFLX' 'DAL' 'NOW' 'LYV']
# 2014-02-25 00:00:00
# 11550.165813764635
# ['TSLA' 'INCY' 'MU' 'META' 'NFLX' 'NOW' 'LYV' 'REGN' 'EPAM' 'WYNN']
# 2014-02-26 00:00:00
# 11627.354348774024
# ['INCY' 'DXCM' 'MU' 'META' 'NFLX' 'NOW' 'REGN' 'GILD' 'EPAM' 'BKNG']
# 2014-02-27 00:00:00
# 11516.638488351424
# ['DXCM' 'MU' 'FANG' 'META' 'NFLX' 'NOW' 'BIIB' 'FSLR' 'HII' 'REGN']
# 2014-02-28 00:00:00
# 11674.143865649014
# ['ILMN' 'DXCM' 'MU' 'FANG' 'META' 'NFLX' 'FSLR' 'NOW' 'HII' 'BIIB']
# 2014-03-03 00:00:00
# 11379.173025101878
# ['ILMN' 'DXCM' 'MU' 'FANG' 'META' 'NFLX' 'FSLR' 'NOW' 'BIIB' 'REGN']
# 2014-03-04 00:00:00
# 11669.687953906465
# ['ILMN' 'DXCM' 'MU' 'FANG' 'NFLX' 'META' 'MGM' 'FSLR' 'BIIB' 'REGN']
# 2014-03-05 00:00:00
# 11830.449317046152
# ['ILMN' 'DXCM' 'MU' 'FANG' 'AAL' 'META' 'MGM' 'FSLR' 'LYV' 'BIIB']
# 2014-03-06 00:00:00
# 11952.523585629591
# ['TSLA' 'ILMN' 'INCY' 'MU' 'FANG' 'AAL' 'META' 'MGM' 'FSLR' 'LYV']
# 2014-03-07 00:00:00
# 11918.413549650113
# ['TSLA' 'ILMN' 'INCY' 'AAL' 'META' 'FANG' 'NFLX' 'MGM' 'FSLR' 'WYNN']
# 2014-03-10 00:00:00
# 11685.890859945617
# ['TSLA' 'ILMN' 'DXCM' 'INCY' 'FANG' 'NFLX' 'META' 'MGM' 'FSLR' 'WYNN']
# 2014-03-11 00:00:00
# 11545.267828953474
# ['TSLA' 'ILMN' 'DXCM' 'INCY' 'FANG' 'NFLX' 'MGM' 'CSGP' 'WYNN' 'FSLR']
# 2014-03-12 00:00:00
# 11357.880328324021
# ['TSLA' 'ILMN' 'DXCM' 'INCY' 'FANG' 'NFLX' 'MGM' 'CSGP' 'WYNN' 'FSLR']
# 2014-03-13 00:00:00
# 11580.041840580529
# ['TSLA' 'ILMN' 'DXCM' 'FANG' 'NFLX' 'AAL' 'DAL' 'CSGP' 'MGM' 'WYNN']
# 2014-03-14 00:00:00
# 11193.083048040658
# ['TSLA' 'DXCM' 'FANG' 'META' 'MU' 'AAL' 'DAL' 'CSGP' 'MGM' 'WYNN']
# 2014-03-17 00:00:00
# 11265.796947940527
# ['TSLA' 'DXCM' 'FANG' 'MU' 'INCY' 'META' 'AAL' 'DAL' 'CSGP' 'MGM']
# 2014-03-18 00:00:00
# 11359.12797664744
# ['TSLA' 'ILMN' 'DXCM' 'INCY' 'FANG' 'MU' 'META' 'NFLX' 'AAL' 'MGM']
# 2014-03-19 00:00:00
# 11522.124610707808
# ['TSLA' 'ILMN' 'DXCM' 'INCY' 'META' 'MU' 'NFLX' 'AAL' 'MGM' 'CSGP']
# 2014-03-20 00:00:00
# 11337.000597648916
# ['TSLA' 'ILMN' 'DXCM' 'META' 'MU' 'NFLX' 'AAL' 'MGM' 'DAL' 'NXPI']
# 2014-03-21 00:00:00
# 11387.347930747277
# ['TSLA' 'META' 'MU' 'NFLX' 'AAL' 'MGM' 'DAL' 'CSGP' 'HII' 'LYV']
# 2014-03-24 00:00:00
# 11147.529383665349
# ['TSLA' 'INCY' 'META' 'MU' 'NFLX' 'AAL' 'CSGP' 'WYNN' 'LYV' 'REGN']
# 2014-03-25 00:00:00
# 10895.569967024543
# ['TSLA' 'ILMN' 'DXCM' 'META' 'INCY' 'MU' 'AAL' 'NFLX' 'NXPI' 'CSGP']
# 2014-03-26 00:00:00
# 10847.050634017269
# ['TSLA' 'ILMN' 'DXCM' 'META' 'FANG' 'INCY' 'MU' 'DAL' 'NXPI' 'HII']
# 2014-03-27 00:00:00
# 10551.760193060072
# ['TSLA' 'ILMN' 'DXCM' 'FANG' 'META' 'MU' 'DAL' 'NXPI' 'MGM' 'HII']
# 2014-03-28 00:00:00
# 10584.649700009664
# ['TSLA' 'ILMN' 'META' 'MU' 'DXCM' 'AAL' 'NXPI' 'MGM' 'HII' 'SIVB']
# 2014-03-31 00:00:00
# 10638.01868674823
# ['TSLA' 'FSLR' 'ILMN' 'META' 'MU' 'DXCM' 'AAL' 'NXPI' 'MGM' 'AVGO']
# 2014-04-01 00:00:00
# 10863.50605159072
# ['TSLA' 'ILMN' 'FSLR' 'MU' 'DXCM' 'INCY' 'AAL' 'META' 'NXPI' 'MGM']
# 2014-04-02 00:00:00
# 11189.991634192716
# ['TSLA' 'FSLR' 'INCY' 'DXCM' 'META' 'URI' 'AVGO' 'SIVB' 'CMG' 'SWKS']
# 2014-04-03 00:00:00
# 11199.477711062591
# ['FSLR' 'DXCM' 'SIVB' 'URI' 'SWKS' 'AMD' 'CMG' 'GNRC' 'CSGP' 'SCHW']
# 2014-04-04 00:00:00
# 11125.148928987563
# ['FSLR' 'SIVB' 'TSN' 'CSGP' 'CMG' 'LNC' 'SCHW' 'DD' 'HAL' 'PRU']
# 2014-04-07 00:00:00
# 10717.230227188746
# ['SIVB' 'AVGO' 'FSLR' 'TSN' 'AKAM' 'DD' 'SCHW' 'AMD' 'STX' 'HAL']
# 2014-04-08 00:00:00
# 10583.524013328804
# ['FANG' 'AAL' 'DAL' 'FSLR' 'NXPI' 'SIVB' 'TSN' 'AVGO' 'BSX' 'WDC']
# 2014-04-09 00:00:00
# 10761.81655274055
# ['FANG' 'AAL' 'DAL' 'FSLR' 'NXPI' 'MGM' 'HII' 'TSN' 'SIVB' 'WDC']
# 2014-04-10 00:00:00
# 10877.279922920115
# ['FANG' 'DXCM' 'MU' 'DAL' 'NXPI' 'FSLR' 'MGM' 'HII' 'AVGO' 'TSN']
# 2014-04-11 00:00:00
# 10333.150014266967
# ['TSLA' 'FANG' 'ILMN' 'DXCM' 'MU' 'NXPI' 'MGM' 'FSLR' 'HII' 'TSN']
# 2014-04-14 00:00:00
# 10448.849496039333
# ['TSLA' 'FANG' 'ILMN' 'AAL' 'NXPI' 'MGM' 'HII' 'FSLR' 'TSN' 'LUV']
# 2014-04-15 00:00:00
# 10364.630154122091
# ['TSLA' 'ILMN' 'NXPI' 'DAL' 'AAL' 'HII' 'MGM' 'FSLR' 'BSX' 'AVGO']
# 2014-04-16 00:00:00
# 10455.753150364588
# ['TSLA' 'ILMN' 'NXPI' 'DAL' 'AAL' 'HII' 'BSX' 'AVGO' 'WDC' 'SWKS']
# 2014-04-17 00:00:00
# 10565.505528258536
# ['TSLA' 'ILMN' 'NXPI' 'AAL' 'DAL' 'AVGO' 'WDC' 'EOG' 'FSLR' 'LUV']
# 2014-04-21 00:00:00
# 10615.058770433297
# ['TSLA' 'LUV' 'FSLR' 'GRMN' 'SIVB' 'VTRS' 'GLW' 'HPQ' 'EQT' 'RCL']
# 2014-04-22 00:00:00
# 10759.428330837603
# ['FSLR' 'HPQ' 'GLW' 'RCL' 'HUM' 'AMAT' 'ZBRA' 'FRC' 'CMA' 'IDXX']
# 2014-04-23 00:00:00
# 10900.136513122448
# ['HPQ' 'FSLR' 'HUM' 'ZBRA' 'NVDA' 'FRC' 'ADM' 'XYL' 'UNH' 'ON']
# 2014-04-24 00:00:00
# 10979.840276619736
# ['HPQ' 'HUM' 'NVDA' 'FRC' 'ADM' 'UNH' 'ON' 'STLD' 'TFC' 'CAT']
# 2014-04-25 00:00:00
# 10927.134861087226
# ['HPQ' 'ADM' 'UNH' 'STLD' 'EW' 'NEE']
# 2014-04-28 00:00:00
# 10947.192017314035
# ['TSN' 'EOG' 'WDC' 'PXD' 'TRGP' 'HPQ' 'GRMN' 'TMO' 'TEL' 'FFIV']
# 2014-04-29 00:00:00
# 10953.087823585229
# ['FANG' 'HII' 'BSX' 'TSN' 'SBNY' 'TRGP' 'EOG' 'WDC' 'NOC' 'BWA']
# 2014-04-30 00:00:00
# 10939.877927852209
# ['FANG' 'MU' 'NXPI' 'ILMN' 'HII' 'URI' 'TSN' 'BSX' 'TRGP' 'EOG']
# 2014-05-01 00:00:00
# 11038.708984147686
# ['MU' 'FANG' 'NXPI' 'ILMN' 'AAL' 'META' 'AVGO' 'HII' 'URI' 'LUV']
# 2014-05-02 00:00:00
# 11163.206345759958
# ['MU' 'FANG' 'META' 'NXPI' 'ILMN' 'AAL' 'AVGO' 'HII' 'LUV' 'VTRS']
# 2014-05-05 00:00:00
# 11109.897497731827
# ['TSLA' 'MU' 'FANG' 'META' 'NXPI' 'AAL' 'ILMN' 'DAL' 'AVGO' 'HII']
# 2014-05-06 00:00:00
# 11355.482487872507
# ['TSLA' 'MU' 'FANG' 'AAL' 'NXPI' 'ILMN' 'DAL' 'AVGO' 'SWKS' 'LUV']
# 2014-05-07 00:00:00
# 11240.29451875034
# ['MU' 'FANG' 'AAL' 'NXPI' 'ILMN' 'DAL' 'SWKS' 'LUV' 'VTRS' 'BSX']
# 2014-05-08 00:00:00
# 11179.106657860897
# ['MU' 'DAL' 'SWKS' 'LUV' 'VTRS' 'LMT' 'TSN' 'OKE' 'HPQ' 'ODFL']
# 2014-05-09 00:00:00
# 11151.482036831077
# ['DAL' 'SWKS' 'LUV' 'LMT' 'STZ' 'VTRS' 'TSN' 'ODFL' 'OKE' 'BKR']
# 2014-05-12 00:00:00
# 11173.270078323087
# ['DAL' 'HII' 'SWKS' 'LUV' 'LMT' 'STZ' 'TSN' 'GRMN' 'MGM' 'HPQ']
# 2014-05-13 00:00:00
# 11320.474766705778
# ['MU' 'FANG' 'META' 'DAL' 'HII' 'SWKS' 'LMT' 'STZ' 'TSN' 'GRMN']
# 2014-05-14 00:00:00
# 11327.578344900678
# ['MU' 'FANG' 'META' 'TSLA' 'DAL' 'NXPI' 'HII' 'SWKS' 'STZ' 'MGM']
# 2014-05-15 00:00:00
# 11146.905997331249
# ['MU' 'INCY' 'FANG' 'TSLA' 'DAL' 'NXPI' 'HII' 'SWKS' 'TMUS' 'ZBRA']
# 2014-05-16 00:00:00
# 11012.985004079452
# ['MU' 'INCY' 'FANG' 'TSLA' 'DAL' 'NXPI' 'AVGO' 'HII' 'SWKS' 'TMUS']
# 2014-05-19 00:00:00
# 11032.0285465164
# ['MU' 'FANG' 'TSLA' 'AAL' 'DAL' 'NXPI' 'AVGO' 'HII' 'SWKS' 'TRGP']
# 2014-05-20 00:00:00
# 11148.248177048528
# ['MU' 'FANG' 'AAL' 'DAL' 'NXPI' 'AVGO' 'SWKS' 'HII' 'LYV' 'EA']
# 2014-05-21 00:00:00
# 11119.076282808648
# ['MU' 'FANG' 'AAL' 'DAL' 'NXPI' 'AVGO' 'SWKS' 'LYV' 'ALK' 'ZBRA']
# 2014-05-22 00:00:00
# 11221.361418080207
# ['MU' 'AAL' 'DAL' 'NXPI' 'AVGO' 'SWKS' 'LUV' 'LYV' 'ALK' 'EOG']
# 2014-05-23 00:00:00
# 11299.01169469759
# ['MU' 'AAL' 'NXPI' 'DAL' 'AVGO' 'SWKS' 'LUV' 'HII' 'URI' 'ALK']
# 2014-05-27 00:00:00
# 11533.832584824766
# ['MU' 'AAL' 'DAL' 'AVGO' 'NXPI' 'SWKS' 'HII' 'URI' 'ALK' 'TMUS']
# 2014-05-28 00:00:00
# 11567.78035692822
# ['AAL' 'ALK' 'TSN' 'TMUS' 'MCK' 'EOG' 'HUM' 'DISH' 'LMT' 'EA']
# 2014-05-29 00:00:00
# 11630.648920342657
# ['TMUS' 'TSN' 'MCK' 'EA' 'GILD' 'PXD' 'BALL' 'KR' 'ATVI' 'VFC']
# 2014-05-30 00:00:00
# 11703.452527958036
# ['TRGP' 'MCK' 'TMUS' 'EA' 'GILD' 'AAP' 'ATVI' 'BALL' 'ADSK' 'KR']
# 2014-06-02 00:00:00
# 11736.957614454583
# ['TRGP' 'LYV' 'TMUS' 'STZ' 'HUM' 'GILD' 'EA' 'AAP' 'ATVI' 'ADSK']
# 2014-06-03 00:00:00
# 11709.801686270284
# ['ILMN' 'TSLA' 'TRGP' 'EPAM' 'LYV' 'TMUS' 'STZ' 'HUM' 'GILD' 'EA']
# 2014-06-04 00:00:00
# 11742.484308813233
# ['ILMN' 'TSLA' 'URI' 'NFLX' 'TRGP' 'LYV' 'EPAM' 'OKE' 'TMUS' 'GILD']
# 2014-06-05 00:00:00
# 11897.875872624523
# ['META' 'ILMN' 'TSLA' 'URI' 'NFLX' 'TRGP' 'LYV' 'EPAM' 'OKE' 'RCL']
# 2014-06-06 00:00:00
# 12106.785920501708
# ['META' 'ILMN' 'URI' 'TSLA' 'NFLX' 'AVGO' 'ALK' 'EPAM' 'LYV' 'MGM']
# 2014-06-09 00:00:00
# 12077.286738305293
# ['META' 'ILMN' 'MU' 'TSLA' 'NXPI' 'NFLX' 'AVGO' 'ALK' 'EPAM' 'GRMN']
# 2014-06-10 00:00:00
# 12090.186844751595
# ['META' 'MU' 'TSLA' 'NXPI' 'AVGO' 'NFLX' 'LUV' 'GRMN' 'EPAM' 'ALK']
# 2014-06-11 00:00:00
# 12112.766601366733
# ['META' 'MU' 'DAL' 'TSLA' 'NFLX' 'AVGO' 'LUV' 'ALK' 'EPAM' 'MCK']
# 2014-06-12 00:00:00
# 12106.029379168724
# ['META' 'DAL' 'TSLA' 'NFLX' 'AVGO' 'LUV' 'HII' 'EPAM' 'ALK' 'MCK']
# 2014-06-13 00:00:00
# 11920.460986814054
# ['AAL' 'SWKS' 'DAL' 'NXPI' 'TSLA' 'NFLX' 'AVGO' 'LUV' 'TRGP' 'HII']
# 2014-06-16 00:00:00
# 11903.233888019324
# ['AAL' 'SWKS' 'URI' 'DAL' 'TSLA' 'NXPI' 'LUV' 'AVGO' 'NFLX' 'TRGP']
# 2014-06-17 00:00:00
# 12109.159174809405
# ['AAL' 'ILMN' 'SWKS' 'DAL' 'URI' 'NXPI' 'LUV' 'NFLX' 'AVGO' 'TRGP']
# 2014-06-18 00:00:00
# 12246.925586158124
# ['META' 'AAL' 'ILMN' 'SWKS' 'DAL' 'URI' 'NXPI' 'LUV' 'NFLX' 'TRGP']
# 2014-06-19 00:00:00
# 12366.16321848059
# ['META' 'AAL' 'ILMN' 'SWKS' 'DAL' 'URI' 'NXPI' 'NFLX' 'DXCM' 'LUV']
# 2014-06-20 00:00:00
# 12386.496755737197
# ['AAL' 'META' 'ILMN' 'SWKS' 'DAL' 'URI' 'NXPI' 'LUV' 'AVGO' 'ALK']
# 2014-06-23 00:00:00
# 12498.098128503478
# ['FANG' 'META' 'ILMN' 'SWKS' 'DAL' 'URI' 'AVGO' 'ZBRA' 'MPWR' 'RCL']
# 2014-06-24 00:00:00
# 12450.487728636659
# ['FANG' 'META' 'ILMN' 'SWKS' 'URI' 'NFLX' 'AVGO' 'ZBRA' 'MPWR' 'CMG']
# 2014-06-25 00:00:00
# 12287.90484531725
# ['META' 'FANG' 'MU' 'ILMN' 'SWKS' 'URI' 'NFLX' 'AVGO' 'ZBRA' 'MPWR']
# 2014-06-26 00:00:00
# 12473.055784722734
# ['FANG' 'ILMN' 'MU' 'SWKS' 'NFLX' 'AVGO' 'ZBRA' 'EOG' 'MPWR' 'GRMN']
# 2014-06-27 00:00:00
# 12361.794721577224
# ['FANG' 'ILMN' 'MU' 'TSLA' 'SWKS' 'NFLX' 'DXCM' 'WMB' 'EOG' 'MPWR']
# 2014-06-30 00:00:00
# 12437.295715608132
# ['FANG' 'ILMN' 'MU' 'SWKS' 'NXPI' 'TRGP' 'TSLA' 'NFLX' 'WMB' 'MPWR']
# 2014-07-01 00:00:00
# 12689.315557109705
# ['AAL' 'FANG' 'MU' 'SWKS' 'LUV' 'NXPI' 'TRGP' 'TSLA' 'NFLX' 'ZBRA']
# 2014-07-02 00:00:00
# 12831.83233165025
# ['AAL' 'FANG' 'SWKS' 'LUV' 'TRGP' 'NXPI' 'TSLA' 'ZBRA' 'WMB' 'DXCM']
# 2014-07-03 00:00:00
# 12772.903066431978
# ['AAL' 'FANG' 'SWKS' 'TRGP' 'NXPI' 'TSLA' 'STZ' 'WMB' 'DXCM' 'MPWR']
# 2014-07-07 00:00:00
# 12723.979442462232
# ['META' 'FANG' 'AAL' 'TRGP' 'TSLA' 'OKE' 'STZ' 'WMB' 'DXCM' 'RCL']
# 2014-07-08 00:00:00
# 12435.634678572525
# ['META' 'FANG' 'AAL' 'TRGP' 'DAL' 'TSLA' 'OKE' 'STZ' 'MGM' 'WMB']
# 2014-07-09 00:00:00
# 12527.007452787851
# ['MU' 'AAL' 'FANG' 'LUV' 'TRGP' 'DAL' 'TSLA' 'OKE' 'STZ' 'WMB']
# 2014-07-10 00:00:00
# 12317.233808352832
# ['MU' 'AAL' 'FANG' 'ILMN' 'LUV' 'TRGP' 'DAL' 'NFLX' 'OKE' 'TSLA']
# 2014-07-11 00:00:00
# 12542.751024492944
# ['MU' 'META' 'AAL' 'ILMN' 'FANG' 'TRGP' 'LUV' 'NXPI' 'DAL' 'ZBRA']
# 2014-07-14 00:00:00
# 12686.64314525413
# ['META' 'MU' 'ILMN' 'FANG' 'SWKS' 'TRGP' 'LUV' 'NXPI' 'AVGO' 'DAL']
# 2014-07-15 00:00:00
# 12711.624731180984
# ['META' 'MU' 'ILMN' 'FANG' 'SWKS' 'TRGP' 'TSLA' 'LUV' 'NXPI' 'DAL']
# 2014-07-16 00:00:00
# 12679.72748086505
# ['MU' 'ILMN' 'FANG' 'SWKS' 'LUV' 'TRGP' 'NXPI' 'URI' 'AVGO' 'TSLA']
# 2014-07-17 00:00:00
# 12666.198554539511
# ['ILMN' 'FANG' 'SWKS' 'TRGP' 'NXPI' 'AVGO' 'URI' 'ZBRA' 'OKE' 'WMB']
# 2014-07-18 00:00:00
# 12618.101598192276
# ['ILMN' 'FANG' 'TRGP' 'NXPI' 'URI' 'SWKS' 'AVGO' 'ZBRA' 'OKE' 'WMB']
# 2014-07-21 00:00:00
# 12810.235674020996
# ['ILMN' 'NXPI' 'TRGP' 'AVGO' 'ZBRA' 'WMB' 'STZ' 'MCK' 'AAP' 'ALK']
# 2014-07-22 00:00:00
# 12828.945152624688
# ['MU' 'TRGP' 'ZBRA' 'WMB' 'STZ' 'MCK' 'MAR' 'AAPL' 'ALK' 'AAP']
# 2014-07-23 00:00:00
# 12841.600852821892
# ['MU' 'AAL' 'TRGP' 'ZBRA' 'WMB' 'STZ' 'MAR' 'MCK' 'ALK' 'CDW']
# 2014-07-24 00:00:00
# 12883.498884431294
# ['MU' 'AAL' 'TRGP' 'NXPI' 'ZBRA' 'STZ' 'NFLX' 'ALK' 'WDC' 'AAPL']
# 2014-07-25 00:00:00
# 12705.880106230336
# ['MU' 'AAL' 'TRGP' 'AVGO' 'NXPI' 'NFLX' 'STZ' 'WDC' 'AAP' 'ADBE']
# 2014-07-28 00:00:00
# 12550.060550025351
# ['MU' 'AAL' 'TRGP' 'AVGO' 'NXPI' 'NFLX' 'WMB' 'WDC' 'EOG' 'GPN']
# 2014-07-29 00:00:00
# 12439.00642898001
# ['MU' 'AAL' 'URI' 'TRGP' 'AVGO' 'NXPI' 'NFLX' 'WMB' 'HCA' 'EOG']
# 2014-07-30 00:00:00
# 12476.258360970618
# ['MU' 'FANG' 'SWKS' 'ILMN' 'AAL' 'TRGP' 'URI' 'AVGO' 'NXPI' 'NFLX']
# 2014-07-31 00:00:00
# 12265.04048205582
# ['MU' 'SWKS' 'ILMN' 'AAL' 'FANG' 'TRGP' 'AVGO' 'URI' 'NXPI' 'NFLX']
# 2014-08-01 00:00:00
# 12091.48988487611
# ['MU' 'SWKS' 'AAL' 'LUV' 'FANG' 'META' 'AVGO' 'TRGP' 'URI' 'NXPI']
# 2014-08-04 00:00:00
# 12227.69686692526
# ['MU' 'SWKS' 'AAL' 'LUV' 'AVGO' 'TRGP' 'FANG' 'META' 'URI' 'NXPI']
# 2014-08-05 00:00:00
# 12222.933831121623
# ['MU' 'SWKS' 'LUV' 'ILMN' 'TRGP' 'AVGO' 'FANG' 'META' 'URI' 'NXPI']
# 2014-08-06 00:00:00
# 12024.871314319731
# ['MU' 'SWKS' 'LUV' 'ILMN' 'URI' 'META' 'FANG' 'DXCM' 'CMG' 'ZBRA']
# 2014-08-07 00:00:00
# 12133.325905757276
# ['SWKS' 'MU' 'LUV' 'URI' 'META' 'FANG' 'ENPH' 'HCA' 'CMG' 'FSLR']
# 2014-08-08 00:00:00
# 12072.510285456006
# ['SWKS' 'MU' 'LUV' 'META' 'URI' 'FANG' 'HCA' 'FSLR' 'CMG' 'RCL']
# 2014-08-11 00:00:00
# 12213.379203965633
# ['MU' 'SWKS' 'LUV' 'URI' 'META' 'FANG' 'HCA' 'CMG' 'MAR' 'LYB']
# 2014-08-12 00:00:00
# 12203.145388061654
# ['LUV' 'SWKS' 'META' 'FANG' 'HCA' 'EXPE' 'CMG' 'GILD' 'RCL' 'MCK']
# 2014-08-13 00:00:00
# 12213.516912127703
# ['META' 'FANG' 'EXPE' 'HCA' 'CMG' 'GILD' 'LYB' 'RCL' 'MCK' 'UHS']
# 2014-08-14 00:00:00
# 12342.610695586136
# ['EXPE' 'HCA' 'CMG' 'LYB' 'ZBRA' 'UHS' 'MCK' 'WDC' 'REGN' 'UAL']
# 2014-08-15 00:00:00
# 12452.661983877995
# ['EXPE' 'HCA' 'CMG' 'LYB' 'MCK' 'ZBRA' 'UHS' 'WDC' 'REGN' 'UAL']
# 2014-08-18 00:00:00
# 12515.577171032091
# ['EXPE' 'TSLA' 'HCA' 'CMG' 'LYB' 'UHS' 'WDC' 'REGN' 'AMT' 'EW']
# 2014-08-19 00:00:00
# 12557.303174815164
# ['HCA' 'TSLA' 'CMG' 'WDC' 'REGN' 'PTC' 'EW' 'BKNG' 'ADM' 'EPAM']
# 2014-08-20 00:00:00
# 12454.733722305951
# ['FSLR' 'TSLA' 'DXCM' 'ADSK' 'WDC' 'SBAC' 'REGN' 'PTC' 'ADM' 'EW']
# 2014-08-21 00:00:00
# 12509.55952011571
# ['FSLR' 'TSLA' 'DXCM' 'SBAC' 'WDC' 'ADSK' 'REGN' 'AMT' 'ADM' 'EW']
# 2014-08-22 00:00:00
# 12486.097361421796
# ['FSLR' 'CMG' 'DXCM' 'TSLA' 'SBAC' 'TAP' 'REGN' 'AMT' 'ADSK' 'ADM']
# 2014-08-25 00:00:00
# 12550.785989821654
# ['TRGP' 'FSLR' 'CMG' 'DXCM' 'HII' 'TSLA' 'TAP' 'SBAC' 'ADM' 'MCO']
# 2014-08-26 00:00:00
# 12581.134200766042
# ['SWKS' 'TRGP' 'FSLR' 'RCL' 'CMG' 'DXCM' 'BIIB' 'HII' 'STZ' 'TSLA']
# 2014-08-27 00:00:00
# 12619.107875289568
# ['SWKS' 'DAL' 'AVGO' 'FSLR' 'HCA' 'RCL' 'MAR' 'DXCM' 'CMG' 'UHS']
# 2014-08-28 00:00:00
# 12519.042825140752
# ['ENPH' 'SWKS' 'URI' 'DAL' 'AVGO' 'FSLR' 'EXPE' 'META' 'HCA' 'RCL']
# 2014-08-29 00:00:00
# 12666.416147542408
# ['LUV' 'MU' 'ENPH' 'SWKS' 'URI' 'TRGP' 'DAL' 'AVGO' 'FSLR' 'EXPE']
# 2014-09-02 00:00:00
# 12701.46234511052
# ['LUV' 'MU' 'SWKS' 'ENPH' 'URI' 'TRGP' 'DAL' 'FSLR' 'EXPE' 'HCA']
# 2014-09-03 00:00:00
# 12739.336568758414
# ['LUV' 'AAL' 'SWKS' 'MU' 'URI' 'ENPH' 'DAL' 'TRGP' 'FSLR' 'META']
# 2014-09-04 00:00:00
# 12738.855717571925
# ['LUV' 'AAL' 'ILMN' 'SWKS' 'MU' 'URI' 'ENPH' 'TRGP' 'DAL' 'FSLR']
# 2014-09-05 00:00:00
# 12717.20365402119
# ['LUV' 'ILMN' 'ENPH' 'SWKS' 'MU' 'URI' 'DAL' 'TRGP' 'FSLR' 'FANG']
# 2014-09-08 00:00:00
# 12813.470114671023
# ['LUV' 'ILMN' 'SWKS' 'MU' 'URI' 'ENPH' 'TRGP' 'DAL' 'FANG' 'HCA']
# 2014-09-09 00:00:00
# 12843.561807705435
# ['LUV' 'ILMN' 'URI' 'MU' 'ENPH' 'TRGP' 'HCA' 'DAL' 'GILD' 'EXPE']
# 2014-09-10 00:00:00
# 12714.933893182375
# ['LUV' 'URI' 'ILMN' 'TRGP' 'MU' 'ENPH' 'HCA' 'DAL' 'GILD' 'AAP']
# 2014-09-11 00:00:00
# 12846.913334925193
# ['LUV' 'SWKS' 'ILMN' 'URI' 'TRGP' 'MU' 'NXPI' 'DAL' 'GILD' 'TSLA']
# 2014-09-12 00:00:00
# 12870.570350963435
# ['AVGO' 'SWKS' 'ILMN' 'URI' 'NXPI' 'DAL' 'EXPE' 'AAP' 'TSLA' 'GILD']
# 2014-09-15 00:00:00
# 12712.800996010496
# ['AVGO' 'SWKS' 'URI' 'ILMN' 'HPQ' 'AAP' 'TSLA' 'EXPE' 'GILD' 'MAR']
# 2014-09-16 00:00:00
# 12435.022639684545
# ['LUV' 'AVGO' 'SWKS' 'URI' 'ILMN' 'TRGP' 'FSLR' 'MU' 'AAP' 'HPQ']
# 2014-09-17 00:00:00
# 12739.719894351638
# ['LUV' 'SWKS' 'AVGO' 'ILMN' 'URI' 'TRGP' 'NXPI' 'MU' 'FSLR' 'AAP']
# 2014-09-18 00:00:00
# 12828.037632156433
# ['SWKS' 'ILMN' 'AVGO' 'URI' 'TRGP' 'NXPI' 'MU' 'FSLR' 'HPQ' 'RCL']
# 2014-09-19 00:00:00
# 12994.43038278969
# ['ILMN' 'AVGO' 'NXPI' 'TRGP' 'MU' 'FSLR' 'RCL' 'MAR' 'GILD' 'AAP']
# 2014-09-22 00:00:00
# 12749.042834453194
# ['AVGO' 'ILMN' 'ENPH' 'NXPI' 'TRGP' 'FSLR' 'HCA' 'RCL' 'GILD' 'AAP']
# 2014-09-23 00:00:00
# 12515.456236971168
# ['LUV' 'ILMN' 'AVGO' 'ENPH' 'TRGP' 'NXPI' 'HCA' 'RCL' 'FSLR' 'MNST']
# 2014-09-24 00:00:00
# 12447.56002778949
# ['LUV' 'ILMN' 'AVGO' 'URI' 'ENPH' 'NXPI' 'TRGP' 'HCA' 'FSLR' 'MNST']
# 2014-09-25 00:00:00
# 12466.851049085511
# ['LUV' 'AVGO' 'ILMN' 'URI' 'TRGP' 'ENPH' 'HCA' 'MNST' 'FSLR' 'MAR']
# 2014-09-26 00:00:00
# 12220.483574324448
# ['LUV' 'AVGO' 'ILMN' 'URI' 'TRGP' 'ENPH' 'RCL' 'HCA' 'MNST' 'HPQ']
# 2014-09-29 00:00:00
# 12191.769020055333
# ['LUV' 'ILMN' 'AVGO' 'URI' 'NXPI' 'TRGP' 'ENPH' 'RCL' 'MNST' 'FSLR']
# 2014-09-30 00:00:00
# 12400.15787125611
# ['LUV' 'ILMN' 'AVGO' 'URI' 'NXPI' 'TRGP' 'ENPH' 'MNST' 'RCL' 'MAR']
# 2014-10-01 00:00:00
# 12279.673767855702
# ['SWKS' 'LUV' 'ILMN' 'AVGO' 'URI' 'TRGP' 'NXPI' 'ENPH' 'MNST' 'RCL']
# 2014-10-02 00:00:00
# 11864.86088574318
# ['LUV' 'SWKS' 'AVGO' 'TRGP' 'MNST' 'NXPI' 'ENPH' 'GILD' 'RCL' 'HPQ']
# 2014-10-03 00:00:00
# 11783.794961069238
# ['LUV' 'SWKS' 'AVGO' 'MNST' 'NXPI' 'GILD' 'RCL' 'MAR' 'HII' 'META']
# 2014-10-06 00:00:00
# 11952.57659001932
# ['LUV' 'SWKS' 'AVGO' 'URI' 'MNST' 'NXPI' 'RCL' 'GILD' 'MAR' 'HCA']
# 2014-10-07 00:00:00
# 11646.346660605468
# ['LUV' 'SWKS' 'AVGO' 'URI' 'RCL' 'MU' 'NXPI' 'GILD' 'META' 'MAR']
# 2014-10-08 00:00:00
# 11456.012326576643
# ['LUV' 'SWKS' 'AVGO' 'NXPI' 'GILD' 'MU' 'RCL' 'EXPE' 'META' 'MAR']
# 2014-10-09 00:00:00
# 11557.982824416233
# ['SWKS' 'LUV' 'AVGO' 'TRGP' 'NXPI' 'MU' 'GILD' 'RCL' 'EXPE' 'META']
# 2014-10-10 00:00:00
# 10931.07088616123
# ['SWKS' 'LUV' 'AVGO' 'TRGP' 'GILD' 'EXPE' 'META' 'UAL' 'CMG' 'VRTX']
# 2014-10-13 00:00:00
# 10656.116070110666
# ['LUV' 'EXPE' 'GILD' 'CMG' 'META' 'UAL' 'VRTX' 'GD' 'TSN' 'ODFL']
# 2014-10-14 00:00:00
# 10365.248644319361
# ['LUV' 'GILD' 'AAP' 'CMG' 'META' 'HCA' 'KDP' 'VRTX' 'EW' 'MCK']
# 2014-10-15 00:00:00
# 10117.781990828957
# ['LUV' 'CMG' 'GILD' 'HCA' 'META' 'KDP' 'AAP' 'NFLX' 'VRTX' 'IRM']
# 2014-10-16 00:00:00
# 9766.063180564144
# ['LUV' 'MNST' 'CMG' 'GILD' 'META' 'KDP' 'DXCM' 'AAP' 'HCA' 'NFLX']
# 2014-10-17 00:00:00
# 10144.887506932932
# ['SWKS' 'LUV' 'AVGO' 'MNST' 'GILD' 'HCA' 'ODFL' 'KDP' 'UNP' 'AAP']
# 2014-10-20 00:00:00
# 10145.579107020118
# ['SWKS' 'AVGO' 'MNST' 'GILD' 'HCA' 'META' 'KDP' 'UNP' 'AAP' 'VRTX']
# 2014-10-21 00:00:00
# 10450.362592809399
# ['MNST' 'GILD' 'KDP' 'MCK' 'CAH' 'AAPL' 'CVS' 'ISRG' 'ELV' 'EW']
# 2014-10-22 00:00:00
# 10675.969658492058
# ['MNST' 'TSLA' 'CAH' 'TSN' 'EW' 'CVS' 'TAP' 'MSFT' 'MCO' 'MO']
# 2014-10-23 00:00:00
# 10707.168487525303
# ['TSN' 'TSLA' 'TAP' 'EQR' 'CF']
# 2014-10-24 00:00:00
# 10697.379639804554
# ['EQR' 'ARE' 'EIX']
# 2014-10-27 00:00:00
# 10722.85821241688
# ['EQR' 'EIX' 'ARE']
# 2014-10-28 00:00:00
# 10745.996133190227
# ['DPZ' 'EQR' 'EIX' 'ARE']
# 2014-10-29 00:00:00
# 10774.515837774952
# ['BALL' 'DPZ' 'EQR' 'ARE' 'EXR' 'CMG' 'APD']
# 2014-10-30 00:00:00
# 10707.744300451388
# ['HCA' 'MOH' 'BALL' 'CSX' 'VTRS' 'DPZ' 'EQR' 'ARE' 'SNA' 'EXR']
# 2014-10-31 00:00:00
# 10858.274440311565
# ['LUV' 'MNST' 'META' 'MOH' 'HCA' 'DLR' 'VTRS' 'REGN' 'UNH' 'CSX']
# 2014-11-03 00:00:00
# 10921.636485509356
# ['ILMN' 'LUV' 'AAL' 'MNST' 'URI' 'DXCM' 'META' 'WMB' 'IRM' 'AAP']
# 2014-11-04 00:00:00
# 10969.51622456695
# ['ILMN' 'LUV' 'AVGO' 'AAL' 'MNST' 'VRTX' 'URI' 'WMB' 'GILD' 'ODFL']
# 2014-11-05 00:00:00
# 11077.150008086312
# ['ILMN' 'AAL' 'AVGO' 'VRTX' 'MNST' 'URI' 'DXCM' 'GILD' 'ODFL' 'DAL']
# 2014-11-06 00:00:00
# 10895.550367432485
# ['ILMN' 'AAL' 'EW' 'VRTX' 'URI' 'MNST' 'GD' 'RCL' 'META' 'DAL']
# 2014-11-07 00:00:00
# 11067.103066929583
# ['ILMN' 'EW' 'VRTX' 'AAL' 'MU' 'MNST' 'MAR' 'GD' 'DAL' 'META']
# 2014-11-10 00:00:00
# 11030.980574902604
# ['ILMN' 'EW' 'VRTX' 'AAL' 'MU' 'MAR' 'META' 'GD' 'CNC' 'WMB']
# 2014-11-11 00:00:00
# 11132.585755909553
# ['SWKS' 'EW' 'ILMN' 'AVGO' 'AAL' 'MU' 'TSLA' 'INCY' 'MAR' 'CNC']
# 2014-11-12 00:00:00
# 11150.379884525551
# ['SWKS' 'ILMN' 'EW' 'AVGO' 'AAL' 'TSLA' 'MU' 'MAR' 'CNC' 'GD']
# 2014-11-13 00:00:00
# 11186.370251915945
# ['SWKS' 'AVGO' 'ILMN' 'EW' 'AAL' 'MU' 'CNC' 'MAR' 'GD' 'INCY']
# 2014-11-14 00:00:00
# 11216.3198264247
# ['SWKS' 'ILMN' 'AVGO' 'EW' 'AAL' 'VRTX' 'NXPI' 'EA' 'CNC' 'MU']
# 2014-11-17 00:00:00
# 11182.840400076266
# ['SWKS' 'LUV' 'AVGO' 'ILMN' 'EW' 'VRTX' 'AAL' 'NXPI' 'EA' 'URI']
# 2014-11-18 00:00:00
# 11221.670108489883
# ['SWKS' 'LUV' 'AVGO' 'ILMN' 'EW' 'NXPI' 'AAL' 'VRTX' 'EA' 'CNC']
# 2014-11-19 00:00:00
# 11403.757134978969
# ['SWKS' 'LUV' 'ILMN' 'EW' 'AAL' 'EA' 'NXPI' 'MU' 'URI' 'VRTX']
# 2014-11-20 00:00:00
# 11320.187244398909
# ['SWKS' 'LUV' 'EW' 'MNST' 'AAL' 'NXPI' 'VRTX' 'URI' 'MU' 'MAR']
# 2014-11-21 00:00:00
# 11537.313966881573
# ['LUV' 'TSLA' 'EW' 'MNST' 'AAL' 'NXPI' 'VRTX' 'CNC' 'URI' 'MU']
# 2014-11-24 00:00:00
# 11396.926471256409
# ['TSLA' 'MNST' 'EW' 'NXPI' 'AAL' 'URI' 'CNC' 'META' 'VRTX' 'MAR']
# 2014-11-25 00:00:00
# 11513.920958270628
# ['TSLA' 'EW' 'MNST' 'AAL' 'NXPI' 'URI' 'VRTX' 'CNC' 'MAR' 'FFIV']
# 2014-11-26 00:00:00
# 11567.748081695194
# ['AVGO' 'LUV' 'TSLA' 'EW' 'MNST' 'AAL' 'CNC' 'MAR' 'GD' 'INCY']
# 2014-11-28 00:00:00
# 11826.27110182019
# ['LUV' 'AVGO' 'EW' 'TSLA' 'AAL' 'MNST' 'CNC' 'MAR' 'RCL' 'GD']
# 2014-12-01 00:00:00
# 11890.040056762145
# ['EA' 'TSLA' 'MNST' 'RCL' 'CNC' 'URI' 'GD' 'FFIV' 'DXCM' 'AAPL']
# 2014-12-02 00:00:00
# 11744.317275624933
# ['SWKS' 'EA' 'MNST' 'TTWO' 'CNC' 'GD' 'FFIV' 'URI' 'DXCM' 'MOH']
# 2014-12-03 00:00:00
# 11874.229533436714
# ['SWKS' 'AVGO' 'EA' 'ILMN' 'MNST' 'NXPI' 'TTWO' 'CNC' 'GD' 'FFIV']
# 2014-12-04 00:00:00
# 12192.623682778141
# ['SWKS' 'EA' 'AVGO' 'ILMN' 'NXPI' 'MNST' 'TTWO' 'CNC' 'GD' 'FFIV']
# 2014-12-05 00:00:00
# 12284.699666591874
# ['SWKS' 'NXPI' 'MNST' 'TTWO' 'CNC' 'URI' 'GD' 'INCY' 'FFIV' 'ODFL']
# 2014-12-08 00:00:00
# 12265.87988469731
# ['NXPI' 'MNST' 'TTWO' 'INCY' 'URI' 'GD' 'MU' 'ODFL' 'META' 'FTNT']
# 2014-12-09 00:00:00
# 11976.784295614934
# ['EW' 'ILMN' 'NXPI' 'MNST' 'INCY' 'GD' 'LRCX' 'ODFL' 'TTWO' 'MU']
# 2014-12-10 00:00:00
# 12152.064467155536
# ['SWKS' 'LUV' 'EW' 'ILMN' 'VRTX' 'NXPI' 'CNC' 'MAR' 'MNST' 'TTWO']
# 2014-12-11 00:00:00
# 12049.510348192163
# ['SWKS' 'LUV' 'EA' 'EW' 'AAL' 'ILMN' 'VRTX' 'CNC' 'NXPI' 'MNST']
# 2014-12-12 00:00:00
# 12129.414140823428
# ['SWKS' 'LUV' 'EW' 'EA' 'AAL' 'VRTX' 'ILMN' 'RCL' 'MNST' 'NXPI']
# 2014-12-15 00:00:00
# 12122.31774926616
# ['SWKS' 'EW' 'EA' 'AVGO' 'AAL' 'VRTX' 'CNC' 'ILMN' 'RCL' 'NXPI']
# 2014-12-16 00:00:00
# 11829.245779389801
# ['SWKS' 'ENPH' 'EW' 'EA' 'AAL' 'AVGO' 'RCL' 'ILMN' 'VRTX' 'UAL']
# 2014-12-17 00:00:00
# 11723.853791244335
# ['SWKS' 'ENPH' 'LUV' 'EA' 'EW' 'AVGO' 'AAL' 'RCL' 'DAL' 'NXPI']
# 2014-12-18 00:00:00
# 12182.925418401534
# ['SWKS' 'ENPH' 'LUV' 'EW' 'EA' 'AVGO' 'AAL' 'RCL' 'NXPI' 'UAL']
# 2014-12-19 00:00:00
# 12281.155773292412
# ['SWKS' 'ENPH' 'LUV' 'EW' 'EA' 'AVGO' 'AAL' 'ILMN' 'UAL' 'DAL']
# 2014-12-22 00:00:00
# 12383.609631634514
# ['LUV' 'EW' 'AAL' 'AVGO' 'ILMN' 'UAL' 'DAL' 'RCL' 'DXCM' 'VRTX']
# 2014-12-23 00:00:00
# 12405.55757888148
# ['LUV' 'AVGO' 'DAL' 'UAL' 'DXCM' 'HCA' 'VRTX' 'ORLY' 'REGN' 'INCY']
# 2014-12-24 00:00:00
# 12110.889372816884
# ['LUV' 'DAL' 'UAL' 'ORLY' 'AAP' 'WELL' 'REGN' 'EPAM' 'STE' 'INCY']
# 2014-12-26 00:00:00
# 12257.222598532097
# ['AAL' 'DAL' 'UAL' 'ORLY' 'AAP' 'REGN' 'INCY' 'WELL' 'EPAM' 'ULTA']
# 2014-12-29 00:00:00
# 12300.279045759522
# ['AAL' 'CNC' 'ORLY' 'INCY' 'AAP' 'ETR' 'HUM' 'ULTA' 'WBA' 'VTR']
# 2014-12-30 00:00:00
# 12362.84937925875
# ['CNC' 'ORLY' 'AAP' 'ETR' 'HUM' 'RHI' 'LLY' 'ULTA' 'PKG' 'ADBE']
# 2014-12-31 00:00:00
# 12371.636188971346
# ['SWKS' 'ENPH' 'EA' 'EW' 'CNC' 'NXPI' 'KR' 'MNST' 'DXCM' 'HCA']
# 2015-01-02 00:00:00
# 12375.550053577794
# ['SWKS' 'EA' 'ENPH' 'AVGO' 'EW' 'CNC' 'NXPI' 'RCL' 'ILMN' 'KR']
# 2015-01-05 00:00:00
# 12270.477549016827
# ['SWKS' 'EA' 'ENPH' 'EW' 'AVGO' 'RCL' 'NXPI' 'CNC' 'ILMN' 'MU']
# 2015-01-06 00:00:00
# 12225.604334861882
# ['SWKS' 'EA' 'EW' 'AVGO' 'ENPH' 'RCL' 'NXPI' 'CNC' 'ILMN' 'KR']
# 2015-01-07 00:00:00
# 12020.68997051316
# ['SWKS' 'LUV' 'EA' 'EW' 'AVGO' 'ENPH' 'RCL' 'CNC' 'ILMN' 'NXPI']
# 2015-01-08 00:00:00
# 12187.650496894574
# ['SWKS' 'EA' 'LUV' 'EW' 'AVGO' 'AAL' 'RCL' 'NXPI' 'CNC' 'KR']
# 2015-01-09 00:00:00
# 12418.75343802097
# ['SWKS' 'EA' 'LUV' 'AVGO' 'AAL' 'NXPI' 'CNC' 'RCL' 'KR' 'TTWO']
# 2015-01-12 00:00:00
# 12321.984180220252
# ['SWKS' 'EA' 'LUV' 'AAL' 'RCL' 'MAR' 'TTWO' 'VRTX' 'FTNT' 'ALK']
# 2015-01-13 00:00:00
# 12281.631670512932
# ['LUV' 'AAL' 'RCL' 'TTWO' 'ALK' 'BBWI' 'VRTX' 'FTNT' 'EIX' 'ETR']
# 2015-01-14 00:00:00
# 12040.72032813396
# ['LUV' 'AAL' 'RCL' 'TTWO' 'ALK' 'VRTX' 'DAL' 'BBWI' 'FTNT' 'KMX']
# 2015-01-15 00:00:00
# 12079.115148223002
# ['LUV' 'AAL' 'RCL' 'VRTX' 'BBWI' 'ILMN' 'DAL' 'KMX' 'LOW' 'LRCX']
# 2015-01-16 00:00:00
# 11907.541666616378
# ['SWKS' 'LUV' 'AAL' 'RCL' 'BBWI' 'DAL' 'LRCX' 'BBY' 'LOW' 'KMX']
# 2015-01-20 00:00:00
# 12304.938790650682
# ['SWKS' 'LUV' 'EW' 'RCL' 'AAL' 'ULTA' 'BBWI' 'BBY' 'DAL' 'REG']
# 2015-01-21 00:00:00
# 12254.989209021991
# ['EW' 'AAL' 'MNST' 'RCL' 'DXCM' 'ULTA' 'BBWI' 'MAR' 'EQR' 'KMX']
# 2015-01-22 00:00:00
# 12378.43542454436
# ['EW' 'AVGO' 'KR' 'MNST' 'RCL' 'NXPI' 'BBWI' 'DXCM' 'ULTA' 'MAR']

# %%
spy_select = spy[(spy.Date>'2014-01-23')& (spy.Date<'2015-01-23')]
spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100
result['benchmark-spy(%)'] =  spy_select.set_index('Date')['benchmark-spy(%)']
# Out:
# C:\Users\CHIN\AppData\Local\Temp/ipykernel_20500/2067108274.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100

# %%
# plot the return and calculate the annualized return and MDD (maximum draw down) for both strategy
plt.rcParams["figure.figsize"] = (15,6)
plt.plot(result.Return_without_trailing, label='Return without Annualized_return of Portfolio based on EMA and SMA cross-over strategy')
plt.plot(result['benchmark-spy(%)'], label='benchmark-spy(%)')
plt.legend()
print('Annualized_return of Portfolio based on EMA and SMA cross-over strategy:',annualized (result,'Return_without_trailing'))
print('MDD of Portfolio based on EMA AND SMA cross-over strategy:', MDD(result,'Return_without_trailing'))

print('Annualized_return of benchmark-spy:',annualized (result,'benchmark-spy(%)'))
print('MDD of benchmark-spy:', MDD(result,'benchmark-spy(%)'))
# Out:
# Annualized_return of Portfolio based on EMA and SMA cross-over strategy: 36.38072377068448
# MDD of Portfolio based on EMA AND SMA cross-over strategy: -24.844237932132184
# Annualized_return of benchmark-spy: 22.8628409290069
# MDD of benchmark-spy: -7.704886774073449

# %% [markdown]
# # 5 STOCK

# %%
result, hold_detail= backtest_strategy_portfolio(signal_etf_stock[(signal_etf_stock.Date>'2014-01-23') &(signal_etf_stock.Date<'2015-01-23')],10000)
# Out:
# 2014-01-24 00:00:00
# 10000.0
# ['INCY' 'MU' 'DXCM' 'DAL' 'ENPH']
# 2014-01-27 00:00:00
# 9835.962370939775
# ['INCY' 'MU' 'DXCM' 'DAL' 'HII']
# 2014-01-28 00:00:00
# 9717.146526724464
# ['INCY' 'MU' 'DXCM' 'DAL' 'AAL']
# 2014-01-29 00:00:00
# 9916.859021773253
# ['TSLA' 'INCY' 'MU' 'ILMN' 'DXCM']
# 2014-01-30 00:00:00
# 10134.241617351536
# ['TSLA' 'INCY' 'MU' 'ILMN' 'DXCM']
# 2014-01-31 00:00:00
# 10141.839606423822
# ['TSLA' 'INCY' 'MU' 'ILMN' 'STZ']
# 2014-02-03 00:00:00
# 10293.294201306977
# ['TSLA' 'INCY' 'ILMN' 'MU' 'STZ']
# 2014-02-04 00:00:00
# 10185.928814910696
# ['TSLA' 'INCY' 'ILMN' 'MU' 'STZ']
# 2014-02-05 00:00:00
# 10162.57589235028
# ['TSLA' 'INCY' 'ILMN' 'MU' 'STZ']
# 2014-02-06 00:00:00
# 10139.430842726992
# ['TSLA' 'INCY' 'MU' 'ILMN' 'STZ']
# 2014-02-07 00:00:00
# 10320.607874232244
# ['TSLA' 'INCY' 'ILMN' 'NFLX' 'LYV']
# 2014-02-10 00:00:00
# 10689.246549769201
# ['TSLA' 'INCY' 'ILMN' 'DXCM' 'NFLX']
# 2014-02-11 00:00:00
# 10988.902579068726
# ['INCY' 'ILMN' 'DXCM' 'AAL' 'STZ']
# 2014-02-12 00:00:00
# 10983.50879798121
# ['INCY' 'ILMN' 'DXCM' 'STZ' 'AAL']
# 2014-02-13 00:00:00
# 10986.824144913688
# ['ILMN' 'DXCM' 'AAL' 'NFLX' 'META']
# 2014-02-14 00:00:00
# 11327.63820582857
# ['AAL' 'META' 'NOW' 'WYNN' 'CMG']
# 2014-02-18 00:00:00
# 11302.185003050938
# ['AAL' 'WYNN' 'CMG' 'TYL' 'EQT']
# 2014-02-19 00:00:00
# 11369.563439107638
# ['AAL' 'NFLX' 'WYNN' 'CMG' 'DISH']
# 2014-02-20 00:00:00
# 11338.505178943136
# ['INCY' 'AAL' 'NFLX' 'DAL' 'NOW']
# 2014-02-21 00:00:00
# 11602.24805885682
# ['MU' 'INCY' 'FANG' 'AAL' 'NFLX']
# 2014-02-24 00:00:00
# 11717.297990142404
# ['TSLA' 'FANG' 'MU' 'INCY' 'AAL']
# 2014-02-25 00:00:00
# 12062.020678016514
# ['TSLA' 'INCY' 'MU' 'META' 'NFLX']
# 2014-02-26 00:00:00
# 12416.020987689668
# ['INCY' 'DXCM' 'MU' 'META' 'NFLX']
# 2014-02-27 00:00:00
# 12247.822466180449
# ['DXCM' 'MU' 'FANG' 'META' 'NFLX']
# 2014-02-28 00:00:00
# 12338.596859246987
# ['ILMN' 'DXCM' 'MU' 'FANG' 'META']
# 2014-03-03 00:00:00
# 12014.624187365973
# ['ILMN' 'DXCM' 'MU' 'FANG' 'META']
# 2014-03-04 00:00:00
# 12326.978718803957
# ['ILMN' 'DXCM' 'MU' 'FANG' 'NFLX']
# 2014-03-05 00:00:00
# 12513.343177367944
# ['ILMN' 'DXCM' 'MU' 'FANG' 'AAL']
# 2014-03-06 00:00:00
# 12588.304091888316
# ['TSLA' 'ILMN' 'INCY' 'MU' 'FANG']
# 2014-03-07 00:00:00
# 12431.84996911471
# ['TSLA' 'ILMN' 'INCY' 'AAL' 'META']
# 2014-03-10 00:00:00
# 12134.396270500456
# ['TSLA' 'ILMN' 'DXCM' 'INCY' 'FANG']
# 2014-03-11 00:00:00
# 11927.203050128512
# ['TSLA' 'ILMN' 'DXCM' 'INCY' 'FANG']
# 2014-03-12 00:00:00
# 11807.372575641873
# ['TSLA' 'ILMN' 'DXCM' 'INCY' 'FANG']
# 2014-03-13 00:00:00
# 12122.454678246833
# ['TSLA' 'ILMN' 'DXCM' 'FANG' 'NFLX']
# 2014-03-14 00:00:00
# 11731.57581449257
# ['TSLA' 'DXCM' 'FANG' 'META' 'MU']
# 2014-03-17 00:00:00
# 11742.644439411266
# ['TSLA' 'DXCM' 'FANG' 'MU' 'INCY']
# 2014-03-18 00:00:00
# 11811.891067945277
# ['TSLA' 'ILMN' 'DXCM' 'INCY' 'FANG']
# 2014-03-19 00:00:00
# 12127.153216916387
# ['TSLA' 'ILMN' 'DXCM' 'INCY' 'META']
# 2014-03-20 00:00:00
# 11919.517946515316
# ['TSLA' 'ILMN' 'DXCM' 'META' 'MU']
# 2014-03-21 00:00:00
# 11884.309379419441
# ['TSLA' 'META' 'MU' 'NFLX' 'AAL']
# 2014-03-24 00:00:00
# 11631.682263839704
# ['TSLA' 'INCY' 'META' 'MU' 'NFLX']
# 2014-03-25 00:00:00
# 11161.862292651365
# ['TSLA' 'ILMN' 'DXCM' 'META' 'INCY']
# 2014-03-26 00:00:00
# 10998.31782645746
# ['TSLA' 'ILMN' 'DXCM' 'META' 'FANG']
# 2014-03-27 00:00:00
# 10586.796317644821
# ['TSLA' 'ILMN' 'DXCM' 'FANG' 'META']
# 2014-03-28 00:00:00
# 10704.698383771898
# ['TSLA' 'ILMN' 'META' 'MU' 'DXCM']
# 2014-03-31 00:00:00
# 10751.94605486968
# ['TSLA' 'FSLR' 'ILMN' 'META' 'MU']
# 2014-04-01 00:00:00
# 10937.426152887445
# ['TSLA' 'ILMN' 'FSLR' 'MU' 'DXCM']
# 2014-04-02 00:00:00
# 11268.732821308175
# ['TSLA' 'FSLR' 'INCY' 'DXCM' 'META']
# 2014-04-03 00:00:00
# 11380.45035258725
# ['FSLR' 'DXCM' 'SIVB' 'URI' 'SWKS']
# 2014-04-04 00:00:00
# 11298.069644925316
# ['FSLR' 'SIVB' 'TSN' 'CSGP' 'CMG']
# 2014-04-07 00:00:00
# 10874.675454700999
# ['SIVB' 'AVGO' 'FSLR' 'TSN' 'AKAM']
# 2014-04-08 00:00:00
# 10799.580610970766
# ['FANG' 'AAL' 'DAL' 'FSLR' 'NXPI']
# 2014-04-09 00:00:00
# 11117.77249519228
# ['FANG' 'AAL' 'DAL' 'FSLR' 'NXPI']
# 2014-04-10 00:00:00
# 11249.126562716303
# ['FANG' 'DXCM' 'MU' 'DAL' 'NXPI']
# 2014-04-11 00:00:00
# 10571.941346562397
# ['TSLA' 'FANG' 'ILMN' 'DXCM' 'MU']
# 2014-04-14 00:00:00
# 10767.411415088009
# ['TSLA' 'FANG' 'ILMN' 'AAL' 'NXPI']
# 2014-04-15 00:00:00
# 10630.626279829772
# ['TSLA' 'ILMN' 'NXPI' 'DAL' 'AAL']
# 2014-04-16 00:00:00
# 10742.78583582987
# ['TSLA' 'ILMN' 'NXPI' 'DAL' 'AAL']
# 2014-04-17 00:00:00
# 10987.845758161426
# ['TSLA' 'ILMN' 'NXPI' 'AAL' 'DAL']
# 2014-04-21 00:00:00
# 10963.515913109215
# ['TSLA' 'LUV' 'FSLR' 'GRMN' 'SIVB']
# 2014-04-22 00:00:00
# 11186.533449197901
# ['FSLR' 'HPQ' 'GLW' 'RCL' 'HUM']
# 2014-04-23 00:00:00
# 11312.48222090853
# ['HPQ' 'FSLR' 'HUM' 'ZBRA' 'NVDA']
# 2014-04-24 00:00:00
# 11422.316973840261
# ['HPQ' 'HUM' 'NVDA' 'FRC' 'ADM']
# 2014-04-25 00:00:00
# 11372.49885825166
# ['HPQ' 'ADM' 'UNH' 'STLD' 'EW']
# 2014-04-28 00:00:00
# 11365.55958044526
# ['TSN' 'EOG' 'WDC' 'PXD' 'TRGP']
# 2014-04-29 00:00:00
# 11367.216042319866
# ['FANG' 'HII' 'BSX' 'TSN' 'SBNY']
# 2014-04-30 00:00:00
# 11392.245390091013
# ['FANG' 'MU' 'NXPI' 'ILMN' 'HII']
# 2014-05-01 00:00:00
# 11601.40781384883
# ['MU' 'FANG' 'NXPI' 'ILMN' 'AAL']
# 2014-05-02 00:00:00
# 11769.822687514112
# ['MU' 'FANG' 'META' 'NXPI' 'ILMN']
# 2014-05-05 00:00:00
# 11721.676358497065
# ['TSLA' 'MU' 'FANG' 'META' 'NXPI']
# 2014-05-06 00:00:00
# 11894.399883681273
# ['TSLA' 'MU' 'FANG' 'AAL' 'NXPI']
# 2014-05-07 00:00:00
# 11750.756855971049
# ['MU' 'FANG' 'AAL' 'NXPI' 'ILMN']
# 2014-05-08 00:00:00
# 11716.562170853813
# ['MU' 'DAL' 'SWKS' 'LUV' 'VTRS']
# 2014-05-09 00:00:00
# 11730.43170893063
# ['DAL' 'SWKS' 'LUV' 'LMT' 'STZ']
# 2014-05-12 00:00:00
# 11795.025982144733
# ['DAL' 'HII' 'SWKS' 'LUV' 'LMT']
# 2014-05-13 00:00:00
# 12014.535408627693
# ['MU' 'FANG' 'META' 'DAL' 'HII']
# 2014-05-14 00:00:00
# 12042.573089792646
# ['MU' 'FANG' 'META' 'TSLA' 'DAL']
# 2014-05-15 00:00:00
# 11890.725641343879
# ['MU' 'INCY' 'FANG' 'TSLA' 'DAL']
# 2014-05-16 00:00:00
# 11720.256902683017
# ['MU' 'INCY' 'FANG' 'TSLA' 'DAL']
# 2014-05-19 00:00:00
# 11716.579949428522
# ['MU' 'FANG' 'TSLA' 'AAL' 'DAL']
# 2014-05-20 00:00:00
# 11922.44242184318
# ['MU' 'FANG' 'AAL' 'DAL' 'NXPI']
# 2014-05-21 00:00:00
# 11855.723546177187
# ['MU' 'FANG' 'AAL' 'DAL' 'NXPI']
# 2014-05-22 00:00:00
# 11924.7114611977
# ['MU' 'AAL' 'DAL' 'NXPI' 'AVGO']
# 2014-05-23 00:00:00
# 12033.360000724366
# ['MU' 'AAL' 'NXPI' 'DAL' 'AVGO']
# 2014-05-27 00:00:00
# 12279.269671354428
# ['MU' 'AAL' 'DAL' 'AVGO' 'NXPI']
# 2014-05-28 00:00:00
# 12351.51306615166
# ['AAL' 'ALK' 'TSN' 'TMUS' 'MCK']
# 2014-05-29 00:00:00
# 12533.869584522621
# ['TMUS' 'TSN' 'MCK' 'EA' 'GILD']
# 2014-05-30 00:00:00
# 12607.098493873866
# ['TRGP' 'MCK' 'TMUS' 'EA' 'GILD']
# 2014-06-02 00:00:00
# 12581.89752889595
# ['TRGP' 'LYV' 'TMUS' 'STZ' 'HUM']
# 2014-06-03 00:00:00
# 12609.133361036871
# ['ILMN' 'TSLA' 'TRGP' 'EPAM' 'LYV']
# 2014-06-04 00:00:00
# 12646.813306355918
# ['ILMN' 'TSLA' 'URI' 'NFLX' 'TRGP']
# 2014-06-05 00:00:00
# 12790.879839949474
# ['META' 'ILMN' 'TSLA' 'URI' 'NFLX']
# 2014-06-06 00:00:00
# 13053.981152984925
# ['META' 'ILMN' 'URI' 'TSLA' 'NFLX']
# 2014-06-09 00:00:00
# 13021.33498785354
# ['META' 'ILMN' 'MU' 'TSLA' 'NXPI']
# 2014-06-10 00:00:00
# 13056.881941951739
# ['META' 'MU' 'TSLA' 'NXPI' 'AVGO']
# 2014-06-11 00:00:00
# 13260.367732747563
# ['META' 'MU' 'DAL' 'TSLA' 'NFLX']
# 2014-06-12 00:00:00
# 13313.231255622557
# ['META' 'DAL' 'TSLA' 'NFLX' 'AVGO']
# 2014-06-13 00:00:00
# 13168.664298001237
# ['AAL' 'SWKS' 'DAL' 'NXPI' 'TSLA']
# 2014-06-16 00:00:00
# 13102.529683932933
# ['AAL' 'SWKS' 'URI' 'DAL' 'TSLA']
# 2014-06-17 00:00:00
# 13424.150707172332
# ['AAL' 'ILMN' 'SWKS' 'DAL' 'URI']
# 2014-06-18 00:00:00
# 13549.938035297646
# ['META' 'AAL' 'ILMN' 'SWKS' 'DAL']
# 2014-06-19 00:00:00
# 13690.193263214
# ['META' 'AAL' 'ILMN' 'SWKS' 'DAL']
# 2014-06-20 00:00:00
# 13688.517622807902
# ['AAL' 'META' 'ILMN' 'SWKS' 'DAL']
# 2014-06-23 00:00:00
# 13825.559215258343
# ['FANG' 'META' 'ILMN' 'SWKS' 'DAL']
# 2014-06-24 00:00:00
# 13718.168808671817
# ['FANG' 'META' 'ILMN' 'SWKS' 'URI']
# 2014-06-25 00:00:00
# 13516.55375657946
# ['META' 'FANG' 'MU' 'ILMN' 'SWKS']
# 2014-06-26 00:00:00
# 13747.6301837069
# ['FANG' 'ILMN' 'MU' 'SWKS' 'NFLX']
# 2014-06-27 00:00:00
# 13596.8216843882
# ['FANG' 'ILMN' 'MU' 'TSLA' 'SWKS']
# 2014-06-30 00:00:00
# 13711.762955856622
# ['FANG' 'ILMN' 'MU' 'SWKS' 'NXPI']
# 2014-07-01 00:00:00
# 14022.838889713028
# ['AAL' 'FANG' 'MU' 'SWKS' 'LUV']
# 2014-07-02 00:00:00
# 14082.408620500264
# ['AAL' 'FANG' 'SWKS' 'LUV' 'TRGP']
# 2014-07-03 00:00:00
# 14011.272109833224
# ['AAL' 'FANG' 'SWKS' 'TRGP' 'NXPI']
# 2014-07-07 00:00:00
# 13986.479884755063
# ['META' 'FANG' 'AAL' 'TRGP' 'TSLA']
# 2014-07-08 00:00:00
# 13549.18519196525
# ['META' 'FANG' 'AAL' 'TRGP' 'DAL']
# 2014-07-09 00:00:00
# 13786.539817028457
# ['MU' 'AAL' 'FANG' 'LUV' 'TRGP']
# 2014-07-10 00:00:00
# 13552.223714294127
# ['MU' 'AAL' 'FANG' 'ILMN' 'LUV']
# 2014-07-11 00:00:00
# 13828.087746232164
# ['MU' 'META' 'AAL' 'ILMN' 'FANG']
# 2014-07-14 00:00:00
# 13993.127126522528
# ['META' 'MU' 'ILMN' 'FANG' 'SWKS']
# 2014-07-15 00:00:00
# 14089.776517814713
# ['META' 'MU' 'ILMN' 'FANG' 'SWKS']
# 2014-07-16 00:00:00
# 14008.776056797982
# ['MU' 'ILMN' 'FANG' 'SWKS' 'LUV']
# 2014-07-17 00:00:00
# 13969.403833825
# ['ILMN' 'FANG' 'SWKS' 'TRGP' 'NXPI']
# 2014-07-18 00:00:00
# 13971.12775884655
# ['ILMN' 'FANG' 'TRGP' 'NXPI' 'URI']
# 2014-07-21 00:00:00
# 14141.320705771503
# ['ILMN' 'NXPI' 'TRGP' 'AVGO' 'ZBRA']
# 2014-07-22 00:00:00
# 14241.341414266066
# ['MU' 'TRGP' 'ZBRA' 'WMB' 'STZ']
# 2014-07-23 00:00:00
# 14249.661730124453
# ['MU' 'AAL' 'TRGP' 'ZBRA' 'WMB']
# 2014-07-24 00:00:00
# 14267.555695054758
# ['MU' 'AAL' 'TRGP' 'NXPI' 'ZBRA']
# 2014-07-25 00:00:00
# 14159.54138304714
# ['MU' 'AAL' 'TRGP' 'AVGO' 'NXPI']
# 2014-07-28 00:00:00
# 13865.26145482342
# ['MU' 'AAL' 'TRGP' 'AVGO' 'NXPI']
# 2014-07-29 00:00:00
# 13659.433432084194
# ['MU' 'AAL' 'URI' 'TRGP' 'AVGO']
# 2014-07-30 00:00:00
# 13639.23200892201
# ['MU' 'FANG' 'SWKS' 'ILMN' 'AAL']
# 2014-07-31 00:00:00
# 13285.39089110721
# ['MU' 'SWKS' 'ILMN' 'AAL' 'FANG']
# 2014-08-01 00:00:00
# 13090.07899546755
# ['MU' 'SWKS' 'AAL' 'LUV' 'FANG']
# 2014-08-04 00:00:00
# 13261.14949696592
# ['MU' 'SWKS' 'AAL' 'LUV' 'AVGO']
# 2014-08-05 00:00:00
# 13109.14063652675
# ['MU' 'SWKS' 'LUV' 'ILMN' 'TRGP']
# 2014-08-06 00:00:00
# 12918.772248486504
# ['MU' 'SWKS' 'LUV' 'ILMN' 'URI']
# 2014-08-07 00:00:00
# 13029.647882017829
# ['SWKS' 'MU' 'LUV' 'URI' 'META']
# 2014-08-08 00:00:00
# 12836.104589801866
# ['SWKS' 'MU' 'LUV' 'META' 'URI']
# 2014-08-11 00:00:00
# 13044.823842936796
# ['MU' 'SWKS' 'LUV' 'URI' 'META']
# 2014-08-12 00:00:00
# 13120.756366254844
# ['LUV' 'SWKS' 'META' 'FANG' 'HCA']
# 2014-08-13 00:00:00
# 13095.481773497962
# ['META' 'FANG' 'EXPE' 'HCA' 'CMG']
# 2014-08-14 00:00:00
# 13246.217624558169
# ['EXPE' 'HCA' 'CMG' 'LYB' 'ZBRA']
# 2014-08-15 00:00:00
# 13267.257112656955
# ['EXPE' 'HCA' 'CMG' 'LYB' 'MCK']
# 2014-08-18 00:00:00
# 13347.497975246366
# ['EXPE' 'TSLA' 'HCA' 'CMG' 'LYB']
# 2014-08-19 00:00:00
# 13353.62955217858
# ['HCA' 'TSLA' 'CMG' 'WDC' 'REGN']
# 2014-08-20 00:00:00
# 13191.731395715959
# ['FSLR' 'TSLA' 'DXCM' 'ADSK' 'WDC']
# 2014-08-21 00:00:00
# 13229.43573715127
# ['FSLR' 'TSLA' 'DXCM' 'SBAC' 'WDC']
# 2014-08-22 00:00:00
# 13202.133686790301
# ['FSLR' 'CMG' 'DXCM' 'TSLA' 'SBAC']
# 2014-08-25 00:00:00
# 13318.14608122332
# ['TRGP' 'FSLR' 'CMG' 'DXCM' 'HII']
# 2014-08-26 00:00:00
# 13280.650455066223
# ['SWKS' 'TRGP' 'FSLR' 'RCL' 'CMG']
# 2014-08-27 00:00:00
# 13279.258600285622
# ['SWKS' 'DAL' 'AVGO' 'FSLR' 'HCA']
# 2014-08-28 00:00:00
# 13165.01782127496
# ['ENPH' 'SWKS' 'URI' 'DAL' 'AVGO']
# 2014-08-29 00:00:00
# 13472.022716219188
# ['LUV' 'MU' 'ENPH' 'SWKS' 'URI']
# 2014-09-02 00:00:00
# 13506.074346606983
# ['LUV' 'MU' 'SWKS' 'ENPH' 'URI']
# 2014-09-03 00:00:00
# 13537.444368428798
# ['LUV' 'AAL' 'SWKS' 'MU' 'URI']
# 2014-09-04 00:00:00
# 13499.701344926722
# ['LUV' 'AAL' 'ILMN' 'SWKS' 'MU']
# 2014-09-05 00:00:00
# 13341.958988965805
# ['LUV' 'ILMN' 'ENPH' 'SWKS' 'MU']
# 2014-09-08 00:00:00
# 13485.874369599873
# ['LUV' 'ILMN' 'SWKS' 'MU' 'URI']
# 2014-09-09 00:00:00
# 13489.586152048469
# ['LUV' 'ILMN' 'URI' 'MU' 'ENPH']
# 2014-09-10 00:00:00
# 13317.834831808137
# ['LUV' 'URI' 'ILMN' 'TRGP' 'MU']
# 2014-09-11 00:00:00
# 13333.066830782836
# ['LUV' 'SWKS' 'ILMN' 'URI' 'TRGP']
# 2014-09-12 00:00:00
# 13383.438679263596
# ['AVGO' 'SWKS' 'ILMN' 'URI' 'NXPI']
# 2014-09-15 00:00:00
# 13228.69092993689
# ['AVGO' 'SWKS' 'URI' 'ILMN' 'HPQ']
# 2014-09-16 00:00:00
# 12958.231154481138
# ['LUV' 'AVGO' 'SWKS' 'URI' 'ILMN']
# 2014-09-17 00:00:00
# 13324.693409178679
# ['LUV' 'SWKS' 'AVGO' 'ILMN' 'URI']
# 2014-09-18 00:00:00
# 13423.992251366888
# ['SWKS' 'ILMN' 'AVGO' 'URI' 'TRGP']
# 2014-09-19 00:00:00
# 13602.423246018558
# ['ILMN' 'AVGO' 'NXPI' 'TRGP' 'MU']
# 2014-09-22 00:00:00
# 13286.641407595214
# ['AVGO' 'ILMN' 'ENPH' 'NXPI' 'TRGP']
# 2014-09-23 00:00:00
# 13000.375998310315
# ['LUV' 'ILMN' 'AVGO' 'ENPH' 'TRGP']
# 2014-09-24 00:00:00
# 12869.321682732223
# ['LUV' 'ILMN' 'AVGO' 'URI' 'ENPH']
# 2014-09-25 00:00:00
# 12827.574318790868
# ['LUV' 'AVGO' 'ILMN' 'URI' 'TRGP']
# 2014-09-26 00:00:00
# 12565.368662326051
# ['LUV' 'AVGO' 'ILMN' 'URI' 'TRGP']
# 2014-09-29 00:00:00
# 12531.623865056516
# ['LUV' 'ILMN' 'AVGO' 'URI' 'NXPI']
# 2014-09-30 00:00:00
# 12653.48764940989
# ['LUV' 'ILMN' 'AVGO' 'URI' 'NXPI']
# 2014-10-01 00:00:00
# 12470.269425339571
# ['SWKS' 'LUV' 'ILMN' 'AVGO' 'URI']
# 2014-10-02 00:00:00
# 12013.862866401701
# ['LUV' 'SWKS' 'AVGO' 'TRGP' 'MNST']
# 2014-10-03 00:00:00
# 12032.071275352268
# ['LUV' 'SWKS' 'AVGO' 'MNST' 'NXPI']
# 2014-10-06 00:00:00
# 12248.615326506919
# ['LUV' 'SWKS' 'AVGO' 'URI' 'MNST']
# 2014-10-07 00:00:00
# 11901.918371724943
# ['LUV' 'SWKS' 'AVGO' 'URI' 'RCL']
# 2014-10-08 00:00:00
# 11626.314925710218
# ['LUV' 'SWKS' 'AVGO' 'NXPI' 'GILD']
# 2014-10-09 00:00:00
# 11826.539535401487
# ['SWKS' 'LUV' 'AVGO' 'TRGP' 'NXPI']
# 2014-10-10 00:00:00
# 11022.928801048623
# ['SWKS' 'LUV' 'AVGO' 'TRGP' 'GILD']
# 2014-10-13 00:00:00
# 10625.810154607185
# ['LUV' 'EXPE' 'GILD' 'CMG' 'META']
# 2014-10-14 00:00:00
# 10346.565774886407
# ['LUV' 'GILD' 'AAP' 'CMG' 'META']
# 2014-10-15 00:00:00
# 10112.744786382564
# ['LUV' 'CMG' 'GILD' 'HCA' 'META']
# 2014-10-16 00:00:00
# 10078.891843569492
# ['LUV' 'MNST' 'CMG' 'GILD' 'META']
# 2014-10-17 00:00:00
# 10493.25216106211
# ['SWKS' 'LUV' 'AVGO' 'MNST' 'GILD']
# 2014-10-20 00:00:00
# 10474.724092182281
# ['SWKS' 'AVGO' 'MNST' 'GILD' 'HCA']
# 2014-10-21 00:00:00
# 10809.271784371653
# ['MNST' 'GILD' 'KDP' 'MCK' 'CAH']
# 2014-10-22 00:00:00
# 11027.788286476223
# ['MNST' 'TSLA' 'CAH' 'TSN' 'EW']
# 2014-10-23 00:00:00
# 11054.034347695992
# ['TSN' 'TSLA' 'TAP' 'EQR' 'CF']
# 2014-10-24 00:00:00
# 11043.928383728431
# ['EQR' 'ARE' 'EIX']
# 2014-10-27 00:00:00
# 11070.232351683642
# ['EQR' 'EIX' 'ARE']
# 2014-10-28 00:00:00
# 11094.119840823354
# ['DPZ' 'EQR' 'EIX' 'ARE']
# 2014-10-29 00:00:00
# 11123.563460248322
# ['BALL' 'DPZ' 'EQR' 'ARE' 'EXR']
# 2014-10-30 00:00:00
# 11022.78137905671
# ['HCA' 'MOH' 'BALL' 'CSX' 'VTRS']
# 2014-10-31 00:00:00
# 11204.24358146182
# ['LUV' 'MNST' 'META' 'MOH' 'HCA']
# 2014-11-03 00:00:00
# 11369.186179389062
# ['ILMN' 'LUV' 'AAL' 'MNST' 'URI']
# 2014-11-04 00:00:00
# 11542.918490267875
# ['ILMN' 'LUV' 'AVGO' 'AAL' 'MNST']
# 2014-11-05 00:00:00
# 11662.454483945636
# ['ILMN' 'AAL' 'AVGO' 'VRTX' 'MNST']
# 2014-11-06 00:00:00
# 11495.72294058412
# ['ILMN' 'AAL' 'EW' 'VRTX' 'URI']
# 2014-11-07 00:00:00
# 11724.195436490714
# ['ILMN' 'EW' 'VRTX' 'AAL' 'MU']
# 2014-11-10 00:00:00
# 11600.303102694987
# ['ILMN' 'EW' 'VRTX' 'AAL' 'MU']
# 2014-11-11 00:00:00
# 11770.012838433962
# ['SWKS' 'EW' 'ILMN' 'AVGO' 'AAL']
# 2014-11-12 00:00:00
# 11718.105352826395
# ['SWKS' 'ILMN' 'EW' 'AVGO' 'AAL']
# 2014-11-13 00:00:00
# 11724.224659593468
# ['SWKS' 'AVGO' 'ILMN' 'EW' 'AAL']
# 2014-11-14 00:00:00
# 11754.432627384756
# ['SWKS' 'ILMN' 'AVGO' 'EW' 'AAL']
# 2014-11-17 00:00:00
# 11776.85330857657
# ['SWKS' 'LUV' 'AVGO' 'ILMN' 'EW']
# 2014-11-18 00:00:00
# 11859.905960306614
# ['SWKS' 'LUV' 'AVGO' 'ILMN' 'EW']
# 2014-11-19 00:00:00
# 12115.538287271807
# ['SWKS' 'LUV' 'ILMN' 'EW' 'AAL']
# 2014-11-20 00:00:00
# 11947.651170093057
# ['SWKS' 'LUV' 'EW' 'MNST' 'AAL']
# 2014-11-21 00:00:00
# 12150.880717026004
# ['LUV' 'TSLA' 'EW' 'MNST' 'AAL']
# 2014-11-24 00:00:00
# 11925.519894136754
# ['TSLA' 'MNST' 'EW' 'NXPI' 'AAL']
# 2014-11-25 00:00:00
# 12046.344358018008
# ['TSLA' 'EW' 'MNST' 'AAL' 'NXPI']
# 2014-11-26 00:00:00
# 12102.698389741341
# ['AVGO' 'LUV' 'TSLA' 'EW' 'MNST']
# 2014-11-28 00:00:00
# 12350.830355431688
# ['LUV' 'AVGO' 'EW' 'TSLA' 'AAL']
# 2014-12-01 00:00:00
# 12454.124356044487
# ['EA' 'TSLA' 'MNST' 'RCL' 'CNC']
# 2014-12-02 00:00:00
# 12394.342102448443
# ['SWKS' 'EA' 'MNST' 'TTWO' 'CNC']
# 2014-12-03 00:00:00
# 12469.637477644128
# ['SWKS' 'AVGO' 'EA' 'ILMN' 'MNST']
# 2014-12-04 00:00:00
# 12886.855068083174
# ['SWKS' 'EA' 'AVGO' 'ILMN' 'NXPI']
# 2014-12-05 00:00:00
# 13073.313186660038
# ['SWKS' 'NXPI' 'MNST' 'TTWO' 'CNC']
# 2014-12-08 00:00:00
# 13035.475870857092
# ['NXPI' 'MNST' 'TTWO' 'INCY' 'URI']
# 2014-12-09 00:00:00
# 12698.285334178938
# ['EW' 'ILMN' 'NXPI' 'MNST' 'INCY']
# 2014-12-10 00:00:00
# 12913.138182846651
# ['SWKS' 'LUV' 'EW' 'ILMN' 'VRTX']
# 2014-12-11 00:00:00
# 12752.14865195107
# ['SWKS' 'LUV' 'EA' 'EW' 'AAL']
# 2014-12-12 00:00:00
# 12871.166456145129
# ['SWKS' 'LUV' 'EW' 'EA' 'AAL']
# 2014-12-15 00:00:00
# 12781.632707814912
# ['SWKS' 'EW' 'EA' 'AVGO' 'AAL']
# 2014-12-16 00:00:00
# 12637.957713736434
# ['SWKS' 'ENPH' 'EW' 'EA' 'AAL']
# 2014-12-17 00:00:00
# 12639.113444807836
# ['SWKS' 'ENPH' 'LUV' 'EA' 'EW']
# 2014-12-18 00:00:00
# 13222.573681137092
# ['SWKS' 'ENPH' 'LUV' 'EW' 'EA']
# 2014-12-19 00:00:00
# 13398.721640974989
# ['SWKS' 'ENPH' 'LUV' 'EW' 'EA']
# 2014-12-22 00:00:00
# 13407.970508734235
# ['LUV' 'EW' 'AAL' 'AVGO' 'ILMN']
# 2014-12-23 00:00:00
# 13507.391301863247
# ['LUV' 'AVGO' 'DAL' 'UAL' 'DXCM']
# 2014-12-24 00:00:00
# 13283.963530930145
# ['LUV' 'DAL' 'UAL' 'ORLY' 'AAP']
# 2014-12-26 00:00:00
# 13400.440757185383
# ['AAL' 'DAL' 'UAL' 'ORLY' 'AAP']
# 2014-12-29 00:00:00
# 13376.34872197942
# ['AAL' 'CNC' 'ORLY' 'INCY' 'AAP']
# 2014-12-30 00:00:00
# 13465.960638262719
# ['CNC' 'ORLY' 'AAP' 'ETR' 'HUM']
# 2014-12-31 00:00:00
# 13468.387773303011
# ['SWKS' 'ENPH' 'EA' 'EW' 'CNC']
# 2015-01-02 00:00:00
# 13489.699658073543
# ['SWKS' 'EA' 'ENPH' 'AVGO' 'EW']
# 2015-01-05 00:00:00
# 13352.716034527448
# ['SWKS' 'EA' 'ENPH' 'EW' 'AVGO']
# 2015-01-06 00:00:00
# 13269.808856001371
# ['SWKS' 'EA' 'EW' 'AVGO' 'ENPH']
# 2015-01-07 00:00:00
# 12895.85678615691
# ['SWKS' 'LUV' 'EA' 'EW' 'AVGO']
# 2015-01-08 00:00:00
# 13119.998947812855
# ['SWKS' 'EA' 'LUV' 'EW' 'AVGO']
# 2015-01-09 00:00:00
# 13479.726678731226
# ['SWKS' 'EA' 'LUV' 'AVGO' 'AAL']
# 2015-01-12 00:00:00
# 13222.716291456181
# ['SWKS' 'EA' 'LUV' 'AAL' 'RCL']
# 2015-01-13 00:00:00
# 13172.56179132615
# ['LUV' 'AAL' 'RCL' 'TTWO' 'ALK']
# 2015-01-14 00:00:00
# 12952.213486844907
# ['LUV' 'AAL' 'RCL' 'TTWO' 'ALK']
# 2015-01-15 00:00:00
# 12979.09332055127
# ['LUV' 'AAL' 'RCL' 'VRTX' 'BBWI']
# 2015-01-16 00:00:00
# 12788.92000484415
# ['SWKS' 'LUV' 'AAL' 'RCL' 'BBWI']
# 2015-01-20 00:00:00
# 13281.038745938524
# ['SWKS' 'LUV' 'EW' 'RCL' 'AAL']
# 2015-01-21 00:00:00
# 13343.244621667307
# ['EW' 'AAL' 'MNST' 'RCL' 'DXCM']
# 2015-01-22 00:00:00
# 13493.194845160418
# ['EW' 'AVGO' 'KR' 'MNST' 'RCL']

# %%
spy_select = spy[(spy.Date>'2014-01-23')& (spy.Date<'2015-01-23')]
spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100
result['benchmark-spy(%)'] =  spy_select.set_index('Date')['benchmark-spy(%)']
# Out:
# C:\Users\CHIN\AppData\Local\Temp/ipykernel_20500/2067108274.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spy_select['benchmark-spy(%)'] = spy_select['Close']/spy_select['Close'].iloc[0]*100

# %%
# plot the return and calculate the annualized return and MDD (maximum draw down) for both strategy
plt.rcParams["figure.figsize"] = (15,6)
plt.plot(result.Return_without_trailing, label='Return without Annualized_return of Portfolio based on EMA and SMA cross-over strategy')
plt.plot(result['benchmark-spy(%)'], label='benchmark-spy(%)')
plt.legend()
print('Annualized_return of Portfolio based on EMA and SMA cross-over strategy:',annualized (result,'Return_without_trailing'))
print('MDD of Portfolio based on EMA AND SMA cross-over strategy:', MDD(result,'Return_without_trailing'))

print('Annualized_return of benchmark-spy:',annualized (result,'benchmark-spy(%)'))
print('MDD of benchmark-spy:', MDD(result,'benchmark-spy(%)'))
# Out:
# Annualized_return of Portfolio based on EMA and SMA cross-over strategy: 54.600449720481926
# MDD of Portfolio based on EMA AND SMA cross-over strategy: -29.357963907840844
# Annualized_return of benchmark-spy: 22.8628409290069
# MDD of benchmark-spy: -7.704886774073449
